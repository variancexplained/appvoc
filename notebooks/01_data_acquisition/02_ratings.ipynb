# %% [markdown]
# # AppStore Ratings
# App Store apps are rated on a five-star scale. In this section, we extract the number of ratings on each of the five-points of the scale, as well as the total ratings and reviews.
#
# The AppStore Review entity is defined as follows.
#
# | #  | name        | description                                    | api_field            |
# |----|-------------|------------------------------------------------|----------------------|
# | 1  | id          | Unique app identifier                          | adamId               |
# | 2  | name        | App name                                       | name                 |
# | 3  | category_id | Four digit IOS category identifier             | categoryId           |
# | 4  | category    | The category in text                           | category             |
# | 5  | rating      | Average rating                                 | ratingAverage        |
# | 6  | reviews     | The total number of reviews                    | totalNumberOfReviews |
# | 7  | ratings     | The total number of ratings                    | ratingCount          |
# | 8  | onestar     | The count of one star ratings                  | ratingCountList      |
# | 9  | twostar     | The count of two star ratings                  | ratingCountList      |
# | 10 | threestar   | The count of three star ratings                | ratingCountList      |
# | 11 | fourstar    | The count of four star ratings                 | ratingCountList      |
# | 12 | fivestar    | The count of five star ratings                 | ratingCountList      |
# | 13 | source      | The base url from which the data were obtained | itunes.apple.com     |
#
# Ratings will be extracted by category of apps in the appdata repository. Concretely, ratings will be obtained for the following categories:
#
# | ID   | NAME                   |
# |------|------------------------|
# | 6018 |  "BOOKS",              |
# | 6000 |  "BUSINESS",           |
# | 6017 |  "EDUCATION",          |
# | 6016 |  "ENTERTAINMENT",      |
# | 6015 |  "FINANCE",            |
# | 6023 |  "FOOD_AND_DRINK",     |
# | 6013 |  "HEALTH_AND_FITNESS", |
# | 6012 |  "LIFESTYLE",          |
# | 6020 |  "MEDICAL",            |
# | 6011 |  "MUSIC",              |
# | 6008 |  "PHOTO_AND_VIDEO",    |
# | 6007 |  "PRODUCTIVITY",       |
# | 6006 |  "REFERENCE",          |
# | 6024 |  "SHOPPING",           |
# | 6005 |  "SOCIAL_NETWORKING",  |
# | 6003 |  "TRAVEL",             |
# | 6002 |  "UTILITIES",          |

# %% [markdown]
# **Imports**

# %%
import asyncio
from appstore.data.acquisition.rating.controller import RatingController
from appstore.data.acquisition import AppStoreTargetCategories
from appstore.container import AppstoreContainer

# %%
CATEGORIES = AppStoreTargetCategories.IDS

# %% [markdown]
# ## AppStore Ratings
# RatingController iterates through the categories, extracting the apps from the repository and retrieves the rating data from the App Store. The results are persisted in the RatingRepo.

# %%
async def wire():
    container = AppstoreContainer()
    container.init_resources()
    container.wire(packages=["appstore.data.acquisition"])

async def scrape():
    ctrl = RatingController()
    await ctrl.scrape(category_ids=CATEGORIES)    
    ctrl.archive()

async def main():
    await asyncio.gather(wire(), scrape())

await main()
# Out:
# [07/26/2023 08:31:08 PM] [INFO] [RatingController] [_get_apps] :
#
# A total of 4103 apps in category 6018 to process.
# There are 1735 apps in category 6018 which have already been processed.
# Apps remaining: 2368
# [07/26/2023 08:34:53 PM] [INFO] [RatingController] [_announce] :
#
# RatingController
# 	                       Category: | 
PM] [INFO] [RatingController] [_announce] :
#
# RatingController
# 	                       Category: | 6018-BOOKS
# 	                 Total Requests: | 2000
# 	            Successful Requests: | 119
# 	                Failed Requests: | 1881
# 	                           Apps: | 119
# 	                        Elapsed: | 0:07:28.257069
# 	                Apps Per Second: | 0.27
#
# [07/26/2023 08:39:55 PM] [INFO] [RatingController] [_get_apps] :
#
# A total of 29184 apps in category 6017 to process.
# There are 353 apps in category 6017 which have already been processed.
# Apps remaining: 28831
# [07/26/2023 08:42:41 PM] [INFO] [RatingController] [_announce] :
#
# RatingController
# 	                       Category: | 6017-EDUCATION
# 	                 Total Requests: | 3000
# 	            Successful Requests: | 200
# 	                Failed Requests: | 2800
# 	                           Apps: | 200
# 	                        Elapsed: | 0:11:35.179926
# 	                Apps Per Second: | 0.29
#
# [07/26/2023 08:46:42 PM] [INFO] [RatingController] [_announce] :
#
# RatingController
# 	                       Category: | 6017-EDUCATION
# 	                 Total Requests: | 4000
# 	            Successful Requests: | 200
# 	                Failed Requests: | 3800
# 	                           Apps: | 200
# 	                        Elapsed: | 0:15:36.800167
# 	                Apps Per Second: | 0.21
#
# [07/26/2023 08:50:54 PM] [INFO] [RatingController] [_announce] :
#
# RatingController
# 	                       Category: | 6017-EDUCATION
# 	                 Total Requests: | 5000
# 	            Successful Requests: | 200
# 	                Failed Requests: | 4800
# 	                           Apps: | 200
# 	                        Elapsed: | 0:19:48.741333
# 	                Apps Per Second: | 0.17
#
# [07/26/2023 08:54:40 PM] [INFO] [RatingController] [_announce] :
#
# RatingController
# 	                       Category: | 6017-EDUCATION
# 	                 Total Requests: | 6000
# 	            Successful Requests: | 208
# 	                Failed Requests: | 5792
# 	                           Apps: | 208
# 	                        Elapsed: | 0:23:34.181494
# 	                Apps Per Second: | 0.15
#
# [07/26/2023 08:55:48 PM] [ERROR] [ASessionHandler] [_make_request] : Exception type <class 'asyncio.exceptions.TimeoutError'> occurred.
#
# Executing retry # 1.
# Traceback (most recent call last):
#   File "/home/john/projects/appstore/appstore/infrastructure/web/asession.py", line 121, in _make_request
#     async with client.get(url, proxy=proxy, ssl=False) as response:
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/client.py", line 1141, in __aenter__
#     self._resp = await self._coro
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/client.py", line 560, in _request
#     await resp.start(conn)
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/client_reqrep.py", line 894, in start
#     with self._timer:
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/helpers.py", line 721, in __exit__
#     raise asyncio.TimeoutError from None
# asyncio.exceptions.TimeoutError
# [07/26/2023 08:58:44 PM] [INFO] [RatingController] [_announce] :
#
# RatingController
# 	                       Category: | 6017-EDUCATION
# 	                 Total Requests: | 7000
# 	            Successful Requests: | 222
# 	                Failed Requests: | 6778
# 	                           Apps: | 222
# 	                        Elapsed: | 0:27:38.402414
# 	                Apps Per Second: | 0.13
#
# [07/26/2023 09:02:55 PM] [INFO] [RatingController] [_announce] :
#
# RatingController
# 	                       Category: | 6017-EDUCATION
# 	                 Total Requests: | 8000
# 	            Successful Requests: | 227
# 	                Failed Requests: | 7773
# 	                           Apps: | 227
# 	                        Elapsed: | 0:31:49.602052
# 	                Apps Per Second: | 0.12
#
# [07/26/2023 09:07:14 PM] [INFO] [RatingController] [_announce] :
#
# RatingController
# 	                       Category: | 6017-EDUCATION
# 	                 Total Requests: | 9000
# 	            Successful Requests: | 227
# 	                Failed Requests: | 8773
# 	                           Apps: | 227
# 	                        Elapsed: | 0:36:08.405274
# 	                Apps Per Second: | 0.1
#
# [07/26/2023 09:11:08 PM] [INFO] [RatingController] [_announce] :
#
# RatingController
# 	                       Category: | 6017-EDUCATION
# 	                 Total Requests: | 10000
# 	            Successful Requests: | 421
# 	                Failed Requests: | 9579
# 	                           Apps: | 421
# 	                        Elapsed: | 0:40:02.948447
# 	                Apps Per Second: | 0.18
#
# [07/26/2023 09:14:46 PM] [ERROR] [MySQLDatabase] [insert] : Exception occurred during database insert.
# Exception type:type[sqlalchemy.exc.SQLAlchemyError]
# (pymysql.err.DataError) (1406, "Data too long for column 'name' at row 48")
# [SQL: INSERT INTO rating (id, name, category_id, category, rating, reviews, ratings, onestar, twostar, threestar, fourstar, fivestar) VALUES (%(id)s, %(name)s, %(category_id)s, %(category)s, %(rating)s, %(reviews)s, %(ratings)s, %(onestar)s, %(twostar)s, %(threestar)s, %(fourstar)s, %(fivestar)s)]
# [parameters: [{'id': 1140000003, 'name': 'italki - Language Learning', 'category_id': 6017, 'category': 'Education', 'rating': 5.0, 'reviews': 307, 'ratings': 3067, 'onestar': 118, 'twostar': 25, 'threestar': 51, 'fourstar': 105, 'fivestar': 2768}, {'id': 1252681871, 'name': 'Rice Business', 'category_id': 6017, 'category': 'Education', 'rating': 5.0, 'reviews': 0, 'ratings': 34, 'onestar': 2, 'twostar': 0, 'threestar': 0, 'fourstar': 0, 'fivestar': 32}, {'id': 1610117443, 'name': 'Nerdify', 'category_id': 6017, 'category': 'Education', 'rating': 5.0, 'reviews': 7, 'ratings': 420, 'onestar': 8, 'twostar': 0, 'threestar': 2, 'fourstar': 9, 'fivestar': 401}, {'id': 915390018, 'name': 'English for Meetings by Business English Pod', 'category_id': 6017, 'category': 'Education', 'rating': 3.0, 'reviews': 2, 'ratings': 5, 'onestar': 1, 'twostar': 0, 'threestar': 2, 'fourstar': 1, 'fivestar': 1}, {'id': 1571862675, 'name': 'SMA Official', 'category_id': 6017, 'category': 'Education', 'rating': 5.0, 'reviews': 3, 'ratings': 25, 'onestar': 0, 'twostar': 2, 'threestar': 0, 'fourstar': 0, 'fivestar': 23}, {'id': 1216843324, 'name': 'HBS Mobile', 'category_id': 6017, 'category': 'Education', 'rating': 4.5, 'reviews': 1, 'ratings': 9, 'onestar': 1, 'twostar': 0, 'threestar': 0, 'fourstar': 0, 'fivestar': 8}, {'id': 1212125206, 'name': '25 Test For TOEFL® 2020', 'category_id': 6017, 'category': 'Education', 'rating': 3.5, 'reviews': 2, 'ratings': 25, 'onestar': 6, 'twostar': 0, 'threestar': 2, 'fourstar': 5, 'fivestar': 12}, {'id': 1083059911, 'name': 'Project Lead The Way', 'category_id': 6017, 'category': 'Education', 'rating': 2.0, 'reviews': 27, 'ratings': 75, 'onestar': 54, 'twostar': 5, 'threestar': 4, 'fourstar': 3, 'fivestar': 9}  ... displaying 10 of 53 total bound parameter sets ...  {'id': 1597689215, 'name': 'Unreal Chemist', 'category_id': 6017, 'category': 'Education', 'rating': 3.5, 'reviews': 13, 'ratings': 52, 'onestar': 12, 'twostar': 3, 'threestar': 1, 'fourstar': 8, 'fivestar': 28}, {'id': 1544229358, 'name': 'Pixel & Tangram games for baby', 'category_id': 6017, 'category': 'Education', 'rating': 4.5, 'reviews': 21, 'ratings': 170, 'onestar': 2, 'twostar': 4, 'threestar': 18, 'fourstar': 20, 'fivestar': 126}]]
# (Background on this error at: https://sqlalche.me/e/20/9h9h)
# [07/26/2023 09:14:46 PM] [INFO] [RatingController] [_announce] :
#
# RatingController
# 	                       Category: | 6017-EDUCATION
# 	                 Total Requests: | 11000
# 	            Successful Requests: | 603
# 	                Failed Requests: | 10397
# 	                           Apps: | 603
# 	                        Elapsed: | 0:43:40.505484
# 	                Apps Per Second: | 0.23
#
# [07/26/2023 09:18:37 PM] [INFO] [RatingController] [_announce] :
#
# RatingController
# 	                       Category: | 6017-EDUCATION
# 	                 Total Requests: | 12000
# 	            Successful Requests: | 1144
# 	                Failed Requests: | 10856
# 	                           Apps: | 1144
# 	                        Elapsed: | 0:47:31.290102
# 	                Apps Per Second: | 0.4
#
# [07/26/2023 09:22:40 PM] [INFO] [RatingController] [_announce] :
#
# RatingController
# 	                       Category: | 6017-EDUCATION
# 	                 Total Requests: | 13000
# 	            Successful Requests: | 1148
# 	                Failed Requests: | 11852
# 	                           Apps: | 1148
# 	                        Elapsed: | 0:51:34.942348
# 	                Apps Per Second: | 0.37
#
# [07/26/2023 09:26:34 PM] [INFO] [RatingController] [_announce] :
#
# RatingController
# 	                       Category: | 6017-EDUCATION
# 	                 Total Requests: | 14000
# 	            Successful Requests: | 1794
# 	                Failed Requests: | 12206
# 	                           Apps: | 1794
# 	                        Elapsed: | 0:55:28.377111
# 	                Apps Per Second: | 0.54
#
# [07/26/2023 09:30:28 PM] [INFO] [RatingController] [_announce] :
#
# RatingController
# 	                       Category: | 6017-EDUCATION
# 	                 Total Requests: | 15000
# 	            Successful Requests: | 2022
# 	                Failed Requests: | 12978
# 	                           Apps: | 2022
# 	                        Elapsed: | 0:59:22.290638
# 	                Apps Per Second: | 0.57
#
# [07/26/2023 09:33:52 PM] [INFO] [RatingController] [_announce] :
#
# RatingController
# 	                       Category: | 6017-EDUCATION
# 	                 Total Requests: |
 'category_id': 6017, 'category': 'Education', 'rating': 4.5, 'reviews': 116, 'ratings': 22, 'onestar': 1, 'twostar': 1, 'threestar': 1, 'fourstar': 4, 'fivestar': 15}, {'id': 1569155922, 'name': '10 Minute Spanish', 'category_id': 6017, 'category': 'Education', 'rating': 4.5, 'reviews': 34, 'ratings': 303, 'onestar': 19, 'twostar': 3, 'threestar': 6, 'fourstar': 31, 'fivestar': 244}, {'id': 412142472, 'name': 'Living Proof with Beth Moore', 'category_id': 6017, 'category': 'Education', 'rating': 4.5, 'reviews': 87, 'ratings': 99, 'onestar': 3, 'twostar': 0, 'threestar': 3, 'fourstar': 8, 'fivestar': 85}, {'id': 1502397616, 'name': 'Multifly: Multiplication Games', 'category_id': 6017, 'category': 'Education', 'rating': 4.5, 'reviews': 44, 'ratings': 1857, 'onestar': 89, 'twostar': 41, 'threestar': 79, 'fourstar': 178, 'fivestar': 1470}, {'id': 725382606, 'name': 'Memory Training. Bible Study', 'category_id': 6017, 'category': 'Education', 'rating': 4.5, 'reviews': 121, 'ratings': 152, 'onestar': 13, 'twostar': 3, 'threestar': 6, 'fourstar': 20, 'fivestar': 110}, {'id': 1065290732, 'name': 'Skyeng: Learn English', 'category_id': 6017, 'category': 'Education', 'rating': 5.0, 'reviews': 49, 'ratings': 1362, 'onestar': 37, 'twostar': 7, 'threestar': 22, 'fourstar': 63, 'fivestar': 1233}, {'id': 1084712308, 'name': 'History •', 'category_id': 6017, 'category': 'Education', 'rating': 4.5, 'reviews': 32, 'ratings': 1789, 'onestar': 45, 'twostar': 19, 'threestar': 56, 'fourstar': 219, 'fivestar': 1450}, {'id': 480437544, 'name': 'Hadith of the Day', 'category_id': 6017, 'category': 'Education', 'rating': 4.5, 'reviews': 326, 'ratings': 271, 'onestar': 7, 'twostar': 8, 'threestar': 8, 'fourstar': 21, 'fivestar': 227}  ... displaying 10 of 97 total bound parameter sets ...  {'id': 1272093574, 'name': 'small talk', 'category_id': 6017, 'category': 'Education', 'rating': 4.5, 'reviews': 47, 'ratings': 284, 'onestar': 10, 'twostar': 3, 'threestar': 6, 'fourstar': 39, 'fivestar': 226}, {'id': 1199129216, 'name': 'Reward Charts by Stellar', 'category_id': 6017, 'category': 'Education', 'rating': 4.5, 'reviews': 24, 'ratings': 396, 'onestar': 9, 'twostar': 7, 'threestar': 19, 'fourstar': 37, 'fivestar': 324}]]
# (Background on this error at: https://sqlalche.me/e/20/9h9h)
# [07/26/2023 09:45:26 PM] [INFO] [RatingController] [_announce] :
#
# RatingController
# 	                       Category: | 6017-EDUCATION
# 	                 Total Requests: | 19000
# 	            Successful Requests: | 5880
# 	                Failed Requests: | 13120
# 	                           Apps: | 5880
# 	                        Elapsed: | 1:14:20.227137
# 	                Apps Per Second: | 1.32
#
# [07/26/2023 09:45:59 PM] [ERROR] [ASessionHandler] [_make_request] : Exception type <class 'asyncio.exceptions.TimeoutError'> occurred.
#
# Executing retry # 1.
# Traceback (most recent call last):
#   File "/home/john/projects/appstore/appstore/infrastructure/web/asession.py", line 121, in _make_request
#     async with client.get(url, proxy=proxy, ssl=False) as response:
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/client.py", line 1141, in __aenter__
#     self._resp = await self._coro
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/client.py", line 560, in _request
#     await resp.start(conn)
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/client_reqrep.py", line 894, in start
#     with self._timer:
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/helpers.py", line 721, in __exit__
#     raise asyncio.TimeoutError from None
# asyncio.exceptions.TimeoutError
# [07/26/2023 09:49:23 PM] [INFO] [RatingController] [_announce] :
#
# RatingController
# 	                       Category: | 6017-EDUCATION
# 	                 Total Requests: | 20000
# 	            Successful Requests: | 6387
# 	                Failed Requests: | 13613
# 	                           Apps: | 6387
# 	                        Elapsed: | 1:18:17.832252
# 	                Apps Per Second: | 1.36
