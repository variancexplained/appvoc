# %% [markdown]
# # AppStore Ratings
# App Store apps are rated on a five-star scale. In this section, we extract the number of ratings on each of the five-points of the scale, as well as the total ratings and reviews.
#
# The AppStore Review entity is defined as follows.
#
# | #  | name        | description                                    | api_field            |
# |----|-------------|------------------------------------------------|----------------------|
# | 1  | id          | Unique app identifier                          | adamId               |
# | 2  | name        | App name                                       | name                 |
# | 3  | category_id | Four digit IOS category identifier             | categoryId           |
# | 4  | category    | The category in text                           | category             |
# | 5  | rating      | Average rating                                 | ratingAverage        |
# | 6  | reviews     | The total number of reviews                    | totalNumberOfReviews |
# | 7  | ratings     | The total number of ratings                    | ratingCount          |
# | 8  | onestar     | The count of one star ratings                  | ratingCountList      |
# | 9  | twostar     | The count of two star ratings                  | ratingCountList      |
# | 10 | threestar   | The count of three star ratings                | ratingCountList      |
# | 11 | fourstar    | The count of four star ratings                 | ratingCountList      |
# | 12 | fivestar    | The count of five star ratings                 | ratingCountList      |
# | 13 | source      | The base url from which the data were obtained | itunes.apple.com     |
#
# Ratings will be extracted by category of apps in the appdata repository. Concretely, ratings will be obtained for the following categories:
#
# | ID   | NAME                   |
# |------|------------------------|
# | 6018 |  "BOOKS",              |
# | 6000 |  "BUSINESS",           |
# | 6017 |  "EDUCATION",          |
# | 6016 |  "ENTERTAINMENT",      |
# | 6015 |  "FINANCE",            |
# | 6023 |  "FOOD_AND_DRINK",     |
# | 6013 |  "HEALTH_AND_FITNESS", |
# | 6012 |  "LIFESTYLE",          |
# | 6020 |  "MEDICAL",            |
# | 6011 |  "MUSIC",              |
# | 6008 |  "PHOTO_AND_VIDEO",    |
# | 6007 |  "PRODUCTIVITY",       |
# | 6006 |  "REFERENCE",          |
# | 6024 |  "SHOPPING",           |
# | 6005 |  "SOCIAL_NETWORKING",  |
# | 6003 |  "TRAVEL",             |
# | 6002 |  "UTILITIES",          |

# %% [markdown]
# **Imports**

# %%
import asyncio
from appstore.data.acquisition.rating.controller import RatingController
from appstore.data.acquisition import AppStoreTargetCategories
from appstore.container import AppstoreContainer

# %%
CATEGORIES = [
        # 6016,
        6015,
        6023,
        6013,
        6012,
        6020,        
        6008,
        6007,
        6006,
        6024,
        6005,
        6003,
        6002,
    ]

# %% [markdown]
# ## AppStore Ratings
# RatingController iterates through the categories, extracting the apps from the repository and retrieves the rating data from the App Store. The results are persisted in the RatingRepo.

# %%
async def wire():
    container = AppstoreContainer()
    container.init_resources()
    container.wire(packages=["appstore.data.acquisition"])

async def scrape():
    ctrl = RatingController()
    await ctrl.scrape(category_ids=CATEGORIES)    
    ctrl.archive()

async def main():
    await asyncio.gather(wire(), scrape())

await main()
# Out:
# [07/27/2023 03:44:11 AM] [INFO] [RatingController] [_get_apps] :
#
# A total of 58428 apps in category 6015 to process.
# There are 0 apps in category 6015 which have already been processed.
# [07/27/2023 03:46:38 AM] [INFO] [RatingController] [_announce] :
#
# RatingController
# 	                       Category: | 6015-FINANCE
# 	                 Total Requests: | 1000
# 	            Successful Requests: | 946
# 	                Failed Requests: | 54
# 	                           Apps: | 1000
# 	                        Elapsed: | 0:02:31.096432
# 	                Apps Per Second: | 6.62
#
# [07/27/2023 03:48:49 AM] [INFO] [RatingController] [_announce] :
#
# RatingController
# 	                       Category: | 6015-FINANCE
# 	                 Total Requests: | 2000
# 	            Successful Requests: | 1925
# 	                Failed Requests: | 75
# 	                           Apps: | 2000
# 	                        Elapsed: | 0:04:42.528318
# 	                Apps Per Second: | 7.08
#
# [07/27/2023 03:50:47 AM] [INFO] [RatingController] [_announce] :
#
# RatingController
# 	                       Category: | 6015-FINANCE
# 	                 Total Requests: | 3000
# 	            Successful Requests: | 2884
# 	                Failed Requests: | 116
# 	                           Apps: | 3000
# 	                        Elapsed: | 0:06:40.336304
# 	                Apps Per Second: | 7.49
#
# [07/27/2023 03:52:57 AM] [INFO] [RatingController] [_announce] :
#
# RatingController
# 	                       Category: | 6015-FINANCE
# 	                 Total Requests: | 4000
# 	            Successful Requests: | 3822
# 	                Failed Requests: | 178
# 	                           Apps: | 4000
# 	                        Elapsed: | 0:08:50.310553
# 	                Apps Per Second: | 7.54
#
# [07/27/2023 03:55:00 AM] [INFO] [RatingController] [_announce] :
#
# RatingController
# 	                       Category: | 6015-FINANCE
# 	                 Total Requests: | 5000
# 	            Successful Requests: | 4739
# 	                Failed Requests: | 261
# 	                           Apps: | 5000
# 	                        Elapsed: | 0:10:53.348921
# 	                Apps Per Second: | 7.65
#
# [07/27/2023 03:56:58 AM] [INFO] [RatingController] [_announce] :
#
# RatingController
# 	                       Category: | 6015-FINANCE
# 	                 Total Requests: | 6000
# 	            Successful Requests: | 5625
# 	                Failed Requests: | 375
# 	                           Apps: | 6000
# 	                        Elapsed: | 0:12:51.050142
# 	                Apps Per Second: | 7.78
#
# [07/27/2023 03:59:06 AM] [INFO] [RatingController] [_announce] :
#
# RatingController
# 	                       Category: | 6015-FINANCE
# 	                 Total Requests: | 7000
# 	            Successful Requests: | 6433
# 	                Failed Requests: | 567
# 	                           Apps: | 7000
# 	                        Elapsed: | 0:14:58.852309
# 	                Apps Per Second: | 7.79
#
# [07/27/2023 04:01:10 AM] [INFO] [RatingController] [_announce] :
#
# RatingController
# 	                       Category: | 6015-FINANCE
# 	                 Total Requests: | 8000
# 	            Successful Requests: | 7200
# 	                Failed Requests: | 800
# 	                           Apps: | 8000
# 	                        Elapsed: | 0:17:03.223988
# 	                Apps Per Second: | 7.82
#
# [07/27/2023 04:03:41 AM] [INFO] [RatingController] [_announce] :
#
# RatingController
# 	                       Category: | 6015-FINANCE
# 	                 Total Requests: | 9000
# 	            Successful Requests: | 7907
# 	                Failed Requests: | 1093
# 	                           Apps: | 9000
# 	                        Elapsed: | 0:19:34.443585
# 	                Apps Per Second: | 7.66
#
# [07/27/2023 04:05:48 AM] [INFO] [RatingController] [_announce] :
#
# RatingController
# 	                       Category: | 6015-FINANCE
# 	                 Total Requests: | 10000
# 	            Successful Requests: | 8522
# 	                Failed Requests: | 1478
# 	                           Apps: | 10000
# 	                        Elapsed: | 0:21:41.312963
# 	                Apps Per Second: | 7.68
#
# [07/27/2023 04:08:02 AM] [INFO] [RatingController] [_announce] :
#
# RatingController
# 	                       Category: | 6015-FINANCE
# 	                 Total Requests: | 11000
# 	            Successful Requests: | 9059
# 	                Failed Requests: | 1941
# 	                           Apps: | 11000
# 	                        Elapsed: | 0:23:54.857145
# 	                Apps Per Second: | 7.67
#
# [07/27/2023 04:10:13 AM] [INFO] [RatingController] [_announce] :
#
# RatingController
# 	                       Category: | 6015-FINANCE
# 	                 Total Requests: | 12000
# 	            Successful Requests: | 9512
# 	                Failed Requests: | 2488
# 	                           Apps: | 12000
# 	                        Elapsed: | 0:26:06.340122
# 	                Apps Per Second: | 7.66
#
# [07/27/2023 04:12:23 AM] [INFO] [RatingController] [_announce] :
#
# RatingController
# 	                       Category: | 6015-FINANCE
# 	                 Total Requests: | 13000
# 	            Successful Requests: | 9893
# 	                Failed Requests: | 3107
# 	                           Apps: | 13000
# 	                        Elapsed: | 0:28:15.838195
# 	                Apps Per Second: | 7.67
#
# [07/27/2023 04:14:22 AM] [INFO] [RatingController] [_announce] :
#
# RatingController
# 	                       Category: | 6015-FINANCE
# 	                 Total Requests: | 14000
# 	            Successful Requests: | 10187
# 	                Failed Requests: | 3813
# 	                           Apps: | 14000
# 	                        Elapsed: | 0:30:15.658843
# 	                Apps Per Second: | 7.71
#
# [07/27/2023 04:16:54 AM] [INFO] [RatingController] [_announce] :
#
# RatingController
# 	                       Category: | 6015-FINANCE
# 	                 Total Requests: | 15000
# 	            Successful Requests: | 10459
# 	                Failed Requests: | 4541
# 	                           Apps: | 15000
# 	                        Elapsed: | 0:32:47.785387
# 	                Apps Per Second: | 7.62
#
# [07/27/2023 04:19:04 AM] [INFO] [RatingController] [_announce] :
#
# RatingController
# 	                       Category: | 6015-FINANCE
# 	                 Total Requests: | 16000
# 	            Successful Requests: | 10668
# 	                Failed Requests: | 5332
# 	                           Apps: | 16000
# 	                        Elapsed: | 0:34:57.019391
# 	                Apps Per Second: | 7.63
#
# [07/27/2023 04:21:07 AM] [INFO] [RatingController] [_announce] :
#
# RatingController
# 	                       Category: | 6015-FINANCE
# 	                 Total Requests: | 17000
# 	            Successful Requests: | 10831
# 	                Failed Requests: | 6169
# 	                           Apps: | 17000
# 	                        Elapsed: | 0:36:59.865082
# 	                Apps Per Second: | 7.66
#
# [07/27/2023 04:23:16 AM] [INFO] [RatingController] [_announce] :
#
# RatingController
# 	                       Category: | 6015-FINANCE
# 	                 Total Requests: | 18000
# 	            Successful Requests: | 11006
# 	                Failed Requests: | 6994
# 	                           Apps: | 18000
# 	                        Elapsed: | 0:39:09.074325
# 	                Apps Per Second: | 7.66
#
# [07/27/2023 04:25:38 AM] [INFO] [RatingController] [_announce] :
#
# RatingController
# 	                       Category: | 6015-FINANCE
# 	                 Total Requests: | 19000
# 	            Successful Requests: | 11147
# 	                Failed Requests: | 7853
# 	                           Apps: | 19000
# 	                        Elapsed: | 0:41:30.936589
# 	                Apps Per Second: | 7.63
#
# [07/27/2023 04:27:58 AM] [INFO] [RatingController] [_announce] :
#
# RatingController
# 	                       Category: | 6015-FINANCE
# 	                 Total Requests: | 20000
# 	            Successful Requests: | 11235
# 	                Failed Requests: | 8765
# 	                           Apps: | 20000
# 	                        Elapsed: | 0:43:51.285777
# 	                Apps Per Second: | 7.6
#
# [07/27/2023 04:28:28 AM] [ERROR] [ASessionHandler] [_make_request] : Exception type <class 'asyncio.exceptions.TimeoutError'> occurred.
#
# Executing retry # 1.
# Traceback (most recent call last):
#   File "/home/john/projects/appstore/appstore/infrastructure/web/asession.py", line 121, in _make_request
#     async with client.get(url, proxy=proxy, ssl=False) as response:
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/client.py", line 1141, in __aenter__
#     self._resp = await self._coro
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/client.py", line 560, in _request
#     await resp.start(conn)
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/client_reqrep.py", line 894, in start
#     with self._timer:
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/helpers.py", line 721, in __exit__
#     raise asyncio.TimeoutError from None
# asyncio.exceptions.TimeoutError
# [07/27/2023 04:30:29 AM] [INFO] [RatingController] [_announce] :
#
# RatingController
# 	                       Category: | 6015-FINANCE
# 	                 Total Requests: | 21000
# 	            Successful Requests: | 11316
# 	                Failed Requests: | 9684
# 	                           Apps: | 21000
# 	                        Elapsed: | 0:46:22.099367
# 	                Apps Per Second: | 7.55
#
# [07/27/2023 04:32:46 AM] [INFO] [RatingController] [_announce] :
#
# RatingController
# 	                       Category: | 6015-FINANCE
# 	                 Total Requests: | 22000
# 	            Successful Requests: | 11382
# 	                Failed Requests: | 10618
# 	                           Apps: | 22000
# 	                        Elapsed: | 0:48:39.215462
# 	                Apps Per Second: | 7.54
#
# [07/27/2023 04:34:43 AM] [ERROR] [ASessionHandler] [_make_request] : Exception type <class 'asyncio.exceptions.TimeoutError'> occurred.
#
# Executing retry # 1.
# Traceback (most recent call last):
#   File "/home/john/projects/appstore/appstore/infrastructure/web/asession.py", line 121, in _make_request
#     async with client.get(url, proxy=proxy, ssl=False) as response:
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/client.py", line 1141, in __aenter__
#     self._resp = await self._coro
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/client.py", line 560, in _request
#     await resp.start(conn)
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/client_reqrep.py", line 894, in start
#     with self._timer:
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/helpers.py", line 721, in __exit__
#     raise asyncio.TimeoutError from None
# asyncio.exceptions.TimeoutError
# [07/27/2023 04:35:18 AM] [INFO] [RatingController] [_announce] :
#
# RatingController
# 	                       Category: | 6015-FINANCE
# 	                 Total Requests: | 23000
# 	            Successful Requests: | 11437
# 	                Failed Requests: | 11563
# 	                           Apps: | 23000
# 	                        Elapsed: | 0:51:11.451887
# 	                Apps Per Second: | 7.49
#
# [07/27/2023 04:37:38 AM] [INFO] [RatingController] [_announce] :
#
# RatingController
# 	                       Category: | 6015-FINANCE
# 	                 Total Requests: | 24000
# 	            Successful Requests: | 11470
# 	                Failed Requests: | 12530
# 	                           Apps: | 24000
# 	                        Elapsed: | 0:53:31.301414
# 	                Apps Per Second: | 7.47
#
# [07/27/2023 04:38:22 AM] [ERROR] [ASessionHandler] [_make_request] : Exception type <class 'asyncio.exceptions.TimeoutError'> occurred.
#
# Executing retry # 1.
# Traceback (most recent call last):
#   File "/home/john/projects/appstore/appstore/infrastructure/web/asession.py", line 121, in _make_request
#     async with client.get(url, proxy=proxy, ssl=False) as response:
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/client.py", line 1141, in __aenter__
#     self._resp = await self._coro
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/client.py", line 560, in _request
#     await resp.start(conn)
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/client_reqrep.py", line 894, in start
#     with self._timer:
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/helpers.py", line 721, in __exit__
#     raise asyncio.TimeoutError from None
# asyncio.exceptions.TimeoutError
# [07/27/2023 04:40:00 AM] [INFO] [RatingController] [_announce] :
#
# RatingController
# 	                       Category: | 6015-FINANCE
# 	                 Total Requests: | 25000
# 	            Successful Requests: | 11500
# 	                Failed Requests: | 13500
# 	                           Apps: | 25000
# 	                        Elapsed: | 0:55:53.168052
# 	                Apps Per Second: | 7.46
#
# [07/27/2023 04:41:10 AM] [ERROR] [ASessionHandler] [_make_request] : Exception type <class 'asyncio.exceptions.TimeoutError'> occurred.
#
# Executing retry # 1.
# Traceback (most recent call last):
#   File "/home/john/projects/appstore/appstore/infrastructure/web/asession.py", line 121, in _make_request
#     async with client.get(url, proxy=proxy, ssl=False) as response:
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/client.py", line 1141, in __aenter__
#     self._resp = await self._coro
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/client.py", line 560, in _request
#     await resp.start(conn)
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/client_reqrep.py", line 894, in start
#     with self._timer:
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/helpers.py", line 721, in __exit__
#     raise asyncio.TimeoutError from None
# asyncio.exceptions.TimeoutError
# [07/27/2023 04:42:29 AM] [INFO] [RatingController] [_announce] :
#
# RatingController
# 	                       Category: | 6015-FINANCE
# 	                 Total Requests: | 26000
# 	            Successful Requests: | 11528
# 	                Failed Requests: | 14472
# 	                           Apps: | 26000
# 	                        Elapsed: | 0:58:21.824342
# 	                Apps Per Second: | 7.42
#
# [07/27/2023 04:44:25 AM] [INFO] [RatingController] [_announce] :
#
# RatingController
# 	                       Category: | 6015-FINANCE
# 	                 Total Requests: | 27000
# 	            Successful Requests: | 11548
# 	                Failed Requests: | 15452
# 	                           Apps: | 27000
# 	                        Elapsed: | 1:00:18.773132
# 	                Apps Per Second: | 7.46
#
# [07/27/2023 04:44:33 AM] [ERROR] [ASessionHandler] [_make_request] : Exception type <class 'aiohttp.client_exceptions.ServerDisconnectedError'> occurred.
# Server disconnected
# Executing retry # 1.
# Traceback (most recent call last):
#   File "/home/john/projects/appstore/appstore/infrastructure/web/asession.py", line 121, in _make_request
#     async with client.get(url, proxy=proxy, ssl=False) as response:
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/client.py", line 1141, in __aenter__
#     self._resp = await self._coro
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/client.py", line 560, in _request
#     await resp.start(conn)
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/client_reqrep.py", line 899, in start
#     message, payload = await protocol.read()  # type: ignore[union-attr]
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/streams.py", line 616, in read
#     await self._waiter
# aiohttp.client_exceptions.ServerDisconnectedError: Server disconnected
# [07/27/2023 04:44:57 AM] [ERROR] [ASessionHandler] [_make_request] : Exception type <class 'aiohttp.client_exceptions.ServerDisconnectedError'> occurred.
# Server disconnected
# Executing retry # 1.
# Traceback (most recent call last):
#   File "/home/john/projects/appstore/appstore/infrastructure/web/asession.py", line 121, in _make_request
#     async with client.get(url, proxy=proxy, ssl=False) as response:
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/client.py", line 1141, in __aenter__
#     self._resp = await self._coro
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/client.py", line 560, in _request
#     await resp.start(conn)
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/client_reqrep.py", line 899, in start
#     message, payload = await protocol.read()  # type: ignore[union-attr]
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/streams.py", line 616, in read
#     await self._waiter
# aiohttp.client_exceptions.ServerDisconnectedError: Server disconnected
# [07/27/2023 04:46:37 AM] [INFO] [RatingController] [_announce] :
#
# RatingController
# 	                       Category: | 6015-FINANCE
# 	                 Total Requests: | 28000
# 	            Successful Requests: | 11566
# 	                Failed Requests: | 16434
# 	                           Apps: | 28000
# 	                        Elapsed: | 1:02:29.841497
# 	                Apps Per Second: | 7.47
#
# [07/27/2023 04:48:40 AM] [INFO] [RatingController] [_announce] :
#
# RatingController
# 	                       Category: | 6015-FINANCE
# 	                 Total Requests: | 29000
# 	            Successful Requests: | 11583
# 	                Failed Requests: | 17417
# 	                           Apps: | 29000
# 	                        Elapsed: | 1:04:33.186185
# 	                Apps Per Second: | 7.49
#
# [07/27/2023 04:50:15 AM] [ERROR] [ASessionHandler] [_make_request] : Exception type <class 'asyncio.exceptions.TimeoutError'> occurred.
#
# Executing retry # 1.
# Traceback (most recent call last):
#   File "/home/john/projects/appstore/appstore/infrastructure/web/asession.py", line 121, in _make_request
#     async with client.get(url, proxy=proxy, ssl=False) as response:
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/client.py", line 1141, in __aenter__
#     self._resp = await self._coro
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/client.py", line 560, in _request
#     await resp.start(conn)
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/client_reqrep.py", line 894, in start
#     with self._timer:
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/helpers.py", line 721, in __exit__
#     raise asyncio.TimeoutError from None
# asyncio.exceptions.TimeoutError
# [07/27/2023 04:51:03 AM] [INFO] [RatingController] [_announce] :
#
# RatingController
# 	                       Category: | 6015-FINANCE
# 	                 Total Requests: | 30000
# 	            Successful Requests: | 11590
# 	                Failed Requests: | 18410
# 	                           Apps: | 30000
# 	                        Elapsed: | 1:06:56.558136
# 	                Apps Per Second: | 7.47
#
# [07/27/2023 04:53:00 AM] [INFO] [RatingController] [_announce] :
#
# RatingController
# 	                       Category: | 6015-FINANCE
# 	                 Total Requests: | 31000
# 	            Successful Requests: | 11596
# 	                Failed Requests: | 19404
# 	                           Apps: | 31000
# 	                        Elapsed: | 1:08:53.537870
# 	                Apps Per Second: | 7.5
#
# [07/27/2023 04:53:52 AM] [ERROR] [ASessionHandler] [_make_request] : Exception type <class 'aiohttp.client_exceptions.ClientHttpProxyError'> occurred.
# 402, message='Payment Required', url=URL('http://obyluizw-rotate:te6ly5tnk9s3@p.webshare.io:80')
# Executing retry # 1.
# Traceback (most recent call last):
#   File "/home/john/projects/appstore/appstore/infrastructure/web/asession.py", line 121, in _make_request
#     async with client.get(url, proxy=proxy, ssl=False) as response:
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/client.py", line 1141, in __aenter__
#     self._resp = await self._coro
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/client.py", line 536, in _request
#     conn = await self._connector.connect(
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/connector.py", line 540, in connect
#     proto = await self._create_connection(req, traces, timeout)
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/connector.py", line 899, in _create_connection
#     _, proto = await self._create_proxy_connection(req, traces, timeout)
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/connector.py", line 1288, in _create_proxy_connection
#     raise ClientHttpProxyError(
# aiohttp.client_exceptions.ClientHttpProxyError: 402, message='Payment Required', url=URL('http://obyluizw-rotate:te6ly5tnk9s3@p.webshare.io:80')
# [07/27/2023 04:53:52 AM] [ERROR] [ASessionHandler] [_make_request] : Exception type <class 'aiohttp.client_exceptions.ClientHttpProxyError'> occurred.
# 402, message='Payment Required', url=URL('http://obyluizw-rotate:te6ly5tnk9s3@p.webshare.io:80')
# Executing retry # 1.
# Traceback (most recent call last):
#   File "/home/john/projects/appstore/appstore/infrastructure/web/asession.py", line 121, in _make_request
#     async with client.get(url, proxy=proxy, ssl=False) as response:
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/client.py", line 1141, in __aenter__
#     self._resp = await self._coro
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/client.py", line 536, in _request
#     conn = await self._connector.connect(
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/connector.py", line 540, in connect
#     proto = await self._create_connection(req, traces, timeout)
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/connector.py", line 899, in _create_connection
#     _, proto = await self._create_proxy_connection(req, traces, timeout)
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/connector.py", line 1288, in _create_proxy_connection
#     raise ClientHttpProxyError(
# aiohttp.client_exceptions.ClientHttpProxyError: 402, message='Payment Required', url=URL('http://obyluizw-rotate:te6ly5tnk9s3@p.webshare.io:80')
# [07/27/2023 04:53:52 AM] [ERROR] [ASessionHandler] [_make_request] : Exception type <class 'aiohttp.client_exceptions.ClientHttpProxyError'> occurred.
# 402, message='Payment Required', url=URL('http://obyluizw-rotate:te6ly5tnk9s3@p.webshare.io:80')
# Executing retry # 1.
# Traceback (most recent call last):
#   File "/home/john/projects/appstore/appstore/infrastructure/web/asession.py", line 121, in _make_request
#     async with client.get(url, proxy=proxy, ssl=False) as response:
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/client.py", line 1141, in __aenter__
#     self._resp = await self._coro
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/client.py", line 536, in _request
#     conn = await self._connector.connect(
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/connector.py", line 540, in connect
#     proto = await self._create_connection(req, traces, timeout)
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/connector.py", line 899, in _create_connection
#     _, proto = await self._create_proxy_connection(req, traces, timeout)
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/connector.py", line 1288, in _create_proxy_connection
#     raise ClientHttpProxyError(
# aiohttp.client_exceptions.ClientHttpProxyError: 402, message='Payment Required', url=URL('http://obyluizw-rotate:te6ly5tnk9s3@p.webshare.io:80')
# [07/27/2023 04:53:52 AM] [ERROR] [ASessionHandler] [_make_request] : Exception type <class 'aiohttp.client_exceptions.ClientHttpProxyError'> occurred.
# 402, message='Payment Required', url=URL('http://obyluizw-rotate:te6ly5tnk9s3@p.webshare.io:80')
# Executing retry # 1.
# Traceback (most recent call last):
#   File "/home/john/projects/appstore/appstore/infrastructure/web/asession.py", line 121, in _make_request
#     async with client.get(url, proxy=proxy, ssl=False) as response:
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/client.py", line 1141, in __aenter__
#     self._resp = await self._coro
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/client.py", line 536, in _request
#     conn = await self._connector.connect(
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/connector.py", line 540, in connect
#     proto = await self._create_connection(req, traces, timeout)
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/connector.py", line 899, in _create_connection
#     _, proto = await self._create_proxy_connection(req, traces, timeout)
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/connector.py", line 1288, in _create_proxy_connection
#     raise ClientHttpProxyError(
# aiohttp.client_exceptions.ClientHttpProxyError: 402, message='Payment Required', url=URL('http://obyluizw-rotate:te6ly5tnk9s3@p.webshare.io:80')
# [07/27/2023 04:54:02 AM] [ERROR] [ASessionHandler] [_make_request] : Exception type <class 'aiohttp.client_exceptions.ClientHttpProxyError'> occurred.
# 402, message='Payment Required', url=URL('http://obyluizw-rotate:te6ly5tnk9s3@p.webshare.io:80')
# Executing retry # 1.
# Traceback (most recent call last):
#   File "/home/john/projects/appstore/appstore/infrastructure/web/asession.py", line 121, in _make_request
#     async with client.get(url, proxy=proxy, ssl=False) as response:
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/client.py", line 1141, in __aenter__
#     self._resp = await self._coro
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/client.py", line 536, in _request
#     conn = await self._connector.connect(
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/connector.py", line 540, in connect
#     proto = await self._create_connection(req, traces, timeout)
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/connector.py", line 899, in _create_connection
#     _, proto = await self._create_proxy_connection(req, traces, timeout)
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/connector.py", line 1288, in _create_proxy_connection
#     raise ClientHttpProxyError(
# aiohttp.client_exceptions.ClientHttpProxyError: 402, message='Payment Required', url=URL('http://obyluizw-rotate:te6ly5tnk9s3@p.webshare.io:80')
# [07/27/2023 04:54:02 AM] [ERROR] [ASessionHandler] [_make_request] : Exception type <class 'aiohttp.client_exceptions.ClientHttpProxyError'> occurred.
# 402, message='Payment Required', url=URL('http://obyluizw-rotate:te6ly5tnk9s3@p.webshare.io:80')
# Executing retry # 1.
# Traceback (most recent call last):
#   File "/home/john/projects/appstore/appstore/infrastructure/web/asession.py", line 121, in _make_request
#     async with client.get(url, proxy=proxy, ssl=False) as response:
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/client.py", line 1141, in __aenter__
#     self._resp = await self._coro
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/client.py", line 536, in _request
#     conn = await self._connector.connect(
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/connector.py", line 540, in connect
#     proto = await self._create_connection(req, traces, timeout)
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/connector.py", line 899, in _create_connection
#     _, proto = await self._create_proxy_connection(req, traces, timeout)
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/connector.py", line 1288, in _create_proxy_connection
#     raise ClientHttpProxyError(
# aiohttp.client_exceptions.ClientHttpProxyError: 402, message='Payment Required', url=URL('http://obyluizw-rotate:te6ly5tnk9s3@p.webshare.io:80')
# [07/27/2023 04:54:02 AM] [ERROR] [ASessionHandler] [_make_request] : Exception type <class 'aiohttp.client_exceptions.ClientHttpProxyError'> occurred.
# 402, message='Payment Required', url=URL('http://obyluizw-rotate:te6ly5tnk9s3@p.webshare.io:80')
# Executing retry # 1.
# Traceback (most recent call last):
#   File "/home/john/projects/appstore/appstore/infrastructure/web/asession.py", line 121, in _make_request
#     async with client.get(url, proxy=proxy, ssl=False) as response:
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/client.py", line 1141, in __aenter__
#     self._resp = await self._coro
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/client.py", line 536, in _request
#     conn = await self._connector.connect(
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/connector.py", line 540, in connect
#     proto = await self._create_connection(req, traces, timeout)
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/connector.py", line 899, in _create_connection
#     _, proto = await self._create_proxy_connection(req, traces, timeout)
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/connector.py", line 1288, in _create_proxy_connection
#     raise ClientHttpProxyError(
# aiohttp.client_exceptions.ClientHttpProxyError: 402, message='Payment Required', url=URL('http://obyluizw-rotate:te6ly5tnk9s3@p.webshare.io:80')
# [07/27/2023 04:54:07 AM] [ERROR] [ASessionHandler] [_make_request] : Exception type <class 'aiohttp.client_exceptions.ClientHttpProxyError'> occurred.
# 402, message='Payment Required', url=URL('http://obyluizw-rotate:te6ly5tnk9s3@p.webshare.io:80')
# Executing retry # 1.
# Traceback (most recent call last):
#   File "/home/john/projects/appstore/appstore/infrastructure/web/asession.py", line 121, in _make_request
#     async with client.get(url, proxy=proxy, ssl=False) as response:
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/client.py", line 1141, in __aenter__
#     self._resp = await self._coro
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/client.py", line 536, in _request
#     conn = await self._connector.connect(
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/connector.py", line 540, in connect
#     proto = await self._create_connection(req, traces, timeout)
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/connector.py", line 899, in _create_connection
#     _, proto = await self._create_proxy_connection(req, traces, timeout)
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/connector.py", line 1288, in _create_proxy_connection
#     raise ClientHttpProxyError(
# aiohttp.client_exceptions.ClientHttpProxyError: 402, message='Payment Required', url=URL('http://obyluizw-rotate:te6ly5tnk9s3@p.webshare.io:80')
# [07/27/2023 04:54:07 AM] [ERROR] [ASessionHandler] [_make_request] : Exception type <class 'aiohttp.client_exceptions.ClientHttpProxyError'> occurred.
# 402, message='Payment Required', url=URL('http://obyluizw-rotate:te6ly5tnk9s3@p.webshare.io:80')
# Executing retry # 1.
# Traceback (most recent call last):
#   File "/home/john/projects/appstore/appstore/infrastructure/web/asession.py", line 121, in _make_request
#     async with client.get(url, proxy=proxy, ssl=False) as response:
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/client.py", line 1141, in __aenter__
#     self._resp = await self._coro
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/client.py", line 536, in _request
#     conn = await self._connector.connect(
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/connector.py", line 540, in connect
#     proto = await self._create_connection(req, traces, timeout)
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/connector.py", line 899, in _create_connection
#     _, proto = await self._create_proxy_connection(req, traces, timeout)
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/connector.py", line 1288, in _create_proxy_connection
#     raise ClientHttpProxyError(
# aiohttp.client_exceptions.ClientHttpProxyError: 402, message='Payment Required', url=URL('http://obyluizw-rotate:te6ly5tnk9s3@p.webshare.io:80')
# [07/27/2023 04:54:07 AM] [ERROR] [ASessionHandler] [_make_request] : Exception type <class 'aiohttp.client_exceptions.ClientHttpProxyError'> occurred.
# 402, message='Payment Required', url=URL('http://obyluizw-rotate:te6ly5tnk9s3@p.webshare.io:80')
# Executing retry # 1.
# Traceback (most recent call last):
#   File "/home/john/projects/appstore/appstore/infrastructure/web/asession.py", line 121, in _make_request
#     async with client.get(url, proxy=proxy, ssl=False) as response:
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/client.py", line 1141, in __aenter__
#     self._resp = await self._coro
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/client.py", line 536, in _request
#     conn = await self._connector.connect(
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/connector.py", line 540, in connect
#     proto = await self._create_connection(req, traces, timeout)
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/connector.py", line 899, in _create_connection
#     _, proto = await self._create_proxy_connection(req, traces, timeout)
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/connector.py", line 1288, in _create_proxy_connection
#     raise ClientHttpProxyError(
# aiohttp.client_exceptions.ClientHttpProxyError: 402, message='Payment Required', url=URL('http://obyluizw-rotate:te6ly5tnk9s3@p.webshare.io:80')
# [07/27/2023 04:54:18 AM] [ERROR] [ASessionHandler] [_make_request] : Exception type <class 'aiohttp.client_exceptions.ClientHttpProxyError'> occurred.
# 402, message='Payment Required', url=URL('http://obyluizw-rotate:te6ly5tnk9s3@p.webshare.io:80')
# Executing retry # 1.
# Traceback (most recent call last):
#   File "/home/john/projects/appstore/appstore/infrastructure/web/asession.py", line 121, in _make_request
#     async with client.get(url, proxy=proxy, ssl=False) as response:
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/client.py", line 1141, in __aenter__
#     self._resp = await self._coro
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/client.py", line 536, in _request
#     conn = await self._connector.connect(
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/connector.py", line 540, in connect
#     proto = await self._create_connection(req, traces, timeout)
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/connector.py", line 899, in _create_connection
#     _, proto = await self._create_proxy_connection(req, traces, timeout)
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/connector.py", line 1288, in _create_proxy_connection
#     raise ClientHttpProxyError(
# aiohttp.client_exceptions.ClientHttpProxyError: 402, message='Payment Required', url=URL('http://obyluizw-rotate:te6ly5tnk9s3@p.webshare.io:80')
# [07/27/2023 04:54:18 AM] [ERROR] [ASessionHandler] [_make_request] : Exception type <class 'aiohttp.client_exceptions.ClientHttpProxyError'> occurred.
# 402, message='Payment Required', url=URL('http://obyluizw-rotate:te6ly5tnk9s3@p.webshare.io:80')
# Executing retry # 1.
# Traceback (most recent call last):
#   File "/home/john/projects/appstore/appstore/infrastructure/web/asession.py", line 121, in _make_request
#     async with client.get(url, proxy=proxy, ssl=False) as response:
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/client.py", line 1141, in __aenter__
#     self._resp = await self._coro
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/client.py", line 536, in _request
#     conn = await self._connector.connect(
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/connector.py", line 540, in connect
#     proto = await self._create_connection(req, traces, timeout)
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/connector.py", line 899, in _create_connection
#     _, proto = await self._create_proxy_connection(req, traces, timeout)
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/connector.py", line 1288, in _create_proxy_connection
#     raise ClientHttpProxyError(
# aiohttp.client_exceptions.ClientHttpProxyError: 402, message='Payment Required', url=URL('http://obyluizw-rotate:te6ly5tnk9s3@p.webshare.io:80')
# [07/27/2023 04:54:18 AM] [ERROR] [ASessionHandler] [_make_request] : Exception type <class 'aiohttp.client_exceptions.ClientHttpProxyError'> occurred.
# 402, message='Payment Required', url=URL('http://obyluizw-rotate:te6ly5tnk9s3@p.webshare.io:80')
# Executing retry # 1.
# Traceback (most recent call last):
#   File "/home/john/projects/appstore/appstore/infrastructure/web/asession.py", line 121, in _make_request
#     async with client.get(url, proxy=proxy, ssl=False) as response:
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/client.py", line 1141, in __aenter__
#     self._resp = await self._coro
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/client.py", line 536, in _request
#     conn = await self._connector.connect(
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/connector.py", line 540, in connect
#     proto = await self._create_connection(req, traces, timeout)
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/connector.py", line 899, in _create_connection
#     _, proto = await self._create_proxy_connection(req, traces, timeout)
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/connector.py", line 1288, in _create_proxy_connection
#     raise ClientHttpProxyError(
# aiohttp.client_exceptions.ClientHttpProxyError: 402, message='Payment Required', url=URL('http://obyluizw-rotate:te6ly5tnk9s3@p.webshare.io:80')
# [07/27/2023 04:54:18 AM] [ERROR] [ASessionHandler] [_make_request] : Exception type <class 'aiohttp.client_exceptions.ClientHttpProxyError'> occurred.
# 402, message='Payment Required', url=URL('http://obyluizw-rotate:te6ly5tnk9s3@p.webshare.io:80')
# Executing retry # 1.
# Traceback (most recent call last):
#   File "/home/john/projects/appstore/appstore/infrastructure/web/asession.py", line 121, in _make_request
#     async with client.get(url, proxy=proxy, ssl=False) as response:
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/client.py", line 1141, in __aenter__
#     self._resp = await self._coro
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/client.py", line 536, in _request
#     conn = await self._connector.connect(
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/connector.py", line 540, in connect
#     proto = await self._create_connection(req, traces, timeout)
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/connector.py", line 899, in _create_connection
#     _, proto = await self._create_proxy_connection(req, traces, timeout)
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/connector.py", line 1288, in _create_proxy_connection
#     raise ClientHttpProxyError(
# aiohttp.client_exceptions.ClientHttpProxyError: 402, message='Payment Required', url=URL('http://obyluizw-rotate:te6ly5tnk9s3@p.webshare.io:80')
# [07/27/2023 04:54:18 AM] [ERROR] [ASessionHandler] [_make_request] : Exception type <class 'aiohttp.client_exceptions.ClientHttpProxyError'> occurred.
# 402, message='Payment Required', url=URL('http://obyluizw-rotate:te6ly5tnk9s3@p.webshare.io:80')
# Executing retry # 1.
# Traceback (most recent call last):
#   File "/home/john/projects/appstore/appstore/infrastructure/web/asession.py", line 121, in _make_request
#     async with client.get(url, proxy=proxy, ssl=False) as response:
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/client.py", line 1141, in __aenter__
#     self._resp = await self._coro
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/client.py", line 536, in _request
#     conn = await self._connector.connect(
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/connector.py", line 540, in connect
#     proto = await self._create_connection(req, traces, timeout)
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/connector.py", line 899, in _create_connection
#     _, proto = await self._create_proxy_connection(req, traces, timeout)
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/connector.py", line 1288, in _create_proxy_connection
#     raise ClientHttpProxyError(
# aiohttp.client_exceptions.ClientHttpProxyError: 402, message='Payment Required', url=URL('http://obyluizw-rotate:te6ly5tnk9s3@p.webshare.io:80')
# [07/27/2023 04:54:21 AM] [ERROR] [ASessionHandler] [_make_request] : Exception type <class 'aiohttp.client_exceptions.ClientHttpProxyError'> occurred.
# 402, message='Payment Required', url=URL('http://obyluizw-rotate:te6ly5tnk9s3@p.webshare.io:80')
# Executing retry # 1.
# Traceback (most recent call last):
#   File "/home/john/projects/appstore/appstore/infrastructure/web/asession.py", line 121, in _make_request
#     async with client.get(url, proxy=proxy, ssl=False) as response:
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/client.py", line 1141, in __aenter__
#     self._resp = await self._coro
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/client.py", line 536, in _request
#     conn = await self._connector.connect(
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/connector.py", line 540, in connect
#     proto = await self._create_connection(req, traces, timeout)
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/connector.py", line 899, in _create_connection
#     _, proto = await self._create_proxy_connection(req, traces, timeout)
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/connector.py", line 1288, in _create_proxy_connection
#     raise ClientHttpProxyError(
# aiohttp.client_exceptions.ClientHttpProxyError: 402, message='Payment Required', url=URL('http://obyluizw-rotate:te6ly5tnk9s3@p.webshare.io:80')
# [07/27/2023 04:54:21 AM] [ERROR] [ASessionHandler] [_make_request] : Exception type <class 'aiohttp.client_exceptions.ClientHttpProxyError'> occurred.
# 402, message='Payment Required', url=URL('http://obyluizw-rotate:te6ly5tnk9s3@p.webshare.io:80')
# Executing retry # 1.
# Traceback (most recent call last):
#   File "/home/john/projects/appstore/appstore/infrastructure/web/asession.py", line 121, in _make_request
#     async with client.get(url, proxy=proxy, ssl=False) as response:
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/client.py", line 1141, in __aenter__
#     self._resp = await self._coro
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/client.py", line 536, in _request
#     conn = await self._connector.connect(
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/connector.py", line 540, in connect
#     proto = await self._create_connection(req, traces, timeout)
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/connector.py", line 899, in _create_connection
#     _, proto = await self._create_proxy_connection(req, traces, timeout)
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/connector.py", line 1288, in _create_proxy_connection
#     raise ClientHttpProxyError(
# aiohttp.client_exceptions.ClientHttpProxyError: 402, message='Payment Required', url=URL('http://obyluizw-rotate:te6ly5tnk9s3@p.webshare.io:80')
# [07/27/2023 04:54:21 AM] [ERROR] [ASessionHandler] [_make_request] : Exception type <class 'aiohttp.client_exceptions.ClientHttpProxyError'> occurred.
# 402, message='Payment Required', url=URL('http://obyluizw-rotate:te6ly5tnk9s3@p.webshare.io:80')
# Executing retry # 1.
# Traceback (most recent call last):
#   File "/home/john/projects/appstore/appstore/infrastructure/web/asession.py", line 121, in _make_request
#     async with client.get(url, proxy=proxy, ssl=False) as response:
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/client.py", line 1141, in __aenter__
#     self._resp = await self._coro
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/client.py", line 536, in _request
#     conn = await self._connector.connect(
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/connector.py", line 540, in connect
#     proto = await self._create_connection(req, traces, timeout)
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/connector.py", line 899, in _create_connection
#     _, proto = await self._create_proxy_connection(req, traces, timeout)
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/connector.py", line 1288, in _create_proxy_connection
#     raise ClientHttpProxyError(
# aiohttp.client_exceptions.ClientHttpProxyError: 402, message='Payment Required', url=URL('http://obyluizw-rotate:te6ly5tnk9s3@p.webshare.io:80')
# [07/27/2023 04:54:22 AM] [ERROR] [ASessionHandler] [_make_request] : Exception type <class 'aiohttp.client_exceptions.ClientHttpProxyError'> occurred.
# 402, message='Payment Required', url=URL('http://obyluizw-rotate:te6ly5tnk9s3@p.webshare.io:80')
# Executing retry # 1.
# Traceback (most recent call last):
#   File "/home/john/projects/appstore/appstore/infrastructure/web/asession.py", line 121, in _make_request
#     async with client.get(url, proxy=proxy, ssl=False) as response:
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/client.py", line 1141, in __aenter__
#     self._resp = await self._coro
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/client.py", line 536, in _request
#     conn = await self._connector.connect(
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/connector.py", line 540, in connect
#     proto = await self._create_connection(req, traces, timeout)
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/connector.py", line 899, in _create_connection
#     _, proto = await self._create_proxy_connection(req, traces, timeout)
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/connector.py", line 1288, in _create_proxy_connection
#     raise ClientHttpProxyError(
# aiohttp.client_exceptions.ClientHttpProxyError: 402, message='Payment Required', url=URL('http://obyluizw-rotate:te6ly5tnk9s3@p.webshare.io:80')
# [07/27/2023 04:54:30 AM] [ERROR] [ASessionHandler] [_make_request] : Exception type <class 'aiohttp.client_exceptions.ClientHttpProxyError'> occurred.
# 402, message='Payment Required', url=URL('http://obyluizw-rotate:te6ly5tnk9s3@p.webshare.io:80')
# Executing retry # 1.
# Traceback (most recent call last):
#   File "/home/john/projects/appstore/appstore/infrastructure/web/asession.py", line 121, in _make_request
#     async with client.get(url, proxy=proxy, ssl=False) as response:
# ...
# 402, message='Payment Required', url=URL('http://obyluizw-rotate:te6ly5tnk9s3@p.webshare.io:80')
# Executing retry # 2.
# Traceback (most recent call last):
#   File "/home/john/projects/appstore/appstore/infrastructure/web/asession.py", line 121, in _make_request
#     async with client.get(url, proxy=proxy, ssl=False) as response:
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/client.py", line 1141, in __aenter__
#     self._resp = await self._coro
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/client.py", line 536, in _request
#     conn = await self._connector.connect(
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/connector.py", line 540, in connect
#     proto = await self._create_connection(req, traces, timeout)
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/connector.py", line 899, in _create_connection
#     _, proto = await self._create_proxy_connection(req, traces, timeout)
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/connector.py", line 1288, in _create_proxy_connection
#     raise ClientHttpProxyError(
# aiohttp.client_exceptions.ClientHttpProxyError: 402, message='Payment Required', url=URL('http://obyluizw-rotate:te6ly5tnk9s3@p.webshare.io:80')
# [07/27/2023 04:55:01 AM] [ERROR] [ASessionHandler] [_make_request] : Exception type <class 'aiohttp.client_exceptions.ClientHttpProxyError'> occurred.
# 402, message='Payment Required', url=URL('http://obyluizw-rotate:te6ly5tnk9s3@p.webshare.io:80')
# Executing retry # 2.
# Traceback (most recent call last):
#   File "/home/john/projects/appstore/appstore/infrastructure/web/asession.py", line 121, in _make_request
#     async with client.get(url, proxy=proxy, ssl=False) as response:
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/client.py", line 1141, in __aenter__
#     self._resp = await self._coro
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/client.py", line 536, in _request
#     conn = await self._connector.connect(
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/connector.py", line 540, in connect
#     proto = await self._create_connection(req, traces, timeout)
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/connector.py", line 899, in _create_connection
#     _, proto = await self._create_proxy_connection(req, traces, timeout)
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/connector.py", line 1288, in _create_proxy_connection
#     raise ClientHttpProxyError(
# aiohttp.client_exceptions.ClientHttpProxyError: 402, message='Payment Required', url=URL('http://obyluizw-rotate:te6ly5tnk9s3@p.webshare.io:80')
# [07/27/2023 04:55:01 AM] [ERROR] [ASessionHandler] [_make_request] : Exception type <class 'aiohttp.client_exceptions.ClientHttpProxyError'> occurred.
# 402, message='Payment Required', url=URL('http://obyluizw-rotate:te6ly5tnk9s3@p.webshare.io:80')
# Executing retry # 2.
# Traceback (most recent call last):
#   File "/home/john/projects/appstore/appstore/infrastructure/web/asession.py", line 121, in _make_request
#     async with client.get(url, proxy=proxy, ssl=False) as response:
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/client.py", line 1141, in __aenter__
#     self._resp = await self._coro
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/client.py", line 536, in _request
#     conn = await self._connector.connect(
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/connector.py", line 540, in connect
#     proto = await self._create_connection(req, traces, timeout)
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/connector.py", line 899, in _create_connection
#     _, proto = await self._create_proxy_connection(req, traces, timeout)
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/connector.py", line 1288, in _create_proxy_connection
#     raise ClientHttpProxyError(
# aiohttp.client_exceptions.ClientHttpProxyError: 402, message='Payment Required', url=URL('http://obyluizw-rotate:te6ly5tnk9s3@p.webshare.io:80')
# [07/27/2023 04:55:01 AM] [ERROR] [ASessionHandler] [_make_request] : Exception type <class 'aiohttp.client_exceptions.ClientHttpProxyError'> occurred.
# 402, message='Payment Required', url=URL('http://obyluizw-rotate:te6ly5tnk9s3@p.webshare.io:80')
# Executing retry # 2.
# Traceback (most recent call last):
#   File "/home/john/projects/appstore/appstore/infrastructure/web/asession.py", line 121, in _make_request
#     async with client.get(url, proxy=proxy, ssl=False) as response:
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/client.py", line 1141, in __aenter__
#     self._resp = await self._coro
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/client.py", line 536, in _request
#     conn = await self._connector.connect(
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/connector.py", line 540, in connect
#     proto = await self._create_connection(req, traces, timeout)
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/connector.py", line 899, in _create_connection
#     _, proto = await self._create_proxy_connection(req, traces, timeout)
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/connector.py", line 1288, in _create_proxy_connection
#     raise ClientHttpProxyError(
# aiohttp.client_exceptions.ClientHttpProxyError: 402, message='Payment Required', url=URL('http://obyluizw-rotate:te6ly5tnk9s3@p.webshare.io:80')
# [07/27/2023 04:55:01 AM] [ERROR] [ASessionHandler] [_make_request] : Exception type <class 'aiohttp.client_exceptions.ClientHttpProxyError'> occurred.
# 402, message='Payment Required', url=URL('http://obyluizw-rotate:te6ly5tnk9s3@p.webshare.io:80')
# Executing retry # 2.
# Traceback (most recent call last):
#   File "/home/john/projects/appstore/appstore/infrastructure/web/asession.py", line 121, in _make_request
#     async with client.get(url, proxy=proxy, ssl=False) as response:
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/client.py", line 1141, in __aenter__
#     self._resp = await self._coro
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/client.py", line 536, in _request
#     conn = await self._connector.connect(
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/connector.py", line 540, in connect
#     proto = await self._create_connection(req, traces, timeout)
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/connector.py", line 899, in _create_connection
#     _, proto = await self._create_proxy_connection(req, traces, timeout)
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/connector.py", line 1288, in _create_proxy_connection
#     raise ClientHttpProxyError(
# aiohttp.client_exceptions.ClientHttpProxyError: 402, message='Payment Required', url=URL('http://obyluizw-rotate:te6ly5tnk9s3@p.webshare.io:80')
# [07/27/2023 04:55:01 AM] [ERROR] [ASessionHandler] [_make_request] : Exception type <class 'aiohttp.client_exceptions.ClientHttpProxyError'> occurred.
# 402, message='Payment Required', url=URL('http://obyluizw-rotate:te6ly5tnk9s3@p.webshare.io:80')
# Executing retry # 2.
# Traceback (most recent call last):
#   File "/home/john/projects/appstore/appstore/infrastructure/web/asession.py", line 121, in _make_request
#     async with client.get(url, proxy=proxy, ssl=False) as response:
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/client.py", line 1141, in __aenter__
#     self._resp = await self._coro
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/client.py", line 536, in _request
#     conn = await self._connector.connect(
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/connector.py", line 540, in connect
#     proto = await self._create_connection(req, traces, timeout)
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/connector.py", line 899, in _create_connection
#     _, proto = await self._create_proxy_connection(req, traces, timeout)
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/connector.py", line 1288, in _create_proxy_connection
#     raise ClientHttpProxyError(
# aiohttp.client_exceptions.ClientHttpProxyError: 402, message='Payment Required', url=URL('http://obyluizw-rotate:te6ly5tnk9s3@p.webshare.io:80')
# [07/27/2023 04:55:01 AM] [ERROR] [ASessionHandler] [_make_request] : Exception type <class 'aiohttp.client_exceptions.ClientHttpProxyError'> occurred.
# 402, message='Payment Required', url=URL('http://obyluizw-rotate:te6ly5tnk9s3@p.webshare.io:80')
# Executing retry # 2.
# Traceback (most recent call last):
#   File "/home/john/projects/appstore/appstore/infrastructure/web/asession.py", line 121, in _make_request
#     async with client.get(url, proxy=proxy, ssl=False) as response:
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/client.py", line 1141, in __aenter__
#     self._resp = await self._coro
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/client.py", line 536, in _request
#     conn = await self._connector.connect(
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/connector.py", line 540, in connect
#     proto = await self._create_connection(req, traces, timeout)
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/connector.py", line 899, in _create_connection
#     _, proto = await self._create_proxy_connection(req, traces, timeout)
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/connector.py", line 1288, in _create_proxy_connection
#     raise ClientHttpProxyError(
# aiohttp.client_exceptions.ClientHttpProxyError: 402, message='Payment Required', url=URL('http://obyluizw-rotate:te6ly5tnk9s3@p.webshare.io:80')
# [07/27/2023 04:55:01 AM] [ERROR] [ASessionHandler] [_make_request] : Exception type <class 'aiohttp.client_exceptions.ClientHttpProxyError'> occurred.
# 402, message='Payment Required', url=URL('http://obyluizw-rotate:te6ly5tnk9s3@p.webshare.io:80')
# Executing retry # 2.
# Traceback (most recent call last):
#   File "/home/john/projects/appstore/appstore/infrastructure/web/asession.py", line 121, in _make_request
#     async with client.get(url, proxy=proxy, ssl=False) as response:
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/client.py", line 1141, in __aenter__
#     self._resp = await self._coro
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/client.py", line 536, in _request
#     conn = await self._connector.connect(
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/connector.py", line 540, in connect
#     proto = await self._create_connection(req, traces, timeout)
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/connector.py", line 899, in _create_connection
#     _, proto = await self._create_proxy_connection(req, traces, timeout)
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/connector.py", line 1288, in _create_proxy_connection
#     raise ClientHttpProxyError(
# aiohttp.client_exceptions.ClientHttpProxyError: 402, message='Payment Required', url=URL('http://obyluizw-rotate:te6ly5tnk9s3@p.webshare.io:80')
# [07/27/2023 04:55:01 AM] [ERROR] [ASessionHandler] [_make_request] : Exception type <class 'aiohttp.client_exceptions.ClientHttpProxyError'> occurred.
# 402, message='Payment Required', url=URL('http://obyluizw-rotate:te6ly5tnk9s3@p.webshare.io:80')
# Executing retry # 2.
# Traceback (most recent call last):
#   File "/home/john/projects/appstore/appstore/infrastructure/web/asession.py", line 121, in _make_request
#     async with client.get(url, proxy=proxy, ssl=False) as response:
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/client.py", line 1141, in __aenter__
#     self._resp = await self._coro
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/client.py", line 536, in _request
#     conn = await self._connector.connect(
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/connector.py", line 540, in connect
#     proto = await self._create_connection(req, traces, timeout)
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/connector.py", line 899, in _create_connection
#     _, proto = await self._create_proxy_connection(req, traces, timeout)
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/connector.py", line 1288, in _create_proxy_connection
#     raise ClientHttpProxyError(
# aiohttp.client_exceptions.ClientHttpProxyError: 402, message='Payment Required', url=URL('http://obyluizw-rotate:te6ly5tnk9s3@p.webshare.io:80')
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/projects/appstore/appstore/data/acquisition/rating/scraper.py:126, in RatingScraper._parse_responses(self, responses)
#     125 try:
# --> 126     result["id"] = response["adamId"]
#     127     result["name"] = [app["name"] for app in apps if app["id"] == response["adamId"]][0]
#
# TypeError: 'NoneType' object is not subscriptable
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 14
#      11 async def main():
#      12     await asyncio.gather(wire(), scrape())
# ---> 14 await main()
#
# Cell In[3], line 12, in main()
#      11 async def main():
# ---> 12     await asyncio.gather(wire(), scrape())
#
# Cell In[3], line 8, in scrape()
#       6 async def scrape():
#       7     ctrl = RatingController()
# ----> 8     await ctrl.scrape(category_ids=CATEGORIES)
#       9     ctrl.archive()
#
# File ~/projects/appstore/appstore/data/acquisition/rating/controller.py:80, in RatingController.scrape(self, category_ids)
#      74 """Scrapes app data matching the search term from the target URL.
#      75
#      76 Args:
#      77     category_ids (str): Category id or a list of category ids from AppStoreCategories
#      78 """
#      79 if super().scrape():
# ---> 80     await self._scrape(category_ids=category_ids)
#      81 else:
#      82     msg = f"Running {self.__class__.__name__} is not authorized at this time."
#
# File ~/projects/appstore/appstore/data/acquisition/rating/controller.py:100, in RatingController._scrape(self, category_ids)
#      98 apps = self._get_apps(category_id=category_id)
#      99 # Iterate over list of apps, returning a dictionary for each app in the category
# --> 100 async for result in self._scraper(apps=apps, batch_size=self._batchsize):
#     101     if not result:
#     102         break
#
# File ~/projects/appstore/appstore/data/acquisition/rating/scraper.py:86, in RatingScraper.__anext__(self)
#      80     return False
#      82 responses = await self._session.get(
#      83     urls=self._batches[self._batch]["urls"], headers=self._header
#      84 )
# ---> 86 result = self._parse_responses(responses=responses)
#      87 self._batch += 1
#      88 return result
#
# File ~/projects/appstore/appstore/data/acquisition/rating/scraper.py:147, in RatingScraper._parse_responses(self, responses)
#     144     results.append(result)
#     146 except Exception as e:
# --> 147     result["id"] = response["adamId"]
#     148     result["name"] = [app["name"] for app in apps if app["id"] == response["adamId"]][0]
#     149     result["category_id"] = [
#     150         app["category_id"] for app in apps if app["id"] == response["adamId"]
#     151     ][0]
#
# TypeError: 'NoneType' object is not subscriptable
