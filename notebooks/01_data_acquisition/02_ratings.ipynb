# %% [markdown]
# # AppStore Ratings
# App Store apps are rated on a five-star scale. In this section, we extract the number of ratings on each of the five-points of the scale, as well as the total ratings and reviews.
#
# The AppStore Review entity is defined as follows.
#
# | #  | name        | description                                    | api_field            |
# |----|-------------|------------------------------------------------|----------------------|
# | 1  | id          | Unique app identifier                          | adamId               |
# | 2  | name        | App name                                       | name                 |
# | 3  | category_id | Four digit IOS category identifier             | categoryId           |
# | 4  | category    | The category in text                           | category             |
# | 5  | rating      | Average rating                                 | ratingAverage        |
# | 6  | reviews     | The total number of reviews                    | totalNumberOfReviews |
# | 7  | ratings     | The total number of ratings                    | ratingCount          |
# | 8  | onestar     | The count of one star ratings                  | ratingCountList      |
# | 9  | twostar     | The count of two star ratings                  | ratingCountList      |
# | 10 | threestar   | The count of three star ratings                | ratingCountList      |
# | 11 | fourstar    | The count of four star ratings                 | ratingCountList      |
# | 12 | fivestar    | The count of five star ratings                 | ratingCountList      |
# | 13 | source      | The base url from which the data were obtained | itunes.apple.com     |
#
# Ratings will be extracted by category of apps in the appdata repository. Concretely, ratings will be obtained for the following categories:
#
# | ID   | NAME                |
# |------|---------------------|
# | 6000 |  BUSINESS           |
# | 6002 |  UTILITIES          |
# | 6005 |  SOCIAL_NETWORKING  |
# | 6007 |  PRODUCTIVITY       |
# | 6012 |  LIFESTYLE          |
# | 6013 |  HEALTH_AND_FITNESS |
# | 6015 |  FINANCE            |
# | 6016 |  ENTERTAINMENT      |
# | 6017 |  EDUCATION          |
# | 6020 |  MEDICAL            |
# | 6023 |  FOOD_AND_DRINK     |
# | 6024 |  SHOPPING           |

# %% [markdown]
# **Imports**

# %%
import asyncio
from appstore.data.acquisition.rating.controller import RatingController
from appstore.data.acquisition import AppStoreTargetCategories
from appstore.container import AppstoreContainer

# %%
CATEGORIES = [
        # 6016,
        # "6015",
        # "6023",
        # "6013",
        # "6012",
        # "6020",        
        "6008",
        "6007",
        "6006",
        "6024",
        "6005",
        "6003",
        "6002",
    ]

# %% [markdown]
# ## AppStore Ratings
# RatingController iterates through the categories, extracting the apps from the repository and retrieves the rating data from the App Store. The results are persisted in the RatingRepo.

# %%
async def wire():
    container = AppstoreContainer()
    container.init_resources()
    container.wire(packages=["appstore.data.acquisition"])

async def scrape():
    ctrl = RatingController()
    await ctrl.scrape(category_ids=CATEGORIES)    
    ctrl.archive()

async def main():
    await asyncio.gather(wire(), scrape())

await main()
# Out:
# [07/29/2023 12:48:36 PM] [ERROR] [MySQLDatabase] [connect] : Database is not started. Starting database...
# [sudo] password for john:
# Starting MySQL...
#  * Starting MySQL database server mysqld
# su: warning: cannot change directory to /nonexistent: No such file or directory
#    ...done.
# [07/29/2023 12:48:46 PM] [INFO] [RatingController] [_get_apps] :
#
# A total of 18958 apps in category 6008 to process.
# There are 0 apps in category 6008 which have already been processed.
# [07/29/2023 12:51:01 PM] [INFO] [RatingController] [_announce] :
#
# RatingController
# 	                       Category: | 6008-PHOTO_AND_VIDEO
# 	                 Total Requests: | 1000
# 	            Successful Requests: | 139
# 	                Failed Requests: | 861
# 	                           Apps: | 139
# 	                        Elapsed: | 0:02:19.930092
# 	                Apps Per Second: | 0.99
#
# [07/29/2023 12:53:06 PM] [INFO] [RatingController] [_announce] :
#
# RatingController
# 	                       Category: | 6008-PHOTO_AND_VIDEO
# 	                 Total Requests: | 2000
# 	            Successful Requests: | 295
# 	                Failed Requests: | 1705
# 	                           Apps: | 295
# 	                        Elapsed: | 0:04:24.092871
# 	                Apps Per Second: | 1.12
#
# [07/29/2023 12:55:25 PM] [ERROR] [ASessionHandler] [_make_request] : Exception type <class 'asyncio.exceptions.TimeoutError'> occurred.
#
# Executing retry # 1.
# Traceback (most recent call last):
#   File "/home/john/projects/appstore/appstore/infrastructure/web/asession.py", line 121, in _make_request
#     async with client.get(url, proxy=proxy, ssl=False) as response:
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/client.py", line 1141, in __aenter__
#     self._resp = await self._coro
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/client.py", line 560, in _request
#     await resp.start(conn)
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/client_reqrep.py", line 894, in start
#     with self._timer:
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/helpers.py", line 720, in __exit__
#     raise asyncio.TimeoutError from None
# asyncio.exceptions.TimeoutError
# [07/29/2023 12:55:25 PM] [ERROR] [ASessionHandler] [_make_request] : Exception type <class 'asyncio.exceptions.TimeoutError'> occurred.
#
# Executing retry # 1.
# Traceback (most recent call last):
#   File "/home/john/projects/appstore/appstore/infrastructure/web/asession.py", line 121, in _make_request
#     async with client.get(url, proxy=proxy, ssl=False) as response:
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/client.py", line 1141, in __aenter__
#     self._resp = await self._coro
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/client.py", line 560, in _request
#     await resp.start(conn)
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/client_reqrep.py", line 894, in start
#     with self._timer:
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/helpers.py", line 720, in __exit__
#     raise asyncio.TimeoutError from None
# asyncio.exceptions.TimeoutError
# [07/29/2023 12:55:35 PM] [INFO] [RatingController] [_announce] :
#
# RatingController
# 	                       Category: | 6008-PHOTO_AND_VIDEO
# 	                 Total Requests: | 3000
# 	            Successful Requests: | 400
# 	                Failed Requests: | 2600
# 	                           Apps: | 400
# 	                        Elapsed: | 0:06:53.802124
# 	                Apps Per Second: | 0.97
#
# [07/29/2023 12:57:44 PM] [INFO] [RatingController] [_announce] :
#
# RatingController
# 	                       Category: | 6008-PHOTO_AND_VIDEO
# 	                 Total Requests: | 4000
# 	            Successful Requests: | 513
# 	                Failed Requests: | 3487
# 	                           Apps: | 513
# 	                        Elapsed: | 0:09:02.239908
# 	                Apps Per Second: | 0.95
#
# [07/29/2023 12:59:55 PM] [INFO] [RatingController] [_announce] :
#
# RatingController
# 	                       Category: | 6008-PHOTO_AND_VIDEO
# 	                 Total Requests: | 5000
# 	            Successful Requests: | 1369
# 	                Failed Requests: | 3631
# 	                           Apps: | 1369
# 	                        Elapsed: | 0:11:13.933868
# 	                Apps Per Second: | 2.03
#
# [07/29/2023 01:00:09 PM] [ERROR] [MySQLDatabase] [insert] : Exception occurred during database insert.
# Exception type:type[sqlalchemy.exc.SQLAlchemyError]
# (pymysql.err.DataError) (1406, "Data too long for column 'name' at row 78")
# [SQL: INSERT INTO rating (id, name, category_id, category, rating, reviews, ratings, onestar, twostar, threestar, fourstar, fivestar, status) VALUES (%(id)s, %(name)s, %(category_id)s, %(category)s, %(rating)s, %(reviews)s, %(ratings)s, %(onestar)s, %(twostar)s, %(threestar)s, %(fourstar)s, %(fivestar)s, %(status)s)]
# [parameters: [{'id': '1449454764', 'name': 'fixtouch - retouch & makeup', 'category_id': '6008', 'category': 'Photo & Video', 'rating': 4.0, 'reviews': 77, 'ratings': 3983, 'onestar': 566, 'twostar': 117, 'threestar': 184, 'fourstar': 287, 'fivestar': 2829, 'status': True}, {'id': '827780098', 'name': 'GoSexy - Face and Body Editor', 'category_id': '6008', 'category': 'Photo & Video', 'rating': 4.0, 'reviews': 1795, 'ratings': 1707, 'onestar': 277, 'twostar': 50, 'threestar': 76, 'fourstar': 150, 'fivestar': 1154, 'status': True}, {'id': '1050488345', 'name': 'Agora: The Worldwide Awards', 'category_id': '6008', 'category': 'Photo & Video', 'rating': 4.5, 'reviews': 153, 'ratings': 8141, 'onestar': 223, 'twostar': 129, 'threestar': 418, 'fourstar': 810, 'fivestar': 6561, 'status': True}, {'id': '1463329769', 'name': 'American Football Wallpaper 4K', 'category_id': '6008', 'category': 'Photo & Video', 'rating': 4.5, 'reviews': 80, 'ratings': 8605, 'onestar': 168, 'twostar': 122, 'threestar': 293, 'fourstar': 703, 'fivestar': 7319, 'status': True}, {'id': '1515299503', 'name': 'Loop Videos & GIF Maker', 'category_id': '6008', 'category': 'Photo & Video', 'rating': 4.5, 'reviews': 981, 'ratings': 2814, 'onestar': 161, 'twostar': 22, 'threestar': 67, 'fourstar': 120, 'fivestar': 2444, 'status': True}, {'id': '1479255922', 'name': 'Pro Camera .', 'category_id': '6008', 'category': 'Photo & Video', 'rating': 4.5, 'reviews':
 'category_id': '6008', 'category': 'Photo & Video', 'rating': 5.0, 'reviews': 0, 'ratings': 16, 'onestar': 0, 'twostar': 0, 'threestar': 0, 'fourstar': 1, 'fivestar': 15, 'status': True}, {'id': '1308129128', 'name': 'Perfect Body Slimmer', 'category_id': '6008', 'category': 'Photo & Video', 'rating': 2.5, 'reviews': 0, 'ratings': 6, 'onestar': 3, 'twostar': 1, 'threestar': 0, 'fourstar': 1, 'fivestar': 1, 'status': True}, {'id': '1282778516', 'name': 'Color Pop effects splash blur', 'category_id': '6008', 'category': 'Photo & Video', 'rating': 4.0, 'reviews': 0, 'ratings': 34, 'onestar': 4, 'twostar': 1, 'threestar': 4, 'fourstar': 4, 'fivestar': 21, 'status': True}, {'id': '1067906328', 'name': 'Water Reflection', 'category_id': '6008', 'category': 'Photo & Video', 'rating': 4.0, 'reviews': 0, 'ratings': 5, 'onestar': 1, 'twostar': 0, 'threestar': 0, 'fourstar': 1, 'fivestar': 3, 'status': True}, {'id': '997286193', 'name': 'Calendar Photo Frames', 'category_id': '6008', 'category': 'Photo & Video', 'rating': 0.0, 'reviews': 0, 'ratings': 0, 'onestar': 0, 'twostar': 0, 'threestar': 0, 'fourstar': 0, 'fivestar': 0, 'status': False}  ... displaying 10 of 100 total bound parameter sets ...  {'id': '675626559', 'name': 'Film Rolls – App for Film Photographers', 'category_id': '6008', 'category': 'Photo & Video', 'rating': 4.0, 'reviews': 24, 'ratings': 30, 'onestar': 1, 'twostar': 4, 'threestar': 3, 'fourstar': 5, 'fivestar': 17, 'status': True}, {'id': '925656158', 'name': 'كاميرا كرتون جديد', 'category_id': '6008', 'category': 'Photo & Video', 'rating': 0.0, 'reviews': 0, 'ratings': 0, 'onestar': 0, 'twostar': 0, 'threestar': 0, 'fourstar': 0, 'fivestar': 0, 'status': False}]]
# (Background on this error at: https://sqlalche.me/e/20/9h9h)
# [07/29/2023 01:13:18 PM] [INFO] [RatingController] [_announce] :
#
# RatingController
# 	                       Category: | 6008-PHOTO_AND_VIDEO
# 	                 Total Requests: | 11000
# 	            Successful Requests: | 6351
# 	                Failed Requests: | 4649
# 	                           Apps: | 6351
# 	                        Elapsed: | 0:24:36.459561
# 	                Apps Per Second: | 4.3
#
# [07/29/2023 01:14:38 PM] [ERROR] [ASessionHandler] [_make_request] : Exception type <class 'asyncio.exceptions.TimeoutError'> occurred.
#
# Executing retry # 1.
# Traceback (most recent call last):
#   File "/home/john/projects/appstore/appstore/infrastructure/web/asession.py", line 121, in _make_request
#     async with client.get(url, proxy=proxy, ssl=False) as response:
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/client.py", line 1141, in __aenter__
#     self._resp = await self._coro
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/client.py", line 560, in _request
#     await resp.start(conn)
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/client_reqrep.py", line 894, in start
#     with self._timer:
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/helpers.py", line 720, in __exit__
#     raise asyncio.TimeoutError from None
# asyncio.exceptions.TimeoutError
# [07/29/2023 01:16:02 PM] [INFO] [RatingController] [_announce] :
#
# RatingController
# 	                       Category: | 6008-PHOTO_AND_VIDEO
# 	                 Total Requests: | 12000
# 	            Successful Requests: | 6988
# 	                Failed Requests: | 5012
# 	                           Apps: | 6988
# 	                        Elapsed: | 0:27:20.642536
# 	                Apps Per Second: | 4.26
#
# [07/29/2023 01:16:55 PM] [ERROR] [MySQLDatabase] [insert] : Exception occurred during database insert.
# Exception type:type[sqlalchemy.exc.SQLAlchemyError]
# (pymysql.err.DataError) (1406, "Data too long for column 'name' at row 55")
# [SQL: INSERT INTO rating (id, name, category_id, category, rating, reviews, ratings, onestar, twostar, threestar, fourstar, fivestar, status) VALUES (%(id)s, %(name)s, %(category_id)s, %(category)s, %(rating)s, %(reviews)s, %(ratings)s, %(onestar)s, %(twostar)s, %(threestar)s, %(fourstar)s, %(fivestar)s, %(status)s)]
# [parameters: [{'id': '1272652699', 'name': 'OLDV - Retro Video with BGMs', 'category_id': '6008', 'category': 'Photo & Video', 'rating': 4.0, 'reviews': 10, 'ratings': 30, 'onestar': 4, 'twostar': 2, 'threestar': 2, 'fourstar': 6, 'fivestar': 16, 'status': True}, {'id': '1161697805', 'name': 'Christmas Card Maker – Xmas Greeting Cards', 'category_id': '6008', 'category': 'Photo & Video', 'rating': 4.0, 'reviews': 2, 'ratings': 10, 'onestar': 2, 'twostar': 0, 'threestar': 0, 'fourstar': 0, 'fivestar': 8, 'status': True}, {'id': '1222248673', 'name': 'VPai Home', 'category_id': '6008', 'category': 'Photo & Video', 'rating': 2.0, 'reviews': 17, 'ratings': 25, 'onestar': 14, 'twostar': 6, 'threestar': 0, 'fourstar': 0, 'fivestar': 5, 'status': True}, {'id': '1468450258', 'name': 'Artify', 'category_id': '6008', 'category': 'Photo & Video', 'rating': 4.5, 'reviews': 4, 'ratings': 12, 'onestar': 0, 'twostar': 2, 'threestar': 1, 'fourstar': 0, 'fivestar': 9, 'status': True}, {'id': '1634977744', 'name': 'INCH CAM - vintage film camera', 'category_id': '6008', 'category': 'Photo & Video', 'rating': 5.0, 'reviews': 9, 'ratings': 36, 'onestar': 0, 'twostar': 0, 'threestar': 0, 'fourstar': 2, 'fivestar': 34, 'status': True}, {'id': '1190966631', 'name': 'خلفيات سيارات - Mercedes', 'category_id': '6008', 'category': 'Photo & Video', 'rating': 0.0, 'reviews': 0, 'ratings': 0, 'onestar': 0, 'twostar': 0, 'threestar': 0, 'fourstar': 0, 'fivestar': 0, 'status': False}, {'id': '
 'category_id': '6008', 'category': 'Photo & Video', 'rating': 4.5, 'reviews': 0, 'ratings': 20, 'onestar': 2, 'twostar': 0, 'threestar': 0, 'fourstar': 1, 'fivestar': 17, 'status': True}, {'id': '1442483707', 'name': 'Perfect Visage - Face Makeup', 'category_id': '6008', 'category': 'Photo & Video', 'rating': 4.5, 'reviews': 2, 'ratings': 18, 'onestar': 1, 'twostar': 0, 'threestar': 1, 'fourstar': 6, 'fivestar': 10, 'status': True}]]
# (Background on this error at: https://sqlalche.me/e/20/9h9h)
# [07/29/2023 01:18:10 PM] [INFO] [RatingController] [_announce] :
#
# RatingController
# 	                       Category: | 6008-PHOTO_AND_VIDEO
# 	                 Total Requests: | 13000
# 	            Successful Requests: | 7546
# 	                Failed Requests: | 5454
# 	                           Apps: | 7546
# 	                        Elapsed: | 0:29:28.332403
# 	                Apps Per Second: | 4.27
#
# [07/29/2023 01:19:33 PM] [ERROR] [MySQLDatabase] [insert] : Exception occurred during database insert.
# Exception type:type[sqlalchemy.exc.SQLAlchemyError]
# (pymysql.err.DataError) (1406, "Data too long for column 'name' at row 98")
# [SQL: INSERT INTO rating (id, name, category_id, category, rating, reviews, ratings, onestar, twostar, threestar, fourstar, fivestar, status) VALUES (%(id)s, %(name)s, %(category_id)s, %(category)s, %(rating)s, %(reviews)s, %(ratings)s, %(onestar)s, %(twostar)s, %(threestar)s, %(fourstar)s, %(fivestar)s, %(status)s)]
# [parameters: [{'id': '1016248999', 'name': 'Shutter Stop - Fireworks Long Exposure And Slow Shutter Camera', 'category_id': '6008', 'category': 'Photo & Video', 'rating': 3.5, 'reviews': 17, 'ratings': 15, 'onestar': 5, 'twostar': 0, 'threestar': 0, 'fourstar': 0, 'fivestar': 10, 'status': True}, {'id': '1033292207', 'name': 'تعليقات حزينة وحكيمة للفيس بوك', 'category_id': '6008', 'category': 'Photo & Video', 'rating': 0.0, 'reviews': 0, 'ratings': 0, 'onestar': 0, 'twostar': 0, 'threestar': 0, 'fourstar': 0, 'fivestar': 0, 'status': False}, {'id': '6444903856', 'name': 'Scopio', 'category_id': '6008', 'category': 'Photo & Video', 'rating': 4.0, 'reviews': 12, 'ratings': 18, 'onestar': 3, 'twostar': 0, 'threestar': 1, 'fourstar': 0, 'fivestar': 14, 'status': True}, {'id': '1079845014', 'name': 'Color Effects Maker - Change image colors by just touch gestures!', 'category_id': '6008', 'category': 'Photo & Video', 'rating': 0.0, 'reviews': 0, 'ratings': 0, 'onestar': 0, 'twostar': 0, 'threestar': 0, 'fourstar': 0, 'fivestar': 0, 'status': False}, {'id': '1109351019', 'name': 'TrimVid -Video Trimer & Editor', 'category_id': '6008', 'category': 'Photo & Video', 'rating': 0.0, 'reviews': 0, 'ratings': 0, 'onestar': 0, 'twostar': 0, 'threestar': 0, 'fourstar': 0, 'fivestar': 0, 'status': False}, {'id': '1583923453', 'name': 'XiL MAX', 'category_id': '6008', 'category': 'Photo & Video', 'rating': 0.0, 'reviews': 0, 'ratings': 0, 'onestar': 0, 'twostar': 0, 'threestar': 0, 'fourstar': 0, 'fivestar': 0, 'status': False}, {'id': '789614903', 'name': 'レター', 'category_id': '6008', 'category': 'Photo & Video', 'rating': 5.0, 'reviews': 0, 'ratings': 40, 'onestar': 0, 'twostar': 0, 'threestar': 0, 'fourstar': 2, 'fivestar': 38, 'status': True}, {'id': '1434241963', 'name': 'Photo montage quick', 'category_id': '6008', 'category': 'Photo & Video', 'rating': 0.0, 'reviews': 0, 'ratings': 0, 'onestar': 0, 'twostar': 0, 'threestar': 0, 'fourstar': 0, 'fivestar': 0, 'status': False}  ... displaying 10 of 100 total bound parameter sets ...  {'id': '1482588934', 'name': '唯美视频制作器-短视频vlog制作软件', 'category_id': '6008', 'category': 'Photo & Video', 'rating': 5.0, 'reviews': 1, 'ratings': 46, 'onestar': 0, 'twostar': 0, 'threestar': 2, 'fourstar': 2, 'fivestar': 42, 'status': True}, {'id': '1434787464', 'name': 'Beat Sync Maker', 'category_id': '6008', 'category': 'Photo & Video', 'rating': 0.0, 'reviews': 0, 'ratings': 0, 'onestar': 0, 'twostar': 0, 'threestar': 0, 'fourstar': 0, 'fivestar': 0, 'status': False}]]
# (Background on this error at: https://sqlalche.me/e/20/9h9h)
# [07/29/2023 01:20:21 PM] [INFO] [RatingController] [_announce] :
#
# RatingController
# 	                       Category: | 6008-PHOTO_AND_VIDEO
# 	                 Total Requests: | 14000
# 	            Successful Requests: | 8031
# 	                Failed Requests: | 5969
# 	                           Apps: | 8031
# 	                        Elapsed: | 0:31:39.941208
# 	                Apps Per Second: | 4.23
#
# [07/29/2023 01:22:24 PM] [INFO] [RatingController] [_announce] :
#
# RatingController
# 	                       Category: | 6008-PHOTO_AND_VIDEO
# 	                 Total Requests: | 15000
# 	            Successful Requests: | 8410
# 	                Failed Requests: | 6590
# 	                           Apps: | 8410
# 	                        Elapsed: | 0:33:42.833612
# 	                Apps Per Second: | 4.16
#
# [07/29/2023 01:24:27 PM] [INFO] [RatingController] [_announce] :
#
# RatingController
# 	                       Category: | 6008-PHOTO_AND_VIDEO
# 	                 Total Requests: | 16000
# 	            Successful Requests: | 8738
# 	                Failed Requests: | 7262
# 	                           Apps: | 8738
# 	                        Elapsed: | 0:35:45.456252
# 	                Apps Per Second: | 4.07
#
# [07/29/2023 01:25:38 PM] [ERROR] [MySQLDatabase] [insert] : Exception occurred during database insert.
# Exception type:type[sqlalchemy.exc.SQLAlchemyError]
# (pymysql.err.DataError) (1406, "Data too long for column 'name' at row 95")
# [SQL: INSERT INTO rating (id, name, category_id, category, rating, reviews, ratings, onestar, twostar, threestar, fourstar, fivestar, status) VALUES (%(id)s, %(name)s, %(category_id)s, %(category)s, %(rating)s, %(reviews)s, %(ratings)s, %(onestar)s, %(twostar)s, %(threestar)s, %(fourstar)s, %(fivestar)s, %(status)s)]
# [parameters: [{'id': '1320820284', 'name': 'Write  draw & paint on pics', 'category_id': '6008', 'category': 'Photo & Video', 'rating': 0.0, 'reviews': 0, 'ratings': 0, 'onestar': 0, 'twostar': 0, 'threestar': 0, 'fourstar': 0, 'fivestar': 0, 'status': False}, {'id': '1442356973', 'name': 'Kite Flight - Inmate Postcards', 'category_id': '6008', 'category': 'Photo & Video', 'rating': 3.0, 'reviews': 7, 'ratings': 12, 'onestar': 6, 'twostar': 1, 'threestar': 0, 'fourstar': 0, 'fivestar': 5, 'status': True}, {'id': '499118448', 'name': 'HLS Multitrack Player', 'category_id': '6008', 'category': 'Photo & Video', 'rating': 0.0, 'reviews': 0, 'ratings': 0, 'onestar': 0, 'twostar': 0, 'threestar': 0, 'fourstar': 0, 'fivestar': 0, 'status': False}, {'id': '1412389042', 'name': 'Landscape - Effects Filter', 'category_id': '6008', 'category': 'Photo & Video', 'rating': 0.0, 'reviews': 0, 'ratings': 0, 'onestar': 0, 'twostar': 0, 'threestar': 0, 'fourstar': 0, 'fivestar': 0, 'status': False}, {'id': '1217699848', 'name': 'Bridesmaid Photo Montage', 'category_id': '6008', 'category': 'Photo & Video', 'rating': 0.0, 'reviews': 0, 'ratings': 0, 'onestar': 0, 'twostar': 0, 'threestar': 0, 'fourstar': 0, 'fivestar': 0, 'status': False}, {'id': '1623038099', 'name': 'Square Fit - No Crop Photo App', 'category_id': '6008', 'category': 'Photo & Video', 'rating': 0.0, 'reviews': 0, 'ratings': 0, 'onestar': 0, 'twostar': 0, 'threestar': 0, 'fourstar': 0, 'fivestar': 0, 'status': False}, {'id': '1611325746', 'name': 'Flowers Photo Frames & Editor', 'category_id': '6008', 'category': 'Photo & Video', 'rating': 4.5, 'reviews': 1, 'ratings': 8, 'onestar': 1, 'twostar': 0, 'threestar': 1, 'fourstar': 0, 'fivestar': 6, 'status': True}, {'id': '1078347860', 'name': 'Fish Color Stickers', 'category_id': '6008', 'category': 'Photo & Video', 'rating': 0.0, 'reviews': 0, 'ratings': 0, 'onestar': 0, 'twostar': 0, 'threestar': 0, 'fourstar': 0, 'fivestar': 0, 'status': False}  ... displaying 10 of 100 total bound parameter sets ...  {'id': '1465852159', 'name': 'Emerald Eyes', 'category_id': '6008', 'category': 'Photo & Video', 'rating': 0.0, 'reviews': 0, 'ratings': 0, 'onestar': 0, 'twostar': 0, 'threestar': 0, 'fourstar': 0, 'fivestar': 0, 'status': False}, {'id': '1624506569', 'name': 'Video Maker – Photos and Music', 'category_id': '6008', 'category': 'Photo & Video', 'rating': 0.0, 'reviews': 0, 'ratings': 0, 'onestar': 0, 'twostar': 0, 'threestar': 0, 'fourstar': 0, 'fivestar': 0, 'status': False}]]
# (Background on this error at: https://sqlalche.me/e/20/9h9h)
# [07/29/2023 01:26:50 PM] [INFO] [RatingController] [_announce] :
#
# RatingController
# 	                       Category: | 6008-PHOTO_AND_VIDEO
# 	                 Total Requests: | 17000
# 	            Successful Requests: | 8998
# 	                Failed Requests: | 8002
# 	                           Apps: | 8998
# 	                        Elapsed: | 0:38:08.315974
# 	                Apps Per Second: | 3.93
#
# [07/29/2023 01:28:24 PM] [ERROR] [ASessionHandler] [_make_request] : Exception type <class 'asyncio.exceptions.TimeoutError'> occurred.
#
# Executing retry # 1.
# Traceback (most recent call last):
#   File "/home/john/projects/appstore/appstore/infrastructure/web/asession.py", line 121, in _make_request
#     async with client.get(url, proxy=proxy, ssl=False) as response:
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/client.py", line 1141, in __aenter__
#     self._resp = await self._coro
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/client.py", line 560, in _request
#     await resp.start(conn)
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/client_reqrep.py", line 894, in start
#     with self._timer:
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/aiohttp/helpers.py", line 720, in __exit__
#     raise asyncio.TimeoutError from None
# asyncio.exceptions.TimeoutError
# [07/29/2023 01:29:16 PM] [INFO] [RatingController] [_announce] :
#
# RatingController
# 	                       Category: | 6008-PHOTO_AND_VIDEO
# 	                 Total Requests: | 18000
# 	            Successful Requests: | 9378
# 	                Failed Requests: | 8622
# 	                           Apps: | 9378
# 	                        Elapsed: | 0:40:34.531925
# 	                Apps Per Second: | 3.85
#
# [07/29/2023 01:31:11 PM] [INFO] [RatingController] [_get_apps] :
#
# A total of 12707 apps in category 6007 to process.
# There are 0 apps in category 6007 which have already been processed.
# [07/29/2023 01:31:24 PM] [INFO] [RatingController] [_announce] :
#
# RatingController
# 	                       Category: | 6007-PRODUCTIVITY
# 	                 Total Requests: | 19000
# 	            Successful Requests: | 10301
# 	                Failed Requests: | 8699
# 	                           Apps: | 10301
# 	                        Elapsed: | 0:42:42.252440
# 	                Apps Per Second: | 4.02
#
# [07/29/2023 01:33:38 PM] [INFO] [RatingController] [_announce] :
#
# RatingController
# 	                       Category: | 6007-PRODUCTIVITY
# 	                 Total Requests: | 20000
# 	            Successful Requests: | 10741
# 	                Failed Requests: | 9259
# 	                           Apps: | 10741
# 	                        Elapsed: | 0:44:56.738675
# 	                Apps Per Second: | 3.98
# Failed to restart the Kernel.
#
# listen EMFILE: too many open files 0.0.0.0:9000.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
