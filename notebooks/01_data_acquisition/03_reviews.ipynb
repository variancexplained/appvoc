# %% [markdown]
# # AppStore Reviews
# As of 2022, the average number of reviews per IOS app was 455. This notebook, extracts user reviews of IOS apps defined as follows:
#
# ## AppStore Review Entity
# The AppStore Review entity is defined as follows.
#
# | #  | name        | description                                          | api_field                    |
# |----|-------------|------------------------------------------------------|------------------------------|
# | 1  | id          | Unique review identifier                             | userReviewId                 |
# | 2  | app_id      | Unique identifier for the app                        | from appstore['id']          |
# | 3  | app_name    | Name of app                                          | from appstore['name']        |
# | 4  | category_id | Four digit category identifier                       | from appstore['category_id'] |
# | 5  | category    | Category label                                       | from appstore['category']    |
# | 6  | author      | Review author                                        | name                         |
# | 7  | rating      | Rating accompanying the review                       | rating                       |
# | 8  | title       | Brief description of the review                      | title                        |
# | 9  | content     | Review text                                          | body                         |
# | 10 | vote_sum    | The number of customers who found the review helpful | voteSum                      |
# | 11 | vote_count  | The total number of customers who voted (yes/no)     | voteCount                    |
# | 12 | date        | Datetime of review                                   | date                         |
# | 13 | source      | The base url                                         | itunes.apple.com             |
#
# Reviews will be extracted by category of apps in the appdata repository. Concretely, reviews will be obtained for the following categories:
#
# | category_id | category               |
# |-------------|------------------------|
# | 6000        |  "BUSINESS",           |
# | 6017        |  "EDUCATION",          |
# | 6016        |  "ENTERTAINMENT",      |
# | 6013        |  "HEALTH_AND_FITNESS", |
# | 6012        |  "LIFESTYLE",          |
# | 6020        |  "MEDICAL",            |
# | 6007        |  "PRODUCTIVITY",       |
# | 6005        |  "SOCIAL_NETWORKING",  |

# %% [markdown]
# ### Imports

# %%
from appstore.data.acquisition.review.controller import ReviewController
from appstore.container import AppstoreContainer

# %% [markdown]
# ## Dependencies

# %%
container = AppstoreContainer()
container.init_resources()
container.wire(packages=["appstore.data.acquisition"])

# %% [markdown]
# ### Scrape

# %%
ctrl = ReviewController()
ctrl.scrape()
# Out:
# [08/09/2023 09:04:15 PM] [INFO] [ReviewJobRun] [start] :
# JobRun for job review-6002 Started
# [08/09/2023 09:04:16 PM] [INFO] [ReviewController] [_get_apps] :
#
# A total of 20260 apps in category 6002.
# Apps to process: 7820
# [08/09/2023 09:04:26 PM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 7bc5adca-5134-41fc-bd51-1e69e7477c89
#                            jobid | review-6002
#                       controller | ReviewController
#                      category_id | 6002
#                         category | Utilities
#                          started | 2023-08-09 21:04:15.533017
#                            ended | 2023-08-09 21:04:18.785789
#                          elapsed | 3.252772
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 638
#                         complete | False
#                        completed | None
#                             apps | 1
#                          reviews | 1
#                  apps_per_second | 0.31
#                 bytes_per_second | 196.14
#               reviews_per_second | 0.31
#                         size_ave | 638.0
#
#
# [08/09/2023 09:07:37 PM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 7bc5adca-5134-41fc-bd51-1e69e7477c89
#                            jobid | review-6002
#                       controller | ReviewController
#                      category_id | 6002
#                         category | Utilities
#                          started | 2023-08-09 21:04:15.533017
#                            ended | 2023-08-09 21:07:31.141345
#                          elapsed | 195.608328
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 48687
#                         complete | False
#                        completed | None
#                             apps | 23
#                          reviews | 214
#                  apps_per_second | 0.12
#                 bytes_per_second | 248.9
#               reviews_per_second | 1.09
#                         size_ave | 2116.8260869565215
#
#
# [08/09/2023 09:09:22 PM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 7bc5adca-5134-41fc-bd51-1e69e7477c89
#                            jobid | review-6002
#                       controller | ReviewController
#                      category_id | 6002
#                         category | Utilities
#                          started | 2023-08-09 21:04:15.533017
#                            ended | 2023-08-09 21:09:15.450809
#                          elapsed | 299.917792
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 97905
#                         complete | False
#                        completed | None
#                             apps | 37
#                          reviews | 455
#                  apps_per_second | 0.12
#                 bytes_per_second | 326.44
#               reviews_per_second | 1.52
#                         size_ave | 2646.0810810810813
#
#
# [08/09/2023 09:10:30 PM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 7bc5adca-5134-41fc-bd51-1e69e7477c89
#                            jobid | review-6002
#                       controller | ReviewController
#                      category_id | 6002
#                         category | Utilities
#                          started | 2023-08-09 21:04:15.533017
#                            ended | 2023-08-09 21:10:20.485667
#                          elapsed | 364.95265
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 123471
#                         complete | False
#                        completed | None
#                             apps | 41
#                          reviews | 582
#                  apps_per_second | 0.11
#                 bytes_per_second | 338.32
#               reviews_per_second | 1.59
#                         size_ave | 3011.487804878049
#
#
# [08/09/2023 09:11:29 PM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 7bc5adca-5134-41fc-bd51-1e69e7477c89
#                            jobid | review-6002
#                       controller | ReviewController
#                      category_id | 6002
#                         category | Utilities
#                          started | 2023-08-09 21:04:15.533017
#                            ended | 2023-08-09 21:11:21.897952
#                          elapsed | 426.364935
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 144768
#                         complete | False
#                        completed | None
#                             apps | 48
#                          reviews | 698
#                  apps_per_second | 0.11
#                 bytes_per_second | 339.54
#               reviews_per_second | 1.64
#                         size_ave | 3016.0
#
#
# [08/09/2023 09:13:47 PM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 7bc5adca-5134-41fc-bd51-1e69e7477c89
#                            jobid | review-6002
#                       controller | ReviewController
#                      category_id | 6002
#                         category | Utilities
#                          started | 2023-08-09 21:04:15.533017
#                            ended | 2023-08-09 21:13:40.447278
#                          elapsed | 564.914261
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 187943
#                         complete | False
#                        completed | None
#                             apps | 58
#                          reviews | 952
#                  apps_per_second | 0.1
#                 bytes_per_second | 332.69
#               reviews_per_second | 1.69
#                         size_ave | 3240.396551724138
#
#
# [08/09/2023 09:16:26 PM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 7bc5adca-5134-41fc-bd51-1e69e7477c89
#                            jobid | review-6002
#                       controller | ReviewController
#                      category_id | 6002
#                         category | Utilities
#                          started | 2023-08-09 21:04:15.533017
#                            ended | 2023-08-09 21:16:19.485499
#                          elapsed | 723.952482
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 222548
#                         complete | False
#                        completed | None
#                             apps | 72
#                          reviews | 1116
#                  apps_per_second | 0.1
#                 bytes_per_second | 307.41
#               reviews_per_second | 1.54
#                         size_ave | 3090.9444444444443
#
#
# [08/09/2023 09:20:33 PM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 7bc5adca-5134-41fc-bd51-1e69e7477c89
#                            jobid | review-6002
#                       controller | ReviewController
#                      category_id | 6002
#                         category | Utilities
#                          started | 2023-08-09 21:04:15.533017
#                            ended | 2023-08-09 21:20:26.439677
#                          elapsed | 970.90666
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 350706
#                         complete | False
#                        completed | None
#                             apps | 93
#                          reviews | 2176
#                  apps_per_second | 0.1
#                 bytes_per_second | 361.21
#               reviews_per_second | 2.24
#                         size_ave | 3771.032258064516
#
#
# [08/09/2023 09:21:03 PM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 7bc5adca-5134-41fc-bd51-1e69e7477c89
#                            jobid | review-6002
#                       controller | ReviewController
#                      category_id | 6002
#                         category | Utilities
#                          started | 2023-08-09 21:04:15.533017
#                            ended | 2023-08-09 21:20:56.527259
#                          elapsed | 1000.994242
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 372066
#                         complete | False
#                        completed | None
#                             apps | 97
#                          reviews | 2287
#                  apps_per_second | 0.1
#                 bytes_per_second | 371.7
#               reviews_per_second | 2.28
#                         size_ave | 3835.7319587628867
#
#
# [08/09/2023 09:25:30 PM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 7bc5adca-5134-41fc-bd51-1e69e7477c89
#                            jobid | review-6002
#                       controller | ReviewController
#                      category_id | 6002
#                         category | Utilities
#                          started | 2023-08-09 21:04:15.533017
#                            ended | 2023-08-09 21:25:12.140872
#                          elapsed | 1256.607855
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 795121
#                         complete | False
#                        completed | None
#                             apps | 126
#                          reviews | 4295
#                  apps_per_second | 0.1
#                 bytes_per_second | 632.75
#               reviews_per_second | 3.42
#                         size_ave | 6360.968
#
#
# [08/09/2023 09:26:35 PM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 7bc5adca-5134-41fc-bd51-1e69e7477c89
#                            jobid | review-6002
#                       controller | ReviewController
#                      category_id | 6002
#                         category | Utilities
#                          started | 2023-08-09 21:04:15.533017
#                            ended | 2023-08-09 21:26:28.697824
#                          elapsed | 1333.164807
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 832784
#                         complete | False
#                        completed | None
#                             apps | 134
#                          reviews | 4467
#                  apps_per_second | 0.1
#                 bytes_per_second | 624.67
#               reviews_per_second | 3.35
#                         size_ave | 6214.805970149254
#
#
# [08/09/2023 09:27:49 PM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 7bc5adca-5134-41fc-bd51-1e69e7477c89
#                            jobid | review-6002
#                       controller | ReviewController
#                      category_id | 6002
#                         category | Utilities
#                          started | 2023-08-09 21:04:15.533017
#                            ended | 2023-08-09 21:27:38.061542
#                          elapsed | 1402.528525
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 849161
#                         complete | False
#                        completed | None
#                             apps | 141
#                          reviews | 4554
#                  apps_per_second | 0.1
#                 bytes_per_second | 605.45
#               reviews_per_second | 3.25
#                         size_ave | 6022.418439716312
#
#
# [08/09/2023 09:29:09 PM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 7bc5adca-5134-41fc-bd51-1e69e7477c89
#                            jobid | review-6002
#                       controller | ReviewController
#                      category_id | 6002
#                         category | Utilities
#                          started | 2023-08-09 21:04:15.533017
#                            ended | 2023-08-09 21:29:03.060423
#                          elapsed | 1487.527406
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 996463
#                         complete | False
#                        completed | None
#                             apps | 150
#                          reviews | 5211
#                  apps_per_second | 0.1
#                 bytes_per_second | 669.88
#               reviews_per_second | 3.5
#                         size_ave | 6643.086666666667
#
#
# [08/09/2023 09:30:30 PM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 7bc5adca-5134-41fc-bd51-1e69e7477c89
#                            jobid | review-6002
#                       controller | ReviewController
#                      category_id | 6002
#                         category | Utilities
#                          started | 2023-08-09 21:04:15.533017
#                            ended | 2023-08-09 21:30:16.136483
#                          elapsed | 1560.603466
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 1060247
#                         complete | False
#                        completed | None
#                             apps | 160
#                          reviews | 5573
#                  apps_per_second | 0.1
#                 bytes_per_second | 679.38
#               reviews_per_second | 3.57
#                         size_ave | 6668.220125786163
#
#
# [08/09/2023 09:33:20 PM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 7bc5adca-5134-41fc-bd51-1e69e7477c89
#                            jobid | review-6002
#                       controller | ReviewController
#                      category_id | 6002
#                         category | Utilities
#                          started | 2023-08-09 21:04:15.533017
#                            ended | 2023-08-09 21:33:13.836590
#                          elapsed | 1738.303573
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 1147366
#                         complete | False
#                        completed | None
#                             apps | 179
#                          reviews | 6164
#                  apps_per_second | 0.1
#                 bytes_per_second | 660.05
#               reviews_per_second | 3.55
#                         size_ave | 6409.865921787709
#
#
# [08/09/2023 09:34:36 PM] [WARNING] [urllib3.connectionpool] [urlopen] : Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='itunes.apple.com', port=443): Read timed out. (read timeout=30)")': /WebObjects/MZStore.woa/wa/userReviewsRow?id=824490166&displayable-kind=11&startIndex=0&endIndex=400&sort=1
# [08/09/2023 09:35:07 PM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 7bc5adca-5134-41fc-bd51-1e69e7477c89
#                            jobid | review-6002
#                       controller | ReviewController
#                      category_id | 6002
#                         category | Utilities
#                          started | 2023-08-09 21:04:15.533017
#                            ended | 2023-08-09 21:34:48.338050
#                          elapsed | 1832.805033
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 1183367
#                         complete | False
#                        completed | None
#                             apps | 185
#                          reviews | 6384
#                  apps_per_second | 0.1
#                 bytes_per_second | 645.66
#               reviews_per_second | 3.48
#                         size_ave | 6396.578378378378
#
#
# [08/09/2023 09:36:32 PM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 7bc5adca-5134-41fc-bd51-1e69e7477c89
#                            jobid | review-6002
#                       controller | ReviewController
#                      category_id | 6002
#                         category | Utilities
#                          started | 2023-08-09 21:04:15.533017
#                            ended | 2023-08-09 21:36:22.545649
#                          elapsed | 1927.012632
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 1193259
#                         complete | False
#                        completed | None
#                             apps | 191
#                          reviews | 6435
#                  apps_per_second | 0.1
#                 bytes_per_second | 619.23
#               reviews_per_second | 3.34
#                         size_ave | 6247.429319371728
#
#
# [08/09/2023 09:40:59 PM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 7bc5adca-5134-41fc-bd51-1e69e7477c89
#                            jobid | review-6002
#                       controller | ReviewController
#                      category_id | 6002
#                         category | Utilities
#                          started | 2023-08-09 21:04:15.533017
#                            ended | 2023-08-09 21:40:49.460730
#                          elapsed | 2193.927713
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 1278223
#                         complete | False
#                        completed | None
#                             apps | 211
#                          reviews | 6895
#                  apps_per_second | 0.1
#                 bytes_per_second | 582.62
#               reviews_per_second | 3.14
#                         size_ave | 6057.928909952607
#
#
# [08/09/2023 09:45:12 PM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 7bc5adca-5134-41fc-bd51-1e69e7477c89
#                            jobid | review-6002
#                       controller | ReviewController
#                      category_id | 6002
#                         category | Utilities
#                          started | 2023-08-09 21:04:15.533017
#                            ended | 2023-08-09 21:45:00.084597
#                          elapsed | 2444.55158
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 1386425
#                         complete | False
#                        completed | None
#                             apps | 231
#                          reviews | 7548
#                  apps_per_second | 0.09
#                 bytes_per_second | 567.15
#               reviews_per_second | 3.09
#                         size_ave | 6001.839826839827
#
#
# [08/09/2023 09:48:39 PM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 7bc5adca-5134-41fc-bd51-1e69e7477c89
#                            jobid | review-6002
#                       controller | ReviewController
#                      category_id | 6002
#                         category | Utilities
#                          started | 2023-08-09 21:04:15.533017
#                            ended | 2023-08-09 21:48:20.749956
#                          elapsed | 2645.216939
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 1446001
#                         complete | False
#                        completed | None
#                             apps | 247
#                          reviews | 7822
#                  apps_per_second | 0.09
#                 bytes_per_second | 546.65
#               reviews_per_second | 2.96
#                         size_ave | 5854.255060728745
#
#
# [08/09/2023 09:52:40 PM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 7bc5adca-5134-41fc-bd51-1e69e7477c89
#                            jobid | review-6002
#                       controller | ReviewController
#                      category_id | 6002
#                         category | Utilities
#                          started | 2023-08-09 21:04:15.533017
#                            ended | 2023-08-09 21:52:25.685457
#                          elapsed | 2890.15244
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 1476209
#                         complete | False
#                        completed | None
#                             apps | 262
#                          reviews | 7969
#                  apps_per_second | 0.09
#                 bytes_per_second | 510.77
#               reviews_per_second | 2.76
#                         size_ave | 5634.385496183206
#
#
# [08/09/2023 09:57:35 PM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 7bc5adca-5134-41fc-bd51-1e69e7477c89
#                            jobid | review-6002
#                       controller | ReviewController
#                      category_id | 6002
#                         category | Utilities
#                          started | 2023-08-09 21:04:15.533017
#                            ended | 2023-08-09 21:57:26.214598
#                          elapsed | 3190.681581
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 1521879
#                         complete | False
#                        completed | None
#                             apps | 285
#                          reviews | 8212
#                  apps_per_second | 0.09
#                 bytes_per_second | 476.98
#               reviews_per_second | 2.57
#                         size_ave | 5339.926315789474
#
#
# [08/09/2023 10:00:19 PM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 7bc5adca-5134-41fc-bd51-1e69e7477c89
#                            jobid | review-6002
#                       controller | ReviewController
#                      category_id | 6002
#                         category | Utilities
#                          started | 2023-08-09 21:04:15.533017
#                            ended | 2023-08-09 22:00:10.151366
#                          elapsed | 3354.618349
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 1615064
#                         complete | False
#                        completed | None
#                             apps | 297
#                          reviews | 8667
#                  apps_per_second | 0.09
#                 bytes_per_second | 481.44
#               reviews_per_second | 2.58
#                         size_ave | 5437.925925925926
#
#
# [08/09/2023 10:03:07 PM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 7bc5adca-5134-41fc-bd51-1e69e7477c89
#                            jobid | review-6002
#                       controller | ReviewController
#                      category_id | 6002
#                         category | Utilities
#                          started | 2023-08-09 21:04:15.533017
#                            ended | 2023-08-09 22:02:58.301407
#                          elapsed | 3522.76839
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 1666913
#                         complete | False
#                        completed | None
#                             apps | 311
#                          reviews | 8923
#                  apps_per_second | 0.09
#                 bytes_per_second | 473.18
#               reviews_per_second | 2.53
#                         size_ave | 5359.84887459807
#
#
# [08/09/2023 10:03:51 PM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 7bc5adca-5134-41fc-bd51-1e69e7477c89
#                            jobid | review-6002
#                       controller | ReviewController
#                      category_id | 6002
#                         category | Utilities
#                          started | 2023-08-09 21:04:15.533017
#                            ended | 2023-08-09 22:03:41.729905
#                          elapsed | 3566.196888
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 1700140
#                         complete | False
#                        completed | None
#                             apps | 315
#                          reviews | 9079
#                  apps_per_second | 0.09
#                 bytes_per_second | 476.74
#               reviews_per_second | 2.55
#                         size_ave | 5397.269841269841
#
#
# [08/09/2023 10:05:15 PM] [WARNING] [urllib3.connectionpool] [urlopen] : Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='itunes.apple.com', port=443): Read timed out. (read timeout=30)")': /WebObjects/MZStore.woa/wa/userReviewsRow?id=1498757667&displayable-kind=11&startIndex=1200&endIndex=1600&sort=1
# [08/09/2023 10:08:19 PM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 7bc5adca-5134-41fc-bd51-1e69e7477c89
#                            jobid | review-6002
#                       controller | ReviewController
#                      category_id | 6002
#                         category | Utilities
#                          started | 2023-08-09 21:04:15.533017
#                            ended | 2023-08-09 22:08:12.600448
#                          elapsed | 3837.067431
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 1744373
#                         complete | False
#                        completed | None
#                             apps | 334
#                          reviews | 9310
#                  apps_per_second | 0.09
#                 bytes_per_second | 454.61
#               reviews_per_second | 2.43
#                         size_ave | 5222.673652694611
#
#
# [08/09/2023 10:09:48 PM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 7bc5adca-5134-41fc-bd51-1e69e7477c89
#                            jobid | review-6002
#                       controller | ReviewController
#                      category_id | 6002
#                         category | Utilities
#                          started | 2023-08-09 21:04:15.533017
#                            ended | 2023-08-09 22:09:41.572342
#                          elapsed | 3926.039325
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 1817231
#                         complete | False
#                        completed | None
#                             apps | 344
#                          reviews | 9684
#                  apps_per_second | 0.09
#                 bytes_per_second | 462.87
#               reviews_per_second | 2.47
#                         size_ave | 5282.648255813953
#
#
# [08/09/2023 10:10:17 PM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 7bc5adca-5134-41fc-bd51-1e69e7477c89
#                            jobid | review-6002
#                       controller | ReviewController
#                      category_id | 6002
#                         category | Utilities
#                          started | 2023-08-09 21:04:15.533017
#                            ended | 2023-08-09 22:10:11.300502
#                          elapsed | 3955.767485
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 1835966
#                         complete | False
#                        completed | None
#                             apps | 348
#                          reviews | 9770
#                  apps_per_second | 0.09
#                 bytes_per_second | 464.12
#               reviews_per_second | 2.47
#                         size_ave | 5275.764367816092
#
#
# [08/09/2023 10:11:44 PM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 7bc5adca-5134-41fc-bd51-1e69e7477c89
#                            jobid | review-6002
#                       controller | ReviewController
#                      category_id | 6002
#                         category | Utilities
#                          started | 2023-08-09 21:04:15.533017
#                            ended | 2023-08-09 22:11:37.166778
#                          elapsed | 4041.633761
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 1859280
#                         complete | False
#                        completed | None
#                             apps | 359
#                          reviews | 9893
#                  apps_per_second | 0.09
#                 bytes_per_second | 460.03
#               reviews_per_second | 2.45
#                         size_ave | 5179.052924791086
#
#
# [08/09/2023 10:11:57 PM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 7bc5adca-5134-41fc-bd51-1e69e7477c89
#                            jobid | review-6002
#                       controller | ReviewController
#                      category_id | 6002
#                         category | Utilities
#                          started | 2023-08-09 21:04:15.533017
#                            ended | 2023-08-09 22:11:45.297817
#                          elapsed | 4049.7648
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 1861686
#                         complete | False
#                        completed | None
#                             apps | 360
#                          reviews | 9908
#                  apps_per_second | 0.09
#                 bytes_per_second | 459.7
#               reviews_per_second | 2.45
#                         size_ave | 5171.35
#
#
# [08/09/2023 10:16:03 PM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 7bc5adca-5134-41fc-bd51-1e69e7477c89
#                            jobid | review-6002
#                       controller | ReviewController
#                      category_id | 6002
#                         category | Utilities
#                          started | 2023-08-09 21:04:15.533017
#                            ended | 2023-08-09 22:15:56.236392
#                          elapsed | 4300.703375
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 2295869
#                         complete | False
#                        completed | None
#                             apps | 384
#                          reviews | 15183
#                  apps_per_second | 0.09
#                 bytes_per_second | 533.84
#               reviews_per_second | 3.53
#                         size_ave | 5978.825520833333
#
#
# [08/09/2023 10:18:02 PM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 7bc5adca-5134-41fc-bd51-1e69e7477c89
#                            jobid | review-6002
#                       controller | ReviewController
#                      category_id | 6002
#                         category | Utilities
#                          started | 2023-08-09 21:04:15.533017
#                            ended | 2023-08-09 22:17:19.037097
#                          elapsed | 4383.50408
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 2340949
#                         complete | False
#                        completed | None
#                             apps | 392
#                          reviews | 15405
#                  apps_per_second | 0.09
#                 bytes_per_second | 534.04
#               reviews_per_second | 3.51
#                         size_ave | 5971.808673469388
#
#
# [08/09/2023 10:18:22 PM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 7bc5adca-5134-41fc-bd51-1e69e7477c89
#                            jobid | review-6002
#                       controller | ReviewController
#                      category_id | 6002
#                         category | Utilities
#                          started | 2023-08-09 21:04:15.533017
#                            ended | 2023-08-09 22:18:09.498754
#                          elapsed | 4433.965737
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 2348286
#                         complete | False
#                        completed | None
#                             apps | 395
#                          reviews | 15453
#                  apps_per_second | 0.09
#                 bytes_per_second | 529.61
#               reviews_per_second | 3.49
#                         size_ave | 5960.116751269035
#
#
# [08/09/2023 10:19:01 PM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 7bc5adca-5134-41fc-bd51-1e69e7477c89
#                            jobid | review-6002
#                       controller | ReviewController
#                      category_id | 6002
#                         category | Utilities
#                          started | 2023-08-09 21:04:15.533017
#                            ended | 2023-08-09 22:18:48.172007
#                          elapsed | 4472.63899
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 2354444
#                         complete | False
#                        completed | None
#                             apps | 400
#                          reviews | 15497
#                  apps_per_second | 0.09
#                 bytes_per_second | 526.41
#               reviews_per_second | 3.46
#                         size_ave | 5900.862155388471
#
#
# [08/09/2023 10:20:46 PM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 7bc5adca-5134-41fc-bd51-1e69e7477c89
#                            jobid | review-6002
#                       controller | ReviewController
#                      category_id | 6002
#                         category | Utilities
#                          started | 2023-08-09 21:04:15.533017
#                            ended | 2023-08-09 22:20:39.907737
#                          elapsed | 4584.37472
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 2402639
#                         complete | False
#                        completed | None
#                             apps | 411
#                          reviews | 15844
#                  apps_per_second | 0.09
#                 bytes_per_second | 524.09
#               reviews_per_second | 3.46
#                         size_ave | 5845.83698296837
#
#
# [08/09/2023 10:21:47 PM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 7bc5adca-5134-41fc-bd51-1e69e7477c89
#                            jobid | review-6002
#                       controller | ReviewController
#                      category_id | 6002
#                         category | Utilities
#                          started | 2023-08-09 21:04:15.533017
#                            ended | 2023-08-09 22:21:39.950301
#                          elapsed | 4644.417284
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 2436686
#                         complete | False
#                        completed | None
#                             apps | 418
#                          reviews | 16062
#                  apps_per_second | 0.09
#                 bytes_per_second | 524.65
#               reviews_per_second | 3.46
#                         size_ave | 5829.392344497608
#
#
# [08/09/2023 10:25:27 PM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 7bc5adca-5134-41fc-bd51-1e69e7477c89
#                            jobid | review-6002
#                       controller | ReviewController
#                      category_id | 6002
#                         category | Utilities
#                          started | 2023-08-09 21:04:15.533017
#                            ended | 2023-08-09 22:24:47.803525
#                          elapsed | 4832.270508
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 2550207
#                         complete | False
#                        completed | None
#                             apps | 436
#                          reviews | 16715
#                  apps_per_second | 0.09
#                 bytes_per_second | 527.75
#               reviews_per_second | 3.46
#                         size_ave | 5849.098623853211
#
#
# [08/09/2023 10:29:26 PM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 7bc5adca-5134-41fc-bd51-1e69e7477c89
#                            jobid | review-6002
#                       controller | ReviewController
#                      category_id | 6002
#                         category | Utilities
#                          started | 2023-08-09 21:04:15.533017
#                            ended | 2023-08-09 22:29:20.182588
#                          elapsed | 5104.649571
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 2608467
#                         complete | False
#                        completed | None
#                             apps | 454
#                          reviews | 17089
#                  apps_per_second | 0.09
#                 bytes_per_second | 511.0
#               reviews_per_second | 3.35
#                         size_ave | 5745.522026431718
#
#
# [08/09/2023 10:34:11 PM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 7bc5adca-5134-41fc-bd51-1e69e7477c89
#                            jobid | review-6002
#                       controller | ReviewController
#                      category_id | 6002
#                         category | Utilities
#                          started | 2023-08-09 21:04:15.533017
#                            ended | 2023-08-09 22:34:04.632161
#                          elapsed | 5389.099144
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 2670289
#                         complete | False
#                        completed | None
#                             apps | 477
#                          reviews | 17356
#                  apps_per_second | 0.09
#                 bytes_per_second | 495.5
#               reviews_per_second | 3.22
#                         size_ave | 5598.090146750524
#
#
# [08/09/2023 10:34:42 PM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 7bc5adca-5134-41fc-bd51-1e69e7477c89
#                            jobid | review-6002
#                       controller | ReviewController
#                      category_id | 6002
#                         category | Utilities
#                          started | 2023-08-09 21:04:15.533017
#                            ended | 2023-08-09 22:34:36.432184
#                          elapsed | 5420.899167
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 2700078
#                         complete | False
#                        completed | None
#                             apps | 481
#                          reviews | 17504
#                  apps_per_second | 0.09
#                 bytes_per_second | 498.09
#               reviews_per_second | 3.23
#                         size_ave | 5613.467775467775
#
#
# [08/09/2023 10:37:15 PM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 7bc5adca-5134-41fc-bd51-1e69e7477c89
#                            jobid | review-6002
#                       controller | ReviewController
#                      category_id | 6002
#                         category | Utilities
#                          started | 2023-08-09 21:04:15.533017
#                            ended | 2023-08-09 22:37:08.605569
#                          elapsed | 5573.072552
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 2747720
#                         complete | False
#                        completed | None
#                             apps | 497
#                          reviews | 17745
#                  apps_per_second | 0.09
#                 bytes_per_second | 493.04
#               reviews_per_second | 3.18
#                         size_ave | 5528.611670020121
#
#
# [08/09/2023 10:39:39 PM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 7bc5adca-5134-41fc-bd51-1e69e7477c89
#                            jobid | review-6002
#                       controller | ReviewController
#                      category_id | 6002
#                         category | Utilities
#                          started | 2023-08-09 21:04:15.533017
#                            ended | 2023-08-09 22:39:28.598717
#                          elapsed | 5713.0657
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 2957816
#                         complete | False
#                        completed | None
#                             apps | 509
#                          reviews | 18640
#                  apps_per_second | 0.09
#                 bytes_per_second | 517.73
#               reviews_per_second | 3.26
#                         size_ave | 5811.033398821218
#
#
# [08/09/2023 10:42:07 PM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 7bc5adca-5134-41fc-bd51-1e69e7477c89
#                            jobid | review-6002
#                       controller | ReviewController
#                      category_id | 6002
#                         category | Utilities
#                          started | 2023-08-09 21:04:15.533017
#                            ended | 2023-08-09 22:42:00.131784
#                          elapsed | 5864.598767
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 3019416
#                         complete | False
#                        completed | None
#                             apps | 524
#                          reviews | 18930
#                  apps_per_second | 0.09
#                 bytes_per_second | 514.85
#               reviews_per_second | 3.23
#                         size_ave | 5762.244274809161
#
#
# [08/09/2023 10:46:13 PM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 7bc5adca-5134-41fc-bd51-1e69e7477c89
#                            jobid | review-6002
#                       controller | ReviewController
#                      category_id | 6002
#                         category | Utilities
#                          started | 2023-08-09 21:04:15.533017
#                            ended | 2023-08-09 22:46:06.362499
# ...
#                            ended | 2023-08-09 22:54:49.421879
#                          elapsed | 6633.888862
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 3610285
#                         complete | False
#                        completed | None
#                             apps | 605
#                          reviews | 22596
#                  apps_per_second | 0.09
#                 bytes_per_second | 544.22
#               reviews_per_second | 3.41
#                         size_ave | 5967.413223140496
#
#
# [08/09/2023 10:55:54 PM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 7bc5adca-5134-41fc-bd51-1e69e7477c89
#                            jobid | review-6002
#                       controller | ReviewController
#                      category_id | 6002
#                         category | Utilities
#                          started | 2023-08-09 21:04:15.533017
#                            ended | 2023-08-09 22:55:47.682051
#                          elapsed | 6692.149034
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 3668464
#                         complete | False
#                        completed | None
#                             apps | 613
#                          reviews | 23038
#                  apps_per_second | 0.09
#                 bytes_per_second | 548.17
#               reviews_per_second | 3.44
#                         size_ave | 5984.443719412724
#
#
# [08/09/2023 10:57:58 PM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 7bc5adca-5134-41fc-bd51-1e69e7477c89
#                            jobid | review-6002
#                       controller | ReviewController
#                      category_id | 6002
#                         category | Utilities
#                          started | 2023-08-09 21:04:15.533017
#                            ended | 2023-08-09 22:57:51.810797
#                          elapsed | 6816.27778
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 3738357
#                         complete | False
#                        completed | None
#                             apps | 625
#                          reviews | 23533
#                  apps_per_second | 0.09
#                 bytes_per_second | 548.45
#               reviews_per_second | 3.45
#                         size_ave | 5981.3712
#
#
# [08/09/2023 10:58:53 PM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 7bc5adca-5134-41fc-bd51-1e69e7477c89
#                            jobid | review-6002
#                       controller | ReviewController
#                      category_id | 6002
#                         category | Utilities
#                          started | 2023-08-09 21:04:15.533017
#                            ended | 2023-08-09 22:58:42.878924
#                          elapsed | 6867.345907
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 3767386
#                         complete | False
#                        completed | None
#                             apps | 632
#                          reviews | 23693
#                  apps_per_second | 0.09
#                 bytes_per_second | 548.59
#               reviews_per_second | 3.45
#                         size_ave | 5961.053797468355
#
#
# [08/09/2023 11:00:05 PM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 7bc5adca-5134-41fc-bd51-1e69e7477c89
#                            jobid | review-6002
#                       controller | ReviewController
#                      category_id | 6002
#                         category | Utilities
#                          started | 2023-08-09 21:04:15.533017
#                            ended | 2023-08-09 22:59:59.427651
#                          elapsed | 6943.894634
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 3792154
#                         complete | False
#                        completed | None
#                             apps | 639
#                          reviews | 23831
#                  apps_per_second | 0.09
#                 bytes_per_second | 546.11
#               reviews_per_second | 3.43
#                         size_ave | 5934.513302034429
#
#
# [08/09/2023 11:01:21 PM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 7bc5adca-5134-41fc-bd51-1e69e7477c89
#                            jobid | review-6002
#                       controller | ReviewController
#                      category_id | 6002
#                         category | Utilities
#                          started | 2023-08-09 21:04:15.533017
#                            ended | 2023-08-09 23:01:09.150997
#                          elapsed | 7013.61798
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 3822453
#                         complete | False
#                        completed | None
#                             apps | 648
#                          reviews | 23988
#                  apps_per_second | 0.09
#                 bytes_per_second | 545.0
#               reviews_per_second | 3.42
#                         size_ave | 5898.847222222223
#
#
# [08/09/2023 11:01:49 PM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 7bc5adca-5134-41fc-bd51-1e69e7477c89
#                            jobid | review-6002
#                       controller | ReviewController
#                      category_id | 6002
#                         category | Utilities
#                          started | 2023-08-09 21:04:15.533017
#                            ended | 2023-08-09 23:01:42.805579
#                          elapsed | 7047.272562
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 3826212
#                         complete | False
#                        completed | None
#                             apps | 651
#                          reviews | 24006
#                  apps_per_second | 0.09
#                 bytes_per_second | 542.94
#               reviews_per_second | 3.41
#                         size_ave | 5877.437788018433
#
#
# [08/09/2023 11:03:00 PM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 7bc5adca-5134-41fc-bd51-1e69e7477c89
#                            jobid | review-6002
#                       controller | ReviewController
#                      category_id | 6002
#                         category | Utilities
#                          started | 2023-08-09 21:04:15.533017
#                            ended | 2023-08-09 23:02:54.162719
#                          elapsed | 7118.629702
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 3855628
#                         complete | False
#                        completed | None
#                             apps | 658
#                          reviews | 24151
#                  apps_per_second | 0.09
#                 bytes_per_second | 541.63
#               reviews_per_second | 3.39
#                         size_ave | 5859.617021276596
#
#
# [08/09/2023 11:06:42 PM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 7bc5adca-5134-41fc-bd51-1e69e7477c89
#                            jobid | review-6002
#                       controller | ReviewController
#                      category_id | 6002
#                         category | Utilities
#                          started | 2023-08-09 21:04:15.533017
#                            ended | 2023-08-09 23:06:34.197756
#                          elapsed | 7338.664739
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 3970023
#                         complete | False
#                        completed | None
#                             apps | 679
#                          reviews | 24822
#                  apps_per_second | 0.09
#                 bytes_per_second | 540.97
#               reviews_per_second | 3.38
#                         size_ave | 5846.867452135493
#
#
# [08/09/2023 11:08:20 PM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 7bc5adca-5134-41fc-bd51-1e69e7477c89
#                            jobid | review-6002
#                       controller | ReviewController
#                      category_id | 6002
#                         category | Utilities
#                          started | 2023-08-09 21:04:15.533017
#                            ended | 2023-08-09 23:08:14.099681
#                          elapsed | 7438.566664
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 4009770
#                         complete | False
#                        completed | None
#                             apps | 691
#                          reviews | 25018
#                  apps_per_second | 0.09
#                 bytes_per_second | 539.05
#               reviews_per_second | 3.36
#                         size_ave | 5802.850940665702
#
#
# [08/09/2023 11:09:15 PM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 7bc5adca-5134-41fc-bd51-1e69e7477c89
#                            jobid | review-6002
#                       controller | ReviewController
#                      category_id | 6002
#                         category | Utilities
#                          started | 2023-08-09 21:04:15.533017
#                            ended | 2023-08-09 23:09:04.284387
#                          elapsed | 7488.75137
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 4026180
#                         complete | False
#                        completed | None
#                             apps | 698
#                          reviews | 25109
#                  apps_per_second | 0.09
#                 bytes_per_second | 537.63
#               reviews_per_second | 3.35
#                         size_ave | 5768.166189111748
#
#
# [08/09/2023 11:10:39 PM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 7bc5adca-5134-41fc-bd51-1e69e7477c89
#                            jobid | review-6002
#                       controller | ReviewController
#                      category_id | 6002
#                         category | Utilities
#                          started | 2023-08-09 21:04:15.533017
#                            ended | 2023-08-09 23:10:32.828581
#                          elapsed | 7577.295564
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 4063574
#                         complete | False
#                        completed | None
#                             apps | 710
#                          reviews | 25291
#                  apps_per_second | 0.09
#                 bytes_per_second | 536.28
#               reviews_per_second | 3.34
#                         size_ave | 5723.343661971831
#
#
# [08/09/2023 11:11:23 PM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 7bc5adca-5134-41fc-bd51-1e69e7477c89
#                            jobid | review-6002
#                       controller | ReviewController
#                      category_id | 6002
#                         category | Utilities
#                          started | 2023-08-09 21:04:15.533017
#                            ended | 2023-08-09 23:11:16.861383
#                          elapsed | 7621.328366
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 4083929
#                         complete | False
#                        completed | None
#                             apps | 716
#                          reviews | 25412
#                  apps_per_second | 0.09
#                 bytes_per_second | 535.86
#               reviews_per_second | 3.33
#                         size_ave | 5703.811452513966
#
#
# [08/09/2023 11:12:58 PM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 7bc5adca-5134-41fc-bd51-1e69e7477c89
#                            jobid | review-6002
#                       controller | ReviewController
#                      category_id | 6002
#                         category | Utilities
#                          started | 2023-08-09 21:04:15.533017
#                            ended | 2023-08-09 23:12:51.945515
#                          elapsed | 7716.412498
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 4208739
#                         complete | False
#                        completed | None
#                             apps | 728
#                          reviews | 26322
#                  apps_per_second | 0.09
#                 bytes_per_second | 545.43
#               reviews_per_second | 3.41
#                         size_ave | 5781.23489010989
#
#
# [08/09/2023 11:13:49 PM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 7bc5adca-5134-41fc-bd51-1e69e7477c89
#                            jobid | review-6002
#                       controller | ReviewController
#                      category_id | 6002
#                         category | Utilities
#                          started | 2023-08-09 21:04:15.533017
#                            ended | 2023-08-09 23:13:41.959151
#                          elapsed | 7766.426134
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 4232312
#                         complete | False
#                        completed | None
#                             apps | 735
#                          reviews | 26448
#                  apps_per_second | 0.09
#                 bytes_per_second | 544.95
#               reviews_per_second | 3.41
#                         size_ave | 5758.247619047619
# Failed to restart the Kernel.
#
# listen EMFILE: too many open files 0.0.0.0:9000.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
