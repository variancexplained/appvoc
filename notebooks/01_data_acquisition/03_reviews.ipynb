# %% [markdown]
# # AppStore Reviews
# As of 2022, the average number of reviews per IOS app was 455. This notebook, extracts user reviews of IOS apps defined as follows:
#
# ## AppStore Review Entity
# The AppStore Review entity is defined as follows.
#
# | #  | name        | description                                          | api_field                    |
# |----|-------------|------------------------------------------------------|------------------------------|
# | 1  | id          | Unique review identifier                             | userReviewId                 |
# | 2  | app_id      | Unique identifier for the app                        | from appstore['id']          |
# | 3  | app_name    | Name of app                                          | from appstore['name']        |
# | 4  | category_id | Four digit category identifier                       | from appstore['category_id'] |
# | 5  | category    | Category label                                       | from appstore['category']    |
# | 6  | author      | Review author                                        | name                         |
# | 7  | rating      | Rating accompanying the review                       | rating                       |
# | 8  | title       | Brief description of the review                      | title                        |
# | 9  | content     | Review text                                          | body                         |
# | 10 | vote_sum    | The number of customers who found the review helpful | voteSum                      |
# | 11 | vote_count  | The total number of customers who voted (yes/no)     | voteCount                    |
# | 12 | date        | Datetime of review                                   | date                         |
# | 13 | source      | The base url                                         | itunes.apple.com             |
#
# Reviews will be extracted by category of apps in the appdata repository. Concretely, reviews will be obtained for the following categories:
#
# | category_id | category               |
# |-------------|------------------------|
# | 6000        |  "BUSINESS",           |
# | 6017        |  "EDUCATION",          |
# | 6016        |  "ENTERTAINMENT",      |
# | 6013        |  "HEALTH_AND_FITNESS", |
# | 6012        |  "LIFESTYLE",          |
# | 6020        |  "MEDICAL",            |
# | 6007        |  "PRODUCTIVITY",       |
# | 6005        |  "SOCIAL_NETWORKING",  |

# %% [markdown]
# ### Imports

# %%
from appstore.data.acquisition.review.controller import ReviewController
from appstore.container import AppstoreContainer

# %% [markdown]
# ## Dependencies

# %%
container = AppstoreContainer()
container.init_resources()
container.wire(packages=["appstore.data.acquisition"])

# %% [markdown]
# ### Scrape

# %%
ctrl = ReviewController()
ctrl.scrape()
# Out:
# [08/20/2023 12:55:20 AM] [INFO] [ReviewJobRun] [start] :
# JobRun for job review-6005 Started
# [08/20/2023 12:55:21 AM] [INFO] [ReviewController] [_get_apps] :
#
# A total of 32855 apps in category 6005.
# Apps to process: 3491
# [08/20/2023 12:55:32 AM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 67e7427f-3235-471c-95c2-f81b95b8ebcf
#                            jobid | review-6005
#                       controller | ReviewController
#                      category_id | 6005
#                         category | Social_Networking
#                          elapsed | 4.343718
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 7656
#                         complete | False
#                        completed | None
#                             apps | 1
#                          reviews | 41
#                  apps_per_second | 0.23
#                 bytes_per_second | 1762.55
#               reviews_per_second | 9.44
#                         size_ave | 7656.0
#
#
# [08/20/2023 12:56:33 AM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 67e7427f-3235-471c-95c2-f81b95b8ebcf
#                            jobid | review-6005
#                       controller | ReviewController
#                      category_id | 6005
#                         category | Social_Networking
#                          elapsed | 66.414589
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 175566
#                         complete | False
#                        completed | None
#                             apps | 6
#                          reviews | 840
#                  apps_per_second | 0.09
#                 bytes_per_second | 2643.49
#               reviews_per_second | 12.65
#                         size_ave | 29261.0
#
#
# [08/20/2023 12:57:41 AM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 67e7427f-3235-471c-95c2-f81b95b8ebcf
#                            jobid | review-6005
#                       controller | ReviewController
#                      category_id | 6005
#                         category | Social_Networking
#                          elapsed | 134.394952
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 264597
#                         complete | False
#                        completed | None
#                             apps | 14
#                          reviews | 1613
#                  apps_per_second | 0.1
#                 bytes_per_second | 1968.8
#               reviews_per_second | 12.0
#                         size_ave | 18899.785714285714
#
#
# [08/20/2023 12:58:01 AM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 67e7427f-3235-471c-95c2-f81b95b8ebcf
#                            jobid | review-6005
#                       controller | ReviewController
#                      category_id | 6005
#                         category | Social_Networking
#                          elapsed | 141.926686
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 270688
#                         complete | False
#                        completed | None
#                             apps | 16
#                          reviews | 1646
#                  apps_per_second | 0.11
#                 bytes_per_second | 1907.24
#               reviews_per_second | 11.6
#                         size_ave | 18045.866666666665
#
#
# [08/20/2023 12:59:39 AM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 67e7427f-3235-471c-95c2-f81b95b8ebcf
#                            jobid | review-6005
#                       controller | ReviewController
#                      category_id | 6005
#                         category | Social_Networking
#                          elapsed | 237.436259
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 1280619
#                         complete | False
#                        completed | None
#                             apps | 24
#                          reviews | 9169
#                  apps_per_second | 0.1
#                 bytes_per_second | 5393.53
#               reviews_per_second | 38.62
#                         size_ave | 55679.086956521736
#
#
# [08/20/2023 01:00:44 AM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 67e7427f-3235-471c-95c2-f81b95b8ebcf
#                            jobid | review-6005
#                       controller | ReviewController
#                      category_id | 6005
#                         category | Social_Networking
#                          elapsed | 317.369727
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 1324488
#                         complete | False
#                        completed | None
#                             apps | 33
#                          reviews | 9454
#                  apps_per_second | 0.1
#                 bytes_per_second | 4173.33
#               reviews_per_second | 29.79
#                         size_ave | 40136.0
#
#
# [08/20/2023 01:02:55 AM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 67e7427f-3235-471c-95c2-f81b95b8ebcf
#                            jobid | review-6005
#                       controller | ReviewController
#                      category_id | 6005
#                         category | Social_Networking
#                          elapsed | 436.847225
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 1352760
#                         complete | False
#                        completed | None
#                             apps | 46
#                          reviews | 9649
#                  apps_per_second | 0.1
#                 bytes_per_second | 3096.64
#               reviews_per_second | 22.09
#                         size_ave | 30061.333333333332
#
#
# [08/20/2023 01:03:44 AM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 67e7427f-3235-471c-95c2-f81b95b8ebcf
#                            jobid | review-6005
#                       controller | ReviewController
#                      category_id | 6005
#                         category | Social_Networking
#                          elapsed | 493.512859
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 1373503
#                         complete | False
#                        completed | None
#                             apps | 51
#                          reviews | 9751
#                  apps_per_second | 0.1
#                 bytes_per_second | 2783.11
#               reviews_per_second | 19.76
#                         size_ave | 26931.43137254902
#
#
# [08/20/2023 01:04:59 AM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 67e7427f-3235-471c-95c2-f81b95b8ebcf
#                            jobid | review-6005
#                       controller | ReviewController
#                      category_id | 6005
#                         category | Social_Networking
#                          elapsed | 573.311617
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 1381574
#                         complete | False
#                        completed | None
#                             apps | 61
#                          reviews | 9816
#                  apps_per_second | 0.11
#                 bytes_per_second | 2409.81
#               reviews_per_second | 17.12
#                         size_ave | 22648.754098360656
#
#
# [08/20/2023 01:05:35 AM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 67e7427f-3235-471c-95c2-f81b95b8ebcf
#                            jobid | review-6005
#                       controller | ReviewController
#                      category_id | 6005
#                         category | Social_Networking
#                          elapsed | 608.994726
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 1428560
#                         complete | False
#                        completed | None
#                             apps | 65
#                          reviews | 10125
#                  apps_per_second | 0.11
#                 bytes_per_second | 2345.77
#               reviews_per_second | 16.63
#                         size_ave | 21977.846153846152
#
#
# [08/20/2023 01:09:03 AM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 67e7427f-3235-471c-95c2-f81b95b8ebcf
#                            jobid | review-6005
#                       controller | ReviewController
#                      category_id | 6005
#                         category | Social_Networking
#                          elapsed | 768.232327
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 1522605
#                         complete | False
#                        completed | None
#                             apps | 82
#                          reviews | 10682
#                  apps_per_second | 0.1
#                 bytes_per_second | 1981.96
#               reviews_per_second | 13.9
#                         size_ave | 19032.5625
#
#
# [08/20/2023 01:10:04 AM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 67e7427f-3235-471c-95c2-f81b95b8ebcf
#                            jobid | review-6005
#                       controller | ReviewController
#                      category_id | 6005
#                         category | Social_Networking
#                          elapsed | 877.437411
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 1738315
#                         complete | False
#                        completed | None
#                             apps | 89
#                          reviews | 12568
#                  apps_per_second | 0.1
#                 bytes_per_second | 1981.13
#               reviews_per_second | 14.32
#                         size_ave | 19531.629213483146
#
#
# [08/20/2023 01:46:52 AM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 67e7427f-3235-471c-95c2-f81b95b8ebcf
#                            jobid | review-6005
#                       controller | ReviewController
#                      category_id | 6005
#                         category | Social_Networking
#                          elapsed | 3079.810093
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 47165578
#                         complete | False
#                        completed | None
#                             apps | 100
#                          reviews | 382679
#                  apps_per_second | 0.03
#                 bytes_per_second | 15314.44
#               reviews_per_second | 124.25
#                         size_ave | 471655.78
#
#
# [08/20/2023 02:14:54 AM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 67e7427f-3235-471c-95c2-f81b95b8ebcf
#                            jobid | review-6005
#                       controller | ReviewController
#                      category_id | 6005
#                         category | Social_Networking
#                          elapsed | 4764.700862
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 77008903
#                         complete | False
#                        completed | None
#                             apps | 110
#                          reviews | 621669
#                  apps_per_second | 0.02
#                 bytes_per_second | 16162.38
#               reviews_per_second | 130.47
#                         size_ave | 700080.9363636364
#
#
# [08/20/2023 02:23:40 AM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 67e7427f-3235-471c-95c2-f81b95b8ebcf
#                            jobid | review-6005
#                       controller | ReviewController
#                      category_id | 6005
#                         category | Social_Networking
#                          elapsed | 5289.575455
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 82817399
#                         complete | False
#                        completed | None
#                             apps | 120
#                          reviews | 680093
#                  apps_per_second | 0.02
#                 bytes_per_second | 15656.72
#               reviews_per_second | 128.57
#                         size_ave | 690144.9916666667
#
#
# [08/20/2023 02:31:44 AM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 67e7427f-3235-471c-95c2-f81b95b8ebcf
#                            jobid | review-6005
#                       controller | ReviewController
#                      category_id | 6005
#                         category | Social_Networking
#                          elapsed | 5774.927749
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 89492962
#                         complete | False
#                        completed | None
#                             apps | 130
#                          reviews | 738066
#                  apps_per_second | 0.02
#                 bytes_per_second | 15496.81
#               reviews_per_second | 127.81
#                         size_ave | 688407.4
#
#
# [08/20/2023 02:38:06 AM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 67e7427f-3235-471c-95c2-f81b95b8ebcf
#                            jobid | review-6005
#                       controller | ReviewController
#                      category_id | 6005
#                         category | Social_Networking
#                          elapsed | 6149.975247
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 92803601
#                         complete | False
#                        completed | None
#                             apps | 140
#                          reviews | 766683
#                  apps_per_second | 0.02
#                 bytes_per_second | 15090.08
#               reviews_per_second | 124.66
#                         size_ave | 662882.8642857143
#
#
# [08/20/2023 02:42:25 AM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 67e7427f-3235-471c-95c2-f81b95b8ebcf
#                            jobid | review-6005
#                       controller | ReviewController
#                      category_id | 6005
#                         category | Social_Networking
#                          elapsed | 6415.945534
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 94438160
#                         complete | False
#                        completed | None
#                             apps | 150
#                          reviews | 779407
#                  apps_per_second | 0.02
#                 bytes_per_second | 14719.29
#               reviews_per_second | 121.48
#                         size_ave | 629587.7333333333
#
#
# [08/20/2023 02:47:29 AM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 67e7427f-3235-471c-95c2-f81b95b8ebcf
#                            jobid | review-6005
#                       controller | ReviewController
#                      category_id | 6005
#                         category | Social_Networking
#                          elapsed | 6713.880504
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 97666922
#                         complete | False
#                        completed | None
#                             apps | 160
#                          reviews | 802122
#                  apps_per_second | 0.02
#                 bytes_per_second | 14547.02
#               reviews_per_second | 119.47
#                         size_ave | 610418.2625
#
#
# [08/20/2023 02:50:34 AM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 67e7427f-3235-471c-95c2-f81b95b8ebcf
#                            jobid | review-6005
#                       controller | ReviewController
#                      category_id | 6005
#                         category | Social_Networking
#                          elapsed | 6904.916296
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 98687027
#                         complete | False
#                        completed | None
#                             apps | 170
#                          reviews | 808275
#                  apps_per_second | 0.02
#                 bytes_per_second | 14292.28
#               reviews_per_second | 117.06
#                         size_ave | 580511.9235294118
#
#
# [08/20/2023 02:53:59 AM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 67e7427f-3235-471c-95c2-f81b95b8ebcf
#                            jobid | review-6005
#                       controller | ReviewController
#                      category_id | 6005
#                         category | Social_Networking
#                          elapsed | 7102.688031
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 99873157
#                         complete | False
#                        completed | None
#                             apps | 180
#                          reviews | 816196
#                  apps_per_second | 0.03
#                 bytes_per_second | 14061.32
#               reviews_per_second | 114.91
#                         size_ave | 554850.8722222223
#
#
# [08/20/2023 02:57:24 AM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 67e7427f-3235-471c-95c2-f81b95b8ebcf
#                            jobid | review-6005
#                       controller | ReviewController
#                      category_id | 6005
#                         category | Social_Networking
#                          elapsed | 7286.125973
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 100880055
#                         complete | False
#                        completed | None
#                             apps | 190
#                          reviews | 824030
#                  apps_per_second | 0.03
#                 bytes_per_second | 13845.5
#               reviews_per_second | 113.1
#                         size_ave | 530947.6578947369
#
#
# [08/20/2023 03:00:14 AM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 67e7427f-3235-471c-95c2-f81b95b8ebcf
#                            jobid | review-6005
#                       controller | ReviewController
#                      category_id | 6005
#                         category | Social_Networking
#                          elapsed | 7486.001423
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 101862248
#                         complete | False
#                        completed | None
#                             apps | 199
#                          reviews | 831848
#                  apps_per_second | 0.03
#                 bytes_per_second | 13607.03
#               reviews_per_second | 111.12
#                         size_ave | 511870.5929648241
#
#
# [08/20/2023 03:03:36 AM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 67e7427f-3235-471c-95c2-f81b95b8ebcf
#                            jobid | review-6005
#                       controller | ReviewController
#                      category_id | 6005
#                         category | Social_Networking
#                          elapsed | 7689.239583
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 102955258
#                         complete | False
#                        completed | None
#                             apps | 218
#                          reviews | 838873
#                  apps_per_second | 0.03
#                 bytes_per_second | 13389.52
#               reviews_per_second | 109.1
#                         size_ave | 472271.8256880734
#
#
# [08/20/2023 03:05:43 AM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 67e7427f-3235-471c-95c2-f81b95b8ebcf
#                            jobid | review-6005
#                       controller | ReviewController
#                      category_id | 6005
#                         category | Social_Networking
#                          elapsed | 7810.303659
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 103287053
#                         complete | False
#                        completed | None
#                             apps | 228
#                          reviews | 841526
#                  apps_per_second | 0.03
#                 bytes_per_second | 13224.46
#               reviews_per_second | 107.75
#                         size_ave | 453013.3903508772
#
#
# [08/20/2023 03:07:42 AM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 67e7427f-3235-471c-95c2-f81b95b8ebcf
#                            jobid | review-6005
#                       controller | ReviewController
#                      category_id | 6005
#                         category | Social_Networking
#                          elapsed | 7935.236479
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 103693676
#                         complete | False
#                        completed | None
#                             apps | 238
#                          reviews | 844585
#                  apps_per_second | 0.03
#                 bytes_per_second | 13067.5
#               reviews_per_second | 106.43
#                         size_ave | 435687.71428571426
#
#
# [08/20/2023 03:09:42 AM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 67e7427f-3235-471c-95c2-f81b95b8ebcf
#                            jobid | review-6005
#                       controller | ReviewController
#                      category_id | 6005
#                         category | Social_Networking
#                          elapsed | 8028.224108
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 103978557
#                         complete | False
#                        completed | None
#                             apps | 248
#                          reviews | 846345
#                  apps_per_second | 0.03
#                 bytes_per_second | 12951.63
#               reviews_per_second | 105.42
#                         size_ave | 419268.375
#
#
# [08/20/2023 03:11:40 AM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 67e7427f-3235-471c-95c2-f81b95b8ebcf
#                            jobid | review-6005
#                       controller | ReviewController
#                      category_id | 6005
#                         category | Social_Networking
#                          elapsed | 8166.395822
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 104205695
#                         complete | False
#                        completed | None
#                             apps | 258
#                          reviews | 848630
#                  apps_per_second | 0.03
#                 bytes_per_second | 12760.3
#               reviews_per_second | 103.92
#                         size_ave | 403898.04263565893
#
#
# [08/20/2023 03:13:35 AM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 67e7427f-3235-471c-95c2-f81b95b8ebcf
#                            jobid | review-6005
#                       controller | ReviewController
#                      category_id | 6005
#                         category | Social_Networking
#                          elapsed | 8287.593462
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 104369013
#                         complete | False
#                        completed | None
#                             apps | 268
#                          reviews | 849708
#                  apps_per_second | 0.03
#                 bytes_per_second | 12593.4
#               reviews_per_second | 102.53
#                         size_ave | 389436.6156716418
#
#
# [08/20/2023 03:15:19 AM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 67e7427f-3235-471c-95c2-f81b95b8ebcf
#                            jobid | review-6005
#                       controller | ReviewController
#                      category_id | 6005
#                         category | Social_Networking
#                          elapsed | 8392.392022
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 104619851
#                         complete | False
#                        completed | None
#                             apps | 278
#                          reviews | 851635
#                  apps_per_second | 0.03
#                 bytes_per_second | 12466.03
#               reviews_per_second | 101.48
#                         size_ave | 376330.3992805755
#
#
# [08/20/2023 03:17:08 AM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 67e7427f-3235-471c-95c2-f81b95b8ebcf
#                            jobid | review-6005
#                       controller | ReviewController
#                      category_id | 6005
#                         category | Social_Networking
#                          elapsed | 8500.943268
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 104825232
#                         complete | False
#                        completed | None
#                             apps | 288
#                          reviews | 852701
#                  apps_per_second | 0.03
#                 bytes_per_second | 12331.01
#               reviews_per_second | 100.31
#                         size_ave | 363976.5
#
#
# [08/20/2023 03:19:22 AM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 67e7427f-3235-471c-95c2-f81b95b8ebcf
#                            jobid | review-6005
#                       controller | ReviewController
#                      category_id | 6005
#                         category | Social_Networking
#                          elapsed | 8635.53789
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 105231010
#                         complete | False
#                        completed | None
#                             apps | 298
#                          reviews | 856360
#                  apps_per_second | 0.03
#                 bytes_per_second | 12185.81
#               reviews_per_second | 99.17
#                         size_ave | 353124.19463087246
#
#
# [08/20/2023 03:21:50 AM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 67e7427f-3235-471c-95c2-f81b95b8ebcf
#                            jobid | review-6005
#                       controller | ReviewController
#                      category_id | 6005
#                         category | Social_Networking
#                          elapsed | 8773.219064
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 105373624
#                         complete | False
#                        completed | None
#                             apps | 308
#                          reviews | 857331
#                  apps_per_second | 0.04
#                 bytes_per_second | 12010.83
#               reviews_per_second | 97.72
#                         size_ave | 342122.1558441558
#
#
# [08/20/2023 03:23:28 AM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 67e7427f-3235-471c-95c2-f81b95b8ebcf
#                            jobid | review-6005
#                       controller | ReviewController
#                      category_id | 6005
#                         category | Social_Networking
#                          elapsed | 8880.616223
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 105514277
#                         complete | False
#                        completed | None
#                             apps | 317
#                          reviews | 858232
#                  apps_per_second | 0.04
#                 bytes_per_second | 11881.41
#               reviews_per_second | 96.64
#                         size_ave | 332852.6088328076
#
#
# [08/20/2023 03:24:54 AM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 67e7427f-3235-471c-95c2-f81b95b8ebcf
#                            jobid | review-6005
#                       controller | ReviewController
#                      category_id | 6005
#                         category | Social_Networking
#                          elapsed | 8966.813824
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 105688896
#                         complete | False
#                        completed | None
#                             apps | 326
#                          reviews | 859593
#                  apps_per_second | 0.04
#                 bytes_per_second | 11786.67
#               reviews_per_second | 95.86
#                         size_ave | 324199.0674846626
#
#
# [08/20/2023 03:26:06 AM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 67e7427f-3235-471c-95c2-f81b95b8ebcf
#                            jobid | review-6005
#                       controller | ReviewController
#                      category_id | 6005
#                         category | Social_Networking
#                          elapsed | 9039.412929
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 105948199
#                         complete | False
#                        completed | None
#                             apps | 333
#                          reviews | 860885
#                  apps_per_second | 0.04
#                 bytes_per_second | 11720.69
#               reviews_per_second | 95.24
#                         size_ave | 318162.75975975976
#
#
# [08/20/2023 03:27:32 AM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 67e7427f-3235-471c-95c2-f81b95b8ebcf
#                            jobid | review-6005
#                       controller | ReviewController
#                      category_id | 6005
#                         category | Social_Networking
#                          elapsed | 9125.216656
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 106122958
#                         complete | False
#                        completed | None
#                             apps | 342
#                          reviews | 862949
#                  apps_per_second | 0.04
#                 bytes_per_second | 11629.64
#               reviews_per_second | 94.57
#                         size_ave | 310301.04678362573
#
#
# [08/20/2023 03:29:30 AM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 67e7427f-3235-471c-95c2-f81b95b8ebcf
#                            jobid | review-6005
#                       controller | ReviewController
#                      category_id | 6005
#                         category | Social_Networking
#                          elapsed | 9241.514997
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 106282923
#                         complete | False
#                        completed | None
#                             apps | 352
#                          reviews | 864066
#                  apps_per_second | 0.04
#                 bytes_per_second | 11500.6
#               reviews_per_second | 93.5
#                         size_ave | 301940.1221590909
#
#
# [08/20/2023 03:31:25 AM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 67e7427f-3235-471c-95c2-f81b95b8ebcf
#                            jobid | review-6005
#                       controller | ReviewController
#                      category_id | 6005
#                         category | Social_Networking
#                          elapsed | 9358.346731
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 106416328
#                         complete | False
#                        completed | None
#                             apps | 361
#                          reviews | 865118
#                  apps_per_second | 0.04
#                 bytes_per_second | 11371.27
#               reviews_per_second | 92.44
#                         size_ave | 294782.0720221607
#
#
# [08/20/2023 03:33:15 AM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 67e7427f-3235-471c-95c2-f81b95b8ebcf
#                            jobid | review-6005
#                       controller | ReviewController
#                      category_id | 6005
#                         category | Social_Networking
#                          elapsed | 9468.547954
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 106471444
#                         complete | False
#                        completed | None
#                             apps | 370
#                          reviews | 865483
#                  apps_per_second | 0.04
#                 bytes_per_second | 11244.75
#               reviews_per_second | 91.41
#                         size_ave | 287760.6594594595
#
#
# [08/20/2023 03:34:42 AM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 67e7427f-3235-471c-95c2-f81b95b8ebcf
#                            jobid | review-6005
#                       controller | ReviewController
#                      category_id | 6005
#                         category | Social_Networking
#                          elapsed | 9555.05048
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 106639543
#                         complete | False
#                        completed | None
#                             apps | 380
#                          reviews | 866491
#                  apps_per_second | 0.04
#                 bytes_per_second | 11160.54
#               reviews_per_second | 90.68
#                         size_ave | 280630.3763157895
#
#
# [08/20/2023 03:36:02 AM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 67e7427f-3235-471c-95c2-f81b95b8ebcf
#                            jobid | review-6005
#                       controller | ReviewController
#                      category_id | 6005
#                         category | Social_Networking
#                          elapsed | 9635.204547
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 106722869
#                         complete | False
#                        completed | None
#                             apps | 390
#                          reviews | 867200
#                  apps_per_second | 0.04
#                 bytes_per_second | 11076.35
#               reviews_per_second | 90.0
#                         size_ave | 273648.38205128204
#
#
# [08/20/2023 03:37:53 AM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 67e7427f-3235-471c-95c2-f81b95b8ebcf
#                            jobid | review-6005
#                       controller | ReviewController
#                      category_id | 6005
#                         category | Social_Networking
#                          elapsed | 9744.706391
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 106837761
#                         complete | False
#                        completed | None
#                             apps | 399
#                          reviews | 868008
#                  apps_per_second | 0.04
#                 bytes_per_second | 10963.67
#               reviews_per_second | 89.07
#                         size_ave | 267763.8120300752
#
#
# [08/20/2023 03:40:18 AM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 67e7427f-3235-471c-95c2-f81b95b8ebcf
#                            jobid | review-6005
#                       controller | ReviewController
#                      category_id | 6005
#                         category | Social_Networking
#                          elapsed | 9879.277353
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 106945068
#                         complete | False
#                        completed | None
#                             apps | 407
#                          reviews | 868603
#                  apps_per_second | 0.04
#                 bytes_per_second | 10825.19
#               reviews_per_second | 87.92
#                         size_ave | 262764.29484029487
#
#
# [08/20/2023 03:41:45 AM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 67e7427f-3235-471c-95c2-f81b95b8ebcf
#                            jobid | review-6005
#                       controller | ReviewController
#                      category_id | 6005
#                         category | Social_Networking
#                          elapsed | 9978.378468
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 107117746
#                         complete | False
#                        completed | None
#                             apps | 417
#                          reviews | 869704
#                  apps_per_second | 0.04
#                 bytes_per_second | 10734.99
#               reviews_per_second | 87.16
#                         size_ave | 256877.08872901677
#
#
# [08/20/2023 03:44:02 AM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 67e7427f-3235-471c-95c2-f81b95b8ebcf
#                            jobid | review-6005
#                       controller | ReviewController
#                      category_id | 6005
#                         category | Social_Networking
#                          elapsed | 10106.149689
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 107426960
#                         complete | False
#                        completed | None
#                             apps | 427
#                          reviews | 871770
#                  apps_per_second | 0.04
#                 bytes_per_second | 10629.86
#               reviews_per_second | 86.26
#                         size_ave | 251585.38641686182
#
#
# [08/20/2023 03:44:38 AM] [WARNING] [urllib3.connectionpool] [urlopen] : Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='itunes.apple.com', port=443): Read timed out. (read timeout=30)")': /WebObjects/MZStore.woa/wa/userReviewsRow?id=1500318569&displayable-kind=11&startIndex=1600&endIndex=2000&sort=1
# [08/20/2023 03:49:48 AM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 67e7427f-3235-471c-95c2-f81b95b8ebcf
#                            jobid | review-6005
#                       controller | ReviewController
#                      category_id | 6005
#                         category | Social_Networking
#                          elapsed | 10457.168799
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 107682489
#                         complete | False
#                        completed | None
#                             apps | 446
#                          reviews | 873636
#                  apps_per_second | 0.04
#                 bytes_per_second | 10297.48
#               reviews_per_second | 83.54
#                         size_ave | 241440.55829596412
#
#
# [08/20/2023 03:54:18 AM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 67e7427f-3235-471c-95c2-f81b95b8ebcf
#                            jobid | review-6005
#                       controller | ReviewController
#                      category_id | 6005
#                         category | Social_Networking
#                          elapsed | 10726.943724
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 107863948
#                         complete | False
#                        completed | None
#                             apps | 463
#                          reviews | 874846
#                  apps_per_second | 0.04
#                 bytes_per_second | 10055.42
#               reviews_per_second | 81.56
#                         size_ave | 232967.49028077754
#
#
# [08/20/2023 03:56:21 AM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 67e7427f-3235-471c-95c2-f81b95b8ebcf
#                            jobid | review-6005
#                       controller | ReviewController
#                      category_id | 6005
#                         category | Social_Networking
#                          elapsed | 10851.642823
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 107995340
#                         complete | False
#                        completed | None
#                             apps | 472
#                          reviews | 875910
#                  apps_per_second | 0.04
# ...
#
#
# [08/20/2023 01:04:02 PM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 67e7427f-3235-471c-95c2-f81b95b8ebcf
#                            jobid | review-6005
#                       controller | ReviewController
#                      category_id | 6005
#                         category | Social_Networking
#                          elapsed | 43714.390825
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 281396256
#                         complete | False
#                        completed | None
#                             apps | 2714
#                          reviews | 2276615
#                  apps_per_second | 0.06
#                 bytes_per_second | 6437.15
#               reviews_per_second | 52.08
#                         size_ave | 103683.2188651437
#
#
# [08/20/2023 01:05:25 PM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 67e7427f-3235-471c-95c2-f81b95b8ebcf
#                            jobid | review-6005
#                       controller | ReviewController
#                      category_id | 6005
#                         category | Social_Networking
#                          elapsed | 43790.316783
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 281403147
#                         complete | False
#                        completed | None
#                             apps | 2720
#                          reviews | 2276640
#                  apps_per_second | 0.06
#                 bytes_per_second | 6426.15
#               reviews_per_second | 51.99
#                         size_ave | 103457.03933823529
#
#
# [08/20/2023 01:32:14 PM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 67e7427f-3235-471c-95c2-f81b95b8ebcf
#                            jobid | review-6005
#                       controller | ReviewController
#                      category_id | 6005
#                         category | Social_Networking
#                          elapsed | 45405.343237
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 312260417
#                         complete | False
#                        completed | None
#                             apps | 2728
#                          reviews | 2528517
#                  apps_per_second | 0.06
#                 bytes_per_second | 6877.17
#               reviews_per_second | 55.69
#                         size_ave | 114464.96224340177
#
#
# [08/20/2023 01:54:49 PM] [ERROR] [MySQLDatabase] [insert] : Exception occurred during database insert.
# Exception type:type[sqlalchemy.exc.SQLAlchemyError]
# Can't reconnect until invalid transaction is rolled back.  Please rollback() fully before proceeding (Background on this error at: https://sqlalche.me/e/20/8s2b)
# Traceback (most recent call last):
#   File "/home/john/projects/appstore/appstore/infrastructure/database/base.py", line 162, in insert
#     return data.to_sql(
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/pandas/core/generic.py", line 2878, in to_sql
#     return sql.to_sql(
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/pandas/io/sql.py", line 768, in to_sql
#     with pandasSQL_builder(con, schema=schema, need_transaction=True) as pandas_sql:
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/pandas/io/sql.py", line 1548, in __exit__
#     self.exit_stack.close()
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/contextlib.py", line 584, in close
#     self.__exit__(None, None, None)
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/contextlib.py", line 576, in __exit__
#     raise exc_details[1]
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/contextlib.py", line 561, in __exit__
#     if cb(*exc_details):
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/sqlalchemy/engine/util.py", line 146, in __exit__
#     with util.safe_reraise():
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/sqlalchemy/util/langhelpers.py", line 147, in __exit__
#     raise exc_value.with_traceback(exc_tb)
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/sqlalchemy/engine/util.py", line 144, in __exit__
#     self.commit()
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/sqlalchemy/engine/base.py", line 2615, in commit
#     self._do_commit()
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/sqlalchemy/engine/base.py", line 2720, in _do_commit
#     self._connection_commit_impl()
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/sqlalchemy/engine/base.py", line 2691, in _connection_commit_impl
#     self.connection._commit_impl()
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/sqlalchemy/engine/base.py", line 1134, in _commit_impl
#     self._handle_dbapi_exception(e, None, None, None, None)
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/sqlalchemy/engine/base.py", line 2342, in _handle_dbapi_exception
#     raise exc_info[1].with_traceback(exc_info[2])
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/sqlalchemy/engine/base.py", line 1132, in _commit_impl
#     self.engine.dialect.do_commit(self.connection)
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/sqlalchemy/engine/base.py", line 573, in connection
#     return self._revalidate_connection()
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/sqlalchemy/engine/base.py", line 665, in _revalidate_connection
#     self._invalid_transaction()
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/sqlalchemy/engine/base.py", line 655, in _invalid_transaction
#     raise exc.PendingRollbackError(
# sqlalchemy.exc.PendingRollbackError: Can't reconnect until invalid transaction is rolled back.  Please rollback() fully before proceeding (Background on this error at: https://sqlalche.me/e/20/8s2b)
# ---------------------------------------------------------------------------
# PendingRollbackError                      Traceback (most recent call last)
# Cell In[3], line 2
#       1 ctrl = ReviewController()
# ----> 2 ctrl.scrape()
#
# File ~/projects/appstore/appstore/data/acquisition/review/controller.py:83, in ReviewController.scrape(self)
#      81 """Entry point for scraping operation"""
#      82 if not super().is_locked():
# ---> 83     self._scrape()
#      84 else:  # pragma: no cover
#      85     msg = f"Running {self.__class__.__name__} is not authorized at this time."
#
# File ~/projects/appstore/appstore/data/acquisition/review/controller.py:109, in ReviewController._scrape(self)
#     107 if result.is_valid():
#     108     self._failures = 0
# --> 109     self.persist(result)
#     110     jobrun = self.update_jobrun(jobrun=jobrun, result=result)
#     111     request.last_index = result.index
#
# File ~/projects/appstore/appstore/data/acquisition/review/controller.py:177, in ReviewController.persist(self, result)
#     171 def persist(self, result: ReviewResult) -> None:
#     172     """Persists results to Database
#     173
#     174     Args:
#     175         result (ReviewResult) -> Parsed result object
#     176     """
# --> 177     self._uow.review_repo.load(data=result.get_result())
#     178     self._uow.save()
#
# File ~/projects/appstore/appstore/data/repo/review.py:96, in ReviewRepo.load(self, data)
#      90 def load(self, data: pd.DataFrame) -> None:
#      91     """Adds the dataframe rows to the designated table.
#      92
#      93     Args:
#      94         data (pd.DataFrame): DataFrame containing rows to add to the table.
#      95     """
# ---> 96     self._database.insert(
#      97         data=data, tablename=self._name, dtype=DATABASE_DTYPES, if_exists="append"
#      98     )
#      99     msg = f"Added {data.shape[0]} rows to the {self._name} repository."
#     100     self._logger.debug(msg)
#
# File ~/projects/appstore/appstore/infrastructure/database/base.py:162, in Database.insert(self, data, tablename, dtype, if_exists)
#     145 """Inserts data in pandas DataFrame format into the designated table.
#     146
#     147 Note: This method uses pandas to_sql method. If not in transaction, inserts are
#    (...)
#     159 Returns: Number of rows inserted.
#     160 """
#     161 try:
# --> 162     return data.to_sql(
#     163         tablename, con=self._connection, if_exists=if_exists, dtype=dtype, index=False
#     164     )
#     165 except SQLAlchemyError as e:  # pragma: no cover
#     166     msg = f"Exception occurred during database insert.\nException type:{type[SQLAlchemyError]}\n{e}"
#
# File ~/anaconda3/envs/appstore/lib/python3.10/site-packages/pandas/core/generic.py:2878, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2713 """
#    2714 Write records stored in a DataFrame to a SQL database.
#    2715
#    (...)
#    2874 [(1,), (None,), (2,)]
#    2875 """  # noqa:E501
#    2876 from pandas.io import sql
# -> 2878 return sql.to_sql(
#    2879     self,
#    2880     name,
#    2881     con,
#    2882     schema=schema,
#    2883     if_exists=if_exists,
#    2884     index=index,
#    2885     index_label=index_label,
#    2886     chunksize=chunksize,
#    2887     dtype=dtype,
#    2888     method=method,
#    2889 )
#
# File ~/anaconda3/envs/appstore/lib/python3.10/site-packages/pandas/io/sql.py:768, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     763 elif not isinstance(frame, DataFrame):
#     764     raise NotImplementedError(
#     765         "'frame' argument should be either a Series or a DataFrame"
#     766     )
# --> 768 with pandasSQL_builder(con, schema=schema, need_transaction=True) as pandas_sql:
#     769     return pandas_sql.to_sql(
#     770         frame,
#     771         name,
#    (...)
#     780         **engine_kwargs,
#     781     )
#
# File ~/anaconda3/envs/appstore/lib/python3.10/site-packages/pandas/io/sql.py:1548, in SQLDatabase.__exit__(self, *args)
#    1546 def __exit__(self, *args) -> None:
#    1547     if not self.returns_generator:
# -> 1548         self.exit_stack.close()
#
# File ~/anaconda3/envs/appstore/lib/python3.10/contextlib.py:584, in ExitStack.close(self)
#     582 def close(self):
#     583     """Immediately unwind the context stack."""
# --> 584     self.__exit__(None, None, None)
#
# File ~/anaconda3/envs/appstore/lib/python3.10/contextlib.py:576, in ExitStack.__exit__(self, *exc_details)
#     572 try:
#     573     # bare "raise exc_details[1]" replaces our carefully
#     574     # set-up context
#     575     fixed_ctx = exc_details[1].__context__
# --> 576     raise exc_details[1]
#     577 except BaseException:
#     578     exc_details[1].__context__ = fixed_ctx
#
# File ~/anaconda3/envs/appstore/lib/python3.10/contextlib.py:561, in ExitStack.__exit__(self, *exc_details)
#     559 assert is_sync
#     560 try:
# --> 561     if cb(*exc_details):
#     562         suppressed_exc = True
#     563         pending_raise = False
#
# File ~/anaconda3/envs/appstore/lib/python3.10/site-packages/sqlalchemy/engine/util.py:146, in TransactionalContext.__exit__(self, type_, value, traceback)
#     144     self.commit()
#     145 except:
# --> 146     with util.safe_reraise():
#     147         if self._rollback_can_be_called():
#     148             self.rollback()
#
# File ~/anaconda3/envs/appstore/lib/python3.10/site-packages/sqlalchemy/util/langhelpers.py:147, in safe_reraise.__exit__(self, type_, value, traceback)
#     145     assert exc_value is not None
#     146     self._exc_info = None  # remove potential circular references
# --> 147     raise exc_value.with_traceback(exc_tb)
#     148 else:
#     149     self._exc_info = None  # remove potential circular references
#
# File ~/anaconda3/envs/appstore/lib/python3.10/site-packages/sqlalchemy/engine/util.py:144, in TransactionalContext.__exit__(self, type_, value, traceback)
#     142 if type_ is None and self._transaction_is_active():
#     143     try:
# --> 144         self.commit()
#     145     except:
#     146         with util.safe_reraise():
#
# File ~/anaconda3/envs/appstore/lib/python3.10/site-packages/sqlalchemy/engine/base.py:2615, in Transaction.commit(self)
#    2599 """Commit this :class:`.Transaction`.
#    2600
#    2601 The implementation of this may vary based on the type of transaction in
#    (...)
#    2612
#    2613 """
#    2614 try:
# -> 2615     self._do_commit()
#    2616 finally:
#    2617     assert not self.is_active
#
# File ~/anaconda3/envs/appstore/lib/python3.10/site-packages/sqlalchemy/engine/base.py:2720, in RootTransaction._do_commit(self)
#    2717 assert self.connection._transaction is self
#    2719 try:
# -> 2720     self._connection_commit_impl()
#    2721 finally:
#    2722     # whether or not commit succeeds, cancel any
#    2723     # nested transactions, make this transaction "inactive"
#    2724     # and remove it as a reset agent
#    2725     if self.connection._nested_transaction:
#
# File ~/anaconda3/envs/appstore/lib/python3.10/site-packages/sqlalchemy/engine/base.py:2691, in RootTransaction._connection_commit_impl(self)
#    2690 def _connection_commit_impl(self) -> None:
# -> 2691     self.connection._commit_impl()
#
# File ~/anaconda3/envs/appstore/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1134, in Connection._commit_impl(self)
#    1132     self.engine.dialect.do_commit(self.connection)
#    1133 except BaseException as e:
# -> 1134     self._handle_dbapi_exception(e, None, None, None, None)
#
# File ~/anaconda3/envs/appstore/lib/python3.10/site-packages/sqlalchemy/engine/base.py:2342, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2340     else:
#    2341         assert exc_info[1] is not None
# -> 2342         raise exc_info[1].with_traceback(exc_info[2])
#    2343 finally:
#    2344     del self._reentrant_error
#
# File ~/anaconda3/envs/appstore/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1132, in Connection._commit_impl(self)
#    1130         self._log_info("COMMIT")
#    1131 try:
# -> 1132     self.engine.dialect.do_commit(self.connection)
#    1133 except BaseException as e:
#    1134     self._handle_dbapi_exception(e, None, None, None, None)
#
# File ~/anaconda3/envs/appstore/lib/python3.10/site-packages/sqlalchemy/engine/base.py:573, in Connection.connection(self)
#     571 if self._dbapi_connection is None:
#     572     try:
# --> 573         return self._revalidate_connection()
#     574     except (exc.PendingRollbackError, exc.ResourceClosedError):
#     575         raise
#
# File ~/anaconda3/envs/appstore/lib/python3.10/site-packages/sqlalchemy/engine/base.py:665, in Connection._revalidate_connection(self)
#     663 if self.__can_reconnect and self.invalidated:
#     664     if self._transaction is not None:
# --> 665         self._invalid_transaction()
#     666     self._dbapi_connection = self.engine.raw_connection()
#     667     return self._dbapi_connection
#
# File ~/anaconda3/envs/appstore/lib/python3.10/site-packages/sqlalchemy/engine/base.py:655, in Connection._invalid_transaction(self)
#     654 def _invalid_transaction(self) -> NoReturn:
# --> 655     raise exc.PendingRollbackError(
#     656         "Can't reconnect until invalid %stransaction is rolled "
#     657         "back.  Please rollback() fully before proceeding"
#     658         % ("savepoint " if self._nested_transaction is not None else ""),
#     659         code="8s2b",
#     660     )
#
# PendingRollbackError: Can't reconnect until invalid transaction is rolled back.  Please rollback() fully before proceeding (Background on this error at: https://sqlalche.me/e/20/8s2b)
