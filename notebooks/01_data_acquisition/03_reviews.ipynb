# %% [markdown]
# # AppVoC Reviews
# As of 2022, the average number of reviews per IOS app was 455. This notebook, extracts user reviews of IOS apps defined as follows:
#
# ## AppVoC Review Entity
# The AppVoC Review entity is defined as follows.
#
# | #  | name        | description                                          | api_field                    |
# |----|-------------|------------------------------------------------------|------------------------------|
# | 1  | id          | Unique review identifier                             | userReviewId                 |
# | 2  | app_id      | Unique identifier for the app                        | from appvoc['id']          |
# | 3  | app_name    | Name of app                                          | from appvoc['name']        |
# | 4  | category_id | Four digit category identifier                       | from appvoc['category_id'] |
# | 5  | category    | Category label                                       | from appvoc['category']    |
# | 6  | author      | Review author                                        | name                         |
# | 7  | rating      | Rating accompanying the review                       | rating                       |
# | 8  | title       | Brief description of the review                      | title                        |
# | 9  | content     | Review text                                          | body                         |
# | 10 | vote_sum    | The number of customers who found the review helpful | voteSum                      |
# | 11 | vote_count  | The total number of customers who voted (yes/no)     | voteCount                    |
# | 12 | date        | Datetime of review                                   | date                         |
# | 13 | source      | The base url                                         | itunes.apple.com             |
#
# Reviews will be extracted by category of apps in the appdata repository. Concretely, reviews will be obtained for the following categories:
#
# | category_id | category               |
# |-------------|------------------------|
# | 6000        |  "BUSINESS",           |
# | 6017        |  "EDUCATION",          |
# | 6016        |  "ENTERTAINMENT",      |
# | 6013        |  "HEALTH_AND_FITNESS", |
# | 6012        |  "LIFESTYLE",          |
# | 6020        |  "MEDICAL",            |
# | 6007        |  "PRODUCTIVITY",       |
# | 6005        |  "SOCIAL_NETWORKING",  |

# %% [markdown]
# ### Imports

# %%
from appvoc.data.acquisition.review.controller import ReviewController
from appvoc.container import AppVoCContainer

# %% [markdown]
# ## Dependencies

# %%
container = AppVoCContainer()
container.init_resources()
container.wire(packages=["appvoc.data.acquisition"])

# %% [markdown]
# ### Scrape

# %%
ctrl = ReviewController()
ctrl.scrape()
# Out:
# [09/04/2023 02:27:28 AM] [INFO] [ReviewJobRun] [start] :
# JobRun for job review-7017 Started
# [09/04/2023 02:27:31 AM] [INFO] [ReviewController] [_get_apps] :
#
# A total of 0 apps in category 7017.No apps meet minimum ratings criteria in category 7017
# [09/04/2023 02:27:41 AM] [INFO] [ReviewJobRun] [start] :
# JobRun for job review-6006 Started
# [09/04/2023 02:27:44 AM] [INFO] [ReviewController] [_get_apps] :
#
# A total of 22103 apps in category 6006.
# Apps to process: 3198
# [09/04/2023 02:28:25 AM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 341783cb-da68-4d58-b001-81d1027b5a05
#                            jobid | review-6006
#                       controller | ReviewController
#                      category_id | 6006
#                         category |  Reference
#                          elapsed | 37.655048
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 79972
#                         complete | False
#                        completed | None
#                             apps | 5
#                          reviews | 515
#                  apps_per_second | 0.13
#                 bytes_per_second | 2123.81
#               reviews_per_second | 13.68
#                         size_ave | 15994.4
#
#
# [09/04/2023 02:30:06 AM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 341783cb-da68-4d58-b001-81d1027b5a05
#                            jobid | review-6006
#                       controller | ReviewController
#                      category_id | 6006
#                         category |  Reference
#                          elapsed | 137.493019
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 212927
#                         complete | False
#                        completed | None
#                             apps | 14
#                          reviews | 1501
#                  apps_per_second | 0.1
#                 bytes_per_second | 1548.64
#               reviews_per_second | 10.92
#                         size_ave | 15209.07142857143
#
#
# [09/04/2023 02:31:07 AM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 341783cb-da68-4d58-b001-81d1027b5a05
#                            jobid | review-6006
#                       controller | ReviewController
#                      category_id | 6006
#                         category |  Reference
#                          elapsed | 196.37479
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 246871
#                         complete | False
#                        completed | None
#                             apps | 21
#                          reviews | 1663
#                  apps_per_second | 0.11
#                 bytes_per_second | 1257.14
#               reviews_per_second | 8.47
#                         size_ave | 11755.761904761905
#
#
# [09/04/2023 02:33:53 AM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 341783cb-da68-4d58-b001-81d1027b5a05
#                            jobid | review-6006
#                       controller | ReviewController
#                      category_id | 6006
#                         category |  Reference
#                          elapsed | 349.75534
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 425043
#                         complete | False
#                        completed | None
#                             apps | 40
#                          reviews | 2785
#                  apps_per_second | 0.11
#                 bytes_per_second | 1215.26
#               reviews_per_second | 7.96
#                         size_ave | 11185.342105263158
#
#
# [09/04/2023 02:40:47 AM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 341783cb-da68-4d58-b001-81d1027b5a05
#                            jobid | review-6006
#                       controller | ReviewController
#                      category_id | 6006
#                         category |  Reference
#                          elapsed | 745.046923
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 522091
#                         complete | False
#                        completed | None
#                             apps | 73
#                          reviews | 3377
#                  apps_per_second | 0.1
#                 bytes_per_second | 700.75
#               reviews_per_second | 4.53
#                         size_ave | 7251.263888888889
#
#
# [09/04/2023 02:42:32 AM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 341783cb-da68-4d58-b001-81d1027b5a05
#                            jobid | review-6006
#                       controller | ReviewController
#                      category_id | 6006
#                         category |  Reference
#                          elapsed | 883.741222
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 852009
#                         complete | False
#                        completed | None
#                             apps | 83
#                          reviews | 5566
#                  apps_per_second | 0.09
#                 bytes_per_second | 964.09
#               reviews_per_second | 6.3
#                         size_ave | 10265.168674698794
#
#
# [09/04/2023 02:44:17 AM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 341783cb-da68-4d58-b001-81d1027b5a05
#                            jobid | review-6006
#                       controller | ReviewController
#                      category_id | 6006
#                         category |  Reference
#                          elapsed | 978.761676
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 1101972
#                         complete | False
#                        completed | None
#                             apps | 93
#                          reviews | 7216
#                  apps_per_second | 0.1
#                 bytes_per_second | 1125.88
#               reviews_per_second | 7.37
#                         size_ave | 11849.161290322581
#
#
# [09/04/2023 02:46:42 AM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 341783cb-da68-4d58-b001-81d1027b5a05
#                            jobid | review-6006
#                       controller | ReviewController
#                      category_id | 6006
#                         category |  Reference
#                          elapsed | 1132.741893
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 1371733
#                         complete | False
#                        completed | None
#                             apps | 103
#                          reviews | 9473
#                  apps_per_second | 0.09
#                 bytes_per_second | 1210.98
#               reviews_per_second | 8.36
#                         size_ave | 13317.796116504855
#
#
# [09/04/2023 02:48:45 AM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 341783cb-da68-4d58-b001-81d1027b5a05
#                            jobid | review-6006
#                       controller | ReviewController
#                      category_id | 6006
#                         category |  Reference
#                          elapsed | 1255.10058
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 1641254
#                         complete | False
#                        completed | None
#                             apps | 113
#                          reviews | 11691
#                  apps_per_second | 0.09
#                 bytes_per_second | 1307.67
#               reviews_per_second | 9.31
#                         size_ave | 14524.371681415929
#
#
# [09/04/2023 02:50:25 AM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 341783cb-da68-4d58-b001-81d1027b5a05
#                            jobid | review-6006
#                       controller | ReviewController
#                      category_id | 6006
#                         category |  Reference
#                          elapsed | 1357.092994
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 1910077
#                         complete | False
#                        completed | None
#                             apps | 123
#                          reviews | 13826
#                  apps_per_second | 0.09
#                 bytes_per_second | 1407.48
#               reviews_per_second | 10.19
#                         size_ave | 15529.081300813008
#
#
# [09/04/2023 02:51:47 AM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 341783cb-da68-4d58-b001-81d1027b5a05
#                            jobid | review-6006
#                       controller | ReviewController
#                      category_id | 6006
#                         category |  Reference
#                          elapsed | 1439.13649
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 2193243
#                         complete | False
#                        completed | None
#                             apps | 133
#                          reviews | 15877
#                  apps_per_second | 0.09
#                 bytes_per_second | 1524.0
#               reviews_per_second | 11.03
#                         size_ave | 16490.54887218045
#
#
# [09/04/2023 02:54:24 AM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 341783cb-da68-4d58-b001-81d1027b5a05
#                            jobid | review-6006
#                       controller | ReviewController
#                      category_id | 6006
#                         category |  Reference
#                          elapsed | 1585.734973
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 2527095
#                         complete | False
#                        completed | None
#                             apps | 143
#                          reviews | 18384
#                  apps_per_second | 0.09
#                 bytes_per_second | 1593.64
#               reviews_per_second | 11.59
#                         size_ave | 17671.99300699301
#
#
# [09/04/2023 02:56:32 AM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 341783cb-da68-4d58-b001-81d1027b5a05
#                            jobid | review-6006
#                       controller | ReviewController
#                      category_id | 6006
#                         category |  Reference
#                          elapsed | 1723.998849
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 2696777
#                         complete | False
#                        completed | None
#                             apps | 153
#                          reviews | 19788
#                  apps_per_second | 0.09
#                 bytes_per_second | 1564.26
#               reviews_per_second | 11.48
#                         size_ave | 17625.993464052288
#
#
# [09/04/2023 02:58:19 AM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 341783cb-da68-4d58-b001-81d1027b5a05
#                            jobid | review-6006
#                       controller | ReviewController
#                      category_id | 6006
#                         category |  Reference
#                          elapsed | 1830.239358
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 2913905
#                         complete | False
#                        completed | None
#                             apps | 163
#                          reviews | 21377
#                  apps_per_second | 0.09
#                 bytes_per_second | 1592.09
#               reviews_per_second | 11.68
#                         size_ave | 17876.717791411043
#
#
# [09/04/2023 03:00:04 AM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 341783cb-da68-4d58-b001-81d1027b5a05
#                            jobid | review-6006
#                       controller | ReviewController
#                      category_id | 6006
#                         category |  Reference
#                          elapsed | 1936.054222
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 3242706
#                         complete | False
#                        completed | None
#                             apps | 173
#                          reviews | 23715
#                  apps_per_second | 0.09
#                 bytes_per_second | 1674.9
#               reviews_per_second | 12.25
#                         size_ave | 18743.965317919075
#
#
# [09/04/2023 03:01:44 AM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 341783cb-da68-4d58-b001-81d1027b5a05
#                            jobid | review-6006
#                       controller | ReviewController
#                      category_id | 6006
#                         category |  Reference
#                          elapsed | 2035.508813
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 3469098
#                         complete | False
#                        completed | None
#                             apps | 183
#                          reviews | 25370
#                  apps_per_second | 0.09
#                 bytes_per_second | 1704.29
#               reviews_per_second | 12.46
#                         size_ave | 18956.819672131147
#
#
# [09/04/2023 03:03:41 AM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 341783cb-da68-4d58-b001-81d1027b5a05
#                            jobid | review-6006
#                       controller | ReviewController
#                      category_id | 6006
#                         category |  Reference
#                          elapsed | 2151.709569
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 3752536
#                         complete | False
#                        completed | None
#                             apps | 193
#                          reviews | 27364
#                  apps_per_second | 0.09
#                 bytes_per_second | 1743.98
#               reviews_per_second | 12.72
#                         size_ave | 19443.19170984456
#
#
# [09/04/2023 03:05:38 AM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 341783cb-da68-4d58-b001-81d1027b5a05
#                            jobid | review-6006
#                       controller | ReviewController
#                      category_id | 6006
#                         category |  Reference
#                          elapsed | 2264.971765
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 3966722
#                         complete | False
#                        completed | None
#                             apps | 203
#                          reviews | 29028
#                  apps_per_second | 0.09
#                 bytes_per_second | 1751.33
#               reviews_per_second | 12.82
#                         size_ave | 19540.50246305419
#
#
# [09/04/2023 03:07:17 AM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 341783cb-da68-4d58-b001-81d1027b5a05
#                            jobid | review-6006
#                       controller | ReviewController
#                      category_id | 6006
#                         category |  Reference
#                          elapsed | 2367.311653
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 4155127
#                         complete | False
#                        completed | None
#                             apps | 213
#                          reviews | 30805
#                  apps_per_second | 0.09
#                 bytes_per_second | 1755.21
#               reviews_per_second | 13.01
#                         size_ave | 19507.63849765258
#
#
# [09/04/2023 03:09:23 AM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 341783cb-da68-4d58-b001-81d1027b5a05
#                            jobid | review-6006
#                       controller | ReviewController
#                      category_id | 6006
#                         category |  Reference
#                          elapsed | 2493.690604
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 5169405
#                         complete | False
#                        completed | None
#                             apps | 223
#                          reviews | 37180
#                  apps_per_second | 0.09
#                 bytes_per_second | 2072.99
#               reviews_per_second | 14.91
#                         size_ave | 23181.188340807174
#
#
# [09/04/2023 03:11:36 AM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 341783cb-da68-4d58-b001-81d1027b5a05
#                            jobid | review-6006
#                       controller | ReviewController
#                      category_id | 6006
#                         category |  Reference
#                          elapsed | 2627.195687
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 6101042
#                         complete | False
#                        completed | None
#                             apps | 233
#                          reviews | 45214
#                  apps_per_second | 0.09
#                 bytes_per_second | 2322.26
#               reviews_per_second | 17.21
#                         size_ave | 26184.729613733907
#
#
# [09/04/2023 03:13:55 AM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 341783cb-da68-4d58-b001-81d1027b5a05
#                            jobid | review-6006
#                       controller | ReviewController
#                      category_id | 6006
#                         category |  Reference
#                          elapsed | 2764.777858
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 6908529
#                         complete | False
#                        completed | None
#                             apps | 243
#                          reviews | 51945
#                  apps_per_second | 0.09
#                 bytes_per_second | 2498.76
#               reviews_per_second | 18.79
#                         size_ave | 28430.16049382716
#
#
# [09/04/2023 03:15:55 AM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 341783cb-da68-4d58-b001-81d1027b5a05
#                            jobid | review-6006
#                       controller | ReviewController
#                      category_id | 6006
#                         category |  Reference
#                          elapsed | 2885.590269
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 7319735
#                         complete | False
#                        completed | None
#                             apps | 253
#                          reviews | 55135
#                  apps_per_second | 0.09
#                 bytes_per_second | 2536.65
#               reviews_per_second | 19.11
#                         size_ave | 28931.758893280632
#
#
# [09/04/2023 03:19:14 AM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 341783cb-da68-4d58-b001-81d1027b5a05
#                            jobid | review-6006
#                       controller | ReviewController
#                      category_id | 6006
#                         category |  Reference
#                          elapsed | 3082.536715
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 7910651
#                         complete | False
#                        completed | None
#                             apps | 263
#                          reviews | 60910
#                  apps_per_second | 0.09
#                 bytes_per_second | 2566.28
#               reviews_per_second | 19.76
#                         size_ave | 30078.52091254753
#
#
# [09/04/2023 03:22:36 AM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 341783cb-da68-4d58-b001-81d1027b5a05
#                            jobid | review-6006
#                       controller | ReviewController
#                      category_id | 6006
#                         category |  Reference
#                          elapsed | 3272.401837
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 8741740
#                         complete | False
#                        completed | None
#                             apps | 273
#                          reviews | 67922
#                  apps_per_second | 0.08
#                 bytes_per_second | 2671.35
#               reviews_per_second | 20.76
#                         size_ave | 32021.02564102564
#
#
# [09/04/2023 03:24:58 AM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 341783cb-da68-4d58-b001-81d1027b5a05
#                            jobid | review-6006
#                       controller | ReviewController
#                      category_id | 6006
#                         category |  Reference
#                          elapsed | 3428.576647
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 9670754
#                         complete | False
#                        completed | None
#                             apps | 283
#                          reviews | 75068
#                  apps_per_second | 0.08
#                 bytes_per_second | 2820.63
#               reviews_per_second | 21.89
#                         size_ave | 34172.27561837456
#
#
# [09/04/2023 03:26:51 AM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 341783cb-da68-4d58-b001-81d1027b5a05
#                            jobid | review-6006
#                       controller | ReviewController
#                      category_id | 6006
#                         category |  Reference
#                          elapsed | 3541.943829
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 10093872
#                         complete | False
#                        completed | None
#                             apps | 293
#                          reviews | 78117
#                  apps_per_second | 0.08
#                 bytes_per_second | 2849.81
#               reviews_per_second | 22.05
#                         size_ave | 34450.075085324235
#
#
# [09/04/2023 03:28:53 AM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 341783cb-da68-4d58-b001-81d1027b5a05
#                            jobid | review-6006
#                       controller | ReviewController
#                      category_id | 6006
#                         category |  Reference
#                          elapsed | 3662.901915
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 10506771
#                         complete | False
#                        completed | None
#                             apps | 303
#                          reviews | 80983
#                  apps_per_second | 0.08
#                 bytes_per_second | 2868.43
#               reviews_per_second | 22.11
#                         size_ave | 34675.81188118812
#
#
# [09/04/2023 03:31:21 AM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 341783cb-da68-4d58-b001-81d1027b5a05
#                            jobid | review-6006
#                       controller | ReviewController
#                      category_id | 6006
#                         category |  Reference
#                          elapsed | 3811.920727
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 11169309
#                         complete | False
#                        completed | None
#                             apps | 313
#                          reviews | 87017
#                  apps_per_second | 0.08
#                 bytes_per_second | 2930.1
#               reviews_per_second | 22.83
#                         size_ave | 35684.693290734824
#
#
# [09/04/2023 03:33:53 AM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 341783cb-da68-4d58-b001-81d1027b5a05
#                            jobid | review-6006
#                       controller | ReviewController
#                      category_id | 6006
#                         category |  Reference
#                          elapsed | 3962.934197
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 11677935
#                         complete | False
#                        completed | None
#                             apps | 323
#                          reviews | 90402
#                  apps_per_second | 0.08
#                 bytes_per_second | 2946.79
#               reviews_per_second | 22.81
#                         size_ave | 36154.59752321981
#
#
# [09/04/2023 03:36:34 AM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 341783cb-da68-4d58-b001-81d1027b5a05
#                            jobid | review-6006
#                       controller | ReviewController
#                      category_id | 6006
#                         category |  Reference
#                          elapsed | 4098.90719
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 12055361
#                         complete | False
#                        completed | None
#                             apps | 333
#                          reviews | 93533
#                  apps_per_second | 0.08
#                 bytes_per_second | 2941.12
#               reviews_per_second | 22.82
#                         size_ave | 36202.28528528529
#
#
# [09/04/2023 03:38:20 AM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 341783cb-da68-4d58-b001-81d1027b5a05
#                            jobid | review-6006
#                       controller | ReviewController
#                      category_id | 6006
#                         category |  Reference
#                          elapsed | 4230.795187
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 12319005
#                         complete | False
#                        completed | None
#                             apps | 342
#                          reviews | 95504
#                  apps_per_second | 0.08
#                 bytes_per_second | 2911.75
#               reviews_per_second | 22.57
#                         size_ave | 36020.48245614035
#
#
# [09/04/2023 03:40:19 AM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 341783cb-da68-4d58-b001-81d1027b5a05
#                            jobid | review-6006
#                       controller | ReviewController
#                      category_id | 6006
#                         category |  Reference
#                          elapsed | 4349.827269
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 12767892
#                         complete | False
#                        completed | None
#                             apps | 352
#                          reviews | 99144
#                  apps_per_second | 0.08
#                 bytes_per_second | 2935.26
#               reviews_per_second | 22.79
#                         size_ave | 36272.420454545456
#
#
# [09/04/2023 03:42:20 AM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 341783cb-da68-4d58-b001-81d1027b5a05
#                            jobid | review-6006
#                       controller | ReviewController
#                      category_id | 6006
#                         category |  Reference
#                          elapsed | 4466.461256
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 13102797
#                         complete | False
#                        completed | None
#                             apps | 362
#                          reviews | 101505
#                  apps_per_second | 0.08
#                 bytes_per_second | 2933.6
#               reviews_per_second | 22.73
#                         size_ave | 36195.57182320442
#
#
# [09/04/2023 03:44:00 AM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 341783cb-da68-4d58-b001-81d1027b5a05
#                            jobid | review-6006
#                       controller | ReviewController
#                      category_id | 6006
#                         category |  Reference
#                          elapsed | 4571.741241
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 13568758
#                         complete | False
#                        completed | None
#                             apps | 372
#                          reviews | 105174
#                  apps_per_second | 0.08
#                 bytes_per_second | 2967.96
#               reviews_per_second | 23.01
#                         size_ave | 36475.155913978495
#
#
# [09/04/2023 03:45:30 AM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 341783cb-da68-4d58-b001-81d1027b5a05
#                            jobid | review-6006
#                       controller | ReviewController
#                      category_id | 6006
#                         category |  Reference
#                          elapsed | 4658.367387
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 13821466
#                         complete | False
#                        completed | None
#                             apps | 381
#                          reviews | 106450
#                  apps_per_second | 0.08
#                 bytes_per_second | 2967.02
#               reviews_per_second | 22.85
#                         size_ave | 36276.813648293966
#
#
# [09/04/2023 03:47:12 AM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 341783cb-da68-4d58-b001-81d1027b5a05
#                            jobid | review-6006
#                       controller | ReviewController
#                      category_id | 6006
#                         category |  Reference
#                          elapsed | 4758.998068
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 14248797
#                         complete | False
#                        completed | None
#                             apps | 390
#                          reviews | 109521
#                  apps_per_second | 0.08
#                 bytes_per_second | 2994.07
#               reviews_per_second | 23.01
#                         size_ave | 36535.376923076925
#
#
# [09/04/2023 03:48:57 AM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 341783cb-da68-4d58-b001-81d1027b5a05
#                            jobid | review-6006
#                       controller | ReviewController
#                      category_id | 6006
#                         category |  Reference
#                          elapsed | 4868.490763
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 14487310
#                         complete | False
#                        completed | None
#                             apps | 400
#                          reviews | 111386
#                  apps_per_second | 0.08
#                 bytes_per_second | 2975.73
#               reviews_per_second | 22.88
#                         size_ave | 36218.275
#
#
# [09/04/2023 03:51:00 AM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 341783cb-da68-4d58-b001-81d1027b5a05
#                            jobid | review-6006
#                       controller | ReviewController
#                      category_id | 6006
#                         category |  Reference
#                          elapsed | 4991.297541
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 14956363
#                         complete | False
#                        completed | None
#                             apps | 410
#                          reviews | 115757
#                  apps_per_second | 0.08
#                 bytes_per_second | 2996.49
#               reviews_per_second | 23.19
#                         size_ave | 36478.93414634146
#
#
# [09/04/2023 03:52:51 AM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 341783cb-da68-4d58-b001-81d1027b5a05
#                            jobid | review-6006
#                       controller | ReviewController
#                      category_id | 6006
#                         category |  Reference
#                          elapsed | 5101.380494
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 15156989
#                         complete | False
#                        completed | None
#                             apps | 419
#                          reviews | 117169
#                  apps_per_second | 0.08
#                 bytes_per_second | 2971.15
#               reviews_per_second | 22.97
#                         size_ave | 36174.19809069212
#
#
# [09/04/2023 03:54:55 AM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 341783cb-da68-4d58-b001-81d1027b5a05
#                            jobid | review-6006
#                       controller | ReviewController
#                      category_id | 6006
#                         category |  Reference
#                          elapsed | 5226.350518
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 15494065
#                         complete | False
#                        completed | None
#                             apps | 429
#                          reviews | 118988
#                  apps_per_second | 0.08
#                 bytes_per_second | 2964.61
#               reviews_per_second | 22.77
#                         size_ave | 36116.70163170163
#
#
# [09/04/2023 03:56:13 AM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 341783cb-da68-4d58-b001-81d1027b5a05
#                            jobid | review-6006
#                       controller | ReviewController
#                      category_id | 6006
#                         category |  Reference
#                          elapsed | 5304.080608
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 15640613
#                         complete | False
#                        completed | None
#                             apps | 438
#                          reviews | 120243
#                  apps_per_second | 0.08
#                 bytes_per_second | 2948.79
#               reviews_per_second | 22.67
#                         size_ave | 35709.16210045662
#
#
# [09/04/2023 04:00:34 AM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 341783cb-da68-4d58-b001-81d1027b5a05
#                            jobid | review-6006
#                       controller | ReviewController
#                      category_id | 6006
#                         category |  Reference
#                          elapsed | 5554.718563
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 15884171
#                         complete | False
#                        completed | None
#                             apps | 457
#                          reviews | 122010
#                  apps_per_second | 0.08
#                 bytes_per_second | 2859.58
#               reviews_per_second | 21.97
#                         size_ave | 34757.48577680525
#
#
# [09/04/2023 04:01:57 AM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 341783cb-da68-4d58-b001-81d1027b5a05
#                            jobid | review-6006
#                       controller | ReviewController
#                      category_id | 6006
#                         category |  Reference
#                          elapsed | 5648.285316
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 16126698
#                         complete | False
#                        completed | None
#                             apps | 466
#                          reviews | 123979
#                  apps_per_second | 0.08
#                 bytes_per_second | 2855.15
#               reviews_per_second | 21.95
#                         size_ave | 34606.64806866953
#
#
# [09/04/2023 04:03:40 AM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 341783cb-da68-4d58-b001-81d1027b5a05
#                            jobid | review-6006
#                       controller | ReviewController
#                      category_id | 6006
#                         category |  Reference
#                          elapsed | 5751.690325
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 16279141
#                         complete | False
#                        completed | None
#                             apps | 476
#                          reviews | 125046
#                  apps_per_second | 0.08
#                 bytes_per_second | 2830.32
#               reviews_per_second | 21.74
#                         size_ave | 34199.87605042017
#
#
# [09/04/2023 04:07:41 AM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 341783cb-da68-4d58-b001-81d1027b5a05
#                            jobid | review-6006
#                       controller | ReviewController
#                      category_id | 6006
#                         category |  Reference
#                          elapsed | 5978.922463
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 16551345
#                         complete | False
#                        completed | None
#                             apps | 495
#                          reviews | 126991
#                  apps_per_second | 0.08
#                 bytes_per_second | 2768.28
#               reviews_per_second | 21.24
#                         size_ave | 33437.06060606061
#
#
# [09/04/2023 04:09:23 AM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 341783cb-da68-4d58-b001-81d1027b5a05
#                            jobid | review-6006
#                       controller | ReviewController
#                      category_id | 6006
#                         category |  Reference
#                          elapsed | 6094.94153
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 16858633
#                         complete | False
#                        completed | None
#                             apps | 505
#                          reviews | 129283
#                  apps_per_second | 0.08
#                 bytes_per_second | 2766.0
#               reviews_per_second | 21.21
#                         size_ave | 33383.43168316832
#
#
# [09/04/2023 04:10:56 AM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 341783cb-da68-4d58-b001-81d1027b5a05
#                            jobid | review-6006
#                       controller | ReviewController
#                      category_id | 6006
#                         category |  Reference
#                          elapsed | 6187.033425
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 17041460
#                         complete | False
#                        completed | None
#                             apps | 514
#                          reviews | 130259
#                  apps_per_second | 0.08
#                 bytes_per_second | 2754.38
#               reviews_per_second | 21.05
#                         size_ave | 33154.59143968872
#
#
# [09/04/2023 04:12:29 AM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 341783cb-da68-4d58-b001-81d1027b5a05
#                            jobid | review-6006
#                       controller | ReviewController
#                      category_id | 6006
#                         category |  Reference
#                          elapsed | 6280.572484
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 17151545
#                         complete | False
#                        completed | None
#                             apps | 523
#                          reviews | 130982
#                  apps_per_second | 0.08
#                 bytes_per_second | 2730.89
#               reviews_per_second | 20.86
#                         size_ave | 32794.54110898662
#
#
# [09/04/2023 04:14:00 AM] [INFO] [ReviewJobRun] [announce] :
#
#                           ReviewJobRun
#                               id | 341783cb-da68-4d58-b001-81d1027b5a05
#                            jobid | review-6006
#                       controller | ReviewController
#                      category_id | 6006
#                         category |  Reference
#                          elapsed | 6371.790677
#                    client_errors | 0
#                    server_errors | 0
#                      data_errors | 0
#                           errors | 0
#                             size | 17408141
#                         complete | False
#                        completed | None
#                             apps | 533
#                          reviews | 132934
#                  apps_per_second | 0.08
#                 bytes_per_second | 2732.06
#               reviews_per_second | 20.86
#                         size_ave | 32660.677298311446
#
#
# [09/04/2023 04:14:24 AM] [WARNING] [urllib3.connectionpool] [urlopen] : Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 502 Bad Gateway'))': /WebObjects/MZStore.woa/wa/userReviewsRow?id=590361989&displayable-kind=11&startIndex=3600&endIndex=4000&sort=1
# [09/04/2023 04:14:24 AM] [ERROR] [SessionHandler] [get] : A <class 'TypeError'> exception occurred.
# unsupported operand type(s) for *: 'NoneType' and 'int'
# Retrying with retry #1.
# Traceback (most recent call last):
#   File "/home/john/anaconda3/envs/appvoc/lib/python3.10/site-packages/urllib3/connectionpool.py", line 711, in urlopen
#     self._prepare_proxy(conn)
#   File "/home/john/anaconda3/envs/appvoc/lib/python3.10/site-packages/urllib3/connectionpool.py", line 1007, in _prepare_proxy
#     conn.connect()
#   File "/home/john/anaconda3/envs/appvoc/lib/python3.10/site-packages/urllib3/connection.py", line 374, in connect
#     self._tunnel()
#   File "/home/john/anaconda3/envs/appvoc/lib/python3.10/http/client.py", line 925, in _tunnel
#     raise OSError(f"Tunnel connection failed: {code} {message.strip()}")
# OSError: Tunnel connection failed: 502 Bad Gateway
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/john/projects/appvoc/appvoc/infrastructure/web/session.py", line 80, in get
#     response = self._session.get(
#   File "/home/john/anaconda3/envs/appvoc/lib/python3.10/site-packages/requests/sessions.py", line 602, in get
#     return self.request("GET", url, **kwargs)
#   File "/home/john/anaconda3/envs/appvoc/lib/python3.10/site-packages/requests/sessions.py", line 589, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/home/john/anaconda3/envs/appvoc/lib/python3.10/site-packages/requests/sessions.py", line 703, in send
#     r = adapter.send(request, **kwargs)
#   File "/home/john/projects/appvoc/appvoc/infrastructure/web/adapter.py", line 35, in send
#     return super().send(request, **kwargs)
#   File "/home/john/anaconda3/envs/appvoc/lib/python3.10/site-packages/requests/adapters.py", line 486, in send
#     resp = conn.urlopen(
#   File "/home/john/anaconda3/envs/appvoc/lib/python3.10/site-packages/urllib3/connectionpool.py", line 826, in urlopen
#     return self.urlopen(
#   File "/home/john/anaconda3/envs/appvoc/lib/python3.10/site-packages/urllib3/connectionpool.py", line 801, in urlopen
#     retries.sleep()
#   File "/home/john/anaconda3/envs/appvoc/lib/python3.10/site-packages/urllib3/util/retry.py", line 432, in sleep
#     self._sleep_backoff()
#   File "/home/john/anaconda3/envs/appvoc/lib/python3.10/site-packages/urllib3/util/retry.py", line 413, in _sleep_backoff
#     backoff = self.get_backoff_time()
#   File "/home/john/anaconda3/envs/appvoc/lib/python3.10/site-packages/urllib3/util/retry.py", line 368, in get_backoff_time
#     backoff_value = self.backoff_factor * (2 ** (consecutive_errors_len - 1))
# TypeError: unsupported operand type(s) for *: 'NoneType' and 'int'
# [09/04/2023 04:14:24 AM] [WARNING] [urllib3.connectionpool] [urlopen] : Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 502 Bad Gateway'))': /WebObjects/MZStore.woa/wa/userReviewsRow?id=590361989&displayable-kind=11&startIndex=3600&endIndex=4000&sort=1
# [09/04/2023 04:14:24 AM] [ERROR] [SessionHandler] [get] : A <class 'TypeError'> exception occurred.
# unsupported operand type(s) for *: 'NoneType' and 'int'
# Retrying with retry #2.
# Traceback (most recent call last):
#   File "/home/john/anaconda3/envs/appvoc/lib/python3.10/site-packages/urllib3/connectionpool.py", line 711, in urlopen
#     self._prepare_proxy(conn)
#   File "/home/john/anaconda3/envs/appvoc/lib/python3.10/site-packages/urllib3/connectionpool.py", line 1007, in _prepare_proxy
#     conn.connect()
#   File "/home/john/anaconda3/envs/appvoc/lib/python3.10/site-packages/urllib3/connection.py", line 374, in connect
#     self._tunnel()
#   File "/home/john/anaconda3/envs/appvoc/lib/python3.10/http/client.py", line 925, in _tunnel
#     raise OSError(f"Tunnel connection failed: {code} {message.strip()}")
# OSError: Tunnel connection failed: 502 Bad Gateway
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/john/projects/appvoc/appvoc/infrastructure/web/session.py", line 80, in get
#     response = self._session.get(
#   File "/home/john/anaconda3/envs/appvoc/lib/python3.10/site-packages/requests/sessions.py", line 602, in get
#     return self.request("GET", url, **kwargs)
#   File "/home/john/anaconda3/envs/appvoc/lib/python3.10/site-packages/requests/sessions.py", line 589, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/home/john/anaconda3/envs/appvoc/lib/python3.10/site-packages/requests/sessions.py", line 703, in send
#     r = adapter.send(request, **kwargs)
#   File "/home/john/projects/appvoc/appvoc/infrastructure/web/adapter.py", line 35, in send
#     return super().send(request, **kwargs)
#   File "/home/john/anaconda3/envs/appvoc/lib/python3.10/site-packages/requests/adapters.py", line 486, in send
#     resp = conn.urlopen(
#   File "/home/john/anaconda3/envs/appvoc/lib/python3.10/site-packages/urllib3/connectionpool.py", line 826, in urlopen
#     return self.urlopen(
#   File "/home/john/anaconda3/envs/appvoc/lib/python3.10/site-packages/urllib3/connectionpool.py", line 801, in urlopen
#     retries.sleep()
#   File "/home/john/anaconda3/envs/appvoc/lib/python3.10/site-packages/urllib3/util/retry.py", line 432, in sleep
#     self._sleep_backoff()
#   File "/home/john/anaconda3/envs/appvoc/lib/python3.10/site-packages/urllib3/util/retry.py", line 413, in _sleep_backoff
#     backoff = self.get_backoff_time()
#   File "/home/john/anaconda3/envs/appvoc/lib/python3.10/site-packages/urllib3/util/retry.py", line 368, in get_backoff_time
#     backoff_value = self.backoff_factor * (2 ** (consecutive_errors_len - 1))
# TypeError: unsupported operand type(s) for *: 'NoneType' and 'int'
# [09/04/2023 04:14:25 AM] [WARNING] [urllib3.connectionpool] [urlopen] : Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 502 Bad Gateway'))': /WebObjects/MZStore.woa/wa/userReviewsRow?id=590361989&displayable-kind=11&startIndex=3600&endIndex=4000&sort=1
# [09/04/2023 04:14:25 AM] [ERROR] [SessionHandler] [get] : A <class 'TypeError'> exception occurred.
# unsupported operand type(s) for *: 'NoneType' and 'int'
# Retrying with retry #3.
# Traceback (most recent call last):
#   File "/home/john/anaconda3/envs/appvoc/lib/python3.10/site-packages/urllib3/connectionpool.py", line 711, in urlopen
#     self._prepare_proxy(conn)
#   File "/home/john/anaconda3/envs/appvoc/lib/python3.10/site-packages/urllib3/connectionpool.py", line 1007, in _prepare_proxy
#     conn.connect()
#   File "/home/john/anaconda3/envs/appvoc/lib/python3.10/site-packages/urllib3/connection.py", line 374, in connect
#     self._tunnel()
#   File "/home/john/anaconda3/envs/appvoc/lib/python3.10/http/client.py", line 925, in _tunnel
#     raise OSError(f"Tunnel connection failed: {code} {message.strip()}")
# OSError: Tunnel connection failed: 502 Bad Gateway
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/john/projects/appvoc/appvoc/infrastructure/web/session.py", line 80, in get
#     response = self._session.get(
#   File "/home/john/anaconda3/envs/appvoc/lib/python3.10/site-packages/requests/sessions.py", line 602, in get
#     return self.request("GET", url, **kwargs)
#   File "/home/john/anaconda3/envs/appvoc/lib/python3.10/site-packages/requests/sessions.py", line 589, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/home/john/anaconda3/envs/appvoc/lib/python3.10/site-packages/requests/sessions.py", line 703, in send
#     r = adapter.send(request, **kwargs)
#   File "/home/john/projects/appvoc/appvoc/infrastructure/web/adapter.py", line 35, in send
#     return super().send(request, **kwargs)
#   File "/home/john/anaconda3/envs/appvoc/lib/python3.10/site-packages/requests/adapters.py", line 486, in send
#     resp = conn.urlopen(
#   File "/home/john/anaconda3/envs/appvoc/lib/python3.10/site-packages/urllib3/connectionpool.py", line 826, in urlopen
#     return self.urlopen(
#   File "/home/john/anaconda3/envs/appvoc/lib/python3.10/site-packages/urllib3/connectionpool.py", line 801, in urlopen
#     retries.sleep()
#   File "/home/john/anaconda3/envs/appvoc/lib/python3.10/site-packages/urllib3/util/retry.py", line 432, in sleep
#     self._sleep_backoff()
#   File "/home/john/anaconda3/envs/appvoc/lib/python3.10/site-packages/urllib3/util/retry.py", line 413, in _sleep_backoff
#     backoff = self.get_backoff_time()
#   File "/home/john/anaconda3/envs/appvoc/lib/python3.10/site-packages/urllib3/util/retry.py", line 368, in get_backoff_time
#     backoff_value = self.backoff_factor * (2 ** (consecutive_errors_len - 1))
# TypeError: unsupported operand type(s) for *: 'NoneType' and 'int'
# [09/04/2023 04:14:25 AM] [ERROR] [SessionHandler] [get] : All retry and session limits have been reached. Exiting.
# NoneType: None
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 2
#       1 ctrl = ReviewController()
# ----> 2 ctrl.scrape()
#
# File ~/projects/appvoc/appvoc/data/acquisition/review/controller.py:83, in ReviewController.scrape(self)
#      81 """Entry point for scraping operation"""
#      82 if not super().is_locked():
# ---> 83     self._scrape()
#      84 else:  # pragma: no cover
#      85     msg = f"Running {self.__class__.__name__} is not authorized at this time."
#
# File ~/projects/appvoc/appvoc/data/acquisition/review/controller.py:101, in ReviewController._scrape(self)
#      98 request = self._get_or_create_request_log(app=app)
#      99 jobrun.apps += 1
# --> 101 for result in self._scraper(
#     102     app=app,
#     103     max_pages=self._max_pages,
#     104     max_results_per_page=self._max_results_per_page,
#     105     start=request.last_index,
#     106 ):
#     107     if result.is_valid():
#     108         self._failures = 0
#
# File ~/projects/appvoc/appvoc/data/acquisition/review/scraper.py:74, in ReviewScraper.__next__(self)
#      70 result = ReviewResult()
#      72 response = self._session_handler.get(url=url, header=self._header)
# ---> 74 if validator.is_valid(response=response):
#      75     result.add_response(response=response, app=self._app, index=self._start_index)
#      76 else:  # pragma: no cover
#
# File ~/projects/appvoc/appvoc/data/acquisition/review/validator.py:44, in ReviewValidator.is_valid(self, response)
#      41 self.response = response
#      42 self.valid = True
# ---> 44 self._validate_status_code()
#      45 if self.valid:
#      46     self._validate_response_type()
#
# File ~/projects/appvoc/appvoc/data/acquisition/base.py:214, in Validator._validate_status_code(self)
#     212 def _validate_status_code(self) -> bool:
#     213     """Validates the response return code"""
# --> 214     self.status_code = int(self.response.status_code)
#     215     if not int(self.response.status_code) == 200:
#     216         self.valid = False
#
# AttributeError: 'NoneType' object has no attribute 'status_code'
