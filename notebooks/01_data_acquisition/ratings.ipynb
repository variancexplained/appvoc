# %% [markdown]
# # AppStore Ratings
# App Store apps are rated on a five-star scale. In this section, we extract the number of ratings on each of the five-points of the scale, as well as the total ratings and reviews.
#
# The AppStore Review entity is defined as follows.
#
# | #  | name        | description                                    | api_field            |
# |----|-------------|------------------------------------------------|----------------------|
# | 1  | id          | Unique app identifier                          | adamId               |
# | 2  | name        | App name                                       | name                 |
# | 3  | category_id | Four digit IOS category identifier             | categoryId           |
# | 4  | category    | The category in text                           | category             |
# | 5  | rating      | Average rating                                 | ratingAverage        |
# | 6  | reviews     | The total number of reviews                    | totalNumberOfReviews |
# | 7  | ratings     | The total number of ratings                    | ratingCount          |
# | 8  | onestar     | The count of one star ratings                  | ratingCountList      |
# | 9  | twostar     | The count of two star ratings                  | ratingCountList      |
# | 10 | threestar   | The count of three star ratings                | ratingCountList      |
# | 11 | fourstar    | The count of four star ratings                 | ratingCountList      |
# | 12 | fivestar    | The count of five star ratings                 | ratingCountList      |
# | 13 | source      | The base url from which the data were obtained | itunes.apple.com     |
#
# Ratings will be extracted by category of apps in the appdata repository. Concretely, ratings will be obtained for the following categories:
#
# | ID   | NAME                   |
# |------|------------------------|
# | 6018 |  "BOOKS",              |
# | 6000 |  "BUSINESS",           |
# | 6017 |  "EDUCATION",          |
# | 6016 |  "ENTERTAINMENT",      |
# | 6015 |  "FINANCE",            |
# | 6023 |  "FOOD_AND_DRINK",     |
# | 6013 |  "HEALTH_AND_FITNESS", |
# | 6012 |  "LIFESTYLE",          |
# | 6020 |  "MEDICAL",            |
# | 6011 |  "MUSIC",              |
# | 6008 |  "PHOTO_AND_VIDEO",    |
# | 6007 |  "PRODUCTIVITY",       |
# | 6006 |  "REFERENCE",          |
# | 6024 |  "SHOPPING",           |
# | 6005 |  "SOCIAL_NETWORKING",  |
# | 6003 |  "TRAVEL",             |
# | 6002 |  "UTILITIES",          |

# %% [markdown]
# **Imports**

# %%
import asyncio
from aimobile.data.acquisition.rating.controller import RatingController
from aimobile.data.acquisition import AppStoreTargetCategories
from aimobile.container import AIMobileContainer

# %%
CATEGORIES = AppStoreTargetCategories.IDS

# %% [markdown]
# ## AppStore Ratings
# RatingController iterates through the categories, extracting the apps from the repository and retrieves the rating data from the App Store. The results are persisted in the RatingRepo.

# %%
async def wire():
    container = AIMobileContainer()
    container.init_resources()
    container.wire(packages=["aimobile.data.acquisition"])

async def scrape():
    ctrl = RatingController()
    await ctrl.scrape(category_ids=CATEGORIES)    
    ctrl.archive()

async def main():
    await asyncio.gather(wire(), scrape())

await main()
# Out:
# [05/24/2023 02:40:48 PM] [INFO] [RatingController] [_get_apps] :
#
# A total of 16808 apps in category 6002 to process.
# There are 0 apps in category 6002 which have already been processed.
# [05/24/2023 02:41:01 PM] [INFO] [AThrottle] [_monitor] : AThrottle:
# :	                  Count: | 100
# 	            Min Latency: | 1.120872
# 	            Min Latency: | 1.120872
# 	           Mean Latency: | 7.3190891
# 	            Max Latency: | 13.016897
# 	            Std Latency: | 3.3556186818276226
#
# 	              Min Delay: | 0.0012282589836793258
# 	             Mean Delay: | 0.11472325993710943
# 	              Max Delay: | 0.6814631902429613
# 	              Std Delay: | 0.11230257713153259
#
# [05/24/2023 02:41:01 PM] [INFO] [RatingController] [_announce] :
#
# RatingController
# 	                       Category: | 6002-UTILITIES
# 	                           Apps: | 100
# 	                        Elapsed: | 0:00:15.923999
# 	                Apps Per Second: | 6.28
#
# [05/24/2023 02:41:13 PM] [INFO] [AThrottle] [_monitor] : AThrottle:
# :	                  Count: | 200
# 	            Min Latency: | 0.735366
# 	            Min Latency: | 0.735366
# 	           Mean Latency: | 5.57244514
# 	            Max Latency: | 11.470295
# 	            Std Latency: | 3.04832931436675
#
# 	              Min Delay: | 0.003991784435948333
# 	             Mean Delay: | 0.1021514590216346
# 	              Max Delay: | 0.5037355370871847
# 	              Std Delay: | 0.09857574917048967
#
# [05/24/2023 02:41:13 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:41:13 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:41:13 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:41:13 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:41:13 PM] [INFO] [RatingController] [_announce] :
#
# RatingController
# 	                       Category: | 6002-UTILITIES
# 	                           Apps: | 196
# 	                        Elapsed: | 0:00:27.559901
# 	                Apps Per Second: | 7.11
#
# [05/24/2023 02:41:24 PM] [INFO] [AThrottle] [_monitor] : AThrottle:
# :	                  Count: | 300
# 	            Min Latency: | 0.933339
# 	            Min Latency: | 0.933339
# 	           Mean Latency: | 5.844855500000002
# 	            Max Latency: | 11.214778
# 	            Std Latency: | 3.120402538787528
#
# 	              Min Delay: | 0.0014007595884132722
# 	             Mean Delay: | 0.09626901307623313
# 	              Max Delay: | 0.5904448307980467
# 	              Std Delay: | 0.08373880749766467
#
# [05/24/2023 02:41:26 PM] [INFO] [RatingController] [_announce] :
#
# RatingController
# 	                       Category: | 6002-UTILITIES
# 	                           Apps: | 296
# 	                        Elapsed: | 0:00:40.094999
# 	                Apps Per Second: | 7.38
#
# [05/24/2023 02:41:37 PM] [INFO] [AThrottle] [_monitor] : AThrottle:
# :	                  Count: | 400
# 	            Min Latency: | 0.893842
# 	            Min Latency: | 0.893842
# 	           Mean Latency: | 6.72822479
# 	            Max Latency: | 11.048981
# 	            Std Latency: | 2.8776046949251186
#
# 	              Min Delay: | 0.0005410145095048963
# 	             Mean Delay: | 0.09684718269914144
# 	              Max Delay: | 0.4315470816001716
# 	              Std Delay: | 0.08933841323786995
#
# [05/24/2023 02:41:37 PM] [INFO] [RatingController] [_announce] :
#
# RatingController
# 	                       Category: | 6002-UTILITIES
# 	                           Apps: | 396
# 	                        Elapsed: | 0:00:51.300813
# 	                Apps Per Second: | 7.72
#
# [05/24/2023 02:41:49 PM] [INFO] [AThrottle] [_monitor] : AThrottle:
# :	                  Count: | 500
# 	            Min Latency: | 0.701886
# 	            Min Latency: | 0.701886
# 	           Mean Latency: | 5.910569539999999
# 	            Max Latency: | 12.043038
# 	            Std Latency: | 3.120443485792311
#
# 	              Min Delay: | 2.258255888062247e-05
# 	             Mean Delay: | 0.09781093132825353
# 	              Max Delay: | 0.4541585810634824
# 	              Std Delay: | 0.09054220907771297
#
# [05/24/2023 02:41:49 PM] [INFO] [RatingController] [_announce] :
#
# RatingController
# 	                       Category: | 6002-UTILITIES
# 	                           Apps: | 496
# 	                        Elapsed: | 0:01:03.467453
# 	                Apps Per Second: | 7.82
#
# [05/24/2023 02:42:00 PM] [INFO] [AThrottle] [_monitor] : AThrottle:
# :	                  Count: | 600
# 	            Min Latency: | 0.744595
# 	            Min Latency: | 0.744595
# 	           Mean Latency: | 5.388334980000001
# 	            Max Latency: | 11.072892
# 	            Std Latency: | 2.7903830433173007
#
# 	              Min Delay: | 8.427712577515921e-05
# 	             Mean Delay: | 0.08713174582733293
# 	              Max Delay: | 0.4111631078449712
# 	              Std Delay: | 0.08885898920632208
#
# [05/24/2023 02:42:00 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:42:00 PM] [INFO] [RatingController] [_announce] :
#
# RatingController
# 	                       Category: | 6002-UTILITIES
# 	                           Apps: | 595
# 	                        Elapsed: | 0:01:14.691152
# 	                Apps Per Second: | 7.97
#
# [05/24/2023 02:42:21 PM] [INFO] [AThrottle] [_monitor] : AThrottle:
# :	                  Count: | 700
# 	            Min Latency: | 0.695183
# 	            Min Latency: | 0.695183
# 	           Mean Latency: | 6.605177940000001
# 	            Max Latency: | 20.84454
# 	            Std Latency: | 3.784608460472446
#
# 	              Min Delay: | 4.7750007675050965e-05
# 	             Mean Delay: | 0.10026039663552105
# 	              Max Delay: | 0.4291670084662042
# 	              Std Delay: | 0.08654564277200548
#
# [05/24/2023 02:42:21 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:42:21 PM] [INFO] [RatingController] [_announce] :
#
# RatingController
# 	                       Category: | 6002-UTILITIES
# 	                           Apps: | 694
# 	                        Elapsed: | 0:01:35.814654
# 	                Apps Per Second: | 7.24
#
# [05/24/2023 02:42:36 PM] [INFO] [AThrottle] [_monitor] : AThrottle:
# :	                  Count: | 800
# 	            Min Latency: | 0.766258
# 	            Min Latency: | 0.766258
# 	           Mean Latency: | 7.3312171699999995
# 	            Max Latency: | 14.062906
# 	            Std Latency: | 3.88234783034009
#
# 	              Min Delay: | 0.000893672450074537
# 	             Mean Delay: | 0.12557422443330724
# 	              Max Delay: | 0.5151288762072225
# 	              Std Delay: | 0.11898686404507614
#
# [05/24/2023 02:42:36 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:42:36 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:42:36 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:42:36 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:42:36 PM] [INFO] [RatingController] [_announce] :
#
# RatingController
# 	                       Category: | 6002-UTILITIES
# 	                           Apps: | 790
# 	                        Elapsed: | 0:01:50.147372
# 	                Apps Per Second: | 7.17
#
# [05/24/2023 02:42:59 PM] [INFO] [AThrottle] [_monitor] : AThrottle:
# :	                  Count: | 900
# 	            Min Latency: | 0.770223
# 	            Min Latency: | 0.770223
# 	           Mean Latency: | 6.2523102800000006
# 	            Max Latency: | 22.766416
# 	            Std Latency: | 3.632313847469115
#
# 	              Min Delay: | 0.0006342328972083163
# 	             Mean Delay: | 0.1040526096958056
# 	              Max Delay: | 0.6391659175606657
# 	              Std Delay: | 0.1003798475963645
#
# [05/24/2023 02:43:02 PM] [INFO] [RatingController] [_announce] :
#
# RatingController
# 	                       Category: | 6002-UTILITIES
# 	                           Apps: | 890
# 	                        Elapsed: | 0:02:16.509526
# 	                Apps Per Second: | 6.52
#
# [05/24/2023 02:43:17 PM] [INFO] [AThrottle] [_monitor] : AThrottle:
# :	                  Count: | 1000
# 	            Min Latency: | 0.717401
# 	            Min Latency: | 0.717401
# 	           Mean Latency: | 5.9799058
# 	            Max Latency: | 15.187574
# 	            Std Latency: | 3.2362229399985036
#
# 	              Min Delay: | 6.530062294608578e-05
# 	             Mean Delay: | 0.09406708378596529
# 	              Max Delay: | 0.5906566990090035
# 	              Std Delay: | 0.10091971296865682
#
# [05/24/2023 02:43:17 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:43:17 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:43:17 PM] [INFO] [RatingController] [_announce] :
#
# RatingController
# 	                       Category: | 6002-UTILITIES
# 	                           Apps: | 988
# 	                        Elapsed: | 0:02:31.974820
# 	                Apps Per Second: | 6.5
#
# [05/24/2023 02:43:45 PM] [INFO] [AThrottle] [_monitor] : AThrottle:
# :	                  Count: | 1100
# 	            Min Latency: | 0.812338
# 	            Min Latency: | 0.812338
# 	           Mean Latency: | 9.498895210000002
# 	            Max Latency: | 27.027902
# 	            Std Latency: | 4.218727560442405
#
# 	              Min Delay: | 0.001879775795454608
# 	             Mean Delay: | 0.1347219940699122
# 	              Max Delay: | 0.8984593194768815
# 	              Std Delay: | 0.1541887147791167
#
# [05/24/2023 02:43:45 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:43:45 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:43:45 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:43:45 PM] [INFO] [RatingController] [_announce] :
#
# RatingController
# 	                       Category: | 6002-UTILITIES
# 	                           Apps: | 1085
# 	                        Elapsed: | 0:02:59.335475
# 	                Apps Per Second: | 6.05
#
# [05/24/2023 02:43:57 PM] [INFO] [AThrottle] [_monitor] : AThrottle:
# :	                  Count: | 1200
# 	            Min Latency: | 0.818836
# 	            Min Latency: | 0.818836
# 	           Mean Latency: | 6.2294979999999995
# 	            Max Latency: | 11.740884
# 	            Std Latency: | 3.0987151387240908
#
# 	              Min Delay: | 0.0006228613262392237
# 	             Mean Delay: | 0.10321551142701058
# 	              Max Delay: | 0.4942599340404996
# 	              Std Delay: | 0.10170201605843875
#
# [05/24/2023 02:43:57 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:43:57 PM] [INFO] [RatingController] [_announce] :
#
# RatingController
# 	                       Category: | 6002-UTILITIES
# 	                           Apps: | 1184
# 	                        Elapsed: | 0:03:11.233286
# 	                Apps Per Second: | 6.19
#
# [05/24/2023 02:44:08 PM] [INFO] [AThrottle] [_monitor] : AThrottle:
# :	                  Count: | 1300
# 	            Min Latency: | 0.792014
# 	            Min Latency: | 0.792014
# 	           Mean Latency: | 5.40914261
# 	            Max Latency: | 11.052142
# 	            Std Latency: | 2.8291648233740148
#
# 	              Min Delay: | 1.355435110402331e-05
# 	             Mean Delay: | 0.0888309945927529
# 	              Max Delay: | 0.37179109700860574
# 	              Std Delay: | 0.08418866961983199
#
# [05/24/2023 02:44:08 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:44:08 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:44:08 PM] [INFO] [RatingController] [_announce] :
#
# RatingController
# 	                       Category: | 6002-UTILITIES
# 	                           Apps: | 1282
# 	                        Elapsed: | 0:03:22.406840
# 	                Apps Per Second: | 6.33
#
# [05/24/2023 02:44:18 PM] [INFO] [AThrottle] [_monitor] : AThrottle:
# :	                  Count: | 1400
# 	            Min Latency: | 0.840632
# 	            Min Latency: | 0.840632
# 	           Mean Latency: | 5.36265707
# 	            Max Latency: | 10.162419
# 	            Std Latency: | 2.810830758897583
#
# 	              Min Delay: | 0.00029723245240566185
# 	             Mean Delay: | 0.08757638302837512
# 	              Max Delay: | 0.38886001678856474
# 	              Std Delay: | 0.08564769604552258
#
# [05/24/2023 02:44:18 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:44:18 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:44:18 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:44:18 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:44:18 PM] [INFO] [RatingController] [_announce] :
#
# RatingController
# 	                       Category: | 6002-UTILITIES
# 	                           Apps: | 1378
# 	                        Elapsed: | 0:03:32.800475
# 	                Apps Per Second: | 6.48
#
# [05/24/2023 02:44:30 PM] [INFO] [AThrottle] [_monitor] : AThrottle:
# :	                  Count: | 1500
# 	            Min Latency: | 0.606857
# 	            Min Latency: | 0.606857
# 	           Mean Latency: | 5.946089250000001
# 	            Max Latency: | 12.029793
# 	            Std Latency: | 3.26639029950839
#
# 	              Min Delay: | 0.0017991577620839448
# 	             Mean Delay: | 0.10550733922121244
# 	              Max Delay: | 0.6064624078607525
# 	              Std Delay: | 0.10876834475660026
#
# [05/24/2023 02:44:30 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:44:30 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:44:30 PM] [INFO] [RatingController] [_announce] :
#
# RatingController
# 	                       Category: | 6002-UTILITIES
# 	                           Apps: | 1476
# 	                        Elapsed: | 0:03:44.984025
# 	                Apps Per Second: | 6.56
#
# [05/24/2023 02:44:51 PM] [INFO] [AThrottle] [_monitor] : AThrottle:
# :	                  Count: | 1600
# 	            Min Latency: | 0.746791
# 	            Min Latency: | 0.746791
# 	           Mean Latency: | 6.601228519999999
# 	            Max Latency: | 20.157602
# 	            Std Latency: | 3.804006876163634
#
# 	              Min Delay: | 0.0014977819989229221
# 	             Mean Delay: | 0.10522456258962047
# 	              Max Delay: | 0.52728037578904
# 	              Std Delay: | 0.10224512237250791
#
# [05/24/2023 02:44:51 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:44:51 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:44:51 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:44:51 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:44:51 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:44:51 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:44:51 PM] [ERROR] [MySQLDatabase] [insert] : Exception occurred during database insert.
# Exception type:type[sqlalchemy.exc.SQLAlchemyError]
# (pymysql.err.DataError) (1406, "Data too long for column 'name' at row 37")
# [SQL: INSERT INTO rating (id, name, category_id, category, rating, reviews, ratings, onestar, twostar, threestar, fourstar, fivestar) VALUES (%(id)s, %(name)s, %(category_id)s, %(category)s, %(rating)s, %(reviews)s, %(ratings)s, %(onestar)s, %(twostar)s, %(threestar)s, %(fourstar)s, %(fivestar)s)]
# [parameters: [{'id': 1532663695, 'name': 'LiveScan: Grab Text in Images', 'category_id': 6002, 'category': 'Utilities', 'rating': 4.0, 'reviews': 13, 'ratings': 13, 'onestar': 3, 'twostar': 0, 'threestar': 0, 'fourstar': 0, 'fivestar': 10}, {'id': 1602769239, 'name': '雷霆加速器-vpn全球网络加速器', 'category_id': 6002, 'category': 'Utilities', 'rating': 5.0, 'reviews': 116, 'ratings': 226, 'onestar': 7, 'twostar': 1, 'threestar': 2, 'fourstar': 8, 'fivestar': 208}, {'id': 625688151, 'name': 'Clean,Merge Duplicate Contacts', 'category_id': 6002, 'category': 'Utilities', 'rating': 4.0, 'reviews': 43, 'ratings': 9, 'onestar': 0, 'twostar': 1, 'threestar': 2, 'fourstar': 0, 'fivestar': 6}, {'id': 1475982979, 'name': 'North Shore Gas', 'category_id': 6002, 'category': 'Utilities', 'rating': 5.0, 'reviews': 13, 'ratings': 3077, 'onestar': 15, 'twostar': 12, 'threestar': 68, 'fourstar': 266, 'fivestar': 2716}, {'id': 6446653067, 'name': 'Police Scanner Radio & Fire +', 'category_id': 6002, 'category': 'Utilities', 'rating': 4.5, 'reviews': 1, 'ratings': 31, 'onestar': 3, 'twostar': 1, 'threestar': 0, 'fourstar': 1, 'fivestar': 26}, {'id': 1664266337, 'name': 'WalterAI: Search/Ask Anything', 'category_id': 6002, 'category': 'Utilities', 'rating': 4.5, 'reviews': 6, 'ratings': 103, 'onestar': 1, 'twostar': 0, 'threestar': 2, 'fourstar': 18, 'fivestar': 82}, {'id': 1585012983, 'name': 'Texas by Texas (TxT)', 'category_id': 6002, 'category': 'Utilities', 'rating': 3.0, 'reviews': 77, 'ratings': 169, 'onestar': 73, 'twostar': 12, 'threestar': 7, 'fourstar': 15, 'fivestar': 62}, {'id': 1593228108, 'name': 'QR Code Reader', 'category_id': 6002, 'category': 'Utilities', 'rating': 4.5, 'reviews': 13, 'ratings': 701, 'onestar': 11, 'twostar': 4, 'threestar': 26, 'fourstar': 77, 'fivestar': 583}  ... displaying 10 of 94 total bound parameter sets ...  {'id': 723888288, 'name': 'MyDialog', 'category_id': 6002, 'category': 'Utilities', 'rating': 4.5, 'reviews': 129, 'ratings': 1674, 'onestar': 77, 'twostar': 35, 'threestar': 87, 'fourstar': 159, 'fivestar': 1316}, {'id': 1191334332, 'name': 'BatteryPhone', 'category_id': 6002, 'category': 'Utilities', 'rating': 3.5, 'reviews': 65, 'ratings': 122, 'onestar': 22, 'twostar': 6, 'threestar': 17, 'fourstar': 23, 'fivestar': 54}]]
# (Background on this error at: https://sqlalche.me/e/20/9h9h)
# [05/24/2023 02:44:51 PM] [INFO] [RatingController] [_announce] :
#
# RatingController
# 	                       Category: | 6002-UTILITIES
# 	                           Apps: | 1570
# 	                        Elapsed: | 0:04:05.286803
# 	                Apps Per Second: | 6.4
#
# [05/24/2023 02:45:01 PM] [INFO] [AThrottle] [_monitor] : AThrottle:
# :	                  Count: | 1700
# 	            Min Latency: | 0.817481
# 	            Min Latency: | 0.817481
# 	           Mean Latency: | 5.8561198600000015
# 	            Max Latency: | 10.259042
# 	            Std Latency: | 2.5548513585171917
#
# 	              Min Delay: | 0.00010026425101464616
# 	             Mean Delay: | 0.08455437556975458
# 	              Max Delay: | 0.5482384576569004
# 	              Std Delay: | 0.08835693054975398
#
# [05/24/2023 02:45:01 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:45:01 PM] [INFO] [RatingController] [_announce] :
#
# RatingController
# 	                       Category: | 6002-UTILITIES
# 	                           Apps: | 1669
# 	                        Elapsed: | 0:04:15.697976
# 	                Apps Per Second: | 6.53
#
# [05/24/2023 02:45:14 PM] [INFO] [AThrottle] [_monitor] : AThrottle:
# :	                  Count: | 1800
# 	            Min Latency: | 0.566992
# 	            Min Latency: | 0.566992
# 	           Mean Latency: | 5.692909759999999
# 	            Max Latency: | 12.915976
# 	            Std Latency: | 3.0764697905129577
#
# 	              Min Delay: | 4.542382428015024e-06
# 	             Mean Delay: | 0.0977117912801517
# 	              Max Delay: | 0.5091842762397966
# 	              Std Delay: | 0.10454425723099092
#
# [05/24/2023 02:45:14 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:45:14 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:45:14 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:45:14 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:45:14 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:45:14 PM] [INFO] [RatingController] [_announce] :
#
# RatingController
# 	                       Category: | 6002-UTILITIES
# 	                           Apps: | 1764
# 	                        Elapsed: | 0:04:29.033724
# 	                Apps Per Second: | 6.56
#
# [05/24/2023 02:45:35 PM] [INFO] [AThrottle] [_monitor] : AThrottle:
# :	                  Count: | 1900
# 	            Min Latency: | 0.958708
# 	            Min Latency: | 0.958708
# 	           Mean Latency: | 7.18683074
# 	            Max Latency: | 20.263722
# 	            Std Latency: | 3.505748023594593
#
# 	              Min Delay: | 0.001423286992185518
# 	             Mean Delay: | 0.10639163554502608
# 	              Max Delay: | 0.6788881742994075
# 	              Std Delay: | 0.10826237407363917
#
# [05/24/2023 02:45:35 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:45:35 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:45:35 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:45:35 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:45:35 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:45:35 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:45:35 PM] [INFO] [RatingController] [_announce] :
#
# RatingController
# 	                       Category: | 6002-UTILITIES
# 	                           Apps: | 1858
# 	                        Elapsed: | 0:04:49.642610
# 	                Apps Per Second: | 6.41
#
# [05/24/2023 02:45:56 PM] [INFO] [AThrottle] [_monitor] : AThrottle:
# :	                  Count: | 2000
# 	            Min Latency: | 0.830907
# 	            Min Latency: | 0.830907
# 	           Mean Latency: | 6.80546076
# 	            Max Latency: | 20.603554
# 	            Std Latency: | 3.9729837342473
#
# 	              Min Delay: | 0.0006883091099274042
# 	             Mean Delay: | 0.10194468197977648
# 	              Max Delay: | 0.5603620533643293
# 	              Std Delay: | 0.11999209725635636
#
# [05/24/2023 02:45:56 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:45:56 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:45:56 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:45:56 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:45:56 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:45:56 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:45:56 PM] [INFO] [RatingController] [_announce] :
#
# RatingController
# 	                       Category: | 6002-UTILITIES
# 	                           Apps: | 1952
# 	                        Elapsed: | 0:05:10.454621
# 	                Apps Per Second: | 6.29
#
# [05/24/2023 02:46:09 PM] [INFO] [AThrottle] [_monitor] : AThrottle:
# :	                  Count: | 2100
# 	            Min Latency: | 1.007912
# 	            Min Latency: | 1.007912
# 	           Mean Latency: | 8.02517182
# 	            Max Latency: | 13.361392
# 	            Std Latency: | 3.3258606461822007
#
# 	              Min Delay: | 0.0005362061592778321
# 	             Mean Delay: | 0.1141218692891273
# 	              Max Delay: | 0.7254490541960581
# 	              Std Delay: | 0.12950461538993102
#
# [05/24/2023 02:46:09 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:46:09 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:46:09 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:46:09 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:46:09 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:46:09 PM] [INFO] [RatingController] [_announce] :
#
# RatingController
# 	                       Category: | 6002-UTILITIES
# 	                           Apps: | 2047
# 	                        Elapsed: | 0:05:24.008906
# 	                Apps Per Second: | 6.32
#
# [05/24/2023 02:46:22 PM] [INFO] [AThrottle] [_monitor] : AThrottle:
# :	                  Count: | 2200
# 	            Min Latency: | 1.064585
# 	            Min Latency: | 1.064585
# 	           Mean Latency: | 6.516554129999999
# 	            Max Latency: | 12.466681
# 	            Std Latency: | 3.14895336221936
#
# 	              Min Delay: | 0.0009898996149854539
# 	             Mean Delay: | 0.1044430467097064
# 	              Max Delay: | 0.709688556794349
# 	              Std Delay: | 0.11022004152823599
#
# [05/24/2023 02:46:22 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:46:22 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:46:22 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:46:22 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:46:22 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:46:22 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:46:22 PM] [INFO] [RatingController] [_announce] :
#
# RatingController
# 	                       Category: | 6002-UTILITIES
# 	                           Apps: | 2141
# 	                        Elapsed: | 0:05:36.675750
# 	                Apps Per Second: | 6.36
#
# [05/24/2023 02:46:36 PM] [INFO] [AThrottle] [_monitor] : AThrottle:
# :	                  Count: | 2300
# 	            Min Latency: | 0.850907
# 	            Min Latency: | 0.850907
# 	           Mean Latency: | 6.785853729999999
# 	            Max Latency: | 13.346986
# 	            Std Latency: | 2.9252368204412744
#
# 	              Min Delay: | 0.0009956798121300802
# 	             Mean Delay: | 0.0987303362677547
# 	              Max Delay: | 0.6714695962725226
# 	              Std Delay: | 0.10750871414604282
#
# [05/24/2023 02:46:36 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:46:36 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:46:36 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:46:36 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:46:36 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:46:36 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:46:36 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:46:36 PM] [INFO] [RatingController] [_announce] :
#
# RatingController
# 	                       Category: | 6002-UTILITIES
# 	                           Apps: | 2234
# 	                        Elapsed: | 0:05:50.327870
# 	                Apps Per Second: | 6.38
#
# [05/24/2023 02:46:47 PM] [INFO] [AThrottle] [_monitor] : AThrottle:
# :	                  Count: | 2400
# 	            Min Latency: | 0.716137
# 	            Min Latency: | 0.716137
# 	           Mean Latency: | 6.283180300000001
# 	            Max Latency: | 11.437691
# 	            Std Latency: | 3.034352209682862
#
# 	              Min Delay: | 0.0021831156204227546
# 	             Mean Delay: | 0.09936475501465686
# 	              Max Delay: | 0.5933086042691745
# 	              Std Delay: | 0.10653166944891299
#
# [05/24/2023 02:46:47 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:46:47 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:46:47 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:46:47 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:46:47 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:46:47 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:46:47 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:46:47 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:46:47 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:46:47 PM] [INFO] [RatingController] [_announce] :
#
# RatingController
# 	                       Category: | 6002-UTILITIES
# 	                           Apps: | 2325
# 	                        Elapsed: | 0:06:01.941716
# 	                Apps Per Second: | 6.42
#
# [05/24/2023 02:47:00 PM] [INFO] [AThrottle] [_monitor] : AThrottle:
# :	                  Count: | 2500
# 	            Min Latency: | 0.621969
# 	            Min Latency: | 0.621969
# 	           Mean Latency: | 6.65346735
# 	            Max Latency: | 11.7973
# 	            Std Latency: | 3.1275248287743977
#
# 	              Min Delay: | 2.486577917818248e-05
# 	             Mean Delay: | 0.10466845309362618
# 	              Max Delay: | 0.3770611335204725
# 	              Std Delay: | 0.09647619016343219
#
# [05/24/2023 02:47:00 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:47:00 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:47:00 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:47:00 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:47:00 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:47:00 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:47:00 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:47:00 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:47:00 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:47:00 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:47:00 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:47:00 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:47:00 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:47:00 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:47:00 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:47:00 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:47:00 PM] [INFO] [RatingController] [_announce] :
#
# RatingController
# 	                       Category: | 6002-UTILITIES
# 	                           Apps: | 2409
# 	                        Elapsed: | 0:06:14.235270
# 	                Apps Per Second: | 6.44
#
# [05/24/2023 02:47:11 PM] [INFO] [AThrottle] [_monitor] : AThrottle:
# :	                  Count: | 2600
# 	            Min Latency: | 0.852679
# 	            Min Latency: | 0.852679
# 	           Mean Latency: | 5.28685741
# 	            Max Latency: | 10.760828
# 	            Std Latency: | 2.9571617826822196
#
# 	              Min Delay: | 0.0007037932598810458
# 	             Mean Delay: | 0.0905236405146186
# 	              Max Delay: | 0.4007038363471506
# 	              Std Delay: | 0.08303946573825058
#
# [05/24/2023 02:47:11 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:47:11 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:47:11 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:47:11 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:47:11 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:47:11 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:47:11 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:47:11 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:47:11 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:47:11 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:47:11 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:47:11 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:47:11 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:47:11 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:47:11 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:47:11 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:47:11 PM] [INFO] [RatingController] [_announce] :
#
# RatingController
# 	                       Category: | 6002-UTILITIES
# 	                           Apps: | 2493
# 	                        Elapsed: | 0:06:25.243404
# 	                Apps Per Second: | 6.47
#
# [05/24/2023 02:47:23 PM] [INFO] [AThrottle] [_monitor] : AThrottle:
# :	                  Count: | 2700
# 	            Min Latency: | 0.623784
# 	            Min Latency: | 0.623784
# 	           Mean Latency: | 6.401969299999999
# 	            Max Latency: | 11.821463
# 	            Std Latency: | 3.392852853795403
#
# 	              Min Delay: | 0.0005561394390828466
# 	             Mean Delay: | 0.10443915174107887
# 	              Max Delay: | 0.5976861022238795
# 	              Std Delay: | 0.10636548479561193
#
# [05/24/2023 02:47:23 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:47:23 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:47:23 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:47:23 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:47:23 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:47:23 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:47:23 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:47:23 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:47:23 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:47:23 PM] [INFO] [RatingController] [_announce] :
#
# RatingController
# 	                       Category: | 6002-UTILITIES
# 	                           Apps: | 2584
# 	                        Elapsed: | 0:06:37.396576
# 	                Apps Per Second: | 6.5
#
# [05/24/2023 02:47:38 PM] [INFO] [AThrottle] [_monitor] : AThrottle:
# :	                  Count: | 2800
# 	            Min Latency: | 0.714113
# 	            Min Latency: | 0.714113
# 	           Mean Latency: | 6.39618163
# 	            Max Latency: | 15.581434
# 	            Std Latency: | 3.4596575626092614
#
# 	              Min Delay: | 0.0008545939921293093
# 	             Mean Delay: | 0.10586460486645854
# 	              Max Delay: | 0.6389055166072499
# 	              Std Delay: | 0.10477322288964787
#
# [05/24/2023 02:47:38 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:47:38 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:47:38 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:47:38 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:47:38 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:47:39 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:47:39 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:47:39 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:47:39 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:47:39 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:47:39 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:47:39 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:47:39 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:47:39 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:47:39 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:47:39 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:47:39 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:47:39 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:47:39 PM] [INFO] [RatingController] [_announce] :
#
# RatingController
# 	                       Category: | 6002-UTILITIES
# 	                           Apps: | 2666
# 	                        Elapsed: | 0:06:53.131020
# 	                Apps Per Second: | 6.45
#
# [05/24/2023 02:47:50 PM] [INFO] [AThrottle] [_monitor] : AThrottle:
# :	                  Count: | 2900
# 	            Min Latency: | 0.644139
# 	            Min Latency: | 0.644139
# 	           Mean Latency: | 6.1844977100000005
# 	            Max Latency: | 10.791359
# 	            Std Latency: | 2.9921010743442182
#
# 	              Min Delay: | 0.0007847042698815789
# 	             Mean Delay: | 0.09577210673464419
# 	              Max Delay: | 0.5315804221480288
# 	              Std Delay: | 0.10225359504963291
#
# [05/24/2023 02:47:50 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:47:50 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:47:50 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:47:50 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 02:47:50 PM] [ERROR] [RatingScraper] [_parse_responses] :
# ...
#
# [05/24/2023 03:18:06 PM] [INFO] [AThrottle] [_monitor] : AThrottle:
# :	                  Count: | 15900
# 	            Min Latency: | 0.626024
# 	            Min Latency: | 0.626024
# 	           Mean Latency: | 5.702256129999999
# 	            Max Latency: | 10.823918
# 	            Std Latency: | 3.268706198481612
#
# 	              Min Delay: | 0.001454697855184232
# 	             Mean Delay: | 0.09528769248438029
# 	              Max Delay: | 0.5212175063029045
# 	              Std Delay: | 0.09063728379674167
#
# [05/24/2023 03:18:06 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 03:18:06 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 03:18:06 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 03:18:06 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 03:18:06 PM] [INFO] [RatingController] [_announce] :
#
# RatingController
# 	                       Category: | 6002-UTILITIES
# 	                           Apps: | 11731
# 	                        Elapsed: | 0:37:20.609641
# 	                Apps Per Second: | 5.24
#
# [05/24/2023 03:18:17 PM] [INFO] [AThrottle] [_monitor] : AThrottle:
# :	                  Count: | 16000
# 	            Min Latency: | 0.663391
# 	            Min Latency: | 0.663391
# 	           Mean Latency: | 5.4150869099999985
# 	            Max Latency: | 10.668292
# 	            Std Latency: | 2.9980009767377296
#
# 	              Min Delay: | 0.00016349616333139123
# 	             Mean Delay: | 0.09347551288936636
# 	              Max Delay: | 0.45089133013278176
# 	              Std Delay: | 0.09105712882945934
#
# [05/24/2023 03:18:17 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 03:18:17 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 03:18:17 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 03:18:17 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 03:18:17 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 03:18:17 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 03:18:17 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 03:18:17 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 03:18:17 PM] [INFO] [RatingController] [_announce] :
#
# RatingController
# 	                       Category: | 6002-UTILITIES
# 	                           Apps: | 11823
# 	                        Elapsed: | 0:37:31.455099
# 	                Apps Per Second: | 5.25
#
# [05/24/2023 03:18:45 PM] [INFO] [AThrottle] [_monitor] : AThrottle:
# :	                  Count: | 16100
# 	            Min Latency: | 0.75551
# 	            Min Latency: | 0.75551
# 	           Mean Latency: | 8.190604239999999
# 	            Max Latency: | 27.53939
# 	            Std Latency: | 4.292903724280313
#
# 	              Min Delay: | 0.0023331716005079
# 	             Mean Delay: | 0.12219373830546772
# 	              Max Delay: | 0.5125584679876329
# 	              Std Delay: | 0.11977449717865407
#
# [05/24/2023 03:18:45 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 03:18:45 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 03:18:45 PM] [INFO] [RatingController] [_announce] :
#
# RatingController
# 	                       Category: | 6002-UTILITIES
# 	                           Apps: | 11921
# 	                        Elapsed: | 0:37:59.262306
# 	                Apps Per Second: | 5.23
#
# [05/24/2023 03:18:58 PM] [INFO] [AThrottle] [_monitor] : AThrottle:
# :	                  Count: | 16200
# 	            Min Latency: | 0.646611
# 	            Min Latency: | 0.646611
# 	           Mean Latency: | 5.872926809999999
# 	            Max Latency: | 12.78915
# 	            Std Latency: | 3.2907580900794295
#
# 	              Min Delay: | 0.0005916219166682459
# 	             Mean Delay: | 0.10319447464839451
# 	              Max Delay: | 0.6276090005326961
# 	              Std Delay: | 0.11472483000030766
#
# [05/24/2023 03:18:58 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 03:18:58 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 03:18:58 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 03:18:58 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 03:18:58 PM] [INFO] [RatingController] [_announce] :
#
# RatingController
# 	                       Category: | 6002-UTILITIES
# 	                           Apps: | 12017
# 	                        Elapsed: | 0:38:12.483138
# 	                Apps Per Second: | 5.24
#
# [05/24/2023 03:19:12 PM] [INFO] [AThrottle] [_monitor] : AThrottle:
# :	                  Count: | 16300
# 	            Min Latency: | 0.794851
# 	            Min Latency: | 0.794851
# 	           Mean Latency: | 7.11390349
# 	            Max Latency: | 13.994767
# 	            Std Latency: | 3.5787974086225125
#
# 	              Min Delay: | 2.5160604168681555e-05
# 	             Mean Delay: | 0.12291627163830132
# 	              Max Delay: | 0.5885416054365002
# 	              Std Delay: | 0.12191069115769725
#
# [05/24/2023 03:19:12 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 03:19:12 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 03:19:12 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 03:19:12 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 03:19:12 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 03:19:12 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 03:19:12 PM] [INFO] [RatingController] [_announce] :
#
# RatingController
# 	                       Category: | 6002-UTILITIES
# 	                           Apps: | 12111
# 	                        Elapsed: | 0:38:26.702151
# 	                Apps Per Second: | 5.25
#
# [05/24/2023 03:19:25 PM] [INFO] [AThrottle] [_monitor] : AThrottle:
# :	                  Count: | 16400
# 	            Min Latency: | 0.768473
# 	            Min Latency: | 0.768473
# 	           Mean Latency: | 5.744842880000001
# 	            Max Latency: | 12.55001
# 	            Std Latency: | 2.815757774639336
#
# 	              Min Delay: | 5.8230357901838345e-06
# 	             Mean Delay: | 0.08390291868583183
# 	              Max Delay: | 0.4055299646625037
# 	              Std Delay: | 0.0944713914183883
#
# [05/24/2023 03:19:25 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 03:19:25 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 03:19:25 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 03:19:25 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 03:19:25 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 03:19:25 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 03:19:25 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 03:19:25 PM] [INFO] [RatingController] [_announce] :
#
# RatingController
# 	                       Category: | 6002-UTILITIES
# 	                           Apps: | 12204
# 	                        Elapsed: | 0:38:39.409551
# 	                Apps Per Second: | 5.26
#
# [05/24/2023 03:19:38 PM] [INFO] [AThrottle] [_monitor] : AThrottle:
# :	                  Count: | 16500
# 	            Min Latency: | 0.773525
# 	            Min Latency: | 0.773525
# 	           Mean Latency: | 6.688273309999999
# 	            Max Latency: | 12.744929
# 	            Std Latency: | 3.696845278860306
#
# 	              Min Delay: | 0.004326605825620682
# 	             Mean Delay: | 0.11478980290921349
# 	              Max Delay: | 0.5977175354894741
# 	              Std Delay: | 0.11444849177605154
#
# [05/24/2023 03:19:38 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 03:19:38 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 03:19:38 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 03:19:38 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 03:19:38 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 03:19:38 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 03:19:38 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 03:19:38 PM] [INFO] [RatingController] [_announce] :
#
# RatingController
# 	                       Category: | 6002-UTILITIES
# 	                           Apps: | 12297
# 	                        Elapsed: | 0:38:52.450456
# 	                Apps Per Second: | 5.27
#
# [05/24/2023 03:19:52 PM] [INFO] [AThrottle] [_monitor] : AThrottle:
# :	                  Count: | 16600
# 	            Min Latency: | 0.777222
# 	            Min Latency: | 0.777222
# 	           Mean Latency: | 5.519757060000001
# 	            Max Latency: | 13.708609
# 	            Std Latency: | 2.828867811799529
#
# 	              Min Delay: | 0.00016757496502524592
# 	             Mean Delay: | 0.0873577979967974
# 	              Max Delay: | 0.829466739852194
# 	              Std Delay: | 0.10191295197301022
#
# [05/24/2023 03:19:52 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 03:19:52 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 03:19:52 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 03:19:52 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 03:19:52 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 03:19:52 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 03:19:52 PM] [INFO] [RatingController] [_announce] :
#
# RatingController
# 	                       Category: | 6002-UTILITIES
# 	                           Apps: | 12391
# 	                        Elapsed: | 0:39:06.423238
# 	                Apps Per Second: | 5.28
#
# [05/24/2023 03:20:12 PM] [INFO] [AThrottle] [_monitor] : AThrottle:
# :	                  Count: | 16700
# 	            Min Latency: | 0.623254
# 	            Min Latency: | 0.623254
# 	           Mean Latency: | 6.34193506
# 	            Max Latency: | 19.998104
# 	            Std Latency: | 3.2545947819499887
#
# 	              Min Delay: | 0.00020279749262151872
# 	             Mean Delay: | 0.0980137033358675
# 	              Max Delay: | 0.44001661292488947
# 	              Std Delay: | 0.0948392786111286
#
# [05/24/2023 03:20:12 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 03:20:12 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 03:20:12 PM] [INFO] [RatingController] [_announce] :
#
# RatingController
# 	                       Category: | 6002-UTILITIES
# 	                           Apps: | 12489
# 	                        Elapsed: | 0:39:26.605641
# 	                Apps Per Second: | 5.28
#
# [05/24/2023 03:20:23 PM] [INFO] [AThrottle] [_monitor] : AThrottle:
# :	                  Count: | 16800
# 	            Min Latency: | 0.660127
# 	            Min Latency: | 0.660127
# 	           Mean Latency: | 5.90386342
# 	            Max Latency: | 11.110315
# 	            Std Latency: | 3.011803844823687
#
# 	              Min Delay: | 0.0013297477529810508
# 	             Mean Delay: | 0.09725469666609467
# 	              Max Delay: | 0.3017843450650537
# 	              Std Delay: | 0.07666541662720935
#
# [05/24/2023 03:20:23 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 03:20:23 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 03:20:23 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 03:20:23 PM] [ERROR] [RatingScraper] [_parse_responses] :
# Invalid response. Encountered <class 'KeyError'> exception. No result created.
# 'ratingAverage'
# [05/24/2023 03:20:23 PM] [INFO] [RatingController] [_announce] :
#
# RatingController
# 	                       Category: | 6002-UTILITIES
# 	                           Apps: | 12585
# 	                        Elapsed: | 0:39:37.963865
# 	                Apps Per Second: | 5.29
