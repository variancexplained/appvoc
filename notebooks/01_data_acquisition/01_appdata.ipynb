# %% [markdown]
# # AppData Acquisition
# Acquisition of the core descriptive, rating, and app data; collectively termed AppData, is encapsulated in this notebook. The data acquisition pipeline extracted 11 variables for 24 search terms, loosely corresponding to Apple's app category taxonomy.
#
# |               |            |              |
# |---------------|------------|--------------|
# | books         | health     | productivity |
# | business      | lifestyle  | reference    |
# | catalogs      | magazines  | shopping     |
# | education     | medical    | social       |
# | entertainment | music      | sports       |
# | finance       | navigation | travel       |
# | food          | news       | utilities    |
# | games         | photo      | weather      |
#
#
# The 11 appdata variables are:
#
# | #  | Variable                | Date Type  | Description                                |
# |----|-------------------------|------------|--------------------------------------------|
# | 1  | id                      | Nominal    | App Id from the App Store                  |
# | 2  | name                    | Nominal    | App Name                                   |
# | 3  | description             | Text       | App Description                            |
# | 4  | category_id             | Nominal    | Numeric category identifier                |
# | 5  | category                | Nominal    | Category name                              |
# | 6  | price                   | Continuous | App Price                                  |
# | 7  | developer_id            | Nominal    | Identifier for the developer               |
# | 8  | developer               | Nominal    | Name of the developer                      |
# | 9  | rating                  | Interval   | Average user rating since first released   |
# | 10 | ratings                 | Discrete   | Number of ratings since first release      |
# | 11 | released                | DateTime   | Datetime of first release                  |

# %%
from IPython.display import display, HTML

from appstore.container import AppstoreContainer
from appstore.data.acquisition.appdata.controller import AppDataController
from appstore.data.dataset.appdata import AppDataDataset

# %%
container = AppstoreContainer()
container.init_resources()
container.wire(packages=["appstore.data.acquisition", "appstore.data.dataset"])
repo = container.data.uow().appdata_repo

# %%
TERMS = ["books", "business", "catalogs", "education", "entertainment", "finance", "food", "games", "health", "lifestyle", "magazines", "medical", "music", "navigation", "news", "photo", "productivity", "reference", "shopping", "social", "sports", "travel", "utilities", "weather"]
DECK = ["business", "catalogs", "education", "entertainment", "finance", "food", "games", "health", "lifestyle", "magazines", "medical", "music", "navigation", "news", "photo", "productivity", "reference", "shopping", "social", "sports", "travel", "utilities", "weather"]

# %%
controller = AppDataController()
controller.scrape(terms=DECK)
# Out:
# [08/31/2023 05:36:56 AM] [INFO] [AppDataController] [_get_or_start_project] :
# Retrieved Project:
# None
# [08/31/2023 05:36:56 AM] [INFO] [AppDataController] [_get_or_start_project] :
#
# Started project for Business apps.
# [08/31/2023 05:38:16 AM] [INFO] [AppDataController] [_update_report_stats] : Term: Business	Pages: 10	Apps: 2000	Elapsed Time: 0:01:20.364541	Rate: 24.89 apps per second.
# [08/31/2023 05:39:36 AM] [INFO] [AppDataController] [_update_report_stats] : Term: Business	Pages: 20	Apps: 4000	Elapsed Time: 0:02:40.138430	Rate: 24.98 apps per second.
# [08/31/2023 05:40:05 AM] [INFO] [AppDataController] [_update_report_stats] : Term: Business	Pages: 30	Apps: 5988	Elapsed Time: 0:03:09.239488	Rate: 31.64 apps per second.
# [08/31/2023 05:40:27 AM] [INFO] [AppDataController] [_update_report_stats] : Term: Business	Pages: 40	Apps: 7947	Elapsed Time: 0:03:31.686944	Rate: 37.54 apps per second.
# [08/31/2023 05:40:36 AM] [INFO] [AppDataController] [_update_report_stats] : Term: Business	Pages: 50	Apps: 9898	Elapsed Time: 0:03:40.414890	Rate: 44.91 apps per second.
# [08/31/2023 05:40:45 AM] [INFO] [AppDataController] [_update_report_stats] : Term: Business	Pages: 60	Apps: 11822	Elapsed Time: 0:03:49.163036	Rate: 51.59 apps per second.
# [08/31/2023 05:42:32 AM] [INFO] [AppDataController] [_update_report_stats] : Term: Business	Pages: 70	Apps: 13702	Elapsed Time: 0:05:36.436193	Rate: 40.73 apps per second.
# [08/31/2023 05:44:21 AM] [INFO] [AppDataController] [_update_report_stats] : Term: Business	Pages: 80	Apps: 15574	Elapsed Time: 0:07:25.568557	Rate: 34.95 apps per second.
# [08/31/2023 05:46:19 AM] [INFO] [AppDataController] [_update_report_stats] : Term: Business	Pages: 90	Apps: 17396	Elapsed Time: 0:09:23.733514	Rate: 30.86 apps per second.
# [08/31/2023 05:48:21 AM] [INFO] [AppDataController] [_update_report_stats] : Term: Business	Pages: 100	Apps: 19225	Elapsed Time: 0:11:25.284975	Rate: 28.05 apps per second.
# [08/31/2023 05:50:59 AM] [INFO] [AppDataController] [_update_report_stats] : Term: Business	Pages: 110	Apps: 21018	Elapsed Time: 0:14:03.477246	Rate: 24.92 apps per second.
# [08/31/2023 05:51:11 AM] [INFO] [AppDataRepo] [dedup] : Repository with 21618 observations dropped 5587 duplicates leaving 16031 observations
# [08/31/2023 05:51:11 AM] [INFO] [AppDataController] [_complete_project] : Completed AppDataProject:
#
#
#                          AppDataProject
#                       controller | AppDataController
#                             term | business
#                           status | complete
#                        page_size | 200
#                            pages | 110
#                           vpages | 105
#                             apps | 21018
#                               id | 0
#
#
#
# [08/31/2023 05:51:11 AM] [INFO] [AppDataController] [_get_or_start_project] :
# Retrieved Project:
# None
# [08/31/2023 05:51:11 AM] [INFO] [AppDataController] [_get_or_start_project] :
#
# Started project for Catalogs apps.
# [08/31/2023 05:52:07 AM] [INFO] [AppDataController] [_update_report_stats] : Term: Catalogs	Pages: 10	Apps: 1327	Elapsed Time: 0:00:55.707220	Rate: 23.82 apps per second.
# [08/31/2023 05:53:22 AM] [INFO] [AppDataController] [_update_report_stats] : Term: Catalogs	Pages: 20	Apps: 2479	Elapsed Time: 0:02:10.920321	Rate: 18.94 apps per second.
# [08/31/2023 05:53:52 AM] [WARNING] [urllib3.connectionpool] [urlopen] : Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='itunes.apple.com', port=443): Read timed out. (read timeout=30)")': /search?media=software&term=catalogs&country=us&lang=en-us&explicit=yes&limit=200&offset=2479
# [08/31/2023 05:55:10 AM] [INFO] [AppDataController] [_update_report_stats] : Term: Catalogs	Pages: 30	Apps: 3698	Elapsed Time: 0:03:58.716091	Rate: 15.49 apps per second.
# [08/31/2023 05:55:54 AM] [INFO] [AppDataController] [_update_report_stats] : Term: Catalogs	Pages: 40	Apps: 4364	Elapsed Time: 0:04:42.317191	Rate: 15.46 apps per second.
# [08/31/2023 05:56:06 AM] [INFO] [AppDataController] [_update_report_stats] : Term: Catalogs	Pages: 50	Apps: 4435	Elapsed Time: 0:04:55.082430	Rate: 15.03 apps per second.
# [08/31/2023 05:56:17 AM] [INFO] [AppDataController] [_update_report_stats] : Term: Catalogs	Pages: 60	Apps: 4459	Elapsed Time: 0:05:05.367256	Rate: 14.6 apps per second.
# [08/31/2023 05:56:27 AM] [INFO] [AppDataController] [_update_report_stats] : Term: Catalogs	Pages: 70	Apps: 4475	Elapsed Time: 0:05:15.515343	Rate: 14.18 apps per second.
# [08/31/2023 05:56:37 AM] [INFO] [AppDataController] [_update_report_stats] : Term: Catalogs	Pages: 80	Apps: 4485	Elapsed Time: 0:05:25.261838	Rate: 13.79 apps per second.
# [08/31/2023 05:56:46 AM] [INFO] [AppDataController] [_update_report_stats] : Term: Catalogs	Pages: 90	Apps: 4495	Elapsed Time: 0:05:34.986295	Rate: 13.42 apps per second.
# [08/31/2023 05:57:01 AM] [INFO] [AppDataRepo] [dedup] : Repository with 20527 observations dropped 2483 duplicates leaving 18044 observations
# [08/31/2023 05:57:02 AM] [INFO] [AppDataController] [_complete_project] : Completed AppDataProject:
#
#
#                          AppDataProject
#                       controller | AppDataController
#                             term | catalogs
#                           status | complete
#                        page_size | 200
#                            pages | 91
#                           vpages | 22
#                             apps | 4496
#                               id | 1
#
#
#
# [08/31/2023 05:57:02 AM] [INFO] [AppDataController] [_get_or_start_project] :
# Retrieved Project:
# None
# [08/31/2023 05:57:02 AM] [INFO] [AppDataController] [_get_or_start_project] :
#
# Started project for Education apps.
# [08/31/2023 05:59:30 AM] [INFO] [AppDataController] [_update_report_stats] : Term: Education	Pages: 10	Apps: 2000	Elapsed Time: 0:02:28.531471	Rate: 13.47 apps per second.
# [08/31/2023 06:02:15 AM] [INFO] [AppDataController] [_update_report_stats] : Term: Education	Pages: 20	Apps: 3998	Elapsed Time: 0:05:13.400897	Rate: 12.76 apps per second.
# [08/31/2023 06:03:01 AM] [INFO] [AppDataRepo] [dedup] : Repository with 22442 observations dropped 490 duplicates leaving 21952 observations
# [08/31/2023 06:03:02 AM] [INFO] [AppDataController] [_complete_project] : Completed AppDataProject:
#
#
#                          AppDataProject
#                       controller | AppDataController
#                             term | education
#                           status | complete
#                        page_size | 200
#                            pages | 22
#                           vpages | 21
#                             apps | 4398
#                               id | 2
#
#
#
# [08/31/2023 06:03:02 AM] [INFO] [AppDataController] [_get_or_start_project] :
# Retrieved Project:
# None
# [08/31/2023 06:03:02 AM] [INFO] [AppDataController] [_get_or_start_project] :
#
# Started project for Entertainment apps.
# [08/31/2023 06:05:56 AM] [INFO] [AppDataController] [_update_report_stats] : Term: Entertainment	Pages: 10	Apps: 1998	Elapsed Time: 0:02:54.022283	Rate: 11.48 apps per second.
# [08/31/2023 06:08:39 AM] [INFO] [AppDataController] [_update_report_stats] : Term: Entertainment	Pages: 20	Apps: 3922	Elapsed Time: 0:05:37.023187	Rate: 11.64 apps per second.
# [08/31/2023 06:09:48 AM] [INFO] [AppDataRepo] [dedup] : Repository with 26610 observations dropped 1178 duplicates leaving 25432 observations
# [08/31/2023 06:09:49 AM] [INFO] [AppDataController] [_complete_project] : Completed AppDataProject:
#
#
#                          AppDataProject
#                       controller | AppDataController
#                             term | entertainment
#                           status | complete
#                        page_size | 200
#                            pages | 24
#                           vpages | 23
#                             apps | 4658
#                               id | 3
#
#
#
# [08/31/2023 06:09:49 AM] [INFO] [AppDataController] [_get_or_start_project] :
# Retrieved Project:
# None
# [08/31/2023 06:09:49 AM] [INFO] [AppDataController] [_get_or_start_project] :
#
# Started project for Finance apps.
# [08/31/2023 06:11:36 AM] [INFO] [AppDataController] [_update_report_stats] : Term: Finance	Pages: 10	Apps: 2000	Elapsed Time: 0:01:46.978266	Rate: 18.7 apps per second.
# [08/31/2023 06:13:31 AM] [INFO] [AppDataRepo] [dedup] : Repository with 28632 observations dropped 1095 duplicates leaving 27537 observations
# [08/31/2023 06:13:32 AM] [INFO] [AppDataController] [_complete_project] : Completed AppDataProject:
#
#
#                          AppDataProject
#                       controller | AppDataController
#                             term | finance
#                           status | complete
#                        page_size | 200
#                            pages | 16
#                           vpages | 16
#                             apps | 3200
#                               id | 4
#
#
#
# [08/31/2023 06:13:32 AM] [INFO] [AppDataController] [_get_or_start_project] :
# Retrieved Project:
# None
# [08/31/2023 06:13:32 AM] [INFO] [AppDataController] [_get_or_start_project] :
#
# Started project for Food apps.
# [08/31/2023 06:15:41 AM] [INFO] [AppDataController] [_update_report_stats] : Term: Food	Pages: 10	Apps: 1991	Elapsed Time: 0:02:08.940896	Rate: 15.44 apps per second.
# [08/31/2023 06:16:07 AM] [INFO] [AppDataRepo] [dedup] : Repository with 29728 observations dropped 339 duplicates leaving 29389 observations
# [08/31/2023 06:16:09 AM] [INFO] [AppDataController] [_complete_project] : Completed AppDataProject:
#
#
#                          AppDataProject
#                       controller | AppDataController
#                             term | food
#                           status | complete
#                        page_size | 200
#                            pages | 11
#                           vpages | 10
#                             apps | 2191
#                               id | 5
#
#
#
# [08/31/2023 06:16:09 AM] [INFO] [AppDataController] [_get_or_start_project] :
# Retrieved Project:
# None
# [08/31/2023 06:16:09 AM] [INFO] [AppDataController] [_get_or_start_project] :
#
# Started project for Games apps.
# [08/31/2023 06:17:40 AM] [INFO] [AppDataRepo] [dedup] : Repository with 30789 observations dropped 466 duplicates leaving 30323 observations
# [08/31/2023 06:17:41 AM] [INFO] [AppDataController] [_complete_project] : Completed AppDataProject:
#
#
#                          AppDataProject
#                       controller | AppDataController
#                             term | games
#                           status | complete
#                        page_size | 200
#                            pages | 7
#                           vpages | 7
#                             apps | 1400
#                               id | 6
#
#
#
# [08/31/2023 06:17:41 AM] [INFO] [AppDataController] [_get_or_start_project] :
# Retrieved Project:
# None
# [08/31/2023 06:17:41 AM] [INFO] [AppDataController] [_get_or_start_project] :
#
# Started project for Health apps.
# [08/31/2023 06:19:13 AM] [INFO] [AppDataRepo] [dedup] : Repository with 31323 observations dropped 147 duplicates leaving 31176 observations
# [08/31/2023 06:19:14 AM] [INFO] [AppDataController] [_complete_project] : Completed AppDataProject:
#
#
#                          AppDataProject
#                       controller | AppDataController
#                             term | health
#                           status | complete
#                        page_size | 200
#                            pages | 5
#                           vpages | 5
#                             apps | 1000
#                               id | 7
#
#
#
# [08/31/2023 06:19:14 AM] [INFO] [AppDataController] [_get_or_start_project] :
# Retrieved Project:
# None
# [08/31/2023 06:19:14 AM] [INFO] [AppDataController] [_get_or_start_project] :
#
# Started project for Lifestyle apps.
# [08/31/2023 06:20:29 AM] [INFO] [AppDataRepo] [dedup] : Repository with 31976 observations dropped 316 duplicates leaving 31660 observations
# [08/31/2023 06:20:30 AM] [INFO] [AppDataController] [_complete_project] : Completed AppDataProject:
#
#
#                          AppDataProject
#                       controller | AppDataController
#                             term | lifestyle
#                           status | complete
#                        page_size | 200
#                            pages | 4
#                           vpages | 4
#                             apps | 800
#                               id | 8
#
#
#
# [08/31/2023 06:20:30 AM] [INFO] [AppDataController] [_get_or_start_project] :
# Retrieved Project:
# None
# [08/31/2023 06:20:30 AM] [INFO] [AppDataController] [_get_or_start_project] :
#
# Started project for Magazines apps.
# [08/31/2023 06:20:47 AM] [INFO] [AppDataRepo] [dedup] : Repository with 31660 observations dropped 0 duplicates leaving 31660 observations
# [08/31/2023 06:20:48 AM] [INFO] [AppDataController] [_complete_project] : Completed AppDataProject:
#
#
#                          AppDataProject
#                       controller | AppDataController
#                             term | magazines
#                           status | complete
#                        page_size | 200
#                            pages | 0
#                           vpages | 0
#                             apps | 0
#                          updated | None
#                               id | 9
#
#
#
# [08/31/2023 06:20:48 AM] [INFO] [AppDataController] [_get_or_start_project] :
# Retrieved Project:
# None
# [08/31/2023 06:20:48 AM] [INFO] [AppDataController] [_get_or_start_project] :
#
# Started project for Medical apps.
# [08/31/2023 06:23:05 AM] [INFO] [AppDataController] [_update_report_stats] : Term: Medical	Pages: 10	Apps: 1961	Elapsed Time: 0:02:17.144424	Rate: 14.3 apps per second.
# [08/31/2023 06:23:28 AM] [INFO] [AppDataRepo] [dedup] : Repository with 33812 observations dropped 503 duplicates leaving 33309 observations
# [08/31/2023 06:23:30 AM] [INFO] [AppDataController] [_complete_project] : Completed AppDataProject:
#
#
#                          AppDataProject
#                       controller | AppDataController
#                             term | medical
#                           status | complete
#                        page_size | 200
#                            pages | 11
#                           vpages | 10
#                             apps | 2152
#                               id | 10
#
#
#
# [08/31/2023 06:23:30 AM] [INFO] [AppDataController] [_get_or_start_project] :
# Retrieved Project:
# None
# [08/31/2023 06:23:30 AM] [INFO] [AppDataController] [_get_or_start_project] :
#
# Started project for Music apps.
# [08/31/2023 06:26:11 AM] [INFO] [AppDataController] [_update_report_stats] : Term: Music	Pages: 10	Apps: 1942	Elapsed Time: 0:02:41.415704	Rate: 12.03 apps per second.
# [08/31/2023 06:28:06 AM] [INFO] [AppDataRepo] [dedup] : Repository with 36890 observations dropped 958 duplicates leaving 35932 observations
# [08/31/2023 06:28:08 AM] [INFO] [AppDataController] [_complete_project] : Completed AppDataProject:
#
#
#                          AppDataProject
#                       controller | AppDataController
#                             term | music
#                           status | complete
#                        page_size | 200
#                            pages | 19
#                           vpages | 17
#                             apps | 3581
#                               id | 11
#
#
#
# [08/31/2023 06:28:08 AM] [INFO] [AppDataController] [_get_or_start_project] :
# Retrieved Project:
# None
# [08/31/2023 06:28:08 AM] [INFO] [AppDataController] [_get_or_start_project] :
#
# Started project for Navigation apps.
# [08/31/2023 06:30:17 AM] [INFO] [AppDataController] [_update_report_stats] : Term: Navigation	Pages: 10	Apps: 1846	Elapsed Time: 0:02:09.773156	Rate: 14.22 apps per second.
# [08/31/2023 06:30:45 AM] [INFO] [AppDataRepo] [dedup] : Repository with 37934 observations dropped 409 duplicates leaving 37525 observations
# [08/31/2023 06:30:47 AM] [INFO] [AppDataController] [_complete_project] : Completed AppDataProject:
#
#
#                          AppDataProject
#                       controller | AppDataController
#                             term | navigation
#                           status | complete
#                        page_size | 200
#                            pages | 11
#                           vpages | 10
#                             apps | 2002
#                               id | 12
#
#
#
# [08/31/2023 06:30:47 AM] [INFO] [AppDataController] [_get_or_start_project] :
# Retrieved Project:
# None
# [08/31/2023 06:30:47 AM] [INFO] [AppDataController] [_get_or_start_project] :
#
# Started project for News apps.
# [08/31/2023 06:32:33 AM] [INFO] [AppDataController] [_update_report_stats] : Term: News	Pages: 10	Apps: 1904	Elapsed Time: 0:01:46.021773	Rate: 17.96 apps per second.
# [08/31/2023 06:34:25 AM] [INFO] [AppDataController] [_update_report_stats] : Term: News	Pages: 20	Apps: 3648	Elapsed Time: 0:03:37.867522	Rate: 16.74 apps per second.
# [08/31/2023 06:34:54 AM] [INFO] [AppDataRepo] [dedup] : Repository with 41336 observations dropped 1224 duplicates leaving 40112 observations
# [08/31/2023 06:34:56 AM] [INFO] [AppDataController] [_complete_project] : Completed AppDataProject:
#
#
#                          AppDataProject
#                       controller | AppDataController
#                             term | news
#                           status | complete
#                        page_size | 200
#                            pages | 21
#                           vpages | 19
#                             apps | 3811
#                               id | 13
#
#
#
# [08/31/2023 06:34:56 AM] [INFO] [AppDataController] [_get_or_start_project] :
# Retrieved Project:
# None
# [08/31/2023 06:34:56 AM] [INFO] [AppDataController] [_get_or_start_project] :
#
# Started project for Photo apps.
# [08/31/2023 06:37:37 AM] [INFO] [AppDataRepo] [dedup] : Repository with 41690 observations dropped 618 duplicates leaving 41072 observations
# [08/31/2023 06:37:39 AM] [INFO] [AppDataController] [_complete_project] : Completed AppDataProject:
#
#
#                          AppDataProject
#                       controller | AppDataController
#                             term | photo
#                           status | complete
#                        page_size | 200
#                            pages | 8
#                           vpages | 7
#                             apps | 1578
#                               id | 14
#
#
#
# [08/31/2023 06:37:39 AM] [INFO] [AppDataController] [_get_or_start_project] :
# Retrieved Project:
# None
# [08/31/2023 06:37:39 AM] [INFO] [AppDataController] [_get_or_start_project] :
#
# Started project for Productivity apps.
# [08/31/2023 06:40:31 AM] [INFO] [AppDataRepo] [dedup] : Repository with 42672 observations dropped 817 duplicates leaving 41855 observations
# [08/31/2023 06:40:33 AM] [INFO] [AppDataController] [_complete_project] : Completed AppDataProject:
#
#
#                          AppDataProject
#                       controller | AppDataController
#                             term | productivity
#                           status | complete
#                        page_size | 200
#                            pages | 8
#                           vpages | 8
#                             apps | 1600
#                               id | 15
#
#
#
# [08/31/2023 06:40:33 AM] [INFO] [AppDataController] [_get_or_start_project] :
# Retrieved Project:
# None
# [08/31/2023 06:40:33 AM] [INFO] [AppDataController] [_get_or_start_project] :
#
# Started project for Reference apps.
# [08/31/2023 06:42:33 AM] [INFO] [AppDataController] [_update_report_stats] : Term: Reference	Pages: 10	Apps: 1924	Elapsed Time: 0:01:59.663508	Rate: 16.08 apps per second.
# [08/31/2023 06:43:53 AM] [INFO] [AppDataRepo] [dedup] : Repository with 44638 observations dropped 854 duplicates leaving 43784 observations
# [08/31/2023 06:43:55 AM] [INFO] [AppDataController] [_complete_project] : Completed AppDataProject:
#
#
#                          AppDataProject
#                       controller | AppDataController
#                             term | reference
#                           status | complete
#                        page_size | 200
#                            pages | 15
#                           vpages | 13
#                             apps | 2783
#                               id | 16
#
#
#
# [08/31/2023 06:43:55 AM] [INFO] [AppDataController] [_get_or_start_project] :
# Retrieved Project:
# None
# [08/31/2023 06:43:55 AM] [INFO] [AppDataController] [_get_or_start_project] :
#
# Started project for Shopping apps.
# [08/31/2023 06:44:15 AM] [INFO] [AppDataRepo] [dedup] : Repository with 43784 observations dropped 0 duplicates leaving 43784 observations
# [08/31/2023 06:44:17 AM] [INFO] [AppDataController] [_complete_project] : Completed AppDataProject:
#
#
#                          AppDataProject
#                       controller | AppDataController
#                             term | shopping
#                           status | complete
#                        page_size | 200
#                            pages | 0
#                           vpages | 0
#                             apps | 0
#                          updated | None
#                               id | 17
#
#
#
# [08/31/2023 06:44:17 AM] [INFO] [AppDataController] [_get_or_start_project] :
# Retrieved Project:
# None
# [08/31/2023 06:44:17 AM] [INFO] [AppDataController] [_get_or_start_project] :
#
# Started project for Social apps.
# [08/31/2023 06:46:32 AM] [INFO] [AppDataController] [_update_report_stats] : Term: Social	Pages: 10	Apps: 1731	Elapsed Time: 0:02:14.677207	Rate: 12.85 apps per second.
# [08/31/2023 06:48:09 AM] [INFO] [AppDataRepo] [dedup] : Repository with 46791 observations dropped 1353 duplicates leaving 45438 observations
# [08/31/2023 06:48:11 AM] [INFO] [AppDataController] [_complete_project] : Completed AppDataProject:
#
#
#                          AppDataProject
#                       controller | AppDataController
#                             term | social
#                           status | complete
#                        page_size | 200
#                            pages | 18
#                           vpages | 15
#                             apps | 3007
#                               id | 18
#
#
#
# [08/31/2023 06:48:11 AM] [INFO] [AppDataController] [_get_or_start_project] :
# Retrieved Project:
# None
# [08/31/2023 06:48:11 AM] [INFO] [AppDataController] [_get_or_start_project] :
#
# Started project for Sports apps.
# [08/31/2023 06:49:41 AM] [INFO] [AppDataRepo] [dedup] : Repository with 46215 observations dropped 322 duplicates leaving 45893 observations
# [08/31/2023 06:49:43 AM] [INFO] [AppDataController] [_complete_project] : Completed AppDataProject:
#
#
#                          AppDataProject
#                       controller | AppDataController
#                             term | sports
#                           status | complete
#                        page_size | 200
#                            pages | 4
#                           vpages | 3
#                             apps | 777
#                               id | 19
#
#
#
# [08/31/2023 06:49:43 AM] [INFO] [AppDataController] [_get_or_start_project] :
# Retrieved Project:
# None
# [08/31/2023 06:49:43 AM] [INFO] [AppDataController] [_get_or_start_project] :
#
# Started project for Travel apps.
# [08/31/2023 06:51:57 AM] [INFO] [AppDataController] [_update_report_stats] : Term: Travel	Pages: 10	Apps: 1984	Elapsed Time: 0:02:13.846636	Rate: 14.82 apps per second.
# [08/31/2023 06:53:03 AM] [INFO] [AppDataRepo] [dedup] : Repository with 48651 observations dropped 1233 duplicates leaving 47418 observations
# [08/31/2023 06:53:06 AM] [INFO] [AppDataController] [_complete_project] : Completed AppDataProject:
#
#
#                          AppDataProject
#                       controller | AppDataController
#                             term | travel
#                           status | complete
#                        page_size | 200
#                            pages | 14
#                           vpages | 13
#                             apps | 2758
#                               id | 20
#
#
#
# [08/31/2023 06:53:06 AM] [INFO] [AppDataController] [_get_or_start_project] :
# Retrieved Project:
# None
# [08/31/2023 06:53:06 AM] [INFO] [AppDataController] [_get_or_start_project] :
#
# Started project for Utilities apps.
# [08/31/2023 06:54:56 AM] [INFO] [AppDataRepo] [dedup] : Repository with 48418 observations dropped 622 duplicates leaving 47796 observations
# [08/31/2023 06:54:59 AM] [INFO] [AppDataController] [_complete_project] : Completed AppDataProject:
#
#
#                          AppDataProject
#                       controller | AppDataController
#                             term | utilities
#                           status | complete
#                        page_size | 200
#                            pages | 5
#                           vpages | 5
#                             apps | 1000
#                               id | 21
#
#
#
# [08/31/2023 06:54:59 AM] [INFO] [AppDataController] [_get_or_start_project] :
# Retrieved Project:
# None
# [08/31/2023 06:54:59 AM] [INFO] [AppDataController] [_get_or_start_project] :
#
# Started project for Weather apps.
# [08/31/2023 06:57:09 AM] [INFO] [AppDataController] [_update_report_stats] : Term: Weather	Pages: 10	Apps: 1823	Elapsed Time: 0:02:09.950513	Rate: 14.03 apps per second.
# [08/31/2023 06:58:31 AM] [INFO] [AppDataRepo] [dedup] : Repository with 50683 observations dropped 1327 duplicates leaving 49356 observations
# [08/31/2023 06:58:33 AM] [INFO] [AppDataController] [_complete_project] : Completed AppDataProject:
#
#
#                          AppDataProject
#                       controller | AppDataController
#                             term | weather
#                           status | complete
#                        page_size | 200
#                            pages | 17
#                           vpages | 14
#                             apps | 2887
#                               id | 22

# %% [markdown]
# ## AppData Dataset Overview

# %%
df = repo.getall()
dataset = AppDataDataset(df=df)

# %% [markdown]
# ## AppData Dataset Profile

# %%
dataset.info()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 dataset.info()
#
# TypeError: 'DataFrame' object is not callable

# %% [markdown]
# ## AppData Dataset Summary

# %%
dataset.summary()
