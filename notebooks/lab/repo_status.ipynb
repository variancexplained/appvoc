# %% [markdown]
# # Repo Status

# %%
from appvoc.data.dataset.app import AppDataDataset
from appvoc.data.dataset.rating import RatingDataset
from appvoc.data.dataset.review import ReviewDataset
from appvoc.container import AppVoCContainer

container = AppVoCContainer()
container.init_resources()
container.wire(packages=["appvoc.data.dataset"])

# %% [markdown]
# ## AppData

# %%
repo = container.data.app_repo()
repo.summary
repo.getall()
# Out:
#   Category  Examples  Apps  Average Rating  Rating Count
# 0  Finance         5     5            0.80             4
# 1  Medical         5     5            2.71           849
#            id                           name  \
# 0  1573577748    Amal: Investing for Muslims
# 1  1572970612                        九银村镇E管家
# 2  1642299254        II Australia Forum 2022
# 3   947796104                        CMB Pro
# 4  1588429258                    VLoad Cards
# 5  1515892156                         医见通医生端
# 6  1611548743            Diretriz SBD - 2023
# 7  1330482587  iGluPal - Blood Sugar Tracker
# 8  1276020039                           VšZP
# 9  1517571213                     ZEKUR Zorg
#
#                                          description category_id category  \
# 0  Muslim looking to invest in stocks? Amal Inves...        6015  Finance
# 1  九银村镇E管家手机app是由九银村镇银行为中小企业量身打造的一款手机银行软件，能够为企业用户...        6015  Finance
# 2  Infrastructure Investor returns to Australia a...        6015  Finance
# 3  Toujours à portée de main, votre application C...        6015  Finance
# 4  VLOAD PRODUCT OVERVIEW:
# VLoad is an innovati...        6015  Finance
# 5  「医见通医生端」APP全新上线，包含添加患者、快速接诊、 预约列表、开方列表、邀请患者、拍照...        6020  Medical
# 6  A Diretriz de 2 milhões de acessos!
#
# Incrivelm...        6020  Medical
# 7  - You can add your blood sugar measurements an...        6020  Medical
# 8  Aktuálne pre našich poistencov prinášame tieto...        6020  Medical
# 9  Je zorgzaken regelen: dat kan snel!
# Je registr...        6020  Medical
#
#    price developer_id                            developer  rating  ratings  \
# 0   0.00   1501688583                              Amal AI    4.00        4
# 1   0.00    535354643                           九江银行股份有限公司    0.00        0
# 2   0.00   1434661607                        PEI Media Inc    0.00        0
# 3   0.00    323122391                  Crédit Mutuel Arkéa    0.00        0
# 4   0.00   1500482671                    Global Primex LLC    0.00        0
# 5   0.00   1515892155                          沈阳医见通科技有限公司    0.00        0
# 6   0.00   1458629188     Sociedade Brasileira de Diabetes    0.00        0
# 7   0.00    906666201                        Furkan Ozoglu    4.64      836
# 8   0.00   1276020038  Všeobecná zdravotná poisťovňa, a.s.    3.92       12
# 9   0.00    376560957                  Zorgverzekeraar VGZ    5.00        1
#
#              released
# 0 2022-09-28 07:00:00
# 1 2021-11-09 08:00:00
# 2 2022-09-01 07:00:00
# 3 2014-12-11 08:00:00
# 4 2022-06-17 07:00:00
# 5 2020-06-04 07:00:00
# 6 2022-03-02 08:00:00
# 7 2018-01-15 00:58:00
# 8 2018-09-13 03:59:00
# 9 2020-10-15 07:00:00

# %% [markdown]
# ## Ratings

# %%
repo = container.data.rating_repo()
repo.summary
df = repo.getall()
df.info()
# Out:
# Empty DataFrame
# Columns: [Category, Reviews, Apps, Average Rating]
# Index: []
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 0 entries
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           0 non-null      string
#  1   name         0 non-null      string
#  2   category_id  0 non-null      category
#  3   category     0 non-null      category
#  4   rating       0 non-null      float64
#  5   reviews      0 non-null      int64
#  6   ratings      0 non-null      int64
#  7   onestar      0 non-null      int64
#  8   twostar      0 non-null      int64
#  9   threestar    0 non-null      int64
#  10  fourstar     0 non-null      int64
#  11  fivestar     0 non-null      int64
#  12  status       0 non-null      object
# dtypes: category(2), float64(1), int64(7), object(1), string(2)
# memory usage: 340.0+ bytes

# %% [markdown]
# ## Reviews

# %%
# repo = container.data.review_repo()
# repo.summary
