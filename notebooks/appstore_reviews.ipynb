# %% [markdown]
# # AppStore
# As of 2022, Apple's App Store was home to some 1.76 million apps and over 460,000 games. The aim of this exercise is to obtain app rating and review data for select categories for sentiment analysis, product analytics, opportunity discovery, and selection.  Our data acquisition centers on three entities: AppData, Rating, and Review, which are described below.
#
# ## AppData
# The AppData entity encapsulates the core data for each app and is defined as follows.
#
# | #  | attribute     | type  | description                                  | API Field         |
# |----|---------------|-------|----------------------------------------------|-------------------|
# | 1  | id:           | int   | Unique Apple App Identifier                  | trackId           |
# | 2  | name:         | str   | Name of the app.                             | trackName         |
# | 3  | description:  | str   | Description                                  | description       |
# | 4  | category_id:  | int   | Four digit category identifier               | primaryGenreId    |
# | 5  | category:     | str   | Category name                                | primaryGenreName  |
# | 6  | price:        | float | Cost of the app                              | price             |
# | 7  | rating:       | float | The user average rating                      | averageUserRating |
# | 8  | ratings:      | int   | The rating count                             | userRatingCount   |
# | 9  | developer_id: | int   | The app developer identifier                 | artistId          |
# | 10 | developer:    | str   | The app developer name                       | artistName        |
# | 11 | released:     | str   | The date of initial release                  | releaseDate       |
# | 12 | source:       | str   | The host from which the data were obtained.  | itunes.apple.com  |
#
# The data acquisition pipeline will obtain app data for the following categories and persist them in an RDBMS table.
#
# 1. business
# 2. education
# 3. entertainment
# 4. health
# 5. lifestyle
# 6. medical
# 7. productivity
# 9. social_networking

# %% [markdown]
# ### Imports

# %%
from aimobile.service.appstore.controller import AppStoreAppController, AppStoreReviewController
from aimobile.container import AIMobileContainer

# %%
TERMS = ["business", "education", "entertainment", "health", "lifestyle", "medical", "productivity", "social_networking"]
CATEGORIES = [6000, 6017, 6016, 6013, 6012, 6020, 6007, 6005]

# %% [markdown]
# ### Dependencies

# %%
container = AIMobileContainer()
container.init_resources()
container.wire(packages=["aimobile.service.appstore"])

# %% [markdown]
# ### AppData Scraper
# AppStoreAppController object iterates through the above TERMs, engaging a scraper to extract the app data described above from the App Store. The results are persisted in an RDBMS and archived.

# %%
controller = AppStoreAppController()
controller.scrape(terms=TERMS)
controller.summarize()
# Out:
# [04/22/2023 10:19:52 AM] [INFO] [AppStoreAppController] [scrape] :
#
# Appstore AppData Scraped Status is Complete. Skipping App Store App Data Scraping Operation.
#                   Category  App Count  Average Rating  Average Rating Count
# 0                  Medical     138680            1.54                203.74  \
# 1         Health & Fitness      67879            2.74              1,189.69
# 2        Social Networking      63761            1.78                994.00
# 3                Education      27807            2.56              2,281.81
# 4                 Business      27534            2.68              2,321.21
# 5                Lifestyle      21507            3.09              3,687.58
# 6                    Games      19887            4.09             12,061.64
# 7             Productivity      15179            3.11              4,786.31
# 8                Utilities      12559            2.80              3,567.25
# 9            Entertainment      10278            3.33             10,063.51
# 10                 Finance       6720            3.64              9,655.26
# 11                Shopping       6180            3.05             19,214.63
# 12                  Sports       5911            2.42              1,975.52
# 13           Photo & Video       5309            3.29             26,043.19
# 14            Food & Drink       3794            3.39             14,815.09
# 15                  Travel       3371            2.82             13,979.66
# 16               Reference       3257            2.89              1,777.73
# 17                Stickers       2575            1.48                  9.83
# 18                    News       2569            2.46             10,863.09
# 19                   Music       2467            3.75             24,057.37
# 20                    Book       1468            3.42             13,599.68
# 21              Navigation       1002            2.55                656.93
# 22       Graphics & Design        570            3.71              5,776.49
# 23                 Weather        281            3.54             22,075.30
# 24  Magazines & Newspapers        222            2.81                681.04
# 25         Developer Tools         83            3.59                540.71
#
#     Total Rating Count
# 0             28255057
# 1             80755198
# 2             63378258
# 3             63450186
# 4             63912296
# 5             79308887
# 6            239869878
# 7             72651335
# 8             44801098
# 9            103432717
# 10            64883337
# 11           118746424
# 12            11677328
# 13           138263287
# 14            56208458
# 15            47125445
# 16             5790054
# 17               25323
# 18            27907271
# 19            59349525
# 20            19964323
# 21              658247
# 22             3292600
# 23             6203158
# 24              151190
# 25               44879

# %% [markdown]
# ### Review Scraper
# AppStoreReviewController manages the extraction of review data from the App Store. Iterating through the CATEGORIES above, a scraper returns review data for each app in the repository, by category. As before, the results are stored in an RDBMS and archived.

# %%
controller = AppStoreReviewController()
controller.scrape(category_ids=CATEGORIES)
controller.summarize()
controller.archive()
# Out:
# [04/22/2023 10:20:37 AM] [DEBUG] [AppStoreReviewScraper] [_set_url] :
# URL: Start Index: 0 End Index: 400.
# [04/22/2023 10:20:45 AM] [DEBUG] [urllib3.connectionpool] [_new_conn] : Starting new HTTPS connection (1): itunes.apple.com:443
# [04/22/2023 10:20:46 AM] [DEBUG] [urllib3.connectionpool] [_make_request] : https://itunes.apple.com:443 "GET /WebObjects/MZStore.woa/wa/userReviewsRow?id=444553167&displayable-kind=11&startIndex=0&endIndex=400&sort=1 HTTP/1.1" 200 156282
# [04/22/2023 10:20:46 AM] [DEBUG] [SessionHandler] [_teardown] :
# Request status code: 200. Session: 0
# [04/22/2023 10:20:46 AM] [DEBUG] [AppStoreReviewScraper] [_parse_response] :
# Results returned: 400
# [04/22/2023 10:20:46 AM] [DEBUG] [ReviewRepo] [add] : Added 400 rows to the review repository.
# [04/22/2023 10:20:46 AM] [DEBUG] [AppStoreReviewScraper] [_set_url] :
# URL: Start Index: 400 End Index: 800.
# [04/22/2023 10:20:55 AM] [DEBUG] [urllib3.connectionpool] [_make_request] : https://itunes.apple.com:443 "GET /WebObjects/MZStore.woa/wa/userReviewsRow?id=444553167&displayable-kind=11&startIndex=400&endIndex=800&sort=1 HTTP/1.1" 200 117628
# [04/22/2023 10:20:55 AM] [DEBUG] [SessionHandler] [_teardown] :
# Request status code: 200. Session: 0
# [04/22/2023 10:20:55 AM] [DEBUG] [AppStoreReviewScraper] [_parse_response] :
# Results returned: 400
# [04/22/2023 10:20:55 AM] [DEBUG] [ReviewRepo] [add] : Added 400 rows to the review repository.
# [04/22/2023 10:20:55 AM] [DEBUG] [AppStoreReviewScraper] [_set_url] :
# URL: Start Index: 800 End Index: 1200.
# [04/22/2023 10:21:01 AM] [DEBUG] [urllib3.connectionpool] [_make_request] : https://itunes.apple.com:443 "GET /WebObjects/MZStore.woa/wa/userReviewsRow?id=444553167&displayable-kind=11&startIndex=800&endIndex=1200&sort=1 HTTP/1.1" 200 99750
# [04/22/2023 10:21:01 AM] [DEBUG] [SessionHandler] [_teardown] :
# Request status code: 200. Session: 0
# [04/22/2023 10:21:01 AM] [DEBUG] [AppStoreReviewScraper] [_parse_response] :
# Results returned: 400
# [04/22/2023 10:21:01 AM] [DEBUG] [ReviewRepo] [add] : Added 400 rows to the review repository.
# [04/22/2023 10:21:01 AM] [DEBUG] [AppStoreReviewScraper] [_set_url] :
# URL: Start Index: 1200 End Index: 1600.
# [04/22/2023 10:21:08 AM] [DEBUG] [urllib3.connectionpool] [_make_request] : https://itunes.apple.com:443 "GET /WebObjects/MZStore.woa/wa/userReviewsRow?id=444553167&displayable-kind=11&startIndex=1200&endIndex=1600&sort=1 HTTP/1.1" 200 91712
# [04/22/2023 10:21:08 AM] [DEBUG] [SessionHandler] [_teardown] :
# Request status code: 200. Session: 0
# [04/22/2023 10:21:08 AM] [DEBUG] [AppStoreReviewScraper] [_parse_response] :
# Results returned: 400
# [04/22/2023 10:21:08 AM] [DEBUG] [ReviewRepo] [add] : Added 400 rows to the review repository.
# [04/22/2023 10:21:08 AM] [DEBUG] [AppStoreReviewScraper] [_set_url] :
# URL: Start Index: 1600 End Index: 2000.
# [04/22/2023 10:21:15 AM] [DEBUG] [urllib3.connectionpool] [_make_request] : https://itunes.apple.com:443 "GET /WebObjects/MZStore.woa/wa/userReviewsRow?id=444553167&displayable-kind=11&startIndex=1600&endIndex=2000&sort=1 HTTP/1.1" 200 87133
# [04/22/2023 10:21:16 AM] [DEBUG] [SessionHandler] [_teardown] :
# Request status code: 200. Session: 0
# [04/22/2023 10:21:16 AM] [DEBUG] [AppStoreReviewScraper] [_parse_response] :
# Results returned: 400
# [04/22/2023 10:21:16 AM] [DEBUG] [ReviewRepo] [add] : Added 400 rows to the review repository.
# [04/22/2023 10:21:16 AM] [INFO] [AppStoreReviewController] [_announce] : Category: 6000-Business Apps: 5 Reviews: 2000 Elapsed Time: 0:00:43.818642
# [04/22/2023 10:21:16 AM] [DEBUG] [AppStoreReviewScraper] [_set_url] :
# URL: Start Index: 2000 End Index: 2400.
# [04/22/2023 10:21:20 AM] [DEBUG] [urllib3.connectionpool] [_make_request] : https://itunes.apple.com:443 "GET /WebObjects/MZStore.woa/wa/userReviewsRow?id=444553167&displayable-kind=11&startIndex=2000&endIndex=2400&sort=1 HTTP/1.1" 200 80538
# [04/22/2023 10:21:20 AM] [DEBUG] [SessionHandler] [_teardown] :
# Request status code: 200. Session: 0
# [04/22/2023 10:21:20 AM] [DEBUG] [AppStoreReviewScraper] [_parse_response] :
# Results returned: 400
# [04/22/2023 10:21:20 AM] [DEBUG] [ReviewRepo] [add] : Added 400 rows to the review repository.
# [04/22/2023 10:21:20 AM] [DEBUG] [AppStoreReviewScraper] [_set_url] :
# URL: Start Index: 2400 End Index: 2800.
# [04/22/2023 10:21:23 AM] [DEBUG] [urllib3.connectionpool] [_make_request] : https://itunes.apple.com:443 "GET /WebObjects/MZStore.woa/wa/userReviewsRow?id=444553167&displayable-kind=11&startIndex=2400&endIndex=2800&sort=1 HTTP/1.1" 200 77873
# [04/22/2023 10:21:23 AM] [DEBUG] [SessionHandler] [_teardown] :
# Request status code: 200. Session: 0
# [04/22/2023 10:21:23 AM] [DEBUG] [AppStoreReviewScraper] [_parse_response] :
# Results returned: 400
# [04/22/2023 10:21:23 AM] [DEBUG] [ReviewRepo] [add] : Added 400 rows to the review repository.
# [04/22/2023 10:21:23 AM] [DEBUG] [AppStoreReviewScraper] [_set_url] :
# URL: Start Index: 2800 End Index: 3200.
# [04/22/2023 10:21:25 AM] [DEBUG] [urllib3.connectionpool] [_make_request] : https://itunes.apple.com:443 "GET /WebObjects/MZStore.woa/wa/userReviewsRow?id=444553167&displayable-kind=11&startIndex=2800&endIndex=3200&sort=1 HTTP/1.1" 200 73492
# [04/22/2023 10:21:25 AM] [DEBUG] [SessionHandler] [_teardown] :
# Request status code: 200. Session: 0
# [04/22/2023 10:21:25 AM] [DEBUG] [AppStoreReviewScraper] [_parse_response] :
# Results returned: 400
# [04/22/2023 10:21:25 AM] [DEBUG] [ReviewRepo] [add] : Added 400 rows to the review repository.
# [04/22/2023 10:21:25 AM] [DEBUG] [AppStoreReviewScraper] [_set_url] :
# URL: Start Index: 3200 End Index: 3600.
# [04/22/2023 10:21:31 AM] [DEBUG] [urllib3.connectionpool] [_make_request] : https://itunes.apple.com:443 "GET /WebObjects/MZStore.woa/wa/userReviewsRow?id=444553167&displayable-kind=11&startIndex=3200&endIndex=3600&sort=1 HTTP/1.1" 200 70659
# [04/22/2023 10:21:31 AM] [DEBUG] [SessionHandler] [_teardown] :
# Request status code: 200. Session: 0
# [04/22/2023 10:21:31 AM] [DEBUG] [AppStoreReviewScraper] [_parse_response] :
# Results returned: 400
# [04/22/2023 10:21:31 AM] [DEBUG] [ReviewRepo] [add] : Added 400 rows to the review repository.
# [04/22/2023 10:21:31 AM] [DEBUG] [AppStoreReviewScraper] [_set_url] :
# URL: Start Index: 3600 End Index: 4000.
# [04/22/2023 10:21:35 AM] [DEBUG] [urllib3.connectionpool] [_make_request] : https://itunes.apple.com:443 "GET /WebObjects/MZStore.woa/wa/userReviewsRow?id=444553167&displayable-kind=11&startIndex=3600&endIndex=4000&sort=1 HTTP/1.1" 200 68465
# [04/22/2023 10:21:35 AM] [DEBUG] [SessionHandler] [_teardown] :
# Request status code: 200. Session: 0
# [04/22/2023 10:21:35 AM] [DEBUG] [AppStoreReviewScraper] [_parse_response] :
# Results returned: 400
# [04/22/2023 10:21:35 AM] [DEBUG] [ReviewRepo] [add] : Added 400 rows to the review repository.
# [04/22/2023 10:21:35 AM] [INFO] [AppStoreReviewController] [_announce] : Category: 6000-Business Apps: 10 Reviews: 4000 Elapsed Time: 0:01:02.988681
# [04/22/2023 10:21:35 AM] [DEBUG] [AppStoreReviewScraper] [_set_url] :
# URL: Start Index: 4000 End Index: 4400.
# [04/22/2023 10:21:40 AM] [DEBUG] [urllib3.connectionpool] [_make_request] : https://itunes.apple.com:443 "GET /WebObjects/MZStore.woa/wa/userReviewsRow?id=444553167&displayable-kind=11&startIndex=4000&endIndex=4400&sort=1 HTTP/1.1" 200 67484
# [04/22/2023 10:21:40 AM] [DEBUG] [SessionHandler] [_teardown] :
# Request status code: 200. Session: 0
# [04/22/2023 10:21:40 AM] [DEBUG] [AppStoreReviewScraper] [_parse_response] :
# Results returned: 400
# [04/22/2023 10:21:41 AM] [DEBUG] [ReviewRepo] [add] : Added 400 rows to the review repository.
# [04/22/2023 10:21:41 AM] [DEBUG] [AppStoreReviewScraper] [_set_url] :
# URL: Start Index: 4400 End Index: 4800.

# %%
controller.summarize()
