# %% [markdown]
# # AppStore Rating Exploratory Data Analysis
#
#
# | #  | Variable    | Description                      | Data Type   |
# |----|-------------|----------------------------------|-------------|
# | 1  | id          | App Identifier                   | Nominal     |
# | 2  | name        | App Name                         | Nominal     |
# | 3  | category_id | Four Digit Category Id           | Categorical |
# | 4  | category    | Category Name                    | Categorical |
# | 5  | rating      | Average Customer Rating          | Interval    |
# | 6  | reviews     | Total Number Of Customer Reviews | Discrete    |
# | 7  | ratings     | Rating Count                     | Discrete    |
# | 8  | onestar     | One Star Rating Count            | Discrete    |
# | 9  | twostar     | Two Star Rating Count            | Discrete    |
# | 10 | threestar   | Three Star Rating Count          | Discrete    |
# | 11 | fourstar    | Four Star Rating Count           | Discrete    |
# | 12 | fivestar    | Five Star Rating Count           | Discrete    |

# %%
import os

import numpy as np
import pandas as pd
from IPython.display import HTML, display_html

from aimobile.data.dataset.rating import RatingDataset
from aimobile.container import AIMobileContainer

container = AIMobileContainer()
container.init_resources()
container.wire(packages=["aimobile.data.dataset"])
dataset = RatingDataset()
formatting = {"thousands":",", "precision":2}

# %% [markdown]
# ### Structural Analysis
# The structure and characteristics of the Rating dataset are as follows:

# %%
df1 = dataset.structure
df2 = dataset.dtypes

df1_style = df1.style.set_table_attributes("style='display:inline; margin-right:220px;'").set_caption("Dataset Structure").format(thousands=",")
df2_style = df2.style.set_table_attributes("style='display:inline; margin-right:120px'").set_caption("Dataset Data Types").format(thousands=",")

display_html(df1_style._repr_html_() + df2_style._repr_html_(), raw=True).style.format(**formatting)
# Out:
# <style type="text/css">
# </style>
# <table id="T_7f1ca" style='display:inline; margin-right:220px;'>
#   <caption>Dataset Structure</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7f1ca_level0_col0" class="col_heading level0 col0" >Characteristic</th>
#       <th id="T_7f1ca_level0_col1" class="col_heading level0 col1" >Total</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7f1ca_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7f1ca_row0_col0" class="data row0 col0" >Number of Observations</td>
#       <td id="T_7f1ca_row0_col1" class="data row0 col1" >153,518</td>
#     </tr>
#     <tr>
#       <th id="T_7f1ca_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7f1ca_row1_col0" class="data row1 col0" >Number of Variables</td>
#       <td id="T_7f1ca_row1_col1" class="data row1 col1" >12</td>
#     </tr>
#     <tr>
#       <th id="T_7f1ca_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7f1ca_row2_col0" class="data row2 col0" >Number of Cells</td>
#       <td id="T_7f1ca_row2_col1" class="data row2 col1" >1,842,216</td>
#     </tr>
#     <tr>
#       <th id="T_7f1ca_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7f1ca_row3_col0" class="data row3 col0" >Size (Bytes)</td>
#       <td id="T_7f1ca_row3_col1" class="data row3 col1" >35,081,406</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_87ef6" style='display:inline; margin-right:120px'>
#   <caption>Dataset Data Types</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_87ef6_level0_col0" class="col_heading level0 col0" >Data Type</th>
#       <th id="T_87ef6_level0_col1" class="col_heading level0 col1" >Number of Features</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_87ef6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_87ef6_row0_col0" class="data row0 col0" >Number of Nominal Data Types</td>
#       <td id="T_87ef6_row0_col1" class="data row0 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_87ef6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_87ef6_row1_col0" class="data row1 col0" >Number of Categorical Data Types</td>
#       <td id="T_87ef6_row1_col1" class="data row1 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_87ef6_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_87ef6_row2_col0" class="data row2 col0" >Number of Discrete Data Types</td>
#       <td id="T_87ef6_row2_col1" class="data row2 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_87ef6_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_87ef6_row3_col0" class="data row3 col0" >Number of Interval Data Types</td>
#       <td id="T_87ef6_row3_col1" class="data row3 col1" >1</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Data Quality Analysis
# Data type, cardinality, validity, duplication, and size data are summarized at the variable level.

# %%
dataset.quality.style.format(**formatting)
# Out:
# <style type="text/css">
# </style>
# <table id="T_bf5ef">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bf5ef_level0_col0" class="col_heading level0 col0" >Column</th>
#       <th id="T_bf5ef_level0_col1" class="col_heading level0 col1" >Format</th>
#       <th id="T_bf5ef_level0_col2" class="col_heading level0 col2" >Data Type</th>
#       <th id="T_bf5ef_level0_col3" class="col_heading level0 col3" >Valid</th>
#       <th id="T_bf5ef_level0_col4" class="col_heading level0 col4" >Null</th>
#       <th id="T_bf5ef_level0_col5" class="col_heading level0 col5" >Validity</th>
#       <th id="T_bf5ef_level0_col6" class="col_heading level0 col6" >Cardinality</th>
#       <th id="T_bf5ef_level0_col7" class="col_heading level0 col7" >Percent Unique</th>
#       <th id="T_bf5ef_level0_col8" class="col_heading level0 col8" >Size</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bf5ef_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bf5ef_row0_col0" class="data row0 col0" >id</td>
#       <td id="T_bf5ef_row0_col1" class="data row0 col1" >int64</td>
#       <td id="T_bf5ef_row0_col2" class="data row0 col2" >Nominal</td>
#       <td id="T_bf5ef_row0_col3" class="data row0 col3" >153,518</td>
#       <td id="T_bf5ef_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_bf5ef_row0_col5" class="data row0 col5" >1.00</td>
#       <td id="T_bf5ef_row0_col6" class="data row0 col6" >129,579</td>
#       <td id="T_bf5ef_row0_col7" class="data row0 col7" >0.84</td>
#       <td id="T_bf5ef_row0_col8" class="data row0 col8" >1,228,144</td>
#     </tr>
#     <tr>
#       <th id="T_bf5ef_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_bf5ef_row1_col0" class="data row1 col0" >name</td>
#       <td id="T_bf5ef_row1_col1" class="data row1 col1" >object</td>
#       <td id="T_bf5ef_row1_col2" class="data row1 col2" >Nominal</td>
#       <td id="T_bf5ef_row1_col3" class="data row1 col3" >153,518</td>
#       <td id="T_bf5ef_row1_col4" class="data row1 col4" >0</td>
#       <td id="T_bf5ef_row1_col5" class="data row1 col5" >1.00</td>
#       <td id="T_bf5ef_row1_col6" class="data row1 col6" >129,552</td>
#       <td id="T_bf5ef_row1_col7" class="data row1 col7" >0.84</td>
#       <td id="T_bf5ef_row1_col8" class="data row1 col8" >12,950,810</td>
#     </tr>
#     <tr>
#       <th id="T_bf5ef_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_bf5ef_row2_col0" class="data row2 col0" >category_id</td>
#       <td id="T_bf5ef_row2_col1" class="data row2 col1" >int64</td>
#       <td id="T_bf5ef_row2_col2" class="data row2 col2" >Categorical</td>
#       <td id="T_bf5ef_row2_col3" class="data row2 col3" >153,518</td>
#       <td id="T_bf5ef_row2_col4" class="data row2 col4" >0</td>
#       <td id="T_bf5ef_row2_col5" class="data row2 col5" >1.00</td>
#       <td id="T_bf5ef_row2_col6" class="data row2 col6" >16</td>
#       <td id="T_bf5ef_row2_col7" class="data row2 col7" >0.00</td>
#       <td id="T_bf5ef_row2_col8" class="data row2 col8" >1,228,144</td>
#     </tr>
#     <tr>
#       <th id="T_bf5ef_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_bf5ef_row3_col0" class="data row3 col0" >category</td>
#       <td id="T_bf5ef_row3_col1" class="data row3 col1" >object</td>
#       <td id="T_bf5ef_row3_col2" class="data row3 col2" >Categorical</td>
#       <td id="T_bf5ef_row3_col3" class="data row3 col3" >153,518</td>
#       <td id="T_bf5ef_row3_col4" class="data row3 col4" >0</td>
#       <td id="T_bf5ef_row3_col5" class="data row3 col5" >1.00</td>
#       <td id="T_bf5ef_row3_col6" class="data row3 col6" >16</td>
#       <td id="T_bf5ef_row3_col7" class="data row3 col7" >0.00</td>
#       <td id="T_bf5ef_row3_col8" class="data row3 col8" >10,321,037</td>
#     </tr>
#     <tr>
#       <th id="T_bf5ef_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_bf5ef_row4_col0" class="data row4 col0" >rating</td>
#       <td id="T_bf5ef_row4_col1" class="data row4 col1" >float64</td>
#       <td id="T_bf5ef_row4_col2" class="data row4 col2" >Interval</td>
#       <td id="T_bf5ef_row4_col3" class="data row4 col3" >153,518</td>
#       <td id="T_bf5ef_row4_col4" class="data row4 col4" >0</td>
#       <td id="T_bf5ef_row4_col5" class="data row4 col5" >1.00</td>
#       <td id="T_bf5ef_row4_col6" class="data row4 col6" >9</td>
#       <td id="T_bf5ef_row4_col7" class="data row4 col7" >0.00</td>
#       <td id="T_bf5ef_row4_col8" class="data row4 col8" >1,228,144</td>
#     </tr>
#     <tr>
#       <th id="T_bf5ef_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_bf5ef_row5_col0" class="data row5 col0" >reviews</td>
#       <td id="T_bf5ef_row5_col1" class="data row5 col1" >int64</td>
#       <td id="T_bf5ef_row5_col2" class="data row5 col2" >Discrete</td>
#       <td id="T_bf5ef_row5_col3" class="data row5 col3" >153,518</td>
#       <td id="T_bf5ef_row5_col4" class="data row5 col4" >0</td>
#       <td id="T_bf5ef_row5_col5" class="data row5 col5" >1.00</td>
#       <td id="T_bf5ef_row5_col6" class="data row5 col6" >4,231</td>
#       <td id="T_bf5ef_row5_col7" class="data row5 col7" >0.03</td>
#       <td id="T_bf5ef_row5_col8" class="data row5 col8" >1,228,144</td>
#     </tr>
#     <tr>
#       <th id="T_bf5ef_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_bf5ef_row6_col0" class="data row6 col0" >ratings</td>
#       <td id="T_bf5ef_row6_col1" class="data row6 col1" >int64</td>
#       <td id="T_bf5ef_row6_col2" class="data row6 col2" >Discrete</td>
#       <td id="T_bf5ef_row6_col3" class="data row6 col3" >153,518</td>
#       <td id="T_bf5ef_row6_col4" class="data row6 col4" >0</td>
#       <td id="T_bf5ef_row6_col5" class="data row6 col5" >1.00</td>
#       <td id="T_bf5ef_row6_col6" class="data row6 col6" >11,191</td>
#       <td id="T_bf5ef_row6_col7" class="data row6 col7" >0.07</td>
#       <td id="T_bf5ef_row6_col8" class="data row6 col8" >1,228,144</td>
#     </tr>
#     <tr>
#       <th id="T_bf5ef_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_bf5ef_row7_col0" class="data row7 col0" >onestar</td>
#       <td id="T_bf5ef_row7_col1" class="data row7 col1" >int64</td>
#       <td id="T_bf5ef_row7_col2" class="data row7 col2" >Discrete</td>
#       <td id="T_bf5ef_row7_col3" class="data row7 col3" >153,518</td>
#       <td id="T_bf5ef_row7_col4" class="data row7 col4" >0</td>
#       <td id="T_bf5ef_row7_col5" class="data row7 col5" >1.00</td>
#       <td id="T_bf5ef_row7_col6" class="data row7 col6" >3,075</td>
#       <td id="T_bf5ef_row7_col7" class="data row7 col7" >0.02</td>
#       <td id="T_bf5ef_row7_col8" class="data row7 col8" >1,228,144</td>
#     </tr>
#     <tr>
#       <th id="T_bf5ef_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_bf5ef_row8_col0" class="data row8 col0" >twostar</td>
#       <td id="T_bf5ef_row8_col1" class="data row8 col1" >int64</td>
#       <td id="T_bf5ef_row8_col2" class="data row8 col2" >Discrete</td>
#       <td id="T_bf5ef_row8_col3" class="data row8 col3" >153,518</td>
#       <td id="T_bf5ef_row8_col4" class="data row8 col4" >0</td>
#       <td id="T_bf5ef_row8_col5" class="data row8 col5" >1.00</td>
#       <td id="T_bf5ef_row8_col6" class="data row8 col6" >1,915</td>
#       <td id="T_bf5ef_row8_col7" class="data row8 col7" >0.01</td>
#       <td id="T_bf5ef_row8_col8" class="data row8 col8" >1,228,144</td>
#     </tr>
#     <tr>
#       <th id="T_bf5ef_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_bf5ef_row9_col0" class="data row9 col0" >threestar</td>
#       <td id="T_bf5ef_row9_col1" class="data row9 col1" >int64</td>
#       <td id="T_bf5ef_row9_col2" class="data row9 col2" >Discrete</td>
#       <td id="T_bf5ef_row9_col3" class="data row9 col3" >153,518</td>
#       <td id="T_bf5ef_row9_col4" class="data row9 col4" >0</td>
#       <td id="T_bf5ef_row9_col5" class="data row9 col5" >1.00</td>
#       <td id="T_bf5ef_row9_col6" class="data row9 col6" >2,898</td>
#       <td id="T_bf5ef_row9_col7" class="data row9 col7" >0.02</td>
#       <td id="T_bf5ef_row9_col8" class="data row9 col8" >1,228,144</td>
#     </tr>
#     <t

# %% [markdown]
# ## Content Analysis

# %%
dataset.summary.style.format(**formatting)
# Out:
# <style type="text/css">
# </style>
# <table id="T_6a852">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6a852_level0_col0" class="col_heading level0 col0" >Category</th>
#       <th id="T_6a852_level0_col1" class="col_heading level0 col1" >Examples</th>
#       <th id="T_6a852_level0_col2" class="col_heading level0 col2" >Apps</th>
#       <th id="T_6a852_level0_col3" class="col_heading level0 col3" >Average Rating</th>
#       <th id="T_6a852_level0_col4" class="col_heading level0 col4" >Rating Count</th>
#       <th id="T_6a852_level0_col5" class="col_heading level0 col5" >Review Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6a852_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6a852_row0_col0" class="data row0 col0" >Health & Fitness</td>
#       <td id="T_6a852_row0_col1" class="data row0 col1" >14,681</td>
#       <td id="T_6a852_row0_col2" class="data row0 col2" >11,721</td>
#       <td id="T_6a852_row0_col3" class="data row0 col3" >4.29</td>
#       <td id="T_6a852_row0_col4" class="data row0 col4" >69,368,208</td>
#       <td id="T_6a852_row0_col5" class="data row0 col5" >6,530,265</td>
#     </tr>
#     <tr>
#       <th id="T_6a852_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6a852_row1_col0" class="data row1 col0" >Education</td>
#       <td id="T_6a852_row1_col1" class="data row1 col1" >13,212</td>
#       <td id="T_6a852_row1_col2" class="data row1 col2" >10,931</td>
#       <td id="T_6a852_row1_col3" class="data row1 col3" >4.24</td>
#       <td id="T_6a852_row1_col4" class="data row1 col4" >75,172,396</td>
#       <td id="T_6a852_row1_col5" class="data row1 col5" >3,848,424</td>
#     </tr>
#     <tr>
#       <th id="T_6a852_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6a852_row2_col0" class="data row2 col0" >Utilities</td>
#       <td id="T_6a852_row2_col1" class="data row2 col1" >12,236</td>
#       <td id="T_6a852_row2_col2" class="data row2 col2" >9,701</td>
#       <td id="T_6a852_row2_col3" class="data row2 col3" >4.07</td>
#       <td id="T_6a852_row2_col4" class="data row2 col4" >131,277,902</td>
#       <td id="T_6a852_row2_col5" class="data row2 col5" >6,270,973</td>
#     </tr>
#     <tr>
#       <th id="T_6a852_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6a852_row3_col0" class="data row3 col0" >Shopping</td>
#       <td id="T_6a852_row3_col1" class="data row3 col1" >12,022</td>
#       <td id="T_6a852_row3_col2" class="data row3 col2" >10,329</td>
#       <td id="T_6a852_row3_col3" class="data row3 col3" >4.49</td>
#       <td id="T_6a852_row3_col4" class="data row3 col4" >331,039,135</td>
#       <td id="T_6a852_row3_col5" class="data row3 col5" >9,515,002</td>
#     </tr>
#     <tr>
#       <th id="T_6a852_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6a852_row4_col0" class="data row4 col0" >Lifestyle</td>
#       <td id="T_6a852_row4_col1" class="data row4 col1" >10,913</td>
#       <td id="T_6a852_row4_col2" class="data row4 col2" >8,531</td>
#       <td id="T_6a852_row4_col3" class="data row4 col3" >4.25</td>
#       <td id="T_6a852_row4_col4" class="data row4 col4" >143,917,913</td>
#       <td id="T_6a852_row4_col5" class="data row4 col5" >8,359,071</td>
#     </tr>
#     <tr>
#       <th id="T_6a852_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_6a852_row5_col0" class="data row5 col0" >Photo & Video</td>
#       <td id="T_6a852_row5_col1" class="data row5 col1" >10,482</td>
#       <td id="T_6a852_row5_col2" class="data row5 col2" >9,462</td>
#       <td id="T_6a852_row5_col3" class="data row5 col3" >4.02</td>
#       <td id="T_6a852_row5_col4" class="data row5 col4" >259,327,405</td>
#       <td id="T_6a852_row5_col5" class="data row5 col5" >17,261,525</td>
#     </tr>
#     <tr>
#       <th id="T_6a852_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_6a852_row6_col0" class="data row6 col0" >Music</td>
#       <td id="T_6a852_row6_col1" class="data row6 col1" >9,784</td>
#       <td id="T_6a852_row6_col2" class="data row6 col2" >9,494</td>
#       <td id="T_6a852_row6_col3" class="data row6 col3" >4.24</td>
#       <td id="T_6a852_row6_col4" class="data row6 col4" >123,172,220</td>
#       <td id="T_6a852_row6_col5" class="data row6 col5" >5,502,001</td>
#     </tr>
#     <tr>
#       <th id="T_6a852_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_6a852_row7_col0" class="data row7 col0" >Business</td>
#       <td id="T_6a852_row7_col1" class="data row7 col1" >9,436</td>
#       <td id="T_6a852_row7_col2" class="data row7 col2" >7,728</td>
#       <td id="T_6a852_row7_col3" class="data row7 col3" >3.99</td>
#       <td id="T_6a852_row7_col4" class="data row7 col4" >78,521,689</td>
#       <td id="T_6a852_row7_col5" class="data row7 col5" >2,417,416</td>
#     </tr>
#     <tr>
#       <th id="T_6a852_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_6a852_row8_col0" class="data row8 col0" >Food & Drink</td>
#       <td id="T_6a852_row8_col1" class="data row8 col1" >8,973</td>
#       <td id="T_6a852_row8_col2" class="data row8 col2" >8,688</td>
#       <td id="T_6a852_row8_col3" class="data row8 col3" >4.37</td>
#       <td id="T_6a852_row8_col4" class="data row8 col4" >122,413,043</td>
#       <td id="T_6a852_row8_col5" class="data row8 col5" >3,059,905</td>
#     </tr>
#     <tr>
#       <th id="T_6a852_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_6a852_row9_col0" class="data row9 col0" >Productivity</td>
#       <td id="T_6a852_row9_col1" class="data row9 col1" >8,708</td>
#       <td id="T_6a852_row9_col2" class="data row9 col2" >6,400</td>
#       <td id="T_6a852_row9_col3" class="data row9 col3" >4.19</td>
#       <td id="T_6a852_row9_col4" class="data row9 col4" >126,252,116</td>
#       <td id="T_6a852_row9_col5" class="data row9 col5" >6,034,024</td>
#     </tr>
#     <tr>
#       <th id="T_6a852_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_6a852_row10_col0" class="data row10 col0" >Entertainment</td>
#       <td id="T_6a852_row10_col1" class="data row10 col1" >8,507</td>
#       <td id="T_6a852_row10_col2" class="data row10 col2" >7,297</td>
#       <td id="T_6a852_row10_col3" class="data row10 col3" >4.11</td>
#       <td id="T_6a852_row10_col4" class="data row10 col4" >162,296,982</td>
#       <td id="T_6a852_row10_col5" class="data row10 col5" >11,392,628</td>
#     </tr>
#     <tr>
#       <th id="T_6a852_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_6a852_row11_col0" class="data row11 col0" >Social Networking</td>
#       <td id="T_6a852_row11_col1" class="data row11 col1" >8,108</td>
#       <td id="T_6a852_row11_col2" class="data row11 col2" >6,745</td>
#       <td id="T_6a852_row11_col3" class="data row11 col3" >4.19</td>
#       <td id="T_6a852_row11_col4" class="data row11 col4" >106,553,304</td>
#       <td id="T_6a852_row11_col5" class="data row11 col5" >10,742,752</td>
#     </tr>
#     <tr>
#       <th id="T_6a852_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_6a852_row12_col0" class="data row12 col0" >Finance</td>
#       <td id="T_6a852_row12_col1" class="data row12 col1" >6,950</td>
#       <td id="T_6a852_row12_col2" class="data row12 col2" >5,198</td>
#       <td id="T_6a852_row12_col3" class="data row12 col3" >4.41</td>
#       <td id="T_6a852_row12_col4" class="data row12 col4" >337,578,246</td>
#       <td id="T_6a852_row12_col5" class="data row12 col5" >8,731,553</td>
#     </tr>
#     <tr>
#       <th id="T_6a852_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_6a852_row13_col0" class="data row13 col0" >Medical</td>
#       <td id="T_6a852_row13_col1" class="data row13 col1" >6,949</td>
#       <td id="T_6a852_row13_col2" class="data row13 col2" >5,949</td>
#       <td id="T_6a852_row13_col3" class="data row13 col3" >4.16</td>
#       <td id="T_6a852_row13_col4" class="data row13 col4" >15,569,562</td>
#       <td id="T_6a852_row13_col5" class="data row13 col5" >962,432</td>
#     </tr>
#     <tr>
#       <th id="T_6a852_level0_row14" class="row

# %%
dataset.
