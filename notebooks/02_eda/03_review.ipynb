# %% [markdown]
# # Reviews

# %%
import os

import numpy as np
import pandas as pd
from IPython.display import HTML, display_html

from appstore.data.analysis.review import ReviewDataset
from appstore.container import AppstoreContainer

container = AppstoreContainer()
container.init_resources()
container.wire(packages=["appstore.data.analysis"])
pd.set_option("max_colwidth", 400)

# %%
repo = container.data.review_repo()

# %%
repo.summary
# Out:
#            Category  Reviews  Apps  Average Rating
# 0  Health & Fitness  4183113  4099            4.22
# 1          Business  1435554  7932            3.58
# 2         Lifestyle   753173   628            3.95

# %%
repo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6371840 entries, 0 to 6371839
# Data columns (total 13 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   id           object
#  1   app_id       int64
#  2   app_name     object
#  3   category_id  int64
#  4   category     object
#  5   author       object
#  6   rating       int64
#  7   title        object
#  8   content      object
#  9   vote_sum     int64
#  10  vote_count   int64
#  11  date         object
#  12  source       object
# dtypes: int64(5), object(8)
# memory usage: 632.0+ MB

# %%
repo.sample()
# Out:
#                                                        2280132  \
# id                                                  1321315372
# app_id                                               331308914
# app_name                                   WW / WeightWatchers
# category_id                                               6013
# category                                      Health & Fitness
# author                                               raymi0603
# rating                                                       1
# title                                      Needs a lot of work
# content      Previous app was better. This app quits unexpe...
# vote_sum                                                     0
# vote_count                                                   0
# date                                       2016-01-24 01:32:00
# source                                        itunes.apple.com
#
#                                                        2907218  \
# id                                                  1017703402
# app_id                                               426826309
# app_name                               Strava: Run, Ride, Hike
# category_id                                               6013
# category                                      Health & Fitness
# author                                          gratefuldave77
# rating                                                       5
# title                                              Stravaddict
# content      Strava is my favorite app. It is so much fun t...
# vote_sum                                                     0
# vote_count                                                   0
# date                                2014-06-27 04:48:00.280000
# source                                        itunes.apple.com
#
#                                                        2012675  \
# id                                                   466338391
# app_id                                               341232718
# app_name                         MyFitnessPal: Calorie Counter
# category_id                                               6013
# category                                      Health & Fitness
# author                                           Rochelle Ware
# rating                                                       5
# title                                           My fitness pal
# content      I love the ease of this app! The barcode scann...
# vote_sum                                                     0
# vote_count                                                   0
# date                                2011-09-28 14:36:00.070000
# source                                        itunes.apple.com
#
#                                                        2075499  \
# id                                                   612014203
# app_id                                               341232718
# app_name                         MyFitnessPal: Calorie Counter
# category_id                                               6013
# category                                      Health & Fitness
# author                                               KubDanzer
# rating                                                       1
# title                                                Really!!!
# content      I really like the program until now.  It keeps...
# vote_sum                                                     0
# vote_count                                                   0
# date                                2012-06-30 04:22:00.150000
# source                                        itunes.apple.com
#
#                                                        5001668
# id                                                  1499745158
# app_id                                               449804588
# app_name                                              TalkLife
# category_id                                               6013
# category                                      Health & Fitness
# author                                                  Birdy🐣
# rating                                                       5
# title                                      This app is amazing
# content      It makes me feel so much better having people ...
# vote_sum                                                     0
# vote_count                                                   0
# date                                2016-12-11 05:18:00.010000
# source                                        itunes.apple.com

# %%
repo.get(id=1321315372)['content'].values
# Out:
# array(["Previous app was better. This app quits unexpectedly and does not contain much more information than the previous app. The only difference is that the points values are different, but it's the same old badly written app."],
#       dtype=object)
