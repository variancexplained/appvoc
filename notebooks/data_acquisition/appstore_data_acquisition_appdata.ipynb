# %% [markdown]
# # AppStore
# As of 2022, Apple's App Store was home to some 1.76 million apps and over 460,000 games. The aim of this exercise is to obtain app rating and review data for select categories for sentiment analysis, product analytics, opportunity discovery, and selection.  Our data acquisition centers on three entities: AppData, Rating, and Review, which are described below.
#
# ## AppData
# The AppData entity encapsulates the core data for each app and is defined as follows.
#
# | #  | attribute     | type  | description                                  | API Field         |
# |----|---------------|-------|----------------------------------------------|-------------------|
# | 1  | id:           | int   | Unique Apple App Identifier                  | trackId           |
# | 2  | name:         | str   | Name of the app.                             | trackName         |
# | 3  | description:  | str   | Description                                  | description       |
# | 4  | category_id:  | int   | Four digit category identifier               | primaryGenreId    |
# | 5  | category:     | str   | Category name                                | primaryGenreName  |
# | 6  | price:        | float | Cost of the app                              | price             |
# | 7  | rating:       | float | The user average rating                      | averageUserRating |
# | 8  | ratings:      | int   | The rating count                             | userRatingCount   |
# | 9  | developer_id: | int   | The app developer identifier                 | artistId          |
# | 10 | developer:    | str   | The app developer name                       | artistName        |
# | 11 | released:     | str   | The date of initial release                  | releaseDate       |
# | 12 | source:       | str   | The host from which the data were obtained.  | itunes.apple.com  |
#
# The data acquisition pipeline will obtain app data for the following categories and persist them in an RDBMS table.
#
# 1. business
# 2. education
# 3. entertainment
# 4. health
# 5. lifestyle
# 6. medical
# 7. productivity
# 9. social_networking

# %% [markdown]
# ### Imports

# %%
from aimobile.data.acquisition.appstore.Project import AppStoreAppProject
from aimobile.container import AIMobileContainer

# %%
TERMS_COMPLETE = ["health", "productivity", "social", "business", "education", "entertainment", "lifestyle", "medical"]
TERMS = ["finance", "food", "music", "reference", "photo", "video", "shopping", "travel", "utilities"]

# %% [markdown]
# ### Dependencies

# %%
container = AIMobileContainer()
container.init_resources()
container.wire(packages=["aimobile.data.acquisition.appstore"])

# %% [markdown]
# ### AppData Page
# AppStoreAppProject object iterates through the above TERMs, engaging a scraper to extract the app data described above from the App Store. The results are persisted in an RDBMS and archived.

# %%
Project = AppStoreAppProject()
Project.scrape(terms=TERMS)
Project.summarize()
# Out:
# [04/28/2023 08:19:03 PM] [DEBUG] [urllib3.connectionpool] [_new_conn] : Starting new HTTPS connection (1): itunes.apple.com:443
# [04/28/2023 08:19:04 PM] [DEBUG] [urllib3.connectionpool] [_make_request] : https://itunes.apple.com:443 "GET /search?media=software&term=finance&country=us&lang=en-us&explicit=yes&limit=200&offset=0 HTTP/1.1" 200 447821
# [04/28/2023 08:19:04 PM] [DEBUG] [SessionHandler] [_teardown] :
# Request status code: 200. Session: 0
# [04/28/2023 08:19:08 PM] [DEBUG] [AppStoreAppProject] [_scrape] :              id                            name
# 0    1069512882                          Stocks  \
# 1     300238550  Mint: Budget & Expense Manager
# 2     351727428                           Venmo
# 3     348177453            Fidelity Investments
# 4     328412701    Yahoo Finance: Stocks & News
# ..          ...                             ...
# 195  1210438422        Arvest Go Mobile Banking
# 196  1053148887                 PayPal Business
# 197  1397958651  The General Auto Insurance App
# 198   443932954            Calculator for iPad!
# 199  1050870627            Papaya: Pay Any Bill
#
#                                            description  category_id
# 0    Stocks makes it easy to follow your stocks and...         6015  \
# 1    Experience a fresh way to manage money. Reach ...         6015
# 2    Venmo is the fast, safe, social way to pay and...         6015
# 3    Invest at a firm invested in you. Fidelity’s s...         6015
# 4    Your #1 finance destination to track the marke...         6015
# ..                                                 ...          ...
# 195  Go for Convenience and Control with Arvest Go\...         6015
# 196  The PayPal business app is the best app availa...         6000
# 197  The General’s mobile app is here to help you m...         6015
# 198  Calculator for iPad is an easy to use, beautif...         6002
# 199  Ready for a new way to bill pay? Papaya is a F...         6015
#
#       category  price  developer_id
# 0      Finance   0.00     284417353  \
# 1      Finance   0.00     300238553
# 2      Finance   0.00     351727431
# 3      Finance   0.00     348177456
# 4      Finance   0.00     281970157
# ..         ...    ...           ...
# 195    Finance   0.00     337997680
# 196   Business   0.00     283646712
# 197    Finance   0.00     623411656
# 198  Utilities   0.00     321178305
# 199    Finance   0.00    1136491084
#
#                                            developer  rating   ratings
# 0                                              Apple    2.98      1501  \
# 1                                           Mint.com    4.76    772894
# 2                                              Venmo    4.86  15342015
# 3                               Fidelity Investments    4.76   1929439
# 4                                              Yahoo    4.74    533064
# ..                                               ...     ...       ...
# 195                                           Arvest    4.87    195526
# 196                                     PayPal, Inc.    4.26     23178
# 197  The General Automobile Insurance Services, Inc.    4.69    120156
# 198                                         7th Gear    4.70     53264
# 199                             SnapPays Mobile, Inc    4.76     99362
#
#                             released            source
# 0   2016-05-10 18:16:00.420000+00:00  itunes.apple.com
# 1   2008-12-19 02:09:00.400000+00:00  itunes.apple.com
# 2   2010-04-03 05:41:00.470000+00:00  itunes.apple.com
# 3          2010-02-22 08:00:00+00:00  itunes.apple.com
# 4   2009-09-08 03:58:00.360000+00:00  itunes.apple.com
# ..                               ...               ...
# 195 2017-11-28 13:41:00.230000+00:00  itunes.apple.com
# 196 2016-11-29 03:12:00.570000+00:00  itunes.apple.com
# 197 2018-07-28 10:12:00.400000+00:00  itunes.apple.com
# 198 2011-07-30 03:48:00.110000+00:00  itunes.apple.com
# 199 2015-11-23 17:37:00.130000+00:00  itunes.apple.com
#
# [200 rows x 12 columns]
# [04/28/2023 08:19:08 PM] [DEBUG] [AppStoreAppDataRepo] [add] : Added 200 rows to the appdata repository.
# [04/28/2023 08:19:11 PM] [DEBUG] [urllib3.connectionpool] [_make_request] : https://itunes.apple.com:443 "GET /search?media=software&term=finance&country=us&lang=en-us&explicit=yes&limit=200&offset=1 HTTP/1.1" 200 448799
# [04/28/2023 08:19:11 PM] [DEBUG] [SessionHandler] [_teardown] :
# Request status code: 200. Session: 0
# [04/28/2023 08:19:15 PM] [DEBUG] [AppStoreAppProject] [_scrape] :              id                            name
# 0     300238550  Mint: Budget & Expense Manager  \
# 1     351727428                           Venmo
# 2     348177453            Fidelity Investments
# 3     328412701    Yahoo Finance: Stocks & News
# 4     283646709     PayPal - Send, Shop, Manage
# ..          ...                             ...
# 195  1053148887                 PayPal Business
# 196  1397958651  The General Auto Insurance App
# 197   443932954            Calculator for iPad!
# 198  1050870627            Papaya: Pay Any Bill
# 199  1405254630  Square Invoices: Invoice Maker
#
#                                            description  category_id
# 0    Experience a fresh way to manage money. Reach ...         6015  \
# 1    Venmo is the fast, safe, social way to pay and...         6015
# 2    Invest at a firm invested in you. Fidelity’s s...         6015
# 3    Your #1 finance destination to track the marke...         6015
# 4    Now there’s more ways to PayPal— buy, sell, se...         6015
# ..                                                 ...          ...
# 195  The PayPal business app is the best app availa...         6000
# 196  The General’s mobile app is here to help you m...         6015
# 197  Calculator for iPad is an easy to use, beautif...         6002
# 198  Ready for a new way to bill pay? Papaya is a F...         6015
# 199  Square Invoices is a must have invoicing solut...         6000
#
#       category  price  developer_id
# 0      Finance   0.00     300238553  \
# 1      Finance   0.00     351727431
# 2      Finance   0.00     348177456
# 3      Finance   0.00     281970157
# 4      Finance   0.00     283646712
# ..         ...    ...           ...
# 195   Business   0.00     283646712
# 196    Finance   0.00     623411656
# 197  Utilities   0.00     321178305
# 198    Finance   0.00    1136491084
# 199   Business   0.00     335393791
#
#                                            developer  rating   ratings
# 0                                           Mint.com    4.76    772894  \
# 1                                              Venmo    4.86  15342015
# 2                               Fidelity Investments    4.76   1929439
# 3                                              Yahoo    4.74    533064
# 4                                       PayPal, Inc.    4.80   6172180
# ..                                               ...     ...       ...
# 195                                     PayPal, Inc.    4.26     23178
# 196  The General Automobile Insurance Services, Inc.    4.69    120156
# 197                                         7th Gear    4.70     53264
# 198                             SnapPays Mobile, Inc    4.76     99362
# 199                                     Square, Inc.    4.85     68216
#
#                             released            source
# 0   2008-12-19 02:09:00.400000+00:00  itunes.apple.com
# 1   2010-04-03 05:41:00.470000+00:00  itunes.apple.com
# 2          2010-02-22 08:00:00+00:00  itunes.apple.com
# 3   2009-09-08 03:58:00.360000+00:00  itunes.apple.com
# 4          2019-02-03 08:00:00+00:00  itunes.apple.com
# ..                               ...               ...
# 195 2016-11-29 03:12:00.570000+00:00  itunes.apple.com
# 196 2018-07-28 10:12:00.400000+00:00  itunes.apple.com
# 197 2011-07-30 03:48:00.110000+00:00  itunes.apple.com
# 198 2015-11-23 17:37:00.130000+00:00  itunes.apple.com
# 199 2019-03-26 04:02:00.330000+00:00  itunes.apple.com
#
# [200 rows x 12 columns]
# [04/28/2023 08:19:15 PM] [DEBUG] [AppStoreAppDataRepo] [add] : Added 200 rows to the appdata repository.
