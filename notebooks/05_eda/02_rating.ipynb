# %% [markdown]
# # AppStore Rating Exploratory Data Analysis
#
#
# | #  | Variable    | Description                      | Data Type   |
# |----|-------------|----------------------------------|-------------|
# | 1  | id          | App Identifier                   | Nominal     |
# | 2  | name        | App Name                         | Nominal     |
# | 3  | category_id | Four Digit Category Id           | Categorical |
# | 4  | category    | Category Name                    | Categorical |
# | 5  | rating      | Average Customer Rating          | Interval    |
# | 6  | reviews     | Total Number Of Customer Reviews | Discrete    |
# | 7  | ratings     | Rating Count                     | Discrete    |
# | 8  | onestar     | One Star Rating Count            | Discrete    |
# | 9  | twostar     | Two Star Rating Count            | Discrete    |
# | 10 | threestar   | Three Star Rating Count          | Discrete    |
# | 11 | fourstar    | Four Star Rating Count           | Discrete    |
# | 12 | fivestar    | Five Star Rating Count           | Discrete    |

# %%
import os

import numpy as np
import pandas as pd
from IPython.display import HTML, display_html

from appstore.data.dataset.rating import RatingDataset
from appstore.container import AppstoreContainer

container = AppstoreContainer()
container.init_resources()
container.wire(packages=["appstore.data.dataset"])
dataset = RatingDataset()
formatting = {"thousands":",", "precision":2}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 13
#      11 container.init_resources()
#      12 container.wire(packages=["appstore.data.dataset"])
# ---> 13 dataset = RatingDataset()
#      14 formatting = {"thousands":",", "precision":2}
#
# TypeError: RatingDataset.__init__() missing 1 required positional argument: 'df'

# %% [markdown]
# ### Structural Analysis
# The structure and characteristics of the Rating dataset are as follows:

# %%
df1 = dataset.structure
df2 = dataset.dtypes

df1_style = df1.style.set_table_attributes("style='display:inline; margin-right:220px;'").set_caption("Dataset Structure").format(thousands=",")
df2_style = df2.style.set_table_attributes("style='display:inline; margin-right:120px'").set_caption("Dataset Data Types").format(thousands=",")

display_html(df1_style._repr_html_() + df2_style._repr_html_(), raw=True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_dd2dc" style='display:inline; margin-right:220px;'>
#   <caption>Dataset Structure</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dd2dc_level0_col0" class="col_heading level0 col0" >Characteristic</th>
#       <th id="T_dd2dc_level0_col1" class="col_heading level0 col1" >Total</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dd2dc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_dd2dc_row0_col0" class="data row0 col0" >Number of Observations</td>
#       <td id="T_dd2dc_row0_col1" class="data row0 col1" >177,100</td>
#     </tr>
#     <tr>
#       <th id="T_dd2dc_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_dd2dc_row1_col0" class="data row1 col0" >Number of Variables</td>
#       <td id="T_dd2dc_row1_col1" class="data row1 col1" >13</td>
#     </tr>
#     <tr>
#       <th id="T_dd2dc_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_dd2dc_row2_col0" class="data row2 col0" >Number of Cells</td>
#       <td id="T_dd2dc_row2_col1" class="data row2 col1" >2,302,300</td>
#     </tr>
#     <tr>
#       <th id="T_dd2dc_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_dd2dc_row3_col0" class="data row3 col0" >Size (Bytes)</td>
#       <td id="T_dd2dc_row3_col1" class="data row3 col1" >39,125,826</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_31c6d" style='display:inline; margin-right:120px'>
#   <caption>Dataset Data Types</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_31c6d_level0_col0" class="col_heading level0 col0" >Data Type</th>
#       <th id="T_31c6d_level0_col1" class="col_heading level0 col1" >Number of Features</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_31c6d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_31c6d_row0_col0" class="data row0 col0" >Number of Nominal Data Types</td>
#       <td id="T_31c6d_row0_col1" class="data row0 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_31c6d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_31c6d_row1_col0" class="data row1 col0" >Number of Categorical Data Types</td>
#       <td id="T_31c6d_row1_col1" class="data row1 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_31c6d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_31c6d_row2_col0" class="data row2 col0" >Number of Discrete Data Types</td>
#       <td id="T_31c6d_row2_col1" class="data row2 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_31c6d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_31c6d_row3_col0" class="data row3 col0" >Number of Interval Data Types</td>
#       <td id="T_31c6d_row3_col1" class="data row3 col1" >1</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Data Quality Analysis
# Data type, cardinality, validity, duplication, and size data are summarized at the variable level.

# %%
dataset.quality.style.format(**formatting)
# Out:
# <style type="text/css">
# </style>
# <table id="T_310ab">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_310ab_level0_col0" class="col_heading level0 col0" >Column</th>
#       <th id="T_310ab_level0_col1" class="col_heading level0 col1" >Format</th>
#       <th id="T_310ab_level0_col2" class="col_heading level0 col2" >Data Type</th>
#       <th id="T_310ab_level0_col3" class="col_heading level0 col3" >Valid</th>
#       <th id="T_310ab_level0_col4" class="col_heading level0 col4" >Null</th>
#       <th id="T_310ab_level0_col5" class="col_heading level0 col5" >Validity</th>
#       <th id="T_310ab_level0_col6" class="col_heading level0 col6" >Cardinality</th>
#       <th id="T_310ab_level0_col7" class="col_heading level0 col7" >Percent Unique</th>
#       <th id="T_310ab_level0_col8" class="col_heading level0 col8" >Size</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_310ab_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_310ab_row0_col0" class="data row0 col0" >id</td>
#       <td id="T_310ab_row0_col1" class="data row0 col1" >string</td>
#       <td id="T_310ab_row0_col2" class="data row0 col2" >Nominal</td>
#       <td id="T_310ab_row0_col3" class="data row0 col3" >177,100</td>
#       <td id="T_310ab_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_310ab_row0_col5" class="data row0 col5" >1.00</td>
#       <td id="T_310ab_row0_col6" class="data row0 col6" >177,100</td>
#       <td id="T_310ab_row0_col7" class="data row0 col7" >1.00</td>
#       <td id="T_310ab_row0_col8" class="data row0 col8" >11,839,060</td>
#     </tr>
#     <tr>
#       <th id="T_310ab_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_310ab_row1_col0" class="data row1 col0" >name</td>
#       <td id="T_310ab_row1_col1" class="data row1 col1" >string</td>
#       <td id="T_310ab_row1_col2" class="data row1 col2" >Nominal</td>
#       <td id="T_310ab_row1_col3" class="data row1 col3" >177,100</td>
#       <td id="T_310ab_row1_col4" class="data row1 col4" >0</td>
#       <td id="T_310ab_row1_col5" class="data row1 col5" >1.00</td>
#       <td id="T_310ab_row1_col6" class="data row1 col6" >176,890</td>
#       <td id="T_310ab_row1_col7" class="data row1 col7" >1.00</td>
#       <td id="T_310ab_row1_col8" class="data row1 col8" >14,932,818</td>
#     </tr>
#     <tr>
#       <th id="T_310ab_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_310ab_row2_col0" class="data row2 col0" >category_id</td>
#       <td id="T_310ab_row2_col1" class="data row2 col1" >category</td>
#       <td id="T_310ab_row2_col2" class="data row2 col2" >Categorical</td>
#       <td id="T_310ab_row2_col3" class="data row2 col3" >177,100</td>
#       <td id="T_310ab_row2_col4" class="data row2 col4" >0</td>
#       <td id="T_310ab_row2_col5" class="data row2 col5" >1.00</td>
#       <td id="T_310ab_row2_col6" class="data row2 col6" >7</td>
#       <td id="T_310ab_row2_col7" class="data row2 col7" >0.00</td>
#       <td id="T_310ab_row2_col8" class="data row2 col8" >177,827</td>
#     </tr>
#     <tr>
#       <th id="T_310ab_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_310ab_row3_col0" class="data row3 col0" >category</td>
#       <td id="T_310ab_row3_col1" class="data row3 col1" >category</td>
#       <td id="T_310ab_row3_col2" class="data row3 col2" >Categorical</td>
#       <td id="T_310ab_row3_col3" class="data row3 col3" >177,100</td>
#       <td id="T_310ab_row3_col4" class="data row3 col4" >0</td>
#       <td id="T_310ab_row3_col5" class="data row3 col5" >1.00</td>
#       <td id="T_310ab_row3_col6" class="data row3 col6" >7</td>
#       <td id="T_310ab_row3_col7" class="data row3 col7" >0.00</td>
#       <td id="T_310ab_row3_col8" class="data row3 col8" >177,875</td>
#     </tr>
#     <tr>
#       <th id="T_310ab_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_310ab_row4_col0" class="data row4 col0" >rating</td>
#       <td id="T_310ab_row4_col1" class="data row4 col1" >float64</td>
#       <td id="T_310ab_row4_col2" class="data row4 col2" >Continuous</td>
#       <td id="T_310ab_row4_col3" class="data row4 col3" >177,100</td>
#       <td id="T_310ab_row4_col4" class="data row4 col4" >0</td>
#       <td id="T_310ab_row4_col5" class="data row4 col5" >1.00</td>
#       <td id="T_310ab_row4_col6" class="data row4 col6" >10</td>
#       <td id="T_310ab_row4_col7" class="data row4 col7" >0.00</td>
#       <td id="T_310ab_row4_col8" class="data row4 col8" >1,416,800</td>
#     </tr>
#     <tr>
#       <th id="T_310ab_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_310ab_row5_col0" class="data row5 col0" >reviews</td>
#       <td id="T_310ab_row5_col1" class="data row5 col1" >int64</td>
#       <td id="T_310ab_row5_col2" class="data row5 col2" >Discrete</td>
#       <td id="T_310ab_row5_col3" class="data row5 col3" >177,100</td>
#       <td id="T_310ab_row5_col4" class="data row5 col4" >0</td>
#       <td id="T_310ab_row5_col5" class="data row5 col5" >1.00</td>
#       <td id="T_310ab_row5_col6" class="data row5 col6" >2,494</td>
#       <td id="T_310ab_row5_col7" class="data row5 col7" >0.01</td>
#       <td id="T_310ab_row5_col8" class="data row5 col8" >1,416,800</td>
#     </tr>
#     <tr>
#       <th id="T_310ab_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_310ab_row6_col0" class="data row6 col0" >ratings</td>
#       <td id="T_310ab_row6_col1" class="data row6 col1" >int64</td>
#       <td id="T_310ab_row6_col2" class="data row6 col2" >Discrete</td>
#       <td id="T_310ab_row6_col3" class="data row6 col3" >177,100</td>
#       <td id="T_310ab_row6_col4" class="data row6 col4" >0</td>
#       <td id="T_310ab_row6_col5" class="data row6 col5" >1.00</td>
#       <td id="T_310ab_row6_col6" class="data row6 col6" >6,430</td>
#       <td id="T_310ab_row6_col7" class="data row6 col7" >0.04</td>
#       <td id="T_310ab_row6_col8" class="data row6 col8" >1,416,800</td>
#     </tr>
#     <tr>
#       <th id="T_310ab_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_310ab_row7_col0" class="data row7 col0" >onestar</td>
#       <td id="T_310ab_row7_col1" class="data row7 col1" >int64</td>
#       <td id="T_310ab_row7_col2" class="data row7 col2" >Discrete</td>
#       <td id="T_310ab_row7_col3" class="data row7 col3" >177,100</td>
#       <td id="T_310ab_row7_col4" class="data row7 col4" >0</td>
#       <td id="T_310ab_row7_col5" class="data row7 col5" >1.00</td>
#       <td id="T_310ab_row7_col6" class="data row7 col6" >1,763</td>
#       <td id="T_310ab_row7_col7" class="data row7 col7" >0.01</td>
#       <td id="T_310ab_row7_col8" class="data row7 col8" >1,416,800</td>
#     </tr>
#     <tr>
#       <th id="T_310ab_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_310ab_row8_col0" class="data row8 col0" >twostar</td>
#       <td id="T_310ab_row8_col1" class="data row8 col1" >int64</td>
#       <td id="T_310ab_row8_col2" class="data row8 col2" >Discrete</td>
#       <td id="T_310ab_row8_col3" class="data row8 col3" >177,100</td>
#       <td id="T_310ab_row8_col4" class="data row8 col4" >0</td>
#       <td id="T_310ab_row8_col5" class="data row8 col5" >1.00</td>
#       <td id="T_310ab_row8_col6" class="data row8 col6" >1,086</td>
#       <td id="T_310ab_row8_col7" class="data row8 col7" >0.01</td>
#       <td id="T_310ab_row8_col8" class="data row8 col8" >1,416,800</td>
#     </tr>
#     <tr>
#       <th id="T_310ab_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_310ab_row9_col0" class="data row9 col0" >threestar</td>
#       <td id="T_310ab_row9_col1" class="data row9 col1" >int64</td>
#       <td id="T_310ab_row9_col2" class="data row9 col2" >Discrete</td>
#       <td id="T_310ab_row9_col3" class="data row9 col3" >177,100</td>
#       <td id="T_310ab_row9_col4" class="data row9 col4" >0</td>
#       <td id="T_310ab_row9_col5" class="data row9 col5" >1.00</td>
#       <td id="T_310ab_row9_col6" class="data row9 col6" >1,656</td>
#       <td id="T_310ab_row9_col7" class="data row9 col7" >0.01</td>
#       <td id="T_310ab_row9_col8" class="data row9 col8" >1,416,800</td>
#     </tr>

# %% [markdown]
# ## Content Analysis

# %%
dataset.summary.style.format(**formatting)
# Out:
# <style type="text/css">
# </style>
# <table id="T_48e99">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_48e99_level0_col0" class="col_heading level0 col0" >Category</th>
#       <th id="T_48e99_level0_col1" class="col_heading level0 col1" >Examples</th>
#       <th id="T_48e99_level0_col2" class="col_heading level0 col2" >Apps</th>
#       <th id="T_48e99_level0_col3" class="col_heading level0 col3" >Average Rating</th>
#       <th id="T_48e99_level0_col4" class="col_heading level0 col4" >Rating Count</th>
#       <th id="T_48e99_level0_col5" class="col_heading level0 col5" >Review Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_48e99_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_48e99_row0_col0" class="data row0 col0" >Finance</td>
#       <td id="T_48e99_row0_col1" class="data row0 col1" >58,300</td>
#       <td id="T_48e99_row0_col2" class="data row0 col2" >58,300</td>
#       <td id="T_48e99_row0_col3" class="data row0 col3" >1.21</td>
#       <td id="T_48e99_row0_col4" class="data row0 col4" >132,980,495</td>
#       <td id="T_48e99_row0_col5" class="data row0 col5" >3,846,716</td>
#     </tr>
#     <tr>
#       <th id="T_48e99_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_48e99_row1_col0" class="data row1 col0" >Medical</td>
#       <td id="T_48e99_row1_col1" class="data row1 col1" >31,800</td>
#       <td id="T_48e99_row1_col2" class="data row1 col2" >31,800</td>
#       <td id="T_48e99_row1_col3" class="data row1 col3" >0.68</td>
#       <td id="T_48e99_row1_col4" class="data row1 col4" >9,060,144</td>
#       <td id="T_48e99_row1_col5" class="data row1 col5" >589,224</td>
#     </tr>
#     <tr>
#       <th id="T_48e99_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_48e99_row2_col0" class="data row2 col0" >Health & Fitness</td>
#       <td id="T_48e99_row2_col1" class="data row2 col1" >28,800</td>
#       <td id="T_48e99_row2_col2" class="data row2 col2" >28,800</td>
#       <td id="T_48e99_row2_col3" class="data row2 col3" >2.14</td>
#       <td id="T_48e99_row2_col4" class="data row2 col4" >37,529,874</td>
#       <td id="T_48e99_row2_col5" class="data row2 col5" >3,392,969</td>
#     </tr>
#     <tr>
#       <th id="T_48e99_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_48e99_row3_col0" class="data row3 col0" >Lifestyle</td>
#       <td id="T_48e99_row3_col1" class="data row3 col1" >20,500</td>
#       <td id="T_48e99_row3_col2" class="data row3 col2" >20,500</td>
#       <td id="T_48e99_row3_col3" class="data row3 col3" >1.95</td>
#       <td id="T_48e99_row3_col4" class="data row3 col4" >59,400,346</td>
#       <td id="T_48e99_row3_col5" class="data row3 col5" >3,714,440</td>
#     </tr>
#     <tr>
#       <th id="T_48e99_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_48e99_row4_col0" class="data row4 col0" >Food & Drink</td>
#       <td id="T_48e99_row4_col1" class="data row4 col1" >17,900</td>
#       <td id="T_48e99_row4_col2" class="data row4 col2" >17,900</td>
#       <td id="T_48e99_row4_col3" class="data row4 col3" >2.26</td>
#       <td id="T_48e99_row4_col4" class="data row4 col4" >87,449,927</td>
#       <td id="T_48e99_row4_col5" class="data row4 col5" >2,324,313</td>
#     </tr>
#     <tr>
#       <th id="T_48e99_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_48e99_row5_col0" class="data row5 col0" >Photo & Video</td>
#       <td id="T_48e99_row5_col1" class="data row5 col1" >17,900</td>
#       <td id="T_48e99_row5_col2" class="data row5 col2" >17,900</td>
#       <td id="T_48e99_row5_col3" class="data row5 col3" >2.14</td>
#       <td id="T_48e99_row5_col4" class="data row5 col4" >100,711,313</td>
#       <td id="T_48e99_row5_col5" class="data row5 col5" >7,472,538</td>
#     </tr>
#     <tr>
#       <th id="T_48e99_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_48e99_row6_col0" class="data row6 col0" >Productivity</td>
#       <td id="T_48e99_row6_col1" class="data row6 col1" >1,900</td>
#       <td id="T_48e99_row6_col2" class="data row6 col2" >1,900</td>
#       <td id="T_48e99_row6_col3" class="data row6 col3" >1.16</td>
#       <td id="T_48e99_row6_col4" class="data row6 col4" >31,737</td>
#       <td id="T_48e99_row6_col5" class="data row6 col5" >6,660</td>
#     </tr>
#   </tbody>
# </table>
