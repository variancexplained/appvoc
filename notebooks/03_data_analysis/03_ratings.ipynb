# %% [markdown]
# # Ratings Exploratory Data Analysis
#
# | #  | Variable    | Description                      | Data Type   |
# |----|-------------|----------------------------------|-------------|
# | 1  | id          | App Identifier                   | Nominal     |
# | 2  | name        | App Name                         | Nominal     |
# | 3  | category_id | Four Digit Category Id           | Categorical |
# | 4  | category    | Category Name                    | Categorical |
# | 5  | rating      | Average Customer Rating          | Interval    |
# | 6  | reviews     | Total Number Of Customer Reviews | Discrete    |
# | 7  | ratings     | Rating Count                     | Discrete    |
# | 8  | onestar     | One Star Rating Count            | Discrete    |
# | 9  | twostar     | Two Star Rating Count            | Discrete    |
# | 10 | threestar   | Three Star Rating Count          | Discrete    |
# | 11 | fourstar    | Four Star Rating Count           | Discrete    |
# | 12 | fivestar    | Five Star Rating Count           | Discrete    |

# %%
import os

import numpy as np
import pandas as pd
from IPython.display import HTML, display_html

from aimobile.data.dataset.rating import RatingDataset
from aimobile.container import AIMobileContainer

container = AIMobileContainer()
container.init_resources()
container.wire(packages=["aimobile.data.dataset"])
dataset = RatingDataset()

# %% [markdown]
# ### Structural Analysis
# The structure and characteristics of the Rating dataset are as follows:

# %%
df1 = dataset.structure
df2 = dataset.dtypes

df1_style = df1.style.set_table_attributes("style='display:inline; margin-right:220px;'").set_caption("Dataset Structure")
df2_style = df2.style.set_table_attributes("style='display:inline; margin-right:120px'").set_caption("Dataset Data Types")

display_html(df1_style._repr_html_() + df2_style._repr_html_(), raw=True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_6c7e9" style='display:inline; margin-right:220px;'>
#   <caption>Dataset Structure</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6c7e9_level0_col0" class="col_heading level0 col0" >Characteristic</th>
#       <th id="T_6c7e9_level0_col1" class="col_heading level0 col1" >Total</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6c7e9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6c7e9_row0_col0" class="data row0 col0" >Number of Observations</td>
#       <td id="T_6c7e9_row0_col1" class="data row0 col1" >141278</td>
#     </tr>
#     <tr>
#       <th id="T_6c7e9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6c7e9_row1_col0" class="data row1 col0" >Number of Variables</td>
#       <td id="T_6c7e9_row1_col1" class="data row1 col1" >12</td>
#     </tr>
#     <tr>
#       <th id="T_6c7e9_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6c7e9_row2_col0" class="data row2 col0" >Number of Cells</td>
#       <td id="T_6c7e9_row2_col1" class="data row2 col1" >1695336</td>
#     </tr>
#     <tr>
#       <th id="T_6c7e9_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6c7e9_row3_col0" class="data row3 col0" >Size (Bytes)</td>
#       <td id="T_6c7e9_row3_col1" class="data row3 col1" >32287351</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_3a82e" style='display:inline; margin-right:120px'>
#   <caption>Dataset Data Types</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3a82e_level0_col0" class="col_heading level0 col0" >Data Type</th>
#       <th id="T_3a82e_level0_col1" class="col_heading level0 col1" >Number of Features</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3a82e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3a82e_row0_col0" class="data row0 col0" >Number of Nominal Data Types</td>
#       <td id="T_3a82e_row0_col1" class="data row0 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_3a82e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3a82e_row1_col0" class="data row1 col0" >Number of Categorical Data Types</td>
#       <td id="T_3a82e_row1_col1" class="data row1 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_3a82e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3a82e_row2_col0" class="data row2 col0" >Number of Discrete Data Types</td>
#       <td id="T_3a82e_row2_col1" class="data row2 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_3a82e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3a82e_row3_col0" class="data row3 col0" >Number of Interval Data Types</td>
#       <td id="T_3a82e_row3_col1" class="data row3 col1" >1</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Data Quality Analysis
# Data type, cardinality, validity, duplication, and size data are summarized at the variable level.

# %%
dataset.quality
# Out:
#          Column   Format    Data Type   Valid  Null  Validity  Cardinality
# 0            id    int64      Nominal  141278     0      1.00       119875  \
# 1          name   object      Nominal  141278     0      1.00       119862
# 2   category_id    int64  Categorical  141278     0      1.00           15
# 3      category   object  Categorical  141278     0      1.00           15
# 4        rating  float64     Interval  141278     0      1.00            9
# 5       reviews    int64     Discrete  141278     0      1.00         4032
# 6       ratings    int64     Discrete  141278     0      1.00        10495
# 7       onestar    int64     Discrete  141278     0      1.00         2887
# 8       twostar    int64     Discrete  141278     0      1.00         1821
# 9     threestar    int64     Discrete  141278     0      1.00         2740
# 10     fourstar    int64     Discrete  141278     0      1.00         4241
# 11     fivestar    int64     Discrete  141278     0      1.00         9677
#
#     Percent Unique      Size
# 0             0.85   1130224
# 1             0.85  11907298
# 2             0.00   1130224
# 3             0.00   9513209
# 4             0.00   1130224
# 5             0.03   1130224
# 6             0.07   1130224
# 7             0.02   1130224
# 8             0.01   1130224
# 9             0.02   1130224
# 10            0.03   1130224
# 11            0.07   1130224

# %% [markdown]
# ## Content Analysis

# %%
dataset.summary
# Out:
#              Category  Examples   Apps  Average Rating  Rating Count
# 0    Health & Fitness     14681  11721            4.29      69368208  \
# 1           Education     13212  10931            4.24      75172396
# 2            Shopping     12022  10329            4.49     331039135
# 3           Lifestyle     10913   8531            4.25     143917913
# 4       Photo & Video     10482   9462            4.02     259327405
# 5               Music      9784   9494            4.24     123172220
# 6            Business      9436   7728            3.99      78521689
# 7        Food & Drink      8973   8688            4.37     122413043
# 8        Productivity      8708   6400            4.19     126252116
# 9       Entertainment      8507   7297            4.11     162296982
# 10  Social Networking      8108   6745            4.19     106553304
# 11            Finance      6950   5198            4.41     337578246
# 12            Medical      6949   5949            4.16      15569562
# 13             Travel      6459   5799            4.10     171320098
# 14          Reference      6094   5605            4.29      27798497
#
#     Review Count
# 0        6530265
# 1        3848424
# 2        9515002
# 3        8359071
# 4       17261525
# 5        5502001
# 6        2417416
# 7        3059905
# 8        6034024
# 9       11392628
# 10      10742752
# 11       8731553
# 12        962432
# 13       3621989
# 14       2587086
