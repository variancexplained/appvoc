# %% [markdown]
# # Database
# Includes three tables (so far):
# - Project: One row per search project.
# - Request: One row per HTTP request.
# - AppData: Includes one row per app

# %%
from aimobile.scraper.appstore.database.sqlite import SQLiteDatabase
from aimobile.scraper.appstore.container import AppStoreContainer
# Out:
# ========================================
# <dependency_injector.providers.ConfigurationOption('config.database') at 0x7febe4686ea0>
# ========================================

# %% [markdown]
# ## Projects

# %%
container = AppStoreContainer()
dc = container.datacentre.repo()
dc.project_repository.getall()
# Out:
# 2023-04-10 02:15:33,798 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-04-10 02:15:33,799 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("SELECT * FROM project;")
# 2023-04-10 02:15:33,800 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-04-10 02:15:33,803 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("SELECT * FROM project;")
# 2023-04-10 02:15:33,804 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-04-10 02:15:33,806 INFO sqlalchemy.engine.Engine SELECT * FROM project;
# 2023-04-10 02:15:33,807 INFO sqlalchemy.engine.Engine [raw sql] ()
#      name  app_count  page_count               started                 ended
# 0  health         10           2  04/10/2023, 02:15:09  04/10/2023, 02:15:15  \
#
#    duration        state    source  id              _started
# 0      5.99  in-progress  appstore   1  04/10/2023, 02:15:09

# %% [markdown]
# ## Apps

# %%
dc.appdata_repository.getall()
# Out:
# 2023-04-10 02:15:34,019 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("SELECT * FROM appdata;")
# 2023-04-10 02:15:34,020 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-04-10 02:15:34,024 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("SELECT * FROM appdata;")
# 2023-04-10 02:15:34,025 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-04-10 02:15:34,027 INFO sqlalchemy.engine.Engine SELECT * FROM appdata;
# 2023-04-10 02:15:34,028 INFO sqlalchemy.engine.Engine [raw sql] ()
#            id                           name
# 0  1208224953                        Fitness  \
# 1   341232718  MyFitnessPal: Calorie Counter
# 2   571800810                           Calm
# 3   335364882                      Walgreens
# 4   331308914            WW / WeightWatchers
# 5  1038369065  Flo Period Tracker & Calendar
# 6   297368629     Lose It! – Calorie Counter
# 7   493145008  Headspace: Mindful Meditation
# 8   405075943    AllTrails: Hike, Bike & Run
# 9   485357017     GoodRx: Prescription Saver
#
#                                          description  category_id
# 0  Get a comprehensive view of your fitness, incl...         6013  \
# 1  Track progress toward your nutrition, water, f...         6013
# 2  ** Best of 2018 Award Winner ** — Apple\n\n** ...         6013
# 3  It's your Walgreens - shop and manage your pre...         6024
# 4  WeightWatchers® is for people who want more fr...         6013
# 5  Discover the most popular female health & well...         6013
# 6  Lose It! is a calorie counting, nutrition trac...         6013
# 7  Stress less, sleep soundly, and get happier. H...         6013
# 8  Whether you hike, bike, run, or walk, AllTrail...         6013
# 9  GoodRx is a free pharmacy coupons app that hel...         6020
#
#            category  price  developer_id               developer  rating
# 0  Health & Fitness   0.00     284417353                   Apple    3.01  \
# 1  Health & Fitness   0.00     341232721      MyFitnessPal, Inc.    4.71
# 2  Health & Fitness   0.00     571800813                Calm.com    4.77
# 3          Shopping   0.00     335364885            Walgreen Co.    4.82
# 4  Health & Fitness   0.00     331308917  WW International, Inc.    4.84
# 5  Health & Fitness   0.00    1149787531   FLO HEALTH UK LIMITED    4.77
# 6  Health & Fitness   0.00     297368632                  FitNow    4.76
# 7  Health & Fitness   0.00     384434796          Headspace Inc.    4.85
# 8  Health & Fitness   0.00     405075946         AllTrails, Inc.    4.89
# 9           Medical   0.00     485357020                  GoodRx    4.84
#
#    ratings              released            source
# 0     3653  2017-04-10T23:30:13Z  itunes.apple.com
# 1  1611688  2009-12-08T02:04:45Z  itunes.apple.com
# 2  1610620  2013-02-22T20:09:23Z  itunes.apple.com
# 3  3805419  2009-10-27T00:10:29Z  itunes.apple.com
# 4  1962470  2009-09-19T00:05:27Z  itunes.apple.com
# 5  1049779  2015-10-03T22:28:36Z  itunes.apple.com
# 6   582643  2008-11-21T22:54:04Z  itunes.apple.com
# 7   928489  2012-02-02T18:57:49Z  itunes.apple.com
# 8   763846  2010-12-17T23:35:17Z  itunes.apple.com
# 9   625835  2011-12-07T20:47:44Z  itunes.apple.com

# %% [markdown]
# ## Requests

# %%
dc.request_repository.getall()
# Out:
# 2023-04-10 02:15:34,369 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("SELECT * FROM request;")
# 2023-04-10 02:15:34,371 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-04-10 02:15:34,373 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("SELECT * FROM request;")
# 2023-04-10 02:15:34,374 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-04-10 02:15:34,377 INFO sqlalchemy.engine.Engine SELECT * FROM request;
# 2023-04-10 02:15:34,378 INFO sqlalchemy.engine.Engine [raw sql] ()
#                host    name  page  content_length  results
# 0  itunes.apple.com  health     0           15990        5  \
# 1  itunes.apple.com  health     1           16363        5
#
#              requested            responded  response_time  sessions
# 0  04/10/2023 02:15:12  04/10/2023 02:15:12           0.61         1  \
# 1  04/10/2023 02:15:15  04/10/2023 02:15:15           0.12         1
#
#   status_code  id
# 0        None   1
# 1        None   2
