# %%
from datetime import datetime
from appstore.data.storage.job import JobRepo, RatingJobRun, ReviewJobRun
from appstore.container import AppstoreContainer
from appstore.infrastructure.io.local import IOService

# %%
container = AppstoreContainer()
container.init_resources()
container.wire(packages=["appstore.data.acquisition"])

# %%
JOB_FILEPATH = "tests/data/job/jobs.csv"
REVIEW_JOBRUN_FILEPATH = "tests/data/job/review_jobrun.csv"
RATING_JOBRUN_FILEPATH = "tests/data/job/rating_jobrun.csv"

# %%
job_repo = container.data.job_repo()
review_jobrun_repo = container.data.review_jobrun_repo()
rating_jobrun_repo = container.data.rating_jobrun_repo()

# %%
job_repo.reset()
review_jobrun_repo.reset()
rating_jobrun_repo.reset()
# Out:
# [08/02/2023 08:01:09 AM] [INFO] [JobRepo] [reset] : Repository JobRepo reset.
# [08/02/2023 08:01:12 AM] [INFO] [ReviewJobRunRepo] [reset] : Repository ReviewJobRunRepo reset.
# [08/02/2023 08:01:15 AM] [INFO] [RatingJobRunRepo] [reset] : Repository RatingJobRunRepo reset.

# %%
jobs = IOService.read(JOB_FILEPATH)
review_jobruns = IOService.read(REVIEW_JOBRUN_FILEPATH)
rating_jobruns = IOService.read(RATING_JOBRUN_FILEPATH)

# %%
def setdates(df):
    started = "07/15/2023 04:20:20"    
    ended = "07/29/2023 04:20:20"
    epoch = "01/01/1970 00:00:10"
    try:
        completed = df['complete'] == True    
        df.loc[completed, "completed"] = datetime.strptime(started, "%m/%d/%Y %H:%M:%S")
        df.loc[completed, "started"] = datetime.strptime(started, "%m/%d/%Y %H:%M:%S")
        df.loc[completed, "ended"] = datetime.strptime(ended, "%m/%d/%Y %H:%M:%S")
        notcompleted = df['complete'] == False
        df.loc[notcompleted, "completed"] = datetime.strptime(epoch, "%m/%d/%Y %H:%M:%S")
        df.loc[notcompleted, "started"] = datetime.strptime(epoch, "%m/%d/%Y %H:%M:%S")
        df.loc[notcompleted, "ended"] = datetime.strptime(epoch, "%m/%d/%Y %H:%M:%S")
    except Exception:
        pass
    return df

# %%
jobs = setdates(jobs)
review_jobruns = setdates(review_jobruns)
rating_jobruns = setdates(rating_jobruns)
jobs
review_jobruns
rating_jobruns
# Out:
#              id        controller  category_id            category  complete  \
# 0   rating-6000  RatingController         6000            Business     False
# 1   rating-6002  RatingController         6002           Utilities     False
# 2   rating-6005  RatingController         6005   Social_Networking     False
# 3   rating-6007  RatingController         6007        Productivity     False
# 4   rating-6012  RatingController         6012           Lifestyle      True
# 5   rating-6013  RatingController         6013  Health_And_Fitness      True
# 6   rating-6015  RatingController         6015             Finance      True
# 7   rating-6016  RatingController         6016       Entertainment     False
# 8   rating-6017  RatingController         6017           Education     False
# 9   rating-6020  RatingController         6020             Medical      True
# 10  rating-6023  RatingController         6023      Food_And_Drink      True
# 11  rating-6024  RatingController         6024            Shopping     False
# 12  review-6000  ReviewController         6000            Business      True
# 13  review-6002  ReviewController         6002           Utilities     False
# 14  review-6005  ReviewController         6005   Social_Networking     False
# 15  review-6007  ReviewController         6007        Productivity      True
# 16  review-6012  ReviewController         6012           Lifestyle     False
# 17  review-6013  ReviewController         6013  Health_And_Fitness     False
# 18  review-6015  ReviewController         6015             Finance     False
# 19  review-6016  ReviewController         6016       Entertainment     False
# 20  review-6017  ReviewController         6017           Education     False
# 21  review-6020  ReviewController         6020             Medical     False
# 22  review-6023  ReviewController         6023      Food_And_Drink     False
# 23  review-6024  ReviewController         6024            Shopping     False
#
#               completed
# 0   1970-01-01 00:00:10
# 1   1970-01-01 00:00:10
# 2   1970-01-01 00:00:10
# 3   1970-01-01 00:00:10
# 4   2023-07-15 04:20:20
# 5   2023-07-15 04:20:20
# 6   2023-07-15 04:20:20
# 7   1970-01-01 00:00:10
# 8   1970-01-01 00:00:10
# 9   2023-07-15 04:20:20
# 10  2023-07-15 04:20:20
# 11  1970-01-01 00:00:10
# 12  2023-07-15 04:20:20
# 13  1970-01-01 00:00:10
# 14  1970-01-01 00:00:10
# 15  2023-07-15 04:20:20
# 16  1970-01-01 00:00:10
# 17  1970-01-01 00:00:10
# 18  1970-01-01 00:00:10
# 19  1970-01-01 00:00:10
# 20  1970-01-01 00:00:10
# 21  1970-01-01 00:00:10
# 22  1970-01-01 00:00:10
# 23  1970-01-01 00:00:10
#          jobid        controller  category_id  category          started  \
# 0  rating-6000  RatingController         6000  Business  07/15/2023 4:20
#
#               ended  elapsed  client_errors  server_errors  data_errors  \
# 0  07/16/2023 14:20   236547             22             25           75
#
#    errors    size  size_ave   apps  apps_per_second  reviews  \
# 0     122  548953      6.39  85975             2.36      258
#
#    reviews_per_second            completed  complete
# 0                5.60  2023-07-15 04:20:20      True
#          jobid        controller  category_id  category          started  \
# 0  rating-6000  RatingController         6000  Business  07/15/2023 4:20
#
#               ended  elapsed  client_errors  server_errors  data_errors  \
# 0  07/16/2023 14:20   236547             22             25           75
#
#    errors    size  size_ave   apps  apps_per_second            completed  \
# 0     122  548953      6.39  85975             2.36  1970-01-01 00:00:10
#
#    complete
# 0     False

# %%
job_repo.add(jobs)
review_jobrun_repo.add(review_jobruns)
rating_jobrun_repo.add(rating_jobruns)
# Out:
# [08/02/2023 08:01:16 AM] [DEBUG] [JobRepo] [add] : Added 24 rows to the job repository.
# [08/02/2023 08:01:16 AM] [ERROR] [MySQLDatabase] [insert] : Exception occurred during database insert.
# Exception type:type[sqlalchemy.exc.SQLAlchemyError]
# (pymysql.err.OperationalError) (1292, "Incorrect datetime value: '07/15/2023 4:20' for column 'started' at row 1")
# [SQL: INSERT INTO review_jobrun (jobid, controller, category_id, category, started, ended, elapsed, client_errors, server_errors, data_errors, errors, size, size_ave, apps, apps_per_second, reviews, reviews_per_second, completed, complete) VALUES (%(jobid)s, %(controller)s, %(category_id)s, %(category)s, %(started)s, %(ended)s, %(elapsed)s, %(client_errors)s, %(server_errors)s, %(data_errors)s, %(errors)s, %(size)s, %(size_ave)s, %(apps)s, %(apps_per_second)s, %(reviews)s, %(reviews_per_second)s, %(completed)s, %(complete)s)]
# [parameters: {'jobid': 'rating-6000', 'controller': 'RatingController', 'category_id': 6000, 'category': 'Business', 'started': '07/15/2023 4:20', 'ended': '07/16/2023 14:20', 'elapsed': 236547, 'client_errors': 22, 'server_errors': 25, 'data_errors': 75, 'errors': 122, 'size': 548953, 'size_ave': 6.385030532, 'apps': 85975, 'apps_per_second': 2.36, 'reviews': 258, 'reviews_per_second': 5.6, 'completed': datetime.datetime(2023, 7, 15, 4, 20, 20), 'complete': True}]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Traceback (most recent call last):
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/sqlalchemy/engine/base.py", line 1965, in _exec_single_context
#     self.dialect.do_execute(
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/sqlalchemy/engine/default.py", line 921, in do_execute
#     cursor.execute(statement, parameters)
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/pymysql/cursors.py", line 148, in execute
#     result = self._query(query)
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/pymysql/cursors.py", line 310, in _query
#     conn.query(q)
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/pymysql/connections.py", line 548, in query
#     self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/pymysql/connections.py", line 775, in _read_query_result
#     result.read()
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/pymysql/connections.py", line 1156, in read
#     first_packet = self.connection._read_packet()
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/pymysql/connections.py", line 725, in _read_packet
#     packet.raise_for_error()
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/pymysql/protocol.py", line 221, in raise_for_error
#     err.raise_mysql_exception(self._data)
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/pymysql/err.py", line 143, in raise_mysql_exception
#     raise errorclass(errno, errval)
# pymysql.err.OperationalError: (1292, "Incorrect datetime value: '07/15/2023 4:20' for column 'started' at row 1")
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/john/projects/appstore/appstore/infrastructure/database/base.py", line 162, in insert
#     return data.to_sql(
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/pandas/core/generic.py", line 2878, in to_sql
#     return sql.to_sql(
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/pandas/io/sql.py", line 769, in to_sql
#     return pandas_sql.to_sql(
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/pandas/io/sql.py", line 1920, in to_sql
#     total_inserted = sql_engine.insert_records(
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/pandas/io/sql.py", line 1470, in insert_records
#     raise err
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/pandas/io/sql.py", line 1461, in insert_records
#     return table.insert(chunksize=chunksize, method=method)
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/pandas/io/sql.py", line 1023, in insert
#     num_inserted = exec_insert(conn, keys, chunk_iter)
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/pandas/io/sql.py", line 929, in _execute_insert
#     result = conn.execute(self.table.insert(), data)
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/sqlalchemy/engine/base.py", line 1412, in execute
#     return meth(
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/sqlalchemy/sql/elements.py", line 483, in _execute_on_connection
#     return connection._execute_clauseelement(
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/sqlalchemy/engine/base.py", line 1635, in _execute_clauseelement
#     ret = self._execute_context(
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/sqlalchemy/engine/base.py", line 1844, in _execute_context
#     return self._exec_single_context(
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/sqlalchemy/engine/base.py", line 1984, in _exec_single_context
#     self._handle_dbapi_exception(
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/sqlalchemy/engine/base.py", line 2339, in _handle_dbapi_exception
#     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/sqlalchemy/engine/base.py", line 1965, in _exec_single_context
#     self.dialect.do_execute(
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/sqlalchemy/engine/default.py", line 921, in do_execute
#     cursor.execute(statement, parameters)
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/pymysql/cursors.py", line 148, in execute
#     result = self._query(query)
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/pymysql/cursors.py", line 310, in _query
#     conn.query(q)
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/pymysql/connections.py", line 548, in query
#     self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/pymysql/connections.py", line 775, in _read_query_result
#     result.read()
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/pymysql/connections.py", line 1156, in read
#     first_packet = self.connection._read_packet()
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/pymysql/connections.py", line 725, in _read_packet
#     packet.raise_for_error()
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/pymysql/protocol.py", line 221, in raise_for_error
#     err.raise_mysql_exception(self._data)
#   File "/home/john/anaconda3/envs/appstore/lib/python3.10/site-packages/pymysql/err.py", line 143, in raise_mysql_exception
#     raise errorclass(errno, errval)
# sqlalchemy.exc.OperationalError: (pymysql.err.OperationalError) (1292, "Incorrect datetime value: '07/15/2023 4:20' for column 'started' at row 1")
# [SQL: INSERT INTO review_jobrun (jobid, controller, category_id, category, started, ended, elapsed, client_errors, server_errors, data_errors, errors, size, size_ave, apps, apps_per_second, reviews, reviews_per_second, completed, complete) VALUES (%(jobid)s, %(controller)s, %(category_id)s, %(category)s, %(started)s, %(ended)s, %(elapsed)s, %(client_errors)s, %(server_errors)s, %(data_errors)s, %(errors)s, %(size)s, %(size_ave)s, %(apps)s, %(apps_per_second)s, %(reviews)s, %(reviews_per_second)s, %(completed)s, %(complete)s)]
# [parameters: {'jobid': 'rating-6000', 'controller': 'RatingController', 'category_id': 6000, 'category': 'Business', 'started': '07/15/2023 4:20', 'ended': '07/16/2023 14:20', 'elapsed': 236547, 'client_errors': 22, 'server_errors': 25, 'data_errors': 75, 'errors': 122, 'size': 548953, 'size_ave': 6.385030532, 'apps': 85975, 'apps_per_second': 2.36, 'reviews': 258, 'reviews_per_second': 5.6, 'completed': datetime.datetime(2023, 7, 15, 4, 20, 20), 'complete': True}]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~/anaconda3/envs/appstore/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1965, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1964     if not evt_handled:
# -> 1965         self.dialect.do_execute(
#    1966             cursor, str_statement, effective_parameters, context
#    1967         )
#    1969 if self._has_events or self.engine._has_events:
#
# File ~/anaconda3/envs/appstore/lib/python3.10/site-packages/sqlalchemy/engine/default.py:921, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     920 def do_execute(self, cursor, statement, parameters, context=None):
# --> 921     cursor.execute(statement, parameters)
#
# File ~/anaconda3/envs/appstore/lib/python3.10/site-packages/pymysql/cursors.py:148, in Cursor.execute(self, query, args)
#     146 query = self.mogrify(query, args)
# --> 148 result = self._query(query)
#     149 self._executed = query
#
# File ~/anaconda3/envs/appstore/lib/python3.10/site-packages/pymysql/cursors.py:310, in Cursor._query(self, q)
#     309 self._clear_result()
# --> 310 conn.query(q)
#     311 self._do_get_result()
#
# File ~/anaconda3/envs/appstore/lib/python3.10/site-packages/pymysql/connections.py:548, in Connection.query(self, sql, unbuffered)
#     547 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 548 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     549 return self._affected_rows
#
# File ~/anaconda3/envs/appstore/lib/python3.10/site-packages/pymysql/connections.py:775, in Connection._read_query_result(self, unbuffered)
#     774     result = MySQLResult(self)
# --> 775     result.read()
#     776 self._result = result
#
# File ~/anaconda3/envs/appstore/lib/python3.10/site-packages/pymysql/connections.py:1156, in MySQLResult.read(self)
#    1155 try:
# -> 1156     first_packet = self.connection._read_packet()
#    1158     if first_packet.is_ok_packet():
#
# File ~/anaconda3/envs/appstore/lib/python3.10/site-packages/pymysql/connections.py:725, in Connection._read_packet(self, packet_type)
#     724         self._result.unbuffered_active = False
# --> 725     packet.raise_for_error()
#     726 return packet
#
# File ~/anaconda3/envs/appstore/lib/python3.10/site-packages/pymysql/protocol.py:221, in MysqlPacket.raise_for_error(self)
#     220     print("errno =", errno)
# --> 221 err.raise_mysql_exception(self._data)
#
# File ~/anaconda3/envs/appstore/lib/python3.10/site-packages/pymysql/err.py:143, in raise_mysql_exception(data)
#     142     errorclass = InternalError if errno < 1000 else OperationalError
# --> 143 raise errorclass(errno, errval)
#
# OperationalError: (1292, "Incorrect datetime value: '07/15/2023 4:20' for column 'started' at row 1")
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# Cell In[9], line 2
#       1 job_repo.add(jobs)
# ----> 2 review_jobrun_repo.add(review_jobruns)
#       3 rating_jobrun_repo.add(rating_jobruns)
#
# File ~/projects/appstore/appstore/data/storage/job.py:360, in ReviewJobRunRepo.add(self, data)
#     354 def add(self, data: pd.DataFrame) -> None:
#     355     """Adds the dataframe rows to the designated table.
#     356
#     357     Args:
#     358         data (pd.DataFrame): DataFrame containing rows to add to the table.
#     359     """
# --> 360     self._database.insert(
#     361         data=data,
#     362         tablename=self._name,
#     363         dtype=REVIEW_JOBRUN_DATABASE_DTYPES,
#     364         if_exists="append",
#     365     )
#     366     msg = f"Added {data.shape[0]} rows to the {self._name} repository."
#     367     self._logger.debug(msg)
#
# File ~/projects/appstore/appstore/infrastructure/database/base.py:162, in Database.insert(self, data, tablename, dtype, if_exists)
#     145 """Inserts data in pandas DataFrame format into the designated table.
#     146
#     147 Note: This method uses pandas to_sql method. If not in transaction, inserts are
#    (...)
#     159 Returns: Number of rows inserted.
#     160 """
#     161 try:
# --> 162     return data.to_sql(
#     163         tablename, con=self._connection, if_exists=if_exists, dtype=dtype, index=False
#     164     )
#     165 except SQLAlchemyError as e:  # pragma: no cover
#     166     msg = f"Exception occurred during database insert.\nException type:{type[SQLAlchemyError]}\n{e}"
#
# File ~/anaconda3/envs/appstore/lib/python3.10/site-packages/pandas/core/generic.py:2878, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2713 """
#    2714 Write records stored in a DataFrame to a SQL database.
#    2715
#    (...)
#    2874 [(1,), (None,), (2,)]
#    2875 """  # noqa:E501
#    2876 from pandas.io import sql
# -> 2878 return sql.to_sql(
#    2879     self,
#    2880     name,
#    2881     con,
#    2882     schema=schema,
#    2883     if_exists=if_exists,
#    2884     index=index,
#    2885     index_label=index_label,
#    2886     chunksize=chunksize,
#    2887     dtype=dtype,
#    2888     method=method,
#    2889 )
#
# File ~/anaconda3/envs/appstore/lib/python3.10/site-packages/pandas/io/sql.py:769, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     764     raise NotImplementedError(
#     765         "'frame' argument should be either a Series or a DataFrame"
#     766     )
#     768 with pandasSQL_builder(con, schema=schema, need_transaction=True) as pandas_sql:
# --> 769     return pandas_sql.to_sql(
#     770         frame,
#     771         name,
#     772         if_exists=if_exists,
#     773         index=index,
#     774         index_label=index_label,
#     775         schema=schema,
#     776         chunksize=chunksize,
#     777         dtype=dtype,
#     778         method=method,
#     779         engine=engine,
#     780         **engine_kwargs,
#     781     )
#
# File ~/anaconda3/envs/appstore/lib/python3.10/site-packages/pandas/io/sql.py:1920, in SQLDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    1908 sql_engine = get_engine(engine)
#    1910 table = self.prep_table(
#    1911     frame=frame,
#    1912     name=name,
#    (...)
#    1917     dtype=dtype,
#    1918 )
# -> 1920 total_inserted = sql_engine.insert_records(
#    1921     table=table,
#    1922     con=self.con,
#    1923     frame=frame,
#    1924     name=name,
#    1925     index=index,
#    1926     schema=schema,
#    1927     chunksize=chunksize,
#    1928     method=method,
#    1929     **engine_kwargs,
#    1930 )
#    1932 self.check_case_sensitive(name=name, schema=schema)
#    1933 return total_inserted
#
# File ~/anaconda3/envs/appstore/lib/python3.10/site-packages/pandas/io/sql.py:1470, in SQLAlchemyEngine.insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1468 if re.search(msg, err_text):
#    1469     raise ValueError("inf cannot be used with MySQL") from err
# -> 1470 raise err
#
# File ~/anaconda3/envs/appstore/lib/python3.10/site-packages/pandas/io/sql.py:1461, in SQLAlchemyEngine.insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1458 from sqlalchemy import exc
#    1460 try:
# -> 1461     return table.insert(chunksize=chunksize, method=method)
#    1462 except exc.StatementError as err:
#    1463     # GH34431
#    1464     # https://stackoverflow.com/a/67358288/6067848
#    1465     msg = r"""(\(1054, "Unknown column 'inf(e0)?' in 'field list'"\))(?#
#    1466     )|inf can not be used with MySQL"""
#
# File ~/anaconda3/envs/appstore/lib/python3.10/site-packages/pandas/io/sql.py:1023, in SQLTable.insert(self, chunksize, method)
#    1020     break
#    1022 chunk_iter = zip(*(arr[start_i:end_i] for arr in data_list))
# -> 1023 num_inserted = exec_insert(conn, keys, chunk_iter)
#    1024 # GH 46891
#    1025 if is_integer(num_inserted):
#
# File ~/anaconda3/envs/appstore/lib/python3.10/site-packages/pandas/io/sql.py:929, in SQLTable._execute_insert(self, conn, keys, data_iter)
#     917 """
#     918 Execute SQL statement inserting data
#     919
#    (...)
#     926    Each item contains a list of values to be inserted
#     927 """
#     928 data = [dict(zip(keys, row)) for row in data_iter]
# --> 929 result = conn.execute(self.table.insert(), data)
#     930 return result.rowcount
#
# File ~/anaconda3/envs/appstore/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1412, in Connection.execute(self, statement, parameters, execution_options)
#    1410     raise exc.ObjectNotExecutableError(statement) from err
#    1411 else:
# -> 1412     return meth(
#    1413         self,
#    1414         distilled_parameters,
#    1415         execution_options or NO_OPTIONS,
#    1416     )
#
# File ~/anaconda3/envs/appstore/lib/python3.10/site-packages/sqlalchemy/sql/elements.py:483, in ClauseElement._execute_on_connection(self, connection, distilled_params, execution_options)
#     481     if TYPE_CHECKING:
#     482         assert isinstance(self, Executable)
# --> 483     return connection._execute_clauseelement(
#     484         self, distilled_params, execution_options
#     485     )
#     486 else:
#     487     raise exc.ObjectNotExecutableError(self)
#
# File ~/anaconda3/envs/appstore/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1635, in Connection._execute_clauseelement(self, elem, distilled_parameters, execution_options)
#    1623 compiled_cache: Optional[CompiledCacheType] = execution_options.get(
#    1624     "compiled_cache", self.engine._compiled_cache
#    1625 )
#    1627 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1628     dialect=dialect,
#    1629     compiled_cache=compiled_cache,
#    (...)
#    1633     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1634 )
# -> 1635 ret = self._execute_context(
#    1636     dialect,
#    1637     dialect.execution_ctx_cls._init_compiled,
#    1638     compiled_sql,
#    1639     distilled_parameters,
#    1640     execution_options,
#    1641     compiled_sql,
#    1642     distilled_parameters,
#    1643     elem,
#    1644     extracted_params,
#    1645     cache_hit=cache_hit,
#    1646 )
#    1647 if has_events:
#    1648     self.dispatch.after_execute(
#    1649         self,
#    1650         elem,
#    (...)
#    1654         ret,
#    1655     )
#
# File ~/anaconda3/envs/appstore/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1844, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1839     return self._exec_insertmany_context(
#    1840         dialect,
#    1841         context,
#    1842     )
#    1843 else:
# -> 1844     return self._exec_single_context(
#    1845         dialect, context, statement, parameters
#    1846     )
#
# File ~/anaconda3/envs/appstore/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1984, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1981     result = context._setup_result_proxy()
#    1983 except BaseException as e:
# -> 1984     self._handle_dbapi_exception(
#    1985         e, str_statement, effective_parameters, cursor, context
#    1986     )
#    1988 return result
#
# File ~/anaconda3/envs/appstore/lib/python3.10/site-packages/sqlalchemy/engine/base.py:2339, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2337 elif should_wrap:
#    2338     assert sqlalchemy_exception is not None
# -> 2339     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2340 else:
#    2341     assert exc_info[1] is not None
#
# File ~/anaconda3/envs/appstore/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1965, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1963                 break
#    1964     if not evt_handled:
# -> 1965         self.dialect.do_execute(
#    1966             cursor, str_statement, effective_parameters, context
#    1967         )
#    1969 if self._has_events or self.engine._has_events:
#    1970     self.dispatch.after_cursor_execute(
#    1971         self,
#    1972         cursor,
#    (...)
#    1976         context.executemany,
#    1977     )
#
# File ~/anaconda3/envs/appstore/lib/python3.10/site-packages/sqlalchemy/engine/default.py:921, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     920 def do_execute(self, cursor, statement, parameters, context=None):
# --> 921     cursor.execute(statement, parameters)
#
# File ~/anaconda3/envs/appstore/lib/python3.10/site-packages/pymysql/cursors.py:148, in Cursor.execute(self, query, args)
#     144     pass
#     146 query = self.mogrify(query, args)
# --> 148 result = self._query(query)
#     149 self._executed = query
#     150 return result
#
# File ~/anaconda3/envs/appstore/lib/python3.10/site-packages/pymysql/cursors.py:310, in Cursor._query(self, q)
#     308 self._last_executed = q
#     309 self._clear_result()
# --> 310 conn.query(q)
#     311 self._do_get_result()
#     312 return self.rowcount
#
# File ~/anaconda3/envs/appstore/lib/python3.10/site-packages/pymysql/connections.py:548, in Connection.query(self, sql, unbuffered)
#     546     sql = sql.encode(self.encoding, "surrogateescape")
#     547 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 548 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     549 return self._affected_rows
#
# File ~/anaconda3/envs/appstore/lib/python3.10/site-packages/pymysql/connections.py:775, in Connection._read_query_result(self, unbuffered)
#     773 else:
#     774     result = MySQLResult(self)
# --> 775     result.read()
#     776 self._result = result
#     777 if result.server_status is not None:
#
# File ~/anaconda3/envs/appstore/lib/python3.10/site-packages/pymysql/connections.py:1156, in MySQLResult.read(self)
#    1154 def read(self):
#    1155     try:
# -> 1156         first_packet = self.connection._read_packet()
#    1158         if first_packet.is_ok_packet():
#    1159             self._read_ok_packet(first_packet)
#
# File ~/anaconda3/envs/appstore/lib/python3.10/site-packages/pymysql/connections.py:725, in Connection._read_packet(self, packet_type)
#     723     if self._result is not None and self._result.unbuffered_active is True:
#     724         self._result.unbuffered_active = False
# --> 725     packet.raise_for_error()
#     726 return packet
#
# File ~/anaconda3/envs/appstore/lib/python3.10/site-packages/pymysql/protocol.py:221, in MysqlPacket.raise_for_error(self)
#     219 if DEBUG:
#     220     print("errno =", errno)
# --> 221 err.raise_mysql_exception(self._data)
#
# File ~/anaconda3/envs/appstore/lib/python3.10/site-packages/pymysql/err.py:143, in raise_mysql_exception(data)
#     141 if errorclass is None:
#     142     errorclass = InternalError if errno < 1000 else OperationalError
# --> 143 raise errorclass(errno, errval)
#
# OperationalError: (pymysql.err.OperationalError) (1292, "Incorrect datetime value: '07/15/2023 4:20' for column 'started' at row 1")
# [SQL: INSERT INTO review_jobrun (jobid, controller, category_id, category, started, ended, elapsed, client_errors, server_errors, data_errors, errors, size, size_ave, apps, apps_per_second, reviews, reviews_per_second, completed, complete) VALUES (%(jobid)s, %(controller)s, %(category_id)s, %(category)s, %(started)s, %(ended)s, %(elapsed)s, %(client_errors)s, %(server_errors)s, %(data_errors)s, %(errors)s, %(size)s, %(size_ave)s, %(apps)s, %(apps_per_second)s, %(reviews)s, %(reviews_per_second)s, %(completed)s, %(complete)s)]
# [parameters: {'jobid': 'rating-6000', 'controller': 'RatingController', 'category_id': 6000, 'category': 'Business', 'started': '07/15/2023 4:20', 'ended': '07/16/2023 14:20', 'elapsed': 236547, 'client_errors': 22, 'server_errors': 25, 'data_errors': 75, 'errors': 122, 'size': 548953, 'size_ave': 6.385030532, 'apps': 85975, 'apps_per_second': 2.36, 'reviews': 258, 'reviews_per_second': 5.6, 'completed': datetime.datetime(2023, 7, 15, 4, 20, 20), 'complete': True}]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
job_repo.getall()
review_jobrun_repo.getall()
rating_jobrun_repo.getall()
